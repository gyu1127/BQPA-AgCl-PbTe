# %% [markdown]
# # Beyond the Quasiparticle Approximation: Lattice Heat Capacity of Strongly Anharmonic Solids

# %% [markdown]
# This notebook reproduces the anlaysis and figures for PbTe presented in the manuscript.

# %% [markdown]
# ### File load

# %%
from ase.io import read
import numpy as np

atoms = read('POSCAR')
n_atoms = len(atoms)
masses = atoms.get_masses()  # in amu
cell = atoms.get_cell()      # lattice vectors
positions = atoms.get_positions() # Cartesian coordinates
sc_dims = np.array([4, 4, 4])
kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
T = 300.0                # Temperature in Kelvin

print(f"Loaded {n_atoms} atoms.")
print(f"{atoms}")
# Out:
# Loaded 2 atoms.
# Atoms(symbols='PbTe', pbc=True, cell=[[0.0, 3.239, 3.239], [3.239, 0.0, 3.239], [3.239, 3.239, 0.0]])

# %%
import numpy as np
from scipy.interpolate import interp1d
import os
import re

target_dir = "."  
folders = [d for d in os.listdir(target_dir) if os.path.isdir(d) and d.startswith('T')]

folders.sort(key=lambda x: int(re.findall(r'\d+', x)[0]))

results = {}

print(f"Detected temperature folders: {folders}")

for folder in folders:
    print(f"\n--- Processing Folder: {folder} ---")
    
    omega_path = os.path.join(folder, 'BTE.omega')
    spectrum_path = os.path.join(folder, 'BTE.selfeng3ph_spectrum')
    
    if not os.path.exists(omega_path) or not os.path.exists(spectrum_path):
        print(f"Skipping {folder}: Missing data files.")
        continue

    # --- 1. Load BTE.omega ---
    data_omega = np.loadtxt(omega_path) 
    Nq = data_omega.shape[0]
    num_bands = data_omega.shape[1]
    
    # Band-major flattening (rad/ps -> THz)
    w_bare = (data_omega.T).flatten() / (2 * np.pi)
    num_total_modes = len(w_bare)

    # --- 2. Load and Parse BTE.selfeng3ph_spectrum ---
    spec_data = np.genfromtxt(spectrum_path)
    pts_per_mode = len(spec_data) // num_total_modes

    d_interps = [None] * num_total_modes
    g_interps = [None] * num_total_modes

    for i in range(num_total_modes):
        q_idx = i // num_bands
        b_idx = i % num_bands
        target_mode_idx = b_idx * Nq + q_idx
        
        start = i * pts_per_mode
        end = (i + 1) * pts_per_mode
        mode_block = spec_data[start:end]
        
        w_grid = mode_block[:, 0]
        d_grid = mode_block[:, 1] / (2 * np.pi) 
        g_grid = mode_block[:, 2] / (2 * np.pi)
        
        d_interps[target_mode_idx] = interp1d(w_grid, d_grid, kind='linear', fill_value="extrapolate")
        g_interps[target_mode_idx] = interp1d(w_grid, g_grid, kind='linear', fill_value="extrapolate")

    results[folder] = {
        'w_bare': w_bare,
        'd_interps': d_interps,
        'g_interps': g_interps,
        'Nq': Nq,
        'num_bands': num_bands
    }
    print(f"Done: {folder} loaded successfully.")
# Out:
# Detected temperature folders: ['T50', 'T100', 'T150', 'T200', 'T250', 'T300']
#
# --- Processing Folder: T50 ---
# Done: T50 loaded successfully.
#
# --- Processing Folder: T100 ---
# Done: T100 loaded successfully.
#
# --- Processing Folder: T150 ---
# Done: T150 loaded successfully.
#
# --- Processing Folder: T200 ---
# Done: T200 loaded successfully.
#
# --- Processing Folder: T250 ---
# Done: T250 loaded successfully.
#
# --- Processing Folder: T300 ---
# Done: T300 loaded successfully.

# %%
import numpy as np
from scipy.interpolate import interp1d

# Load BTE.qpoints to get degeneracies
q_data = np.genfromtxt('BTE.qpoints')
# Column 2 (index 2) is the degeneracy
degeneracies = q_data[:, 2] 
Nq_irr = len(degeneracies) # the number of qpoints in irreducible wedge
Nq_total = np.sum(degeneracies) # the number of qpoints in whole BZ
q_coords = q_data[:, 3:6]

print(f"Number of irreducible q-points: {Nq_irr}")
print(f"Total q-points in full BZ (Sum of weights): {Nq_total}")
# Out:
# Number of irreducible q-points: 455
# Total q-points in full BZ (Sum of weights): 15625.0

# %% [markdown]
# ### Data verification

# %%
target_temp = 'T300'

if target_temp in results:
    data = results[target_temp]
    w_bare = data['w_bare']
    d_interps = data['d_interps']
    g_interps = data['g_interps']
    Nq_irr = data['Nq']
    num_bands = data['num_bands']
    
    num_total_modes = len(w_bare)
    
    print(f"Showing results for: {target_temp}")
    print("-" * 100)

    for i in range(num_total_modes):
        w_qs = w_bare[i]

        q_irr_idx = i % Nq_irr
        band_irr_idx = i // Nq_irr
        
        weight = degeneracies[q_irr_idx]
        d_val = d_interps[i](w_qs)
        g_val = abs(g_interps[i](w_qs))
        q_coords_test = q_coords[q_irr_idx]

        print(f"i = {i}, q_irr = {q_irr_idx+1}, band_irr = {band_irr_idx+1}, weight = {weight}, "
              f"w_ha = {w_qs:.4f} THz, {w_qs*(2 * np.pi):.4e} rad/ps, "
              f"delta = {d_val:.4f}, gamma = {g_val:.4f}, {q_coords_test}")

else:
    print(f"Error: {target_temp} not found. Please check your results dictionary.")
# Out:
# Showing results for: T300
# ----------------------------------------------------------------------------------------------------
# i = 0, q_irr = 1, band_irr = 1, weight = 1.0, w_ha = 0.0000 THz, 0.0000e+00 rad/ps, delta = 0.0000, gamma = 0.0000, [0. 0. 0.]
# i = 1, q_irr = 2, band_irr = 1, weight = 8.0, w_ha = 0.2482 THz, 1.5595e+00 rad/ps, delta = -0.0127, gamma = 0.0018, [0.04 0.   0.  ]
# i = 2, q_irr = 3, band_irr = 1, weight = 8.0, w_ha = 0.4728 THz, 2.9709e+00 rad/ps, delta = -0.0252, gamma = 0.0062, [0.08 0.   0.  ]
# i = 3, q_irr = 4, band_irr = 1, weight = 8.0, w_ha = 0.6702 THz, 4.2111e+00 rad/ps, delta = -0.0339, gamma = 0.0100, [0.12 0.   0.  ]
# i = 4, q_irr = 5, band_irr = 1, weight = 8.0, w_ha = 0.8478 THz, 5.3269e+00 rad/ps, delta = -0.0400, gamma = 0.0115, [0.16 0.   0.  ]
# i = 5, q_irr = 6, band_irr = 1, weight = 8.0, w_ha = 1.0118 THz, 6.3570e+00 rad/ps, delta = -0.0447, gamma = 0.0128, [0.2 0.  0. ]
# i = 6, q_irr = 7, band_irr = 1, weight = 8.0, w_ha = 1.1648 THz, 7.3186e+00 rad/ps, delta = -0.0483, gamma = 0.0137, [0.24 0.   0.  ]
# i = 7, q_irr = 8, band_irr = 1, weight = 8.0, w_ha = 1.3075 THz, 8.2152e+00 rad/ps, delta = -0.0507, gamma = 0.0152, [0.28 0.   0.  ]
# i = 8, q_irr = 9, band_irr = 1, weight = 8.0, w_ha = 1.4390 THz, 9.0415e+00 rad/ps, delta = -0.0528, gamma = 0.0151, [0.32 0.   0.  ]
# i = 9, q_irr = 10, band_irr = 1, weight = 8.0, w_ha = 1.5570 THz, 9.7826e+00 rad/ps, delta = -0.0557, gamma = 0.0154, [0.36 0.   0.  ]
# i = 10, q_irr = 11, band_irr = 1, weight = 8.0, w_ha = 1.6568 THz, 1.0410e+01 rad/ps, delta = -0.0580, gamma = 0.0171, [0.4 0.  0. ]
# i = 11, q_irr = 12, band_irr = 1, weight = 8.0, w_ha = 1.7316 THz, 1.0880e+01 rad/ps, delta = -0.0590, gamma = 0.0179, [0.44 0.   0.  ]
# i = 12, q_irr = 13, band_irr = 1, weight = 8.0, w_ha = 1.7723 THz, 1.1135e+01 rad/ps, delta = -0.0585, gamma = 0.0182, [0.48 0.   0.  ]
# i = 13, q_irr = 14, band_irr = 1, weight = 6.0, w_ha = 0.2436 THz, 1.5303e+00 rad/ps, delta = -0.0017, gamma = 0.0001, [0.04 0.04 0.  ]
# i = 14, q_irr = 15, band_irr = 1, weight = 24.0, w_ha = 0.4027 THz, 2.5303e+00 rad/ps, delta = -0.0112, gamma = 0.0020, [0.08 0.04 0.  ]
# i = 15, q_irr = 16, band_irr = 1, weight = 24.0, w_ha = 0.5813 THz, 3.6524e+00 rad/ps, delta = -0.0233, gamma = 0.0061, [0.12 0.04 0.  ]
# i = 16, q_irr = 17, band_irr = 1, weight = 24.0, w_ha = 0.7480 THz, 4.6998e+00 rad/ps, delta = -0.0322, gamma = 0.0091, [0.16 0.04 0.  ]
# i = 17, q_irr = 18, band_irr = 1, weight = 24.0, w_ha = 0.9027 THz, 5.6716e+00 rad/ps, delta = -0.0387, gamma = 0.0111, [0.2  0.04 0.  ]
# i = 18, q_irr = 19, band_irr = 1, weight = 24.0, w_ha = 1.0485 THz, 6.5880e+00 rad/ps, delta = -0.0435, gamma = 0.0123, [0.24 0.04 0.  ]
# i = 19, q_irr = 20, band_irr = 1, weight = 24.0, w_ha = 1.1877 THz, 7.4628e+00 rad/ps, delta = -0.0475, gamma = 0.0138, [0.28 0.04 0.  ]
# i = 20, q_irr = 21, band_irr = 1, weight = 24.0, w_ha = 1.3211 THz, 8.3009e+00 rad/ps, delta = -0.0493, gamma = 0.0153, [0.32 0.04 0.  ]
# i = 21, q_irr = 22, band_irr = 1, weight = 24.0, w_ha = 1.4477 THz, 9.0959e+00 rad/ps, delta = -0.0528, gamma = 0.0151, [0.36 0.04 0.  ]
# i = 22, q_irr = 23, band_irr = 1, weight = 24.0, w_ha = 1.5640 THz, 9.8267e+00 rad/ps, delta = -0.0559, gamma = 0.0158, [0.4  0.04 0.  ]
# i = 23, q_irr = 24, band_irr = 1, weight = 24.0, w_ha = 1.6636 THz, 1.0453e+01 rad/ps, delta = -0.0581, gamma = 0.0171, [0.44 0.04 0.  ]
# i = 24, q_irr = 25, band_irr = 1, weight = 24.0, w_ha = 1.7375 THz, 1.0917e+01 rad/ps, delta = -0.0587, gamma = 0.0177, [0.48 0.04 0.  ]
# i = 25, q_irr = 26, band_irr = 1, weight = 24.0, w_ha = 1.7521 THz, 1.1009e+01 rad/ps, delta = -0.0591, gamma = 0.0177, [0.52 0.04 0.  ]
# i = 26, q_irr = 27, band_irr = 1, weight = 24.0, w_ha = 1.6982 THz, 1.0670e+01 rad/ps, delta = -0.0586, gamma = 0.0180, [0.56 0.04 0.  ]
# i = 27, q_irr = 28, band_irr = 1, weight = 24.0, w_ha = 1.6111 THz, 1.0123e+01 rad/ps, delta = -0.0573, gamma = 0.0164, [0.6  0.04 0.  ]
# i = 28, q_irr = 29, band_irr = 1, weight = 24.0, w_ha = 1.5027 THz, 9.4415e+00 rad/ps, delta = -0.0540, gamma = 0.0154, [0.64 0.04 0.  ]
# i = 29, q_irr = 30, band_irr = 1, weight = 24.0, w_ha = 1.3824 THz, 8.6861e+00 rad/ps, delta = -0.0507, gamma = 0.0151, [0.68 0.04 0.  ]
# i = 30, q_irr = 31, band_irr = 1, weight = 24.0, w_ha = 1.2556 THz, 7.8893e+00 rad/ps, delta = -0.0473, gamma = 0.0142, [0.72 0.04 0.  ]
# i = 31, q_irr = 32, band_irr = 1, weight = 24.0, w_ha = 1.1237 THz, 7.0606e+00 rad/ps, delta = -0.0438, gamma = 0.0125, [0.76 0.04 0.  ]
# i = 32, q_irr = 33, band_irr = 1, weight = 24.0, w_ha = 0.9859 THz, 6.1943e+00 rad/ps, delta = -0.0384, gamma = 0.0106, [0.8  0.04 0.  ]
# i = 33, q_irr = 34, band_irr = 1, weight = 24.0, w_ha = 0.8397 THz, 5.2760e+00 rad/ps, delta = -0.0325, gamma = 0.0091, [0.84 0.04 0.  ]
# i = 34, q_irr = 35, band_irr = 1, weight = 24.0, w_ha = 0.6822 THz, 4.2861e+00 rad/ps, delta = -0.0239, gamma = 0.0063, [0.88 0.04 0.  ]
# i = 35, q_irr = 36, band_irr = 1, weight = 24.0, w_ha = 0.5113 THz, 3.2125e+00 rad/ps, delta = -0.0132, gamma = 0.0026, [0.92 0.04 0.  ]
# i = 36, q_irr = 37, band_irr = 1, weight = 12.0, w_ha = 0.3403 THz, 2.1380e+00 rad/ps, delta = -0.0035, gamma = 0.0003, [0.96 0.04 0.  ]
# i = 37, q_irr = 38, band_irr = 1, weight = 6.0, w_ha = 0.4342 THz, 2.7279e+00 rad/ps, delta = -0.0066, gamma = 0.0007, [0.08 0.08 0.  ]
# i = 38, q_irr = 39, band_irr = 1, weight = 24.0, w_ha = 0.5381 THz, 3.3809e+00 rad/ps, delta = -0.0142, gamma = 0.0027, [0.12 0.08 0.  ]
# i = 39, q_irr = 40, band_irr = 1, weight = 24.0, w_ha = 0.6664 THz, 4.1869e+00 rad/ps, delta = -0.0241, gamma = 0.0061, [0.16 0.08 0.  ]
# i = 40, q_irr = 41, band_irr = 1, weight = 24.0, w_ha = 0.7988 THz, 5.0191e+00 rad/ps, delta = -0.0322, gamma = 0.0090, [0.2  0.08 0.  ]
# i = 41, q_irr = 42, band_irr = 1, weight = 24.0, w_ha = 0.9312 THz, 5.8509e+00 rad/ps, delta = -0.0381, gamma = 0.0107, [0.24 0.08 0.  ]
# i = 42, q_irr = 43, band_irr = 1, weight = 24.0, w_ha = 1.0637 THz, 6.6835e+00 rad/ps, delta = -0.0438, gamma = 0.0122, [0.28 0.08 0.  ]
# i = 43, q_irr = 44, band_irr = 1, weight = 24.0, w_ha = 1.1967 THz, 7.5189e+00 rad/ps, delta = -0.0471, gamma = 0.0136, [0.32 0.08 0.  ]
# i = 44, q_irr = 45, band_irr = 1, weight = 24.0, w_ha = 1.3289 THz, 8.3499e+00 rad/ps, delta = -0.0501, gamma = 0.0143, [0.36 0.08 0.  ]
# i = 45, q_irr = 46, band_irr = 1, weight = 24.0, w_ha = 1.4572 THz, 9.1558e+00 rad/ps, delta = -0.0524, gamma = 0.0145, [0.4  0.08 0.  ]
# i = 46, q_irr = 47, band_irr = 1, weight = 24.0, w_ha = 1.5755 THz, 9.8993e+00 rad/ps, delta = -0.0559, gamma = 0.0154, [0.44 0.08 0.  ]
# i = 47, q_irr = 48, band_irr = 1, weight = 24.0, w_ha = 1.6752 THz, 1.0526e+01 rad/ps, delta = -0.0578, gamma = 0.0163, [0.48 0.08 0.  ]
# i = 48, q_irr = 49, band_irr = 1, weight = 24.0, w_ha = 1.7056 THz, 1.0717e+01 rad/ps, delta = -0.0583, gamma = 0.0169, [0.52 0.08 0.  ]
# i = 49, q_irr = 50, band_irr = 1, weight = 24.0, w_ha = 1.6364 THz, 1.0282e+01 rad/ps, delta = -0.0565, gamma = 0.0160, [0.56 0.08 0.  ]
# i = 50, q_irr = 51, band_irr = 1, weight = 24.0, w_ha = 1.5338 THz, 9.6370e+00 rad/ps, delta = -0.0547, gamma = 0.0153, [0.6  0.08 0.  ]
# i = 51, q_irr = 52, band_irr = 1, weight = 24.0, w_ha = 1.4152 THz, 8.8922e+00 rad/ps, delta = -0.0503, gamma = 0.0147, [0.64 0.08 0.  ]
# i = 52, q_irr = 53, band_irr = 1, weight = 24.0, w_ha = 1.2934 THz, 8.1265e+00 rad/ps, delta = -0.0473, gamma = 0.0137, [0.68 0.08 0.  ]
# i = 53, q_irr = 54, band_irr = 1, weight = 24.0, w_ha = 1.1744 THz, 7.3788e+00 rad/ps, delta = -0.0424, gamma = 0.0125, [0.72 0.08 0.  ]
# i = 54, q_irr = 55, band_irr = 1, weight = 24.0, w_ha = 1.0592 THz, 6.6549e+00 rad/ps, delta = -0.0367, gamma = 0.0103, [0.76 0.08 0.  ]
# i = 55, q_irr = 56, band_irr = 1, weight = 24.0, w_ha = 0.9456 THz, 5.9413e+00 rad/ps, delta = -0.0303, gamma = 0.0088, [0.8  0.08 0.  ]
# i = 56, q_irr = 57, band_irr = 1, weight = 24.0, w_ha = 0.8308 THz, 5.2199e+00 rad/ps, delta = -0.0241, gamma = 0.0068, [0.84 0.08 0.  ]
# i = 57, q_irr = 58, band_irr = 1, weight = 24.0, w_ha = 0.7137 THz, 4.4842e+00 rad/ps, delta = -0.0170, gamma = 0.0042, [0.88 0.08 0.  ]
# i = 58, q_irr = 59, band_irr = 1, weight = 12.0, w_ha = 0.6000 THz, 3.7702e+00 rad/ps, delta = -0.0114, gamma = 0.0020, [0.92 0.08 0.  ]
# i = 59, q_irr = 60, band_irr = 1, weight = 6.0, w_ha = 0.5522 THz, 3.4698e+00 rad/ps, delta = -0.0119, gamma = 0.0019, [0.12 0.12 0.  ]
# i = 60, q_irr = 61, band_irr = 1, weight = 24.0, w_ha = 0.6150 THz, 3.8640e+00 rad/ps, delta = -0.0174, gamma = 0.0037, [0.16 0.12 0.  ]
# i = 61, q_irr = 62, band_irr = 1, weight = 24.0, w_ha = 0.7082 THz, 4.4499e+00 rad/ps, delta = -0.0254, gamma = 0.0068, [0.2  0.12 0.  ]
# i = 62, q_irr = 63, band_irr = 1, weight = 24.0, w_ha = 0.8193 THz, 5.1478e+00 rad/ps, delta = -0.0327, gamma = 0.0095, [0.24 0.12 0.  ]
# i = 63, q_irr = 64, band_irr = 1, weight = 24.0, w_ha = 0.9420 THz, 5.9188e+00 rad/ps, delta = -0.0383, gamma = 0.0105, [0.28 0.12 0.  ]
# i = 64, q_irr = 65, band_irr = 1, weight = 24.0, w_ha = 1.0729 THz, 6.7412e+00 rad/ps, delta = -0.0435, gamma = 0.0119, [0.32 0.12 0.  ]
# i = 65, q_irr = 66, band_irr = 1, weight = 24.0, w_ha = 1.2086 THz, 7.5937e+00 rad/ps, delta = -0.0469, gamma = 0.0136, [0.36 0.12 0.  ]
# i = 66, q_irr = 67, band_irr = 1, weight = 24.0, w_ha = 1.3446 THz, 8.4481e+00 rad/ps, delta = -0.0500, gamma = 0.0141, [0.4  0.12 0.  ]
# i = 67, q_irr = 68, band_irr = 1, weight = 24.0, w_ha = 1.4748 THz, 9.2665e+00 rad/ps, delta = -0.0523, gamma = 0.0141, [0.44 0.12 0.  ]
# i = 68, q_irr = 69, band_irr = 1, weight = 24.0, w_ha = 1.5917 THz, 1.0001e+01 rad/ps, delta = -0.0563, gamma = 0.0153, [0.48 0.12 0.  ]
# i = 69, q_irr = 70, band_irr = 1, weight = 24.0, w_ha = 1.6385 THz, 1.0295e+01 rad/ps, delta = -0.0574, gamma = 0.0151, [0.52 0.12 0.  ]
# i = 70, q_irr = 71, band_irr = 1, weight = 24.0, w_ha = 1.5574 THz, 9.7856e+00 rad/ps, delta = -0.0543, gamma = 0.0152, [0.56 0.12 0.  ]
# i = 71, q_irr = 72, band_irr = 1, weight = 24.0, w_ha = 1.4429 THz, 9.0658e+00 rad/ps, delta = -0.0506, gamma = 0.0145, [0.6  0.12 0.  ]
# i = 72, q_irr = 73, band_irr = 1, weight = 24.0, w_ha = 1.3184 THz, 8.2838e+00 rad/ps, delta = -0.0465, gamma = 0.0133, [0.64 0.12 0.  ]
# i = 73, q_irr = 74, band_irr = 1, weight = 24.0, w_ha = 1.1986 THz, 7.5311e+00 rad/ps, delta = -0.0414, gamma = 0.0122, [0.68 0.12 0.  ]
# i = 74, q_irr = 75, band_irr = 1, weight = 24.0, w_ha = 1.0907 THz, 6.8529e+00 rad/ps, delta = -0.0361, gamma = 0.0101, [0.72 0.12 0.  ]
# i = 75, q_irr = 76, band_irr = 1, weight = 24.0, w_ha = 0.9958 THz, 6.2571e+00 rad/ps, delta = -0.0296, gamma = 0.0086, [0.76 0.12 0.  ]
# i = 76, q_irr = 77, band_irr = 1, weight = 24.0, w_ha = 0.9119 THz, 5.7299e+00 rad/ps, delta = -0.0239, gamma = 0.0075, [0.8  0.12 0.  ]
# i = 77, q_irr = 78, band_irr = 1, weight = 24.0, w_ha = 0.8362 THz, 5.2541e+00 rad/ps, delta = -0.0190, gamma = 0.0059, [0.84 0.12 0.  ]
# i = 78, q_irr = 79, band_irr = 1, weight = 12.0, w_ha = 0.7684 THz, 4.8281e+00 rad/ps, delta = -0.0160, gamma = 0.0045, [0.88 0.12 0.  ]
# i = 79, q_irr = 80, band_irr = 1, weight = 6.0, w_ha = 0.6066 THz, 3.8114e+00 rad/ps, delta = -0.0161, gamma = 0.0030, [0.16 0.16 0.  ]
# i = 80, q_irr = 81, band_irr = 1, weight = 24.0, w_ha = 0.6456 THz, 4.0562e+00 rad/ps, delta = -0.0203, gamma = 0.0045, [0.2  0.16 0.  ]
# i = 81, q_irr = 82, band_irr = 1, weight = 24.0, w_ha = 0.7248 THz, 4.5542e+00 rad/ps, delta = -0.0272, gamma = 0.0073, [0.24 0.16 0.  ]
# i = 82, q_irr = 83, band_irr = 1, weight = 24.0, w_ha = 0.8327 THz, 5.2320e+00 rad/ps, delta = -0.0328, gamma = 0.0097, [0.28 0.16 0.  ]
# i = 83, q_irr = 84, band_irr = 1, weight = 24.0, w_ha = 0.9587 THz, 6.0236e+00 rad/ps, delta = -0.0386, gamma = 0.0109, [0.32 0.16 0.  ]
# i = 84, q_irr = 85, band_irr = 1, weight = 24.0, w_ha = 1.0945 THz, 6.8771e+00 rad/ps, delta = -0.0433, gamma = 0.0116, [0.36 0.16 0.  ]
# i = 85, q_irr = 86, band_irr = 1, weight = 24.0, w_ha = 1.2332 THz, 7.7487e+00 rad/ps, delta = -0.0468, gamma = 0.0128, [0.4  0.16 0.  ]
# i = 86, q_irr = 87, band_irr = 1, weight = 24.0, w_ha = 1.3683 THz, 8.5976e+00 rad/ps, delta = -0.0498, gamma = 0.0137, [0.44 0.16 0.  ]
# i = 87, q_irr = 88, band_irr = 1, weight = 24.0, w_ha = 1.4933 THz, 9.3824e+00 rad/ps, delta = -0.0525, gamma = 0.0137, [0.48 0.16 0.  ]
# i = 88, q_irr = 89, band_irr = 1, weight = 24.0, w_ha = 1.5584 THz, 9.7918e+00 rad/ps, delta = -0.0550, gamma = 0.0140, [0.52 0.16 0.  ]
# i = 89, q_irr = 90, band_irr = 1, weight = 24.0, w_ha = 1.4713 THz, 9.2442e+00 rad/ps, delta = -0.0519, gamma = 0.0142, [0.56 0.16 0.  ]
# i = 90, q_irr = 91, band_irr = 1, weight = 24.0, w_ha = 1.3526 THz, 8.4985e+00 rad/ps, delta = -0.0477, gamma = 0.0135, [0.6  0.16 0.  ]
# i = 91, q_irr = 92, band_irr = 1, weight = 24.0, w_ha = 1.2294 THz, 7.7243e+00 rad/ps, delta = -0.0421, gamma = 0.0122, [0.64 0.16 0.  ]
# i = 92, q_irr = 93, band_irr = 1, weight = 24.0, w_ha = 1.1163 THz, 7.0140e+00 rad/ps, delta = -0.0361, gamma = 0.0102, [0.68 0.16 0.  ]
# i = 93, q_irr = 94, band_irr = 1, weight = 24.0, w_ha = 1.0215 THz, 6.4180e+00 rad/ps, delta = -0.0299, gamma = 0.0092, [0.72 0.16 0.  ]
# i = 94, q_irr = 95, band_irr = 1, weight = 24.0, w_ha = 0.9475 THz, 5.9535e+00 rad/ps, delta = -0.0240, gamma = 0.0080, [0.76 0.16 0.  ]
# i = 95, q_irr = 96, band_irr = 1, weight = 24.0, w_ha = 0.8936 THz, 5.6145e+00 rad/ps, delta = -0.0195, gamma = 0.0070, [0.8  0.16 0.  ]
# i = 96, q_irr = 97, band_irr = 1, weight = 12.0, w_ha = 0.8571 THz, 5.3852e+00 rad/ps, delta = -0.0174, gamma = 0.0061, [0.84 0.16 0.  ]
# i = 97, q_irr = 98, band_irr = 1, weight = 6.0, w_ha = 0.6285 THz, 3.9492e+00 rad/ps, delta = -0.0191, gamma = 0.0039, [0.2 0.2 0. ]
# i = 98, q_irr = 99, band_irr = 1, weight = 24.0, w_ha = 0.6659 THz, 4.1841e+00 rad/ps, delta = -0.0224, gamma = 0.0053, [0.24 0.2  0.  ]
# i = 99, q_irr = 100, band_irr = 1, weight = 24.0, w_ha = 0.7500 THz, 4.7126e+00 rad/ps, delta = -0.0278, gamma = 0.0078, [0.28 0.2  0.  ]
# i = 100, q_irr = 101, band_irr = 1, weight = 24.0, w_ha = 0.8645 THz, 5.4316e+00 rad/ps, delta = -0.0332, gamma = 0.0097, [0.32 0.2  0.  ]
# i = 101, q_irr = 102, band_irr = 1, weight = 24.0, w_ha = 0.9944 THz, 6.2478e+00 rad/ps, delta = -0.0379, gamma = 0.0107, [0.36 0.2  0.  ]
# i = 102, q_irr = 103, band_irr = 1, weight = 24.0, w_ha = 1.1291 THz, 7.0946e+00 rad/ps, delta = -0.0427, gamma = 0.0113, [0.4 0.2 0. ]
# i = 103, q_irr = 104, band_irr = 1, weight = 24.0, w_ha = 1.2614 THz, 7.9258e+00 rad/ps, delta = -0.0460, gamma = 0.0124, [0.44 0.2  0.  ]
# i = 104, q_irr = 105, band_irr = 1, weight = 24.0, w_ha = 1.3857 THz, 8.7065e+00 rad/ps, delta = -0.0491, gamma = 0.0131, [0.48 0.2  0.  ]
# i = 105, q_irr = 106, band_irr = 1, weight = 24.0, w_ha = 1.4717 THz, 9.2468e+00 rad/ps, delta = -0.0520, gamma = 0.0129, [0.52 0.2  0.  ]
# i = 106, q_irr = 107, band_irr = 1, weight = 24.0, w_ha = 1.3957 THz, 8.7697e+00 rad/ps, delta = -0.0485, gamma = 0.0130, [0.56 0.2  0.  ]
# i = 107, q_irr = 108, band_irr = 1, weight = 24.0, w_ha = 1.2725 THz, 7.9953e+00 rad/ps, delta = -0.0442, gamma = 0.0119, [0.6 0.2 0. ]
# i = 108, q_irr = 109, band_irr = 1, weight = 24.0, w_ha = 1.1592 THz, 7.2832e+00 rad/ps, delta = -0.0378, gamma = 0.0111, [0.64 0.2  0.  ]
# i = 109, q_irr = 110, band_irr = 1, weight = 24.0, w_ha = 1.0583 THz, 6.6498e+00 rad/ps, delta = -0.0308, gamma = 0.0099, [0.68 0.2  0.  ]
# i = 110, q_irr = 111, band_irr = 1, weight = 24.0, w_ha = 0.9783 THz, 6.1468e+00 rad/ps, delta = -0.0249, gamma = 0.0090, [0.72 0.2  0.  ]
# i = 111, q_irr = 112, band_irr = 1, weight = 24.0, w_ha = 0.9238 THz, 5.8041e+00 rad/ps, delta = -0.0201, gamma = 0.0077, [0.76 0.2  0.  ]
# i = 112, q_irr = 113, band_irr = 1, weight = 12.0, w_ha = 0.8961 THz, 5.6305e+00 rad/ps, delta = -0.0183, gamma = 0.0071, [0.8 0.2 0. ]
# i = 113, q_irr = 114, band_irr = 1, weight = 6.0, w_ha = 0.6599 THz, 4.1466e+00 rad/ps, delta = -0.0213, gamma = 0.0048, [0.24 0.24 0.  ]
# i = 114, q_irr = 115, band_irr = 1, weight = 24.0, w_ha = 0.7098 THz, 4.4599e+00 rad/ps, delta = -0.0238, gamma = 0.0062, [0.28 0.24 0.  ]
# i = 115, q_irr = 116, band_irr = 1, weight = 24.0, w_ha = 0.8011 THz, 5.0334e+00 rad/ps, delta = -0.0286, gamma = 0.0084, [0.32 0.24 0.  ]
# i = 116, q_irr = 117, band_irr = 1, weight = 24.0, w_ha = 0.9147 THz, 5.7472e+00 rad/ps, delta = -0.0334, gamma = 0.0098, [0.36 0.24 0.  ]
# i = 117, q_irr = 118, band_irr = 1, weight = 24.0, w_ha = 1.0364 THz, 6.5117e+00 rad/ps, delta = -0.0383, gamma = 0.0105, [0.4  0.24 0.  ]
# i = 118, q_irr = 119, band_irr = 1, weight = 24.0, w_ha = 1.1576 THz, 7.2733e+00 rad/ps, delta = -0.0422, gamma = 0.0110, [0.44 0.24 0.  ]
# i = 119, q_irr = 120, band_irr = 1, weight = 24.0, w_ha = 1.2734 THz, 8.0008e+00 rad/ps, delta = -0.0463, gamma = 0.0120, [0.48 0.24 0.  ]
# i = 120, q_irr = 121, band_irr = 1, weight = 24.0, w_ha = 1.3808 THz, 8.6758e+00 rad/ps, delta = -0.0491, gamma = 0.0129, [0.52 0.24 0.  ]
# i = 121, q_irr = 122, band_irr = 1, weight = 24.0, w_ha = 1.3155 THz, 8.2656e+00 rad/ps, delta = -0.0453, gamma = 0.0123, [0.56 0.24 0.  ]
# i = 122, q_irr = 123, band_irr = 1, weight = 24.0, w_ha = 1.2071 THz, 7.5842e+00 rad/ps, delta = -0.0399, gamma = 0.0122, [0.6  0.24 0.  ]
# i = 123, q_irr = 124, band_irr = 1, weight = 24.0, w_ha = 1.1122 THz, 6.9884e+00 rad/ps, delta = -0.0335, gamma = 0.0119, [0.64 0.24 0.  ]
# i = 124, q_irr = 125, band_irr = 1, weight = 24.0, w_ha = 1.0297 THz, 6.4696e+00 rad/ps, delta = -0.0279, gamma = 0.0107, [0.68 0.24 0.  ]
# i = 125, q_irr = 126, band_irr = 1, weight = 24.0, w_ha = 0.9668 THz, 6.0744e+00 rad/ps, delta = -0.0227, gamma = 0.0093, [0.72 0.24 0.  ]
# i = 126, q_irr = 127, band_irr = 1, weight = 12.0, w_ha = 0.9300 THz, 5.8437e+00 rad/ps, delta = -0.0201, gamma = 0.0085, [0.76 0.24 0.  ]
# i = 127, q_irr = 128, band_irr = 1, weight = 6.0, w_ha = 0.7206 THz, 4.5277e+00 rad/ps, delta = -0.0229, gamma = 0.0063, [0.28 0.28 0.  ]
# i = 128, q_irr = 129, band_irr = 1, weight = 24.0, w_ha = 0.7761 THz, 4.8764e+00 rad/ps, delta = -0.0258, gamma = 0.0077, [0.32 0.28 0.  ]
# i = 129, q_irr = 130, band_irr = 1, weight = 24.0, w_ha = 0.8601 THz, 5.4042e+00 rad/ps, delta = -0.0298, gamma = 0.0094, [0.36 0.28 0.  ]
# i = 130, q_irr = 131, band_irr = 1, weight = 24.0, w_ha = 0.9575 THz, 6.0164e+00 rad/ps, delta = -0.0340, gamma = 0.0105, [0.4  0.28 0.  ]
# i = 131, q_irr = 132, band_irr = 1, weight = 24.0, w_ha = 1.0589 THz, 6.6534e+00 rad/ps, delta = -0.0388, gamma = 0.0110, [0.44 0.28 0.  ]
# i = 132, q_irr = 133, band_irr = 1, weight = 24.0, w_ha = 1.1595 THz, 7.2854e+00 rad/ps, delta = -0.0425, gamma = 0.0116, [0.48 0.28 0.  ]
# i = 133, q_irr = 134, band_irr = 1, weight = 24.0, w_ha = 1.2574 THz, 7.9003e+00 rad/ps, delta = -0.0461, gamma = 0.0124, [0.52 0.28 0.  ]
# i = 134, q_irr = 135, band_irr = 1, weight = 24.0, w_ha = 1.2400 THz, 7.7913e+00 rad/ps, delta = -0.0414, gamma = 0.0132, [0.56 0.28 0.  ]
# i = 135, q_irr = 136, band_irr = 1, weight = 24.0, w_ha = 1.1561 THz, 7.2641e+00 rad/ps, delta = -0.0371, gamma = 0.0146, [0.6  0.28 0.  ]
# i = 136, q_irr = 137, band_irr = 1, weight = 24.0, w_ha = 1.0866 THz, 6.8271e+00 rad/ps, delta = -0.0329, gamma = 0.0146, [0.64 0.28 0.  ]
# i = 137, q_irr = 138, band_irr = 1, weight = 24.0, w_ha = 1.0277 THz, 6.4575e+00 rad/ps, delta = -0.0281, gamma = 0.0131, [0.68 0.28 0.  ]
# i = 138, q_irr = 139, band_irr = 1, weight = 12.0, w_ha = 0.9854 THz, 6.1916e+00 rad/ps, delta = -0.0240, gamma = 0.0112, [0.72 0.28 0.  ]
# i = 139, q_irr = 140, band_irr = 1, weight = 6.0, w_ha = 0.7893 THz, 4.9590e+00 rad/ps, delta = -0.0254, gamma = 0.0084, [0.32 0.32 0.  ]
# i = 140, q_irr = 141, band_irr = 1, weight = 24.0, w_ha = 0.8323 THz, 5.2292e+00 rad/ps, delta = -0.0284, gamma = 0.0099, [0.36 0.32 0.  ]
# i = 141, q_irr = 142, band_irr = 1, weight = 24.0, w_ha = 0.8943 THz, 5.6191e+00 rad/ps, delta = -0.0319, gamma = 0.0107, [0.4  0.32 0.  ]
# i = 142, q_irr = 143, band_irr = 1, weight = 24.0, w_ha = 0.9673 THz, 6.0778e+00 rad/ps, delta = -0.0361, gamma = 0.0115, [0.44 0.32 0.  ]
# i = 143, q_irr = 144, band_irr = 1, weight = 24.0, w_ha = 1.0470 THz, 6.5786e+00 rad/ps, delta = -0.0395, gamma = 0.0114, [0.48 0.32 0.  ]
# i = 144, q_irr = 145, band_irr = 1, weight = 24.0, w_ha = 1.1319 THz, 7.1117e+00 rad/ps, delta = -0.0437, gamma = 0.0122, [0.52 0.32 0.  ]
# i = 145, q_irr = 146, band_irr = 1, weight = 24.0, w_ha = 1.1697 THz, 7.3492e+00 rad/ps, delta = -0.0399, gamma = 0.0171, [0.56 0.32 0.  ]
# i = 146, q_irr = 147, band_irr = 1, weight = 24.0, w_ha = 1.1271 THz, 7.0821e+00 rad/ps, delta = -0.0356, gamma = 0.0184, [0.6  0.32 0.  ]
# i = 147, q_irr = 148, band_irr = 1, weight = 24.0, w_ha = 1.0766 THz, 6.7645e+00 rad/ps, delta = -0.0348, gamma = 0.0182, [0.64 0.32 0.  ]
# i = 148, q_irr = 149, band_irr = 1, weight = 12.0, w_ha = 1.0456 THz, 6.5694e+00 rad/ps, delta = -0.0314, gamma = 0.0159, [0.68 0.32 0.  ]
# i = 149, q_irr = 150, band_irr = 1, weight = 6.0, w_ha = 0.8295 THz, 5.2120e+00 rad/ps, delta = -0.0293, gamma = 0.0105, [0.36 0.36 0.  ]
# i = 150, q_irr = 151, band_irr = 1, weight = 24.0, w_ha = 0.8485 THz, 5.3312e+00 rad/ps, delta = -0.0325, gamma = 0.0112, [0.4  0.36 0.  ]
# i = 151, q_irr = 152, band_irr = 1, weight = 24.0, w_ha = 0.8860 THz, 5.5666e+00 rad/ps, delta = -0.0353, gamma = 0.0122, [0.44 0.36 0.  ]
# i = 152, q_irr = 153, band_irr = 1, weight = 24.0, w_ha = 0.9400 THz, 5.9063e+00 rad/ps, delta = -0.0383, gamma = 0.0122, [0.48 0.36 0.  ]
# i = 153, q_irr = 154, band_irr = 1, weight = 24.0, w_ha = 1.0097 THz, 6.3440e+00 rad/ps, delta = -0.0415, gamma = 0.0120, [0.52 0.36 0.  ]
# i = 154, q_irr = 155, band_irr = 1, weight = 24.0, w_ha = 1.0941 THz, 6.8742e+00 rad/ps, delta = -0.0443, gamma = 0.0125, [0.56 0.36 0.  ]
# i = 155, q_irr = 156, band_irr = 1, weight = 24.0, w_ha = 1.0923 THz, 6.8631e+00 rad/ps, delta = -0.0383, gamma = 0.0214, [0.6  0.36 0.  ]
# i = 156, q_irr = 157, band_irr = 1, weight = 12.0, w_ha = 1.0776 THz, 6.7709e+00 rad/ps, delta = -0.0376, gamma = 0.0210, [0.64 0.36 0.  ]
# i = 157, q_irr = 158, band_irr = 1, weight = 6.0, w_ha = 0.8228 THz, 5.1698e+00 rad/ps, delta = -0.0342, gamma = 0.0118, [0.4 0.4 0. ]
# i = 158, q_irr = 159, band_irr = 1, weight = 24.0, w_ha = 0.8208 THz, 5.1572e+00 rad/ps, delta = -0.0369, gamma = 0.0118, [0.44 0.4  0.  ]
# i = 159, q_irr = 160, band_irr = 1, weight = 24.0, w_ha = 0.8456 THz, 5.3132e+00 rad/ps, delta = -0.0389, gamma = 0.0126, [0.48 0.4  0.  ]
# i = 160, q_irr = 161, band_irr = 1, weight = 24.0, w_ha = 0.8982 THz, 5.6439e+00 rad/ps, delta = -0.0403, gamma = 0.0129, [0.52 0.4  0.  ]
# i = 161, q_irr = 162, band_irr = 1, weight = 24.0, w_ha = 0.9766 THz, 6.1364e+00 rad/ps, delta = -0.0422, gamma = 0.0124, [0.56 0.4  0.  ]
# i = 162, q_irr = 163, band_irr = 1, weight = 12.0, w_ha = 1.0681 THz, 6.7111e+00 rad/ps, delta = -0.0422, gamma = 0.0238, [0.6 0.4 0. ]
# i = 163, q_irr = 164, band_irr = 1, weight = 6.0, w_ha = 0.7806 THz, 4.9049e+00 rad/ps, delta = -0.0386, gamma = 0.0116, [0.44 0.44 0.  ]
# i = 164, q_irr = 165, band_irr = 1, weight = 24.0, w_ha = 0.7748 THz, 4.8680e+00 rad/ps, delta = -0.0402, gamma = 0.0119, [0.48 0.44 0.  ]
# i = 165, q_irr = 166, band_irr = 1, weight = 24.0, w_ha = 0.8081 THz, 5.0774e+00 rad/ps, delta = -0.0408, gamma = 0.0125, [0.52 0.44 0.  ]
# i = 166, q_irr = 167, band_irr = 1, weight = 12.0, w_ha = 0.8781 THz, 5.5172e+00 rad/ps, delta = -0.0411, gamma = 0.0131, [0.56 0.44 0.  ]
# i = 167, q_irr = 168, band_irr = 1, weight = 6.0, w_ha = 0.7405 THz, 4.6530e+00 rad/ps, delta = -0.0410, gamma = 0.0117, [0.48 0.48 0.  ]
# i = 168, q_irr = 169, band_irr = 1, weight = 12.0, w_ha = 0.7521 THz, 4.7253e+00 rad/ps, delta = -0.0412, gamma = 0.0120, [0.52 0.48 0.  ]
# i = 169, q_irr = 170, band_irr = 1, weight = 24.0, w_ha = 0.4907 THz, 3.0832e+00 rad/ps, delta = -0.0081, gamma = 0.0010, [0.12 0.08 0.04]
# i = 170, q_irr = 171, band_irr = 1, weight = 48.0, w_ha = 0.6209 THz, 3.9014e+00 rad/ps, delta = -0.0158, gamma = 0.0033, [0.16 0.08 0.04]
# i = 171, q_irr = 172, band_irr = 1, weight = 48.0, w_ha = 0.7580 THz, 4.7629e+00 rad/ps, delta = -0.0249, gamma = 0.0066, [0.2  0.08 0.04]
# i = 172, q_irr = 173, band_irr = 1, weight = 48.0, w_ha = 0.8911 THz, 5.5989e+00 rad/ps, delta = -0.0318, gamma = 0.0090, [0.24 0.08 0.04]
# i = 173, q_irr = 174, band_irr = 1, weight = 48.0, w_ha = 1.0199 THz, 6.4082e+00 rad/ps, delta = -0.0376, gamma = 0.0107, [0.28 0.08 0.04]
# i = 174, q_irr = 175, band_irr = 1, weight = 48.0, w_ha = 1.1465 THz, 7.2034e+00 rad/ps, delta = -0.0435, gamma = 0.0125, [0.32 0.08 0.04]
# i = 175, q_irr = 176, band_irr = 1, weight = 48.0, w_ha = 1.2724 THz, 7.9946e+00 rad/ps, delta = -0.0474, gamma = 0.0137, [0.36 0.08 0.04]
# i = 176, q_irr = 177, band_irr = 1, weight = 48.0, w_ha = 1.3973 THz, 8.7795e+00 rad/ps, delta = -0.0500, gamma = 0.0150, [0.4  0.08 0.04]
# i = 177, q_irr = 178, band_irr = 1, weight = 48.0, w_ha = 1.5175 THz, 9.5345e+00 rad/ps, delta = -0.0543, gamma = 0.0152, [0.44 0.08 0.04]
# i = 178, q_irr = 179, band_irr = 1, weight = 48.0, w_ha = 1.6243 THz, 1.0206e+01 rad/ps, delta = -0.0564, gamma = 0.0164, [0.48 0.08 0.04]
# i = 179, q_irr = 180, band_irr = 1, weight = 48.0, w_ha = 1.7024 THz, 1.0697e+01 rad/ps, delta = -0.0584, gamma = 0.0174, [0.52 0.08 0.04]
# i = 180, q_irr = 181, band_irr = 1, weight = 24.0, w_ha = 0.5964 THz, 3.7476e+00 rad/ps, delta = -0.0128, gamma = 0.0023, [0.16 0.12 0.04]
# i = 181, q_irr = 182, band_irr = 1, weight = 48.0, w_ha = 0.6890 THz, 4.3291e+00 rad/ps, delta = -0.0182, gamma = 0.0044, [0.2  0.12 0.04]
# i = 182, q_irr = 183, band_irr = 1, weight = 48.0, w_ha = 0.7976 THz, 5.0115e+00 rad/ps, delta = -0.0258, gamma = 0.0073, [0.24 0.12 0.04]
# i = 183, q_irr = 184, band_irr = 1, weight = 48.0, w_ha = 0.9131 THz, 5.7374e+00 rad/ps, delta = -0.0324, gamma = 0.0094, [0.28 0.12 0.04]
# i = 184, q_irr = 185, band_irr = 1, weight = 48.0, w_ha = 1.0335 THz, 6.4936e+00 rad/ps, delta = -0.0381, gamma = 0.0108, [0.32 0.12 0.04]
# i = 185, q_irr = 186, band_irr = 1, weight = 48.0, w_ha = 1.1581 THz, 7.2766e+00 rad/ps, delta = -0.0432, gamma = 0.0119, [0.36 0.12 0.04]
# i = 186, q_irr = 187, band_irr = 1, weight = 48.0, w_ha = 1.2858 THz, 8.0787e+00 rad/ps, delta = -0.0469, gamma = 0.0137, [0.4  0.12 0.04]
# i = 187, q_irr = 188, band_irr = 1, weight = 48.0, w_ha = 1.4130 THz, 8.8781e+00 rad/ps, delta = -0.0500, gamma = 0.0140, [0.44 0.12 0.04]
# i = 188, q_irr = 189, band_irr = 1, weight = 48.0, w_ha = 1.5325 THz, 9.6289e+00 rad/ps, delta = -0.0536, gamma = 0.0145, [0.48 0.12 0.04]
# i = 189, q_irr = 190, band_irr = 1, weight = 48.0, w_ha = 1.6283 THz, 1.0231e+01 rad/ps, delta = -0.0566, gamma = 0.0159, [0.52 0.12 0.04]
# i = 190, q_irr = 191, band_irr = 1, weight = 48.0, w_ha = 1.6353 THz, 1.0275e+01 rad/ps, delta = -0.0570, gamma = 0.0162, [0.56 0.12 0.04]
# i = 191, q_irr = 192, band_irr = 1, weight = 48.0, w_ha = 1.5464 THz, 9.7165e+00 rad/ps, delta = -0.0548, gamma = 0.0154, [0.6  0.12 0.04]
# i = 192, q_irr = 193, band_irr = 1, weight = 48.0, w_ha = 1.4301 THz, 8.9853e+00 rad/ps, delta = -0.0506, gamma = 0.0143, [0.64 0.12 0.04]
# i = 193, q_irr = 194, band_irr = 1, weight = 48.0, w_ha = 1.3069 THz, 8.2113e+00 rad/ps, delta = -0.0468, gamma = 0.0140, [0.68 0.12 0.04]
# i = 194, q_irr = 195, band_irr = 1, weight = 48.0, w_ha = 1.1872 THz, 7.4595e+00 rad/ps, delta = -0.0425, gamma = 0.0122, [0.72 0.12 0.04]
# i = 195, q_irr = 196, band_irr = 1, weight = 48.0, w_ha = 1.0751 THz, 6.7550e+00 rad/ps, delta = -0.0368, gamma = 0.0101, [0.76 0.12 0.04]
# i = 196, q_irr = 197, band_irr = 1, weight = 48.0, w_ha = 0.9703 THz, 6.0964e+00 rad/ps, delta = -0.0303, gamma = 0.0089, [0.8  0.12 0.04]
# i = 197, q_irr = 198, band_irr = 1, weight = 48.0, w_ha = 0.8708 THz, 5.4716e+00 rad/ps, delta = -0.0244, gamma = 0.0072, [0.84 0.12 0.04]
# i = 198, q_irr = 199, band_irr = 1, weight = 48.0, w_ha = 0.7758 THz, 4.8744e+00 rad/ps, delta = -0.0188, gamma = 0.0052, [0.88 0.12 0.04]
# i = 199, q_irr = 200, band_irr = 1, weight = 24.0, w_ha = 0.6885 THz, 4.3258e+00 rad/ps, delta = -0.0145, gamma = 0.0032, [0.92 0.12 0.04]
# i = 200, q_irr = 201, band_irr = 1, weight = 24.0, w_ha = 0.6475 THz, 4.0685e+00 rad/ps, delta = -0.0161, gamma = 0.0034, [0.2  0.16 0.04]
# i = 201, q_irr = 202, band_irr = 1, weight = 48.0, w_ha = 0.7179 THz, 4.5109e+00 rad/ps, delta = -0.0204, gamma = 0.0053, [0.24 0.16 0.04]
# i = 202, q_irr = 203, band_irr = 1, weight = 48.0, w_ha = 0.8146 THz, 5.1184e+00 rad/ps, delta = -0.0265, gamma = 0.0076, [0.28 0.16 0.04]
# i = 203, q_irr = 204, band_irr = 1, weight = 48.0, w_ha = 0.9275 THz, 5.8274e+00 rad/ps, delta = -0.0326, gamma = 0.0097, [0.32 0.16 0.04]
# i = 204, q_irr = 205, band_irr = 1, weight = 48.0, w_ha = 1.0505 THz, 6.6005e+00 rad/ps, delta = -0.0384, gamma = 0.0107, [0.36 0.16 0.04]
# i = 205, q_irr = 206, band_irr = 1, weight = 48.0, w_ha = 1.1792 THz, 7.4091e+00 rad/ps, delta = -0.0429, gamma = 0.0120, [0.4  0.16 0.04]
# i = 206, q_irr = 207, band_irr = 1, weight = 48.0, w_ha = 1.3089 THz, 8.2238e+00 rad/ps, delta = -0.0470, gamma = 0.0132, [0.44 0.16 0.04]
# i = 207, q_irr = 208, band_irr = 1, weight = 48.0, w_ha = 1.4332 THz, 9.0051e+00 rad/ps, delta = -0.0503, gamma = 0.0137, [0.48 0.16 0.04]
# i = 208, q_irr = 209, band_irr = 1, weight = 48.0, w_ha = 1.5385 THz, 9.6670e+00 rad/ps, delta = -0.0537, gamma = 0.0147, [0.52 0.16 0.04]
# i = 209, q_irr = 210, band_irr = 1, weight = 48.0, w_ha = 1.5561 THz, 9.7775e+00 rad/ps, delta = -0.0551, gamma = 0.0144, [0.56 0.16 0.04]
# i = 210, q_irr = 211, band_irr = 1, weight = 48.0, w_ha = 1.4576 THz, 9.1582e+00 rad/ps, delta = -0.0512, gamma = 0.0143, [0.6  0.16 0.04]
# i = 211, q_irr = 212, band_irr = 1, weight = 48.0, w_ha = 1.3370 THz, 8.4005e+00 rad/ps, delta = -0.0468, gamma = 0.0129, [0.64 0.16 0.04]
# i = 212, q_irr = 213, band_irr = 1, weight = 48.0, w_ha = 1.2160 THz, 7.6403e+00 rad/ps, delta = -0.0416, gamma = 0.0121, [0.68 0.16 0.04]
# i = 213, q_irr = 214, band_irr = 1, weight = 48.0, w_ha = 1.1056 THz, 6.9467e+00 rad/ps, delta = -0.0364, gamma = 0.0100, [0.72 0.16 0.04]
# i = 214, q_irr = 215, band_irr = 1, weight = 48.0, w_ha = 1.0104 THz, 6.3484e+00 rad/ps, delta = -0.0297, gamma = 0.0090, [0.76 0.16 0.04]
# i = 215, q_irr = 216, band_irr = 1, weight = 48.0, w_ha = 0.9307 THz, 5.8477e+00 rad/ps, delta = -0.0238, gamma = 0.0076, [0.8  0.16 0.04]
# i = 216, q_irr = 217, band_irr = 1, weight = 48.0, w_ha = 0.8651 THz, 5.4357e+00 rad/ps, delta = -0.0192, gamma = 0.0065, [0.84 0.16 0.04]
# i = 217, q_irr = 218, band_irr = 1, weight = 24.0, w_ha = 0.8128 THz, 5.1073e+00 rad/ps, delta = -0.0173, gamma = 0.0054, [0.88 0.16 0.04]
# i = 218, q_irr = 219, band_irr = 1, weight = 24.0, w_ha = 0.6690 THz, 4.2036e+00 rad/ps, delta = -0.0187, gamma = 0.0043, [0.24 0.2  0.04]
# i = 219, q_irr = 220, band_irr = 1, weight = 48.0, w_ha = 0.7378 THz, 4.6358e+00 rad/ps, delta = -0.0220, gamma = 0.0060, [0.28 0.2  0.04]
# i = 220, q_irr = 221, band_irr = 1, weight = 48.0, w_ha = 0.8387 THz, 5.2697e+00 rad/ps, delta = -0.0275, gamma = 0.0081, [0.32 0.2  0.04]
# i = 221, q_irr = 222, band_irr = 1, weight = 48.0, w_ha = 0.9574 THz, 6.0153e+00 rad/ps, delta = -0.0328, gamma = 0.0097, [0.36 0.2  0.04]
# i = 222, q_irr = 223, band_irr = 1, weight = 48.0, w_ha = 1.0839 THz, 6.8106e+00 rad/ps, delta = -0.0377, gamma = 0.0105, [0.4  0.2  0.04]
# i = 223, q_irr = 224, band_irr = 1, weight = 48.0, w_ha = 1.2114 THz, 7.6114e+00 rad/ps, delta = -0.0425, gamma = 0.0118, [0.44 0.2  0.04]
# i = 224, q_irr = 225, band_irr = 1, weight = 48.0, w_ha = 1.3337 THz, 8.3801e+00 rad/ps, delta = -0.0468, gamma = 0.0128, [0.48 0.2  0.04]
# i = 225, q_irr = 226, band_irr = 1, weight = 48.0, w_ha = 1.4409 THz, 9.0533e+00 rad/ps, delta = -0.0506, gamma = 0.0132, [0.52 0.2  0.04]
# i = 226, q_irr = 227, band_irr = 1, weight = 48.0, w_ha = 1.4686 THz, 9.2277e+00 rad/ps, delta = -0.0515, gamma = 0.0130, [0.56 0.2  0.04]
# i = 227, q_irr = 228, band_irr = 1, weight = 48.0, w_ha = 1.3694 THz, 8.6041e+00 rad/ps, delta = -0.0483, gamma = 0.0130, [0.6  0.2  0.04]
# i = 228, q_irr = 229, band_irr = 1, weight = 48.0, w_ha = 1.2529 THz, 7.8721e+00 rad/ps, delta = -0.0428, gamma = 0.0121, [0.64 0.2  0.04]
# i = 229, q_irr = 230, band_irr = 1, weight = 48.0, w_ha = 1.1407 THz, 7.1673e+00 rad/ps, delta = -0.0365, gamma = 0.0105, [0.68 0.2  0.04]
# i = 230, q_irr = 231, band_irr = 1, weight = 48.0, w_ha = 1.0433 THz, 6.5555e+00 rad/ps, delta = -0.0307, gamma = 0.0095, [0.72 0.2  0.04]
# i = 231, q_irr = 232, band_irr = 1, weight = 48.0, w_ha = 0.9661 THz, 6.0704e+00 rad/ps, delta = -0.0240, gamma = 0.0082, [0.76 0.2  0.04]
# i = 232, q_irr = 233, band_irr = 1, weight = 48.0, w_ha = 0.9111 THz, 5.7245e+00 rad/ps, delta = -0.0196, gamma = 0.0073, [0.8  0.2  0.04]
# i = 233, q_irr = 234, band_irr = 1, weight = 24.0, w_ha = 0.8779 THz, 5.5160e+00 rad/ps, delta = -0.0178, gamma = 0.0066, [0.84 0.2  0.04]
# i = 234, q_irr = 235, band_irr = 1, weight = 24.0, w_ha = 0.6995 THz, 4.3954e+00 rad/ps, delta = -0.0206, gamma = 0.0052, [0.28 0.24 0.04]
# i = 235, q_irr = 236, band_irr = 1, weight = 48.0, w_ha = 0.7789 THz, 4.8940e+00 rad/ps, delta = -0.0235, gamma = 0.0068, [0.32 0.24 0.04]
# i = 236, q_irr = 237, band_irr = 1, weight = 48.0, w_ha = 0.8857 THz, 5.5650e+00 rad/ps, delta = -0.0284, gamma = 0.0088, [0.36 0.24 0.04]
# i = 237, q_irr = 238, band_irr = 1, weight = 48.0, w_ha = 1.0037 THz, 6.3067e+00 rad/ps, delta = -0.0326, gamma = 0.0099, [0.4  0.24 0.04]
# i = 238, q_irr = 239, band_irr = 1, weight = 48.0, w_ha = 1.1230 THz, 7.0562e+00 rad/ps, delta = -0.0376, gamma = 0.0107, [0.44 0.24 0.04]
# i = 239, q_irr = 240, band_irr = 1, weight = 48.0, w_ha = 1.2374 THz, 7.7748e+00 rad/ps, delta = -0.0427, gamma = 0.0114, [0.48 0.24 0.04]
# i = 240, q_irr = 241, band_irr = 1, weight = 48.0, w_ha = 1.3401 THz, 8.4201e+00 rad/ps, delta = -0.0470, gamma = 0.0125, [0.52 0.24 0.04]
# i = 241, q_irr = 242, band_irr = 1, weight = 48.0, w_ha = 1.3802 THz, 8.6718e+00 rad/ps, delta = -0.0494, gamma = 0.0122, [0.56 0.24 0.04]
# i = 242, q_irr = 243, band_irr = 1, weight = 48.0, w_ha = 1.2888 THz, 8.0976e+00 rad/ps, delta = -0.0448, gamma = 0.0120, [0.6  0.24 0.04]
# i = 243, q_irr = 244, band_irr = 1, weight = 48.0, w_ha = 1.1855 THz, 7.4485e+00 rad/ps, delta = -0.0385, gamma = 0.0114, [0.64 0.24 0.04]
# i = 244, q_irr = 245, band_irr = 1, weight = 48.0, w_ha = 1.0892 THz, 6.8434e+00 rad/ps, delta = -0.0321, gamma = 0.0107, [0.68 0.24 0.04]
# i = 245, q_irr = 246, band_irr = 1, weight = 48.0, w_ha = 1.0086 THz, 6.3375e+00 rad/ps, delta = -0.0262, gamma = 0.0098, [0.72 0.24 0.04]
# i = 246, q_irr = 247, band_irr = 1, weight = 48.0, w_ha = 0.9498 THz, 5.9680e+00 rad/ps, delta = -0.0216, gamma = 0.0087, [0.76 0.24 0.04]
# i = 247, q_irr = 248, band_irr = 1, weight = 24.0, w_ha = 0.9168 THz, 5.7606e+00 rad/ps, delta = -0.0188, gamma = 0.0079, [0.8  0.24 0.04]
# i = 248, q_irr = 249, band_irr = 1, weight = 24.0, w_ha = 0.7579 THz, 4.7622e+00 rad/ps, delta = -0.0222, gamma = 0.0065, [0.32 0.28 0.04]
# i = 249, q_irr = 250, band_irr = 1, weight = 48.0, w_ha = 0.8409 THz, 5.2834e+00 rad/ps, delta = -0.0248, gamma = 0.0084, [0.36 0.28 0.04]
# i = 250, q_irr = 251, band_irr = 1, weight = 48.0, w_ha = 0.9404 THz, 5.9085e+00 rad/ps, delta = -0.0298, gamma = 0.0099, [0.4  0.28 0.04]
# i = 251, q_irr = 252, band_irr = 1, weight = 48.0, w_ha = 1.0437 THz, 6.5580e+00 rad/ps, delta = -0.0338, gamma = 0.0106, [0.44 0.28 0.04]
# i = 252, q_irr = 253, band_irr = 1, weight = 48.0, w_ha = 1.1443 THz, 7.1901e+00 rad/ps, delta = -0.0382, gamma = 0.0110, [0.48 0.28 0.04]
# i = 253, q_irr = 254, band_irr = 1, weight = 48.0, w_ha = 1.2378 THz, 7.7773e+00 rad/ps, delta = -0.0428, gamma = 0.0112, [0.52 0.28 0.04]
# i = 254, q_irr = 255, band_irr = 1, weight = 48.0, w_ha = 1.2925 THz, 8.1208e+00 rad/ps, delta = -0.0451, gamma = 0.0116, [0.56 0.28 0.04]
# i = 255, q_irr = 256, band_irr = 1, weight = 48.0, w_ha = 1.2340 THz, 7.7532e+00 rad/ps, delta = -0.0396, gamma = 0.0125, [0.6  0.28 0.04]
# i = 256, q_irr = 257, band_irr = 1, weight = 48.0, w_ha = 1.1366 THz, 7.1412e+00 rad/ps, delta = -0.0351, gamma = 0.0136, [0.64 0.28 0.04]
# i = 257, q_irr = 258, band_irr = 1, weight = 48.0, w_ha = 1.0624 THz, 6.6750e+00 rad/ps, delta = -0.0303, gamma = 0.0126, [0.68 0.28 0.04]
# i = 258, q_irr = 259, band_irr = 1, weight = 48.0, w_ha = 1.0026 THz, 6.2998e+00 rad/ps, delta = -0.0255, gamma = 0.0112, [0.72 0.28 0.04]
# i = 259, q_irr = 260, band_irr = 1, weight = 24.0, w_ha = 0.9632 THz, 6.0518e+00 rad/ps, delta = -0.0217, gamma = 0.0098, [0.76 0.28 0.04]
# i = 260, q_irr = 261, band_irr = 1, weight = 24.0, w_ha = 0.8245 THz, 5.1803e+00 rad/ps, delta = -0.0251, gamma = 0.0086, [0.36 0.32 0.04]
# i = 261, q_irr = 262, band_irr = 1, weight = 48.0, w_ha = 0.8943 THz, 5.6188e+00 rad/ps, delta = -0.0276, gamma = 0.0101, [0.4  0.32 0.04]
# i = 262, q_irr = 263, band_irr = 1, weight = 48.0, w_ha = 0.9729 THz, 6.1128e+00 rad/ps, delta = -0.0318, gamma = 0.0113, [0.44 0.32 0.04]
# i = 263, q_irr = 264, band_irr = 1, weight = 48.0, w_ha = 1.0538 THz, 6.6211e+00 rad/ps, delta = -0.0356, gamma = 0.0117, [0.48 0.32 0.04]
# i = 264, q_irr = 265, band_irr = 1, weight = 48.0, w_ha = 1.1340 THz, 7.1248e+00 rad/ps, delta = -0.0396, gamma = 0.0119, [0.52 0.32 0.04]
# i = 265, q_irr = 266, band_irr = 1, weight = 48.0, w_ha = 1.2024 THz, 7.5549e+00 rad/ps, delta = -0.0425, gamma = 0.0124, [0.56 0.32 0.04]
# i = 266, q_irr = 267, band_irr = 1, weight = 48.0, w_ha = 1.1716 THz, 7.3612e+00 rad/ps, delta = -0.0386, gamma = 0.0161, [0.6  0.32 0.04]
# i = 267, q_irr = 268, band_irr = 1, weight = 48.0, w_ha = 1.1036 THz, 6.9340e+00 rad/ps, delta = -0.0355, gamma = 0.0169, [0.64 0.32 0.04]
# i = 268, q_irr = 269, band_irr = 1, weight = 48.0, w_ha = 1.0559 THz, 6.6342e+00 rad/ps, delta = -0.0319, gamma = 0.0159, [0.68 0.32 0.04]
# i = 269, q_irr = 270, band_irr = 1, weight = 24.0, w_ha = 1.0206 THz, 6.4125e+00 rad/ps, delta = -0.0270, gamma = 0.0133, [0.72 0.32 0.04]
# i = 270, q_irr = 271, band_irr = 1, weight = 24.0, w_ha = 0.8643 THz, 5.4309e+00 rad/ps, delta = -0.0284, gamma = 0.0107, [0.4  0.36 0.04]
# i = 271, q_irr = 272, band_irr = 1, weight = 48.0, w_ha = 0.9109 THz, 5.7235e+00 rad/ps, delta = -0.0316, gamma = 0.0119, [0.44 0.36 0.04]
# i = 272, q_irr = 273, band_irr = 1, weight = 48.0, w_ha = 0.9666 THz, 6.0731e+00 rad/ps, delta = -0.0345, gamma = 0.0123, [0.48 0.36 0.04]
# i = 273, q_irr = 274, band_irr = 1, weight = 48.0, w_ha = 1.0300 THz, 6.4717e+00 rad/ps, delta = -0.0377, gamma = 0.0122, [0.52 0.36 0.04]
# i = 274, q_irr = 275, band_irr = 1, weight = 48.0, w_ha = 1.1001 THz, 6.9122e+00 rad/ps, delta = -0.0407, gamma = 0.0126, [0.56 0.36 0.04]
# i = 275, q_irr = 276, band_irr = 1, weight = 48.0, w_ha = 1.1174 THz, 7.0206e+00 rad/ps, delta = -0.0390, gamma = 0.0200, [0.6  0.36 0.04]
# i = 276, q_irr = 277, band_irr = 1, weight = 48.0, w_ha = 1.0829 THz, 6.8038e+00 rad/ps, delta = -0.0377, gamma = 0.0203, [0.64 0.36 0.04]
# i = 277, q_irr = 278, band_irr = 1, weight = 24.0, w_ha = 1.0639 THz, 6.6847e+00 rad/ps, delta = -0.0344, gamma = 0.0182, [0.68 0.36 0.04]
# i = 278, q_irr = 279, band_irr = 1, weight = 24.0, w_ha = 0.8593 THz, 5.3991e+00 rad/ps, delta = -0.0327, gamma = 0.0121, [0.44 0.4  0.04]
# i = 279, q_irr = 280, band_irr = 1, weight = 48.0, w_ha = 0.8868 THz, 5.5716e+00 rad/ps, delta = -0.0349, gamma = 0.0125, [0.48 0.4  0.04]
# i = 280, q_irr = 281, band_irr = 1, weight = 48.0, w_ha = 0.9309 THz, 5.8493e+00 rad/ps, delta = -0.0371, gamma = 0.0127, [0.52 0.4  0.04]
# i = 281, q_irr = 282, band_irr = 1, weight = 48.0, w_ha = 0.9931 THz, 6.2397e+00 rad/ps, delta = -0.0394, gamma = 0.0123, [0.56 0.4  0.04]
# i = 282, q_irr = 283, band_irr = 1, weight = 48.0, w_ha = 1.0698 THz, 6.7216e+00 rad/ps, delta = -0.0416, gamma = 0.0165, [0.6  0.4  0.04]
# i = 283, q_irr = 284, band_irr = 1, weight = 24.0, w_ha = 1.0776 THz, 6.7709e+00 rad/ps, delta = -0.0387, gamma = 0.0216, [0.64 0.4  0.04]
# i = 284, q_irr = 285, band_irr = 1, weight = 24.0, w_ha = 0.8203 THz, 5.1542e+00 rad/ps, delta = -0.0375, gamma = 0.0121, [0.48 0.44 0.04]
# i = 285, q_irr = 286, band_irr = 1, weight = 48.0, w_ha = 0.8456 THz, 5.3130e+00 rad/ps, delta = -0.0383, gamma = 0.0126, [0.52 0.44 0.04]
# i = 286, q_irr = 287, band_irr = 1, weight = 48.0, w_ha = 0.8977 THz, 5.6404e+00 rad/ps, delta = -0.0389, gamma = 0.0130, [0.56 0.44 0.04]
# i = 287, q_irr = 288, band_irr = 1, weight = 24.0, w_ha = 0.9753 THz, 6.1283e+00 rad/ps, delta = -0.0401, gamma = 0.0127, [0.6  0.44 0.04]
# i = 288, q_irr = 289, band_irr = 1, weight = 24.0, w_ha = 0.7831 THz, 4.9201e+00 rad/ps, delta = -0.0391, gamma = 0.0118, [0.52 0.48 0.04]
# i = 289, q_irr = 290, band_irr = 1, weight = 24.0, w_ha = 0.8253 THz, 5.1857e+00 rad/ps, delta = -0.0386, gamma = 0.0126, [0.56 0.48 0.04]
# i = 290, q_irr = 291, band_irr = 1, weight = 24.0, w_ha = 0.7348 THz, 4.6172e+00 rad/ps, delta = -0.0167, gamma = 0.0044, [0.24 0.16 0.08]
# i = 291, q_irr = 292, band_irr = 1, weight = 48.0, w_ha = 0.8044 THz, 5.0540e+00 rad/ps, delta = -0.0196, gamma = 0.0059, [0.28 0.16 0.08]
# i = 292, q_irr = 293, band_irr = 1, weight = 48.0, w_ha = 0.8894 THz, 5.5882e+00 rad/ps, delta = -0.0247, gamma = 0.0075, [0.32 0.16 0.08]
# i = 293, q_irr = 294, band_irr = 1, weight = 48.0, w_ha = 0.9859 THz, 6.1944e+00 rad/ps, delta = -0.0303, gamma = 0.0090, [0.36 0.16 0.08]
# i = 294, q_irr = 295, band_irr = 1, weight = 48.0, w_ha = 1.0923 THz, 6.8632e+00 rad/ps, delta = -0.0364, gamma = 0.0104, [0.4  0.16 0.08]
# i = 295, q_irr = 296, band_irr = 1, weight = 48.0, w_ha = 1.2075 THz, 7.5867e+00 rad/ps, delta = -0.0420, gamma = 0.0119, [0.44 0.16 0.08]
# i = 296, q_irr = 297, band_irr = 1, weight = 48.0, w_ha = 1.3282 THz, 8.3454e+00 rad/ps, delta = -0.0465, gamma = 0.0135, [0.48 0.16 0.08]
# i = 297, q_irr = 298, band_irr = 1, weight = 48.0, w_ha = 1.4471 THz, 9.0925e+00 rad/ps, delta = -0.0508, gamma = 0.0141, [0.52 0.16 0.08]
# i = 298, q_irr = 299, band_irr = 1, weight = 48.0, w_ha = 1.5448 THz, 9.7065e+00 rad/ps, delta = -0.0541, gamma = 0.0145, [0.56 0.16 0.08]
# i = 299, q_irr = 300, band_irr = 1, weight = 24.0, w_ha = 0.7561 THz, 4.7505e+00 rad/ps, delta = -0.0183, gamma = 0.0052, [0.28 0.2  0.08]
# i = 300, q_irr = 301, band_irr = 1, weight = 48.0, w_ha = 0.8245 THz, 5.1807e+00 rad/ps, delta = -0.0208, gamma = 0.0066, [0.32 0.2  0.08]
# i = 301, q_irr = 302, band_irr = 1, weight = 48.0, w_ha = 0.9135 THz, 5.7395e+00 rad/ps, delta = -0.0253, gamma = 0.0080, [0.36 0.2  0.08]
# i = 302, q_irr = 303, band_irr = 1, weight = 48.0, w_ha = 1.0152 THz, 6.3788e+00 rad/ps, delta = -0.0307, gamma = 0.0094, [0.4  0.2  0.08]
# i = 303, q_irr = 304, band_irr = 1, weight = 48.0, w_ha = 1.1247 THz, 7.0668e+00 rad/ps, delta = -0.0358, gamma = 0.0102, [0.44 0.2  0.08]
# i = 304, q_irr = 305, band_irr = 1, weight = 48.0, w_ha = 1.2381 THz, 7.7790e+00 rad/ps, delta = -0.0417, gamma = 0.0117, [0.48 0.2  0.08]
# i = 305, q_irr = 306, band_irr = 1, weight = 48.0, w_ha = 1.3502 THz, 8.4837e+00 rad/ps, delta = -0.0467, gamma = 0.0128, [0.52 0.2  0.08]
# i = 306, q_irr = 307, band_irr = 1, weight = 48.0, w_ha = 1.4470 THz, 9.0918e+00 rad/ps, delta = -0.0508, gamma = 0.0134, [0.56 0.2  0.08]
# i = 307, q_irr = 308, band_irr = 1, weight = 48.0, w_ha = 1.4534 THz, 9.1323e+00 rad/ps, delta = -0.0518, gamma = 0.0131, [0.6  0.2  0.08]
# i = 308, q_irr = 309, band_irr = 1, weight = 48.0, w_ha = 1.3561 THz, 8.5209e+00 rad/ps, delta = -0.0475, gamma = 0.0131, [0.64 0.2  0.08]
# i = 309, q_irr = 310, band_irr = 1, weight = 48.0, w_ha = 1.2435 THz, 7.8135e+00 rad/ps, delta = -0.0423, gamma = 0.0119, [0.68 0.2  0.08]
# i = 310, q_irr = 311, band_irr = 1, weight = 48.0, w_ha = 1.1350 THz, 7.1313e+00 rad/ps, delta = -0.0361, gamma = 0.0102, [0.72 0.2  0.08]
# i = 311, q_irr = 312, band_irr = 1, weight = 48.0, w_ha = 1.0372 THz, 6.5170e+00 rad/ps, delta = -0.0297, gamma = 0.0090, [0.76 0.2  0.08]
# i = 312, q_irr = 313, band_irr = 1, weight = 48.0, w_ha = 0.9533 THz, 5.9895e+00 rad/ps, delta = -0.0245, gamma = 0.0083, [0.8  0.2  0.08]
# i = 313, q_irr = 314, band_irr = 1, weight = 48.0, w_ha = 0.8849 THz, 5.5600e+00 rad/ps, delta = -0.0198, gamma = 0.0070, [0.84 0.2  0.08]
# i = 314, q_irr = 315, band_irr = 1, weight = 24.0, w_ha = 0.8342 THz, 5.2417e+00 rad/ps, delta = -0.0180, gamma = 0.0061, [0.88 0.2  0.08]
# i = 315, q_irr = 316, band_irr = 1, weight = 24.0, w_ha = 0.7852 THz, 4.9334e+00 rad/ps, delta = -0.0195, gamma = 0.0060, [0.32 0.24 0.08]
# i = 316, q_irr = 317, band_irr = 1, weight = 48.0, w_ha = 0.8634 THz, 5.4251e+00 rad/ps, delta = -0.0218, gamma = 0.0074, [0.36 0.24 0.08]
# i = 317, q_irr = 318, band_irr = 1, weight = 48.0, w_ha = 0.9586 THz, 6.0229e+00 rad/ps, delta = -0.0258, gamma = 0.0086, [0.4  0.24 0.08]
# i = 318, q_irr = 319, band_irr = 1, weight = 48.0, w_ha = 1.0604 THz, 6.6628e+00 rad/ps, delta = -0.0308, gamma = 0.0096, [0.44 0.24 0.08]
# i = 319, q_irr = 320, band_irr = 1, weight = 48.0, w_ha = 1.1630 THz, 7.3073e+00 rad/ps, delta = -0.0364, gamma = 0.0101, [0.48 0.24 0.08]
# i = 320, q_irr = 321, band_irr = 1, weight = 48.0, w_ha = 1.2625 THz, 7.9326e+00 rad/ps, delta = -0.0422, gamma = 0.0117, [0.52 0.24 0.08]
# i = 321, q_irr = 322, band_irr = 1, weight = 48.0, w_ha = 1.3505 THz, 8.4856e+00 rad/ps, delta = -0.0473, gamma = 0.0122, [0.56 0.24 0.08]
# i = 322, q_irr = 323, band_irr = 1, weight = 48.0, w_ha = 1.3703 THz, 8.6101e+00 rad/ps, delta = -0.0482, gamma = 0.0122, [0.6  0.24 0.08]
# i = 323, q_irr = 324, band_irr = 1, weight = 48.0, w_ha = 1.2718 THz, 7.9912e+00 rad/ps, delta = -0.0436, gamma = 0.0119, [0.64 0.24 0.08]
# i = 324, q_irr = 325, band_irr = 1, weight = 48.0, w_ha = 1.1723 THz, 7.3659e+00 rad/ps, delta = -0.0378, gamma = 0.0111, [0.68 0.24 0.08]
# i = 325, q_irr = 326, band_irr = 1, weight = 48.0, w_ha = 1.0812 THz, 6.7933e+00 rad/ps, delta = -0.0305, gamma = 0.0100, [0.72 0.24 0.08]
# i = 326, q_irr = 327, band_irr = 1, weight = 48.0, w_ha = 1.0040 THz, 6.3080e+00 rad/ps, delta = -0.0252, gamma = 0.0090, [0.76 0.24 0.08]
# i = 327, q_irr = 328, band_irr = 1, weight = 48.0, w_ha = 0.9438 THz, 5.9300e+00 rad/ps, delta = -0.0204, gamma = 0.0080, [0.8  0.24 0.08]
# i = 328, q_irr = 329, band_irr = 1, weight = 24.0, w_ha = 0.9033 THz, 5.6758e+00 rad/ps, delta = -0.0184, gamma = 0.0073, [0.84 0.24 0.08]
# i = 329, q_irr = 330, band_irr = 1, weight = 24.0, w_ha = 0.8394 THz, 5.2744e+00 rad/ps, delta = -0.0209, gamma = 0.0072, [0.36 0.28 0.08]
# i = 330, q_irr = 331, band_irr = 1, weight = 48.0, w_ha = 0.9219 THz, 5.7923e+00 rad/ps, delta = -0.0232, gamma = 0.0089, [0.4  0.28 0.08]
# i = 331, q_irr = 332, band_irr = 1, weight = 48.0, w_ha = 1.0117 THz, 6.3570e+00 rad/ps, delta = -0.0271, gamma = 0.0099, [0.44 0.28 0.08]
# i = 332, q_irr = 333, band_irr = 1, weight = 48.0, w_ha = 1.1006 THz, 6.9154e+00 rad/ps, delta = -0.0313, gamma = 0.0107, [0.48 0.28 0.08]
# i = 333, q_irr = 334, band_irr = 1, weight = 48.0, w_ha = 1.1848 THz, 7.4440e+00 rad/ps, delta = -0.0369, gamma = 0.0106, [0.52 0.28 0.08]
# i = 334, q_irr = 335, band_irr = 1, weight = 48.0, w_ha = 1.2600 THz, 7.9168e+00 rad/ps, delta = -0.0430, gamma = 0.0114, [0.56 0.28 0.08]
# i = 335, q_irr = 336, band_irr = 1, weight = 48.0, w_ha = 1.2853 THz, 8.0755e+00 rad/ps, delta = -0.0452, gamma = 0.0115, [0.6  0.28 0.08]
# i = 336, q_irr = 337, band_irr = 1, weight = 48.0, w_ha = 1.2000 THz, 7.5401e+00 rad/ps, delta = -0.0397, gamma = 0.0119, [0.64 0.28 0.08]
# i = 337, q_irr = 338, band_irr = 1, weight = 48.0, w_ha = 1.1196 THz, 7.0347e+00 rad/ps, delta = -0.0336, gamma = 0.0119, [0.68 0.28 0.08]
# i = 338, q_irr = 339, band_irr = 1, weight = 48.0, w_ha = 1.0500 THz, 6.5974e+00 rad/ps, delta = -0.0279, gamma = 0.0111, [0.72 0.28 0.08]
# i = 339, q_irr = 340, band_irr = 1, weight = 48.0, w_ha = 0.9952 THz, 6.2531e+00 rad/ps, delta = -0.0233, gamma = 0.0100, [0.76 0.28 0.08]
# i = 340, q_irr = 341, band_irr = 1, weight = 24.0, w_ha = 0.9586 THz, 6.0229e+00 rad/ps, delta = -0.0200, gamma = 0.0089, [0.8  0.28 0.08]
# i = 341, q_irr = 342, band_irr = 1, weight = 24.0, w_ha = 0.9022 THz, 5.6686e+00 rad/ps, delta = -0.0231, gamma = 0.0093, [0.4  0.32 0.08]
# i = 342, q_irr = 343, band_irr = 1, weight = 48.0, w_ha = 0.9737 THz, 6.1182e+00 rad/ps, delta = -0.0249, gamma = 0.0106, [0.44 0.32 0.08]
# i = 343, q_irr = 344, band_irr = 1, weight = 48.0, w_ha = 1.0455 THz, 6.5692e+00 rad/ps, delta = -0.0286, gamma = 0.0115, [0.48 0.32 0.08]
# i = 344, q_irr = 345, band_irr = 1, weight = 48.0, w_ha = 1.1133 THz, 6.9952e+00 rad/ps, delta = -0.0330, gamma = 0.0117, [0.52 0.32 0.08]
# i = 345, q_irr = 346, band_irr = 1, weight = 48.0, w_ha = 1.1755 THz, 7.3858e+00 rad/ps, delta = -0.0379, gamma = 0.0115, [0.56 0.32 0.08]
# ...
# i = 2616, q_irr = 342, band_irr = 6, weight = 24.0, w_ha = 2.8516 THz, 1.7917e+01 rad/ps, delta = -0.1074, gamma = 0.0387, [0.4  0.32 0.08]
# i = 2617, q_irr = 343, band_irr = 6, weight = 48.0, w_ha = 2.8305 THz, 1.7785e+01 rad/ps, delta = -0.1062, gamma = 0.0359, [0.44 0.32 0.08]
# i = 2618, q_irr = 344, band_irr = 6, weight = 48.0, w_ha = 2.8247 THz, 1.7748e+01 rad/ps, delta = -0.1101, gamma = 0.0352, [0.48 0.32 0.08]
# i = 2619, q_irr = 345, band_irr = 6, weight = 48.0, w_ha = 2.8994 THz, 1.8217e+01 rad/ps, delta = -0.1139, gamma = 0.0411, [0.52 0.32 0.08]
# i = 2620, q_irr = 346, band_irr = 6, weight = 48.0, w_ha = 2.9904 THz, 1.8789e+01 rad/ps, delta = -0.1195, gamma = 0.0456, [0.56 0.32 0.08]
# i = 2621, q_irr = 347, band_irr = 6, weight = 48.0, w_ha = 3.0518 THz, 1.9175e+01 rad/ps, delta = -0.1234, gamma = 0.0458, [0.6  0.32 0.08]
# i = 2622, q_irr = 348, band_irr = 6, weight = 48.0, w_ha = 3.0892 THz, 1.9410e+01 rad/ps, delta = -0.1271, gamma = 0.0495, [0.64 0.32 0.08]
# i = 2623, q_irr = 349, band_irr = 6, weight = 48.0, w_ha = 3.0853 THz, 1.9385e+01 rad/ps, delta = -0.1271, gamma = 0.0494, [0.68 0.32 0.08]
# i = 2624, q_irr = 350, band_irr = 6, weight = 48.0, w_ha = 3.0645 THz, 1.9255e+01 rad/ps, delta = -0.1287, gamma = 0.0468, [0.72 0.32 0.08]
# i = 2625, q_irr = 351, band_irr = 6, weight = 24.0, w_ha = 3.0478 THz, 1.9150e+01 rad/ps, delta = -0.1299, gamma = 0.0459, [0.76 0.32 0.08]
# i = 2626, q_irr = 352, band_irr = 6, weight = 24.0, w_ha = 2.7608 THz, 1.7347e+01 rad/ps, delta = -0.0985, gamma = 0.0334, [0.44 0.36 0.08]
# i = 2627, q_irr = 353, band_irr = 6, weight = 48.0, w_ha = 2.7211 THz, 1.7097e+01 rad/ps, delta = -0.0994, gamma = 0.0307, [0.48 0.36 0.08]
# i = 2628, q_irr = 354, band_irr = 6, weight = 48.0, w_ha = 2.7635 THz, 1.7363e+01 rad/ps, delta = -0.1055, gamma = 0.0367, [0.52 0.36 0.08]
# i = 2629, q_irr = 355, band_irr = 6, weight = 48.0, w_ha = 2.8799 THz, 1.8095e+01 rad/ps, delta = -0.1106, gamma = 0.0407, [0.56 0.36 0.08]
# i = 2630, q_irr = 356, band_irr = 6, weight = 48.0, w_ha = 2.9757 THz, 1.8697e+01 rad/ps, delta = -0.1204, gamma = 0.0449, [0.6  0.36 0.08]
# i = 2631, q_irr = 357, band_irr = 6, weight = 48.0, w_ha = 3.0379 THz, 1.9088e+01 rad/ps, delta = -0.1217, gamma = 0.0460, [0.64 0.36 0.08]
# i = 2632, q_irr = 358, band_irr = 6, weight = 48.0, w_ha = 3.0738 THz, 1.9313e+01 rad/ps, delta = -0.1262, gamma = 0.0486, [0.68 0.36 0.08]
# i = 2633, q_irr = 359, band_irr = 6, weight = 24.0, w_ha = 3.0758 THz, 1.9326e+01 rad/ps, delta = -0.1277, gamma = 0.0480, [0.72 0.36 0.08]
# i = 2634, q_irr = 360, band_irr = 6, weight = 24.0, w_ha = 2.6361 THz, 1.6563e+01 rad/ps, delta = -0.0918, gamma = 0.0281, [0.48 0.4  0.08]
# i = 2635, q_irr = 361, band_irr = 6, weight = 48.0, w_ha = 2.6297 THz, 1.6523e+01 rad/ps, delta = -0.0915, gamma = 0.0312, [0.52 0.4  0.08]
# i = 2636, q_irr = 362, band_irr = 6, weight = 48.0, w_ha = 2.7540 THz, 1.7304e+01 rad/ps, delta = -0.1033, gamma = 0.0370, [0.56 0.4  0.08]
# i = 2637, q_irr = 363, band_irr = 6, weight = 48.0, w_ha = 2.8745 THz, 1.8061e+01 rad/ps, delta = -0.1100, gamma = 0.0399, [0.6  0.4  0.08]
# i = 2638, q_irr = 364, band_irr = 6, weight = 48.0, w_ha = 2.9696 THz, 1.8658e+01 rad/ps, delta = -0.1179, gamma = 0.0435, [0.64 0.4  0.08]
# i = 2639, q_irr = 365, band_irr = 6, weight = 24.0, w_ha = 3.0382 THz, 1.9089e+01 rad/ps, delta = -0.1215, gamma = 0.0461, [0.68 0.4  0.08]
# i = 2640, q_irr = 366, band_irr = 6, weight = 24.0, w_ha = 2.5172 THz, 1.5816e+01 rad/ps, delta = -0.0841, gamma = 0.0269, [0.52 0.44 0.08]
# i = 2641, q_irr = 367, band_irr = 6, weight = 48.0, w_ha = 2.6247 THz, 1.6491e+01 rad/ps, delta = -0.0919, gamma = 0.0338, [0.56 0.44 0.08]
# i = 2642, q_irr = 368, band_irr = 6, weight = 48.0, w_ha = 2.7549 THz, 1.7309e+01 rad/ps, delta = -0.1035, gamma = 0.0366, [0.6  0.44 0.08]
# i = 2643, q_irr = 369, band_irr = 6, weight = 24.0, w_ha = 2.8734 THz, 1.8054e+01 rad/ps, delta = -0.1099, gamma = 0.0398, [0.64 0.44 0.08]
# i = 2644, q_irr = 370, band_irr = 6, weight = 24.0, w_ha = 2.5058 THz, 1.5745e+01 rad/ps, delta = -0.0821, gamma = 0.0313, [0.56 0.48 0.08]
# i = 2645, q_irr = 371, band_irr = 6, weight = 24.0, w_ha = 2.6274 THz, 1.6508e+01 rad/ps, delta = -0.0930, gamma = 0.0347, [0.6  0.48 0.08]
# i = 2646, q_irr = 372, band_irr = 6, weight = 24.0, w_ha = 3.1812 THz, 1.9988e+01 rad/ps, delta = -0.1237, gamma = 0.0584, [0.36 0.24 0.12]
# i = 2647, q_irr = 373, band_irr = 6, weight = 48.0, w_ha = 3.1326 THz, 1.9683e+01 rad/ps, delta = -0.1274, gamma = 0.0562, [0.4  0.24 0.12]
# i = 2648, q_irr = 374, band_irr = 6, weight = 48.0, w_ha = 3.1087 THz, 1.9533e+01 rad/ps, delta = -0.1300, gamma = 0.0535, [0.44 0.24 0.12]
# i = 2649, q_irr = 375, band_irr = 6, weight = 48.0, w_ha = 3.1050 THz, 1.9509e+01 rad/ps, delta = -0.1317, gamma = 0.0492, [0.48 0.24 0.12]
# i = 2650, q_irr = 376, band_irr = 6, weight = 48.0, w_ha = 3.1084 THz, 1.9530e+01 rad/ps, delta = -0.1320, gamma = 0.0497, [0.52 0.24 0.12]
# i = 2651, q_irr = 377, band_irr = 6, weight = 48.0, w_ha = 3.1087 THz, 1.9533e+01 rad/ps, delta = -0.1337, gamma = 0.0491, [0.56 0.24 0.12]
# i = 2652, q_irr = 378, band_irr = 6, weight = 48.0, w_ha = 3.1069 THz, 1.9521e+01 rad/ps, delta = -0.1363, gamma = 0.0501, [0.6  0.24 0.12]
# i = 2653, q_irr = 379, band_irr = 6, weight = 24.0, w_ha = 3.0173 THz, 1.8958e+01 rad/ps, delta = -0.1211, gamma = 0.0460, [0.4  0.28 0.12]
# i = 2654, q_irr = 380, band_irr = 6, weight = 48.0, w_ha = 2.9949 THz, 1.8818e+01 rad/ps, delta = -0.1223, gamma = 0.0456, [0.44 0.28 0.12]
# i = 2655, q_irr = 381, band_irr = 6, weight = 48.0, w_ha = 3.0030 THz, 1.8868e+01 rad/ps, delta = -0.1245, gamma = 0.0457, [0.48 0.28 0.12]
# i = 2656, q_irr = 382, band_irr = 6, weight = 48.0, w_ha = 3.0313 THz, 1.9046e+01 rad/ps, delta = -0.1266, gamma = 0.0465, [0.52 0.28 0.12]
# i = 2657, q_irr = 383, band_irr = 6, weight = 48.0, w_ha = 3.0577 THz, 1.9212e+01 rad/ps, delta = -0.1263, gamma = 0.0468, [0.56 0.28 0.12]
# i = 2658, q_irr = 384, band_irr = 6, weight = 48.0, w_ha = 3.0697 THz, 1.9288e+01 rad/ps, delta = -0.1270, gamma = 0.0491, [0.6  0.28 0.12]
# i = 2659, q_irr = 385, band_irr = 6, weight = 48.0, w_ha = 3.0745 THz, 1.9318e+01 rad/ps, delta = -0.1318, gamma = 0.0512, [0.64 0.28 0.12]
# i = 2660, q_irr = 386, band_irr = 6, weight = 48.0, w_ha = 3.0627 THz, 1.9244e+01 rad/ps, delta = -0.1303, gamma = 0.0486, [0.68 0.28 0.12]
# i = 2661, q_irr = 387, band_irr = 6, weight = 48.0, w_ha = 3.0507 THz, 1.9168e+01 rad/ps, delta = -0.1293, gamma = 0.0484, [0.72 0.28 0.12]
# i = 2662, q_irr = 388, band_irr = 6, weight = 48.0, w_ha = 3.0445 THz, 1.9129e+01 rad/ps, delta = -0.1267, gamma = 0.0460, [0.76 0.28 0.12]
# i = 2663, q_irr = 389, band_irr = 6, weight = 48.0, w_ha = 3.0506 THz, 1.9167e+01 rad/ps, delta = -0.1294, gamma = 0.0493, [0.8  0.28 0.12]
# i = 2664, q_irr = 390, band_irr = 6, weight = 24.0, w_ha = 3.0781 THz, 1.9340e+01 rad/ps, delta = -0.1294, gamma = 0.0508, [0.84 0.28 0.12]
# i = 2665, q_irr = 391, band_irr = 6, weight = 24.0, w_ha = 2.9000 THz, 1.8221e+01 rad/ps, delta = -0.1163, gamma = 0.0412, [0.44 0.32 0.12]
# i = 2666, q_irr = 392, band_irr = 6, weight = 48.0, w_ha = 2.8971 THz, 1.8203e+01 rad/ps, delta = -0.1157, gamma = 0.0391, [0.48 0.32 0.12]
# i = 2667, q_irr = 393, band_irr = 6, weight = 48.0, w_ha = 2.9364 THz, 1.8450e+01 rad/ps, delta = -0.1173, gamma = 0.0420, [0.52 0.32 0.12]
# i = 2668, q_irr = 394, band_irr = 6, weight = 48.0, w_ha = 2.9895 THz, 1.8784e+01 rad/ps, delta = -0.1195, gamma = 0.0463, [0.56 0.32 0.12]
# i = 2669, q_irr = 395, band_irr = 6, weight = 48.0, w_ha = 3.0260 THz, 1.9013e+01 rad/ps, delta = -0.1211, gamma = 0.0467, [0.6  0.32 0.12]
# i = 2670, q_irr = 396, band_irr = 6, weight = 48.0, w_ha = 3.0396 THz, 1.9098e+01 rad/ps, delta = -0.1261, gamma = 0.0481, [0.64 0.32 0.12]
# i = 2671, q_irr = 397, band_irr = 6, weight = 48.0, w_ha = 3.0422 THz, 1.9115e+01 rad/ps, delta = -0.1246, gamma = 0.0485, [0.68 0.32 0.12]
# i = 2672, q_irr = 398, band_irr = 6, weight = 48.0, w_ha = 3.0269 THz, 1.9018e+01 rad/ps, delta = -0.1277, gamma = 0.0477, [0.72 0.32 0.12]
# i = 2673, q_irr = 399, band_irr = 6, weight = 48.0, w_ha = 3.0159 THz, 1.8949e+01 rad/ps, delta = -0.1262, gamma = 0.0468, [0.76 0.32 0.12]
# i = 2674, q_irr = 400, band_irr = 6, weight = 24.0, w_ha = 3.0209 THz, 1.8981e+01 rad/ps, delta = -0.1244, gamma = 0.0450, [0.8  0.32 0.12]
# i = 2675, q_irr = 401, band_irr = 6, weight = 24.0, w_ha = 2.8028 THz, 1.7611e+01 rad/ps, delta = -0.1083, gamma = 0.0352, [0.48 0.36 0.12]
# i = 2676, q_irr = 402, band_irr = 6, weight = 48.0, w_ha = 2.8314 THz, 1.7790e+01 rad/ps, delta = -0.1099, gamma = 0.0404, [0.52 0.36 0.12]
# i = 2677, q_irr = 403, band_irr = 6, weight = 48.0, w_ha = 2.9060 THz, 1.8259e+01 rad/ps, delta = -0.1116, gamma = 0.0412, [0.56 0.36 0.12]
# i = 2678, q_irr = 404, band_irr = 6, weight = 48.0, w_ha = 2.9683 THz, 1.8651e+01 rad/ps, delta = -0.1174, gamma = 0.0457, [0.6  0.36 0.12]
# i = 2679, q_irr = 405, band_irr = 6, weight = 48.0, w_ha = 3.0060 THz, 1.8887e+01 rad/ps, delta = -0.1184, gamma = 0.0477, [0.64 0.36 0.12]
# i = 2680, q_irr = 406, band_irr = 6, weight = 48.0, w_ha = 3.0257 THz, 1.9011e+01 rad/ps, delta = -0.1210, gamma = 0.0484, [0.68 0.36 0.12]
# i = 2681, q_irr = 407, band_irr = 6, weight = 48.0, w_ha = 3.0213 THz, 1.8983e+01 rad/ps, delta = -0.1220, gamma = 0.0481, [0.72 0.36 0.12]
# i = 2682, q_irr = 408, band_irr = 6, weight = 24.0, w_ha = 3.0130 THz, 1.8931e+01 rad/ps, delta = -0.1278, gamma = 0.0483, [0.76 0.36 0.12]
# i = 2683, q_irr = 409, band_irr = 6, weight = 24.0, w_ha = 2.7259 THz, 1.7127e+01 rad/ps, delta = -0.1016, gamma = 0.0362, [0.52 0.4  0.12]
# i = 2684, q_irr = 410, band_irr = 6, weight = 48.0, w_ha = 2.8122 THz, 1.7669e+01 rad/ps, delta = -0.1071, gamma = 0.0398, [0.56 0.4  0.12]
# i = 2685, q_irr = 411, band_irr = 6, weight = 48.0, w_ha = 2.8953 THz, 1.8191e+01 rad/ps, delta = -0.1109, gamma = 0.0444, [0.6  0.4  0.12]
# i = 2686, q_irr = 412, band_irr = 6, weight = 48.0, w_ha = 2.9576 THz, 1.8583e+01 rad/ps, delta = -0.1161, gamma = 0.0459, [0.64 0.4  0.12]
# i = 2687, q_irr = 413, band_irr = 6, weight = 48.0, w_ha = 2.9995 THz, 1.8847e+01 rad/ps, delta = -0.1174, gamma = 0.0458, [0.68 0.4  0.12]
# i = 2688, q_irr = 414, band_irr = 6, weight = 24.0, w_ha = 3.0165 THz, 1.8953e+01 rad/ps, delta = -0.1213, gamma = 0.0480, [0.72 0.4  0.12]
# i = 2689, q_irr = 415, band_irr = 6, weight = 24.0, w_ha = 2.7153 THz, 1.7061e+01 rad/ps, delta = -0.0993, gamma = 0.0375, [0.56 0.44 0.12]
# i = 2690, q_irr = 416, band_irr = 6, weight = 48.0, w_ha = 2.8097 THz, 1.7654e+01 rad/ps, delta = -0.1039, gamma = 0.0410, [0.6  0.44 0.12]
# i = 2691, q_irr = 417, band_irr = 6, weight = 48.0, w_ha = 2.8917 THz, 1.8169e+01 rad/ps, delta = -0.1100, gamma = 0.0412, [0.64 0.44 0.12]
# i = 2692, q_irr = 418, band_irr = 6, weight = 24.0, w_ha = 2.9541 THz, 1.8561e+01 rad/ps, delta = -0.1139, gamma = 0.0455, [0.68 0.44 0.12]
# i = 2693, q_irr = 419, band_irr = 6, weight = 24.0, w_ha = 2.7174 THz, 1.7074e+01 rad/ps, delta = -0.0977, gamma = 0.0370, [0.6  0.48 0.12]
# i = 2694, q_irr = 420, band_irr = 6, weight = 24.0, w_ha = 2.8098 THz, 1.7655e+01 rad/ps, delta = -0.1056, gamma = 0.0412, [0.64 0.48 0.12]
# i = 2695, q_irr = 421, band_irr = 6, weight = 24.0, w_ha = 2.9738 THz, 1.8685e+01 rad/ps, delta = -0.1238, gamma = 0.0433, [0.48 0.32 0.16]
# i = 2696, q_irr = 422, band_irr = 6, weight = 48.0, w_ha = 2.9779 THz, 1.8711e+01 rad/ps, delta = -0.1222, gamma = 0.0442, [0.52 0.32 0.16]
# i = 2697, q_irr = 423, band_irr = 6, weight = 48.0, w_ha = 2.9948 THz, 1.8817e+01 rad/ps, delta = -0.1222, gamma = 0.0457, [0.56 0.32 0.16]
# i = 2698, q_irr = 424, band_irr = 6, weight = 48.0, w_ha = 3.0112 THz, 1.8920e+01 rad/ps, delta = -0.1238, gamma = 0.0483, [0.6  0.32 0.16]
# i = 2699, q_irr = 425, band_irr = 6, weight = 48.0, w_ha = 3.0209 THz, 1.8981e+01 rad/ps, delta = -0.1251, gamma = 0.0509, [0.64 0.32 0.16]
# i = 2700, q_irr = 426, band_irr = 6, weight = 24.0, w_ha = 2.9050 THz, 1.8253e+01 rad/ps, delta = -0.1152, gamma = 0.0421, [0.52 0.36 0.16]
# i = 2701, q_irr = 427, band_irr = 6, weight = 48.0, w_ha = 2.9354 THz, 1.8444e+01 rad/ps, delta = -0.1147, gamma = 0.0464, [0.56 0.36 0.16]
# i = 2702, q_irr = 428, band_irr = 6, weight = 48.0, w_ha = 2.9639 THz, 1.8623e+01 rad/ps, delta = -0.1131, gamma = 0.0473, [0.6  0.36 0.16]
# i = 2703, q_irr = 429, band_irr = 6, weight = 48.0, w_ha = 2.9810 THz, 1.8730e+01 rad/ps, delta = -0.1163, gamma = 0.0502, [0.64 0.36 0.16]
# i = 2704, q_irr = 430, band_irr = 6, weight = 48.0, w_ha = 2.9887 THz, 1.8778e+01 rad/ps, delta = -0.1209, gamma = 0.0495, [0.68 0.36 0.16]
# i = 2705, q_irr = 431, band_irr = 6, weight = 48.0, w_ha = 2.9832 THz, 1.8744e+01 rad/ps, delta = -0.1222, gamma = 0.0495, [0.72 0.36 0.16]
# i = 2706, q_irr = 432, band_irr = 6, weight = 48.0, w_ha = 2.9754 THz, 1.8695e+01 rad/ps, delta = -0.1214, gamma = 0.0468, [0.76 0.36 0.16]
# i = 2707, q_irr = 433, band_irr = 6, weight = 24.0, w_ha = 2.9714 THz, 1.8670e+01 rad/ps, delta = -0.1221, gamma = 0.0461, [0.8  0.36 0.16]
# i = 2708, q_irr = 434, band_irr = 6, weight = 24.0, w_ha = 2.8739 THz, 1.8057e+01 rad/ps, delta = -0.1099, gamma = 0.0447, [0.56 0.4  0.16]
# i = 2709, q_irr = 435, band_irr = 6, weight = 48.0, w_ha = 2.9162 THz, 1.8323e+01 rad/ps, delta = -0.1096, gamma = 0.0447, [0.6  0.4  0.16]
# i = 2710, q_irr = 436, band_irr = 6, weight = 48.0, w_ha = 2.9460 THz, 1.8510e+01 rad/ps, delta = -0.1134, gamma = 0.0491, [0.64 0.4  0.16]
# i = 2711, q_irr = 437, band_irr = 6, weight = 48.0, w_ha = 2.9612 THz, 1.8606e+01 rad/ps, delta = -0.1165, gamma = 0.0482, [0.68 0.4  0.16]
# i = 2712, q_irr = 438, band_irr = 6, weight = 48.0, w_ha = 2.9678 THz, 1.8648e+01 rad/ps, delta = -0.1183, gamma = 0.0509, [0.72 0.4  0.16]
# i = 2713, q_irr = 439, band_irr = 6, weight = 24.0, w_ha = 2.9687 THz, 1.8653e+01 rad/ps, delta = -0.1202, gamma = 0.0489, [0.76 0.4  0.16]
# i = 2714, q_irr = 440, band_irr = 6, weight = 24.0, w_ha = 2.8647 THz, 1.7999e+01 rad/ps, delta = -0.1078, gamma = 0.0432, [0.6  0.44 0.16]
# i = 2715, q_irr = 441, band_irr = 6, weight = 48.0, w_ha = 2.9077 THz, 1.8269e+01 rad/ps, delta = -0.1100, gamma = 0.0466, [0.64 0.44 0.16]
# i = 2716, q_irr = 442, band_irr = 6, weight = 48.0, w_ha = 2.9370 THz, 1.8454e+01 rad/ps, delta = -0.1144, gamma = 0.0454, [0.68 0.44 0.16]
# i = 2717, q_irr = 443, band_irr = 6, weight = 24.0, w_ha = 2.9559 THz, 1.8573e+01 rad/ps, delta = -0.1163, gamma = 0.0504, [0.72 0.44 0.16]
# i = 2718, q_irr = 444, band_irr = 6, weight = 24.0, w_ha = 2.8622 THz, 1.7984e+01 rad/ps, delta = -0.1072, gamma = 0.0441, [0.64 0.48 0.16]
# i = 2719, q_irr = 445, band_irr = 6, weight = 24.0, w_ha = 2.9051 THz, 1.8253e+01 rad/ps, delta = -0.1102, gamma = 0.0457, [0.68 0.48 0.16]
# i = 2720, q_irr = 446, band_irr = 6, weight = 24.0, w_ha = 2.9403 THz, 1.8475e+01 rad/ps, delta = -0.1142, gamma = 0.0486, [0.6 0.4 0.2]
# i = 2721, q_irr = 447, band_irr = 6, weight = 48.0, w_ha = 2.9450 THz, 1.8504e+01 rad/ps, delta = -0.1169, gamma = 0.0470, [0.64 0.4  0.2 ]
# i = 2722, q_irr = 448, band_irr = 6, weight = 48.0, w_ha = 2.9478 THz, 1.8522e+01 rad/ps, delta = -0.1160, gamma = 0.0501, [0.68 0.4  0.2 ]
# i = 2723, q_irr = 449, band_irr = 6, weight = 24.0, w_ha = 2.9232 THz, 1.8367e+01 rad/ps, delta = -0.1110, gamma = 0.0490, [0.64 0.44 0.2 ]
# i = 2724, q_irr = 450, band_irr = 6, weight = 48.0, w_ha = 2.9263 THz, 1.8386e+01 rad/ps, delta = -0.1123, gamma = 0.0493, [0.68 0.44 0.2 ]
# i = 2725, q_irr = 451, band_irr = 6, weight = 48.0, w_ha = 2.9286 THz, 1.8401e+01 rad/ps, delta = -0.1145, gamma = 0.0494, [0.72 0.44 0.2 ]
# i = 2726, q_irr = 452, band_irr = 6, weight = 24.0, w_ha = 2.9335 THz, 1.8432e+01 rad/ps, delta = -0.1162, gamma = 0.0510, [0.76 0.44 0.2 ]
# i = 2727, q_irr = 453, band_irr = 6, weight = 24.0, w_ha = 2.9150 THz, 1.8315e+01 rad/ps, delta = -0.1094, gamma = 0.0466, [0.68 0.48 0.2 ]
# i = 2728, q_irr = 454, band_irr = 6, weight = 24.0, w_ha = 2.9197 THz, 1.8345e+01 rad/ps, delta = -0.1116, gamma = 0.0515, [0.72 0.48 0.2 ]
# i = 2729, q_irr = 455, band_irr = 6, weight = 24.0, w_ha = 2.9144 THz, 1.8311e+01 rad/ps, delta = -0.1139, gamma = 0.0503, [0.72 0.48 0.24]

# %% [markdown]
# ### Coefficent for LQPA

# %%
import numpy as np
import pandas as pd

# Settings
temps = ["T50", "T100", "T150", "T200", "T250", "T300"]

exclude_zero_freq = True

results_a = [] 

# Loop over temperatures
for target_temp in temps:

    if target_temp not in results:
        print(f"{target_temp} not found, skipping")
        continue

    data = results[target_temp]

    w_bare = data["w_bare"]
    d_interps = data["d_interps"]
    g_interps = data["g_interps"]
    Nq_irr = data["Nq"]

    omega_list = []
    gamma_list = []
    weight_list = []

    # collect data
    for i in range(len(w_bare)):

        w_qs = w_bare[i]

        if exclude_zero_freq and abs(w_qs) < 1e-5:
            continue

        q_irr_idx = i % Nq_irr

        W = degeneracies[q_irr_idx]

        gamma = abs(float(g_interps[i](w_qs)))

        omega_list.append(w_qs)
        gamma_list.append(gamma)
        weight_list.append(W)

    omega = np.array(omega_list)
    gamma = np.array(gamma_list)
    W = np.array(weight_list)

    # weighted linear fit: Γ = a ω
    numerator = np.sum(W * omega * gamma)
    denominator = np.sum(W * omega**2)

    a = numerator / denominator

    # optional diagnostics
    gamma_mean = np.average(gamma, weights=W)
    omega_mean = np.average(omega, weights=W)

    results_a.append({
        "T": target_temp,
        "a": a,
        "gamma_mean": gamma_mean,
        "omega_mean": omega_mean,
        "n_modes": len(omega)
    })

    print(f"{target_temp}: a = {a:.6f}")

# Save results
df = pd.DataFrame(results_a)

df.to_csv("gamma_linear_fit_vs_temperature.csv", index=False)

print("\nSaved to gamma_linear_fit_vs_temperature.csv")
# Out:
# T50: a = 0.004098
# T100: a = 0.007232
# T150: a = 0.009976
# T200: a = 0.012351
# T250: a = 0.014444
# T300: a = 0.016319
#
# Saved to gamma_linear_fit_vs_temperature.csv

# %% [markdown]
# ### Comparison of linewidths between LQPA and QPA at 300 K

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

gamma_vals = []
freq_vals = []

for i in range(len(w_bare)):
    w_qs = w_bare[i]

    if w_qs < 1e-5:
        continue

    gamma = abs(float(g_interps[i](w_qs)))

    freq_vals.append(w_qs)
    gamma_vals.append(gamma)

plt.figure(figsize=(8, 8))
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.scatter(freq_vals, gamma_vals, s=20, label="QPA", color='#2E8B57', alpha=0.7)
plt.gca().xaxis.set_major_locator(MultipleLocator(1.0))

plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().yaxis.set_minor_locator(AutoMinorLocator(2))
a = 0.016319
x_line = np.linspace(min(freq_vals), max(freq_vals), 100)
y_line = a * x_line

plt.plot(x_line, y_line, color='#0047AB', linestyle="--", linewidth=3.0, label="LQPA")
plt.xticks(fontsize=35)
plt.yticks([0, 0.2, 0.4], fontsize=35)
plt.xlim(0, 3.7)
plt.ylim(0, 0.4)
plt.xlabel("Frequency (THz)", fontsize=35)
plt.ylabel("$\gamma_{\mathbf{q},s}$ (THz)", fontsize=35)
plt.legend(loc='upper left', fontsize=25, edgecolor='black', fancybox=False, framealpha=1)

for spine in plt.gca().spines.values():
    spine.set_zorder(10)
    spine.set_linewidth(2.0)

plt.tick_params(axis='both', which='major', width=2.0, length=8, direction='in', zorder=11)
plt.tick_params(axis='both', which='minor', width=2.0, length=4, direction='in', zorder=11)
plt.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Harmonic heat capacity

# %%
import numpy as np
import pandas as pd
import os
import re

# --- Constants & Unit Conversions ---
KB = 8.617333262e-5        # Boltzmann constant in eV/K
THZ_TO_EV = 0.004135667    # Conversion factor (h * 1e12) to eV
EV_TO_J = 1.60218e-19      # 1 eV in Joules
NA = 6.02214e23            # Avogadro's number

target_dir = "."  
folders = [d for d in os.listdir(target_dir) if os.path.isdir(d) and d.startswith('T')]
folders.sort(key=lambda x: int(re.findall(r'\d+', x)[0]))

harmonic_summary = []
output_dir = "mode_resolved_harmonic"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for folder in folders:
    temp_val = float(re.findall(r'\d+', folder)[0])
    
    omega_path = os.path.join(folder, 'BTE.omega')
    if not os.path.exists(omega_path):
        continue

    # Load BTE.omega
    data_omega = np.loadtxt(omega_path)
    nq_irr = data_omega.shape[0]
    num_bands = data_omega.shape[1]
    
    # Frequency in THz
    w_bare = (data_omega.T).flatten() / (2 * np.pi)
    num_total_modes = len(w_bare)

    total_cv_harmonic = 0.0
    cv_list = []

    for i in range(num_total_modes):
        q_idx = i % nq_irr
        weight = degeneracies[q_idx]
        w_qs = w_bare[i]

        if w_qs <= 1e-6:
            mode_cv = 0.0
        else:
            x = (w_qs * THZ_TO_EV) / (KB * temp_val)
            if x < 50:
                exp_x = np.exp(x)
                mode_cv = KB * (x**2) * exp_x / (exp_x - 1)**2
            else:
                mode_cv = 0.0
        
        total_cv_harmonic += mode_cv * weight
        cv_list.append(mode_cv)

    # Unit Conversion for Total Cv
    cv_per_cell = total_cv_harmonic / Nq_total
    cv_j_mol = cv_per_cell * EV_TO_J * NA
    
    # --- Save Mode-Resolved Data ---
    df_mode_resolved = pd.DataFrame({
        'Mode_Index': np.arange(num_total_modes),
        'Frequency_THz': w_bare,
        'Cv_Contribution_eV_K': cv_list
    })
    
    csv_name = f"mode_resolved_harmonic_{folder}.csv"
    csv_path = os.path.join(output_dir, csv_name)
    df_mode_resolved.to_csv(csv_path, index=False)
    
    harmonic_summary.append({
        'Temperature': temp_val,
        'Folder': folder,
        'Cv_J_mol_K': cv_j_mol,
        'CSV_Path': csv_path
    })
    

df_summary = pd.DataFrame(harmonic_summary)
df_sorted = df_summary.sort_values('Temperature')
temperatures = df_sorted['Temperature'].values
cv_harmonic = df_sorted['Cv_J_mol_K'].values

print(df_summary[['Temperature', 'Cv_J_mol_K']])
# Out:
#    Temperature  Cv_J_mol_K
# 0         50.0   36.229877
# 1        100.0   45.674663
# 2        150.0   47.908048
# 3        200.0   48.740544
# 4        250.0   49.137386
# 5        300.0   49.357117

# %% [markdown]
# ## 1. Linear quasi-particle approximation (LQPA)

# %%
import numpy as np
import pandas as pd
import os
import re

# --- Constants & Setup ---
KB = 8.617333262e-5        
THZ_TO_EV = 0.004135667    
EV_TO_J = 1.60218e-19      
NA = 6.02214e23            

# Frequency shift is zero
DELTA_FIXED = 0.0          

try:
    df_fit = pd.read_csv("gamma_linear_fit_vs_temperature.csv")
    a_map = dict(zip(df_fit['T'], df_fit['a']))
except FileNotFoundError:
    raise FileNotFoundError("NO gamma_linear_fit_vs_temperature.csv")

output_dir = "norm_mode_resolved_linear"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

anharmonic_summary = []

for folder in folders:
    temp_match = re.search(r'T\d+', folder)
    if not temp_match: 
        continue
    temp_key = temp_match.group()
    
    if temp_key not in a_map:
        raise ValueError(f"CRITICAL ERROR: '{temp_key}'")
    
    a_val = a_map[temp_key]
    temp_val = float(re.findall(r'\d+', temp_key)[0])
    
    if folder in results:
        w_bare = results[folder]['w_bare']
        nq_irr = results[folder]['Nq']
    else:
        data_omega = np.loadtxt(os.path.join(folder, 'BTE.omega'))
        nq_irr = data_omega.shape[0]
        w_bare = (data_omega.T).flatten() / (2 * np.pi)

    num_total_modes = len(w_bare)
    total_cv_anharmonic = 0.0
    cv_list = []


    for i in range(num_total_modes):
        q_idx = i % nq_irr
        weight = degeneracies[q_idx]
        w_qs = w_bare[i]

        if w_qs < 1e-10:
            mode_cv_integral = 0.0
        else:
            gamma_dynamic = a_val * w_qs
            
            dw = gamma_dynamic / 10.0
            w_min = max(0.001, w_qs + DELTA_FIXED - 100 * gamma_dynamic)
            w_max = w_qs + DELTA_FIXED + 100 * gamma_dynamic
            local_grid = np.arange(w_min, w_max, dw)
            
            mode_integral = 0.0
            g_list = []
            
            for w in local_grid:
                denom = (w - w_qs - DELTA_FIXED)**2 + gamma_dynamic**2
                b_w = (1.0 / np.pi) * (gamma_dynamic / denom)
                g_w = (w / w_qs) * b_w
                g_list.append(g_w)
                
            g_array = np.array(g_list)
            mode_area = np.sum(g_array) * dw
            g_norm_array = g_array / mode_area

            for w, g_norm in zip(local_grid, g_norm_array):
                x = (w * THZ_TO_EV) / (KB * temp_val)
                if x < 50:
                    cv_kernel = KB * (x**2) * np.exp(x) / (np.exp(x) - 1.0)**2
                    mode_integral += g_norm * cv_kernel * dw
            
            mode_cv_integral = mode_integral

        total_cv_anharmonic += mode_cv_integral * weight
        cv_list.append(mode_cv_integral)

    cv_per_cell = total_cv_anharmonic / Nq_total
    cv_j_mol = cv_per_cell * EV_TO_J * NA
    
    df_mode = pd.DataFrame({
        'Mode_Index': np.arange(num_total_modes),
        'Frequency_THz': w_bare,
        'Cv_Anharmonic_eV_K': cv_list
    })
    
    csv_name = f"mode_resolved_anharmonic_{temp_key}.csv"
    df_mode.to_csv(os.path.join(output_dir, csv_name), index=False)
    
    anharmonic_summary.append({
        'Temperature': temp_val,
        'Cv_Anharmonic_J_mol_K': cv_j_mol
    })

df_anharmonic_summary = pd.DataFrame(anharmonic_summary).sort_values('Temperature')
df_anharmonic_sorted = df_anharmonic_summary.sort_values('Temperature')
temperatures = df_anharmonic_sorted['Temperature'].values
cv_anharmonic = df_anharmonic_sorted['Cv_Anharmonic_J_mol_K'].values
print(df_anharmonic_summary)
# Out:
#    Temperature  Cv_Anharmonic_J_mol_K
# 0         50.0              36.207966
# 1        100.0              45.640369
# 2        150.0              47.874288
# 3        200.0              48.709571
# 4        250.0              49.109326
# 5        300.0              49.331641

# %% [markdown]
# ## 2. Quasi-particle approximation (QPA)

# %%
import numpy as np
import pandas as pd
import os
import re

kB = 8.617333262e-5        
THz_to_eV = 0.004135667    
EV_TO_J = 1.60218e-19
NA = 6.02214e23

output_dir_qpa = "norm_mode_resolved_qpa"
if not os.path.exists(output_dir_qpa):
    os.makedirs(output_dir_qpa)

qpa_summary = []

for folder in folders:
    temp_val = float(re.findall(r'\d+', folder)[0])
    
    if folder not in results:
        print(f"Skipping {folder}: No pre-loaded results found.")
        continue
        
    w_bare = results[folder]['w_bare']
    d_interps = results[folder]['d_interps']
    g_interps = results[folder]['g_interps']
    Nq_irr = results[folder]['Nq']         

    num_total_modes = len(w_bare)
    total_cv_qpa = 0.0
    cv_list_qpa = []


    for i in range(num_total_modes):
        q_idx = i % Nq_irr
        weight = degeneracies[q_idx]
        w_qs = w_bare[i]

        if w_qs < 1e-10:
            mode_integral = 0.0
        else:
            d_val = d_interps[i](w_qs)
            g_val = abs(g_interps[i](w_qs))

            g_floor = max(g_val, 1e-4) 
            dw = g_floor / 10.0 
            w_min = max(0.001, w_qs + d_val - 100 * g_floor)
            w_max = w_qs + d_val + 100 * g_floor
            local_grid = np.arange(w_min, w_max, dw)
            
            mode_integral = 0.0
            g_list = []
            for w in local_grid:
                # b_w (Spectral function)
                denom = (w - w_qs - d_val)**2 + g_val**2
                b_w = (1.0 / np.pi) * (g_val / denom)
                # g_w (Spectral Density)
                g_w = (w / w_qs) * b_w
                g_list.append(g_w)
            g_array = np.array(g_list)

            mode_area = np.sum(g_array) * dw
            g_norm_array = g_array / mode_area
            
            for w, g_norm in zip(local_grid, g_norm_array):
                x = (w * THz_to_eV) / (kB * temp_val)
                if x < 50:
                    cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1.0)**2
                    mode_integral += g_norm * cv_kernel * dw
        
        total_cv_qpa += mode_integral * weight
        cv_list_qpa.append(mode_integral)

    cv_per_cell = total_cv_qpa / Nq_total
    cv_j_mol = cv_per_cell * EV_TO_J * NA
    
    df_mode = pd.DataFrame({
        'Mode_Index': np.arange(num_total_modes),
        'Frequency_THz': w_bare,
        'Cv_QPA_eV_K': cv_list_qpa
    })
    
    csv_name = f"mode_resolved_qpa_{folder}.csv"
    df_mode.to_csv(os.path.join(output_dir_qpa, csv_name), index=False)
    
    qpa_summary.append({
        'Temperature': temp_val,
        'Cv_QPA_J_mol_K': cv_j_mol
    })

df_qpa_summary = pd.DataFrame(qpa_summary).sort_values('Temperature')
df_qpa_sorted = df_qpa_summary.sort_values('Temperature')
temperatures = df_qpa_sorted['Temperature'].values
cv_qpa = df_qpa_sorted['Cv_QPA_J_mol_K'].values

print(df_qpa_summary)
# Out:
#    Temperature  Cv_QPA_J_mol_K
# 0         50.0       36.416817
# 1        100.0       45.758899
# 2        150.0       47.951345
# 3        200.0       48.764987
# 4        250.0       49.151776
# 5        300.0       49.365537

# %% [markdown]
# ## 3. Beyond quasi-particle approximation (BQPA)

# %%
import numpy as np
import pandas as pd
import os
import re

# --- Constants ---
kB = 8.617333262e-5        
THz_to_eV = 0.004135667    
EV_TO_J = 1.60218e-19
NA = 6.02214e23

output_dir_bqpa = "norm_mode_resolved_bqpa"
if not os.path.exists(output_dir_bqpa):
    os.makedirs(output_dir_bqpa)

bqpa_summary = []

for folder in folders:
    
    T = float(re.findall(r'\d+', folder)[0])
    
    if folder not in results:
        continue
    
    w_bare = results[folder]['w_bare']
    d_interps = results[folder]['d_interps']
    g_interps = results[folder]['g_interps']
    Nq_irr = results[folder]['Nq']

    num_total_modes = len(w_bare)
    
    spectrum_path = os.path.join(folder, 'BTE.selfeng3ph_spectrum')
    spec_data = np.genfromtxt(spectrum_path)

    total_cv_full = 0.0
    frequencies_bqpa = []
    cv_contributions_bqpa = []

    global_w_min = spec_data[:, 0].min()
    global_w_max = spec_data[:, 0].max()

    for i in range(num_total_modes):

        q_irr_idx = i % Nq_irr
        weight = degeneracies[q_irr_idx]

        w_qs = w_bare[i]

        if w_qs < 1e-10:
            continue

        g_ref = abs(g_interps[i](w_qs))
        g_floor = max(g_ref, 1e-4)

        dw = g_floor / 10.0

        center = w_qs + d_interps[i](w_qs)

        w_min = max(global_w_min, center - 100 * g_floor)

        w_max = min(global_w_max, center + 100 * g_floor)

        w_grid = np.arange(w_min, w_max, dw)

        d_ws = d_interps[i](w_grid)
        g_ws = np.abs(g_interps[i](w_grid))

        g_ws_safe = np.where(g_ws < 1e-8, 1e-8, g_ws)

        denoms = (w_grid - w_qs - d_ws)**2 + g_ws_safe**2

        b_ws = (1 / np.pi) * (g_ws_safe / denoms)

        g_w = (w_grid / w_qs) * b_ws

        mode_area = np.trapz(g_w, w_grid)

        if mode_area < 1e-14:
            continue

        g_w_norm = g_w / mode_area

        x = (w_grid * THz_to_eV) / (kB * T)

        cv_kernels = np.zeros_like(x)

        m_zero = (x < 1e-7)
        m_finite = (x >= 1e-7) & (x < 50)

        cv_kernels[m_zero] = kB

        cv_kernels[m_finite] = (kB * (x[m_finite]**2 * np.exp(x[m_finite])) / (np.exp(x[m_finite]) - 1)**2)

        mode_integral = np.trapz(g_w_norm * cv_kernels, w_grid)
        total_cv_weighted = mode_integral * weight
        total_cv_full += total_cv_weighted

        frequencies_bqpa.append(w_qs)
        cv_contributions_bqpa.append(mode_integral)

    cv_per_cell = total_cv_full / Nq_total

    cv_j_mol = cv_per_cell * EV_TO_J * NA

    df_mode = pd.DataFrame({
        'Frequency_THz': frequencies_bqpa,
        'Cv_Contribution_eV_K': cv_contributions_bqpa
    })

    csv_name = f"mode_resolved_bqpa_{folder}.csv"

    df_mode.to_csv(os.path.join(output_dir_bqpa,
                                csv_name),
                   index=False)

    bqpa_summary.append({
        'Temperature': T,
        'Cv_J_mol_K': cv_j_mol
    })


df_bqpa_summary = pd.DataFrame(bqpa_summary).sort_values('Temperature')
df_bqpa_sorted = df_bqpa_summary.sort_values('Temperature')
temperatures = df_bqpa_sorted['Temperature'].values
cv_bqpa = df_bqpa_sorted['Cv_J_mol_K'].values

print(df_bqpa_summary)
# Out:
#    Temperature  Cv_J_mol_K
# 0         50.0   36.346448
# 1        100.0   45.685008
# 2        150.0   47.894479
# 3        200.0   48.722212
# 4        250.0   49.118762
# 5        300.0   49.339952

# %% [markdown]
# ## Plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
from matplotlib.ticker import AutoMinorLocator, MultipleLocator

kB = 8.617333262e-5
THz_to_eV = 0.004135667
Unit_conv = 1.60218e-19 * 6.02214e23  # eV/K -> J/mol·K
T = 300
target_temp = "T300"

dirs = {
    "har": "mode_resolved_harmonic",
    "anh": "norm_mode_resolved_linear",
    "qpa": "norm_mode_resolved_qpa",
    "bqpa": "norm_mode_resolved_bqpa"
}

plt.figure(figsize=(10, 8))

try:
    # 1. Harmonic Reference 
    har_path = os.path.join(dirs["har"], f"mode_resolved_harmonic_{target_temp}.csv")
    if os.path.exists(har_path):
        df_har = pd.read_csv(har_path)
        w_ref = np.linspace(df_har['Frequency_THz'].min(), df_har['Frequency_THz'].max(), 500)
        x_ref = (w_ref * THz_to_eV) / (kB * T)
        cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2
        plt.plot(w_ref, cv_harmonic * Unit_conv, 
                 color='SlateGrey', linestyle='--', linewidth=5, label='HA', zorder=1)

    # LQPA
    anh_path = os.path.join(dirs["anh"], f"mode_resolved_anharmonic_{target_temp}.csv")
    if os.path.exists(anh_path):
        df_anh = pd.read_csv(anh_path)
        plt.scatter(df_anh['Frequency_THz'], df_anh['Cv_Anharmonic_eV_K'] * Unit_conv, 
                    alpha=0.7, s=30, color='#0047AB', label='LQPA', zorder=2)

    # QPA
    qpa_path = os.path.join(dirs["qpa"], f"mode_resolved_qpa_{target_temp}.csv")
    if os.path.exists(qpa_path):
        df_qpa = pd.read_csv(qpa_path)
        plt.scatter(df_qpa['Frequency_THz'], df_qpa['Cv_QPA_eV_K'] * Unit_conv, 
                    alpha=0.7, s=30, color='#2E8B57', label='QPA', zorder=3)

    # BQPA
    bqpa_path = os.path.join(dirs["bqpa"], f"mode_resolved_bqpa_{target_temp}.csv")
    if os.path.exists(bqpa_path):
        df_bqpa = pd.read_csv(bqpa_path)
        plt.scatter(df_bqpa['Frequency_THz'], df_bqpa['Cv_Contribution_eV_K'] * Unit_conv, 
                    alpha=0.7, s=30, color='#DAA520', label='BQPA', zorder=4)

except Exception as e:
    print(f"error: {e}")
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'stix'
plt.xlabel('Frequency (THz)', fontsize=35)
plt.ylabel('$C_{v}^{\mathbf{q},s}$ (J/mol$\cdot$K)', fontsize=35)
plt.xticks(fontsize=35)
plt.yticks([8, 8.2, 8.4], fontsize=35)

plt.legend(loc='best', fontsize=25, edgecolor='black', fancybox=False)

plt.xlim(0, 3.7) 
plt.ylim(7.8, 8.4)

plt.grid(False)
plt.tick_params(axis='both', which='major', width=2.0, length=8, direction='in')
plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().yaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().xaxis.set_major_locator(MultipleLocator(1.0))
plt.tick_params(axis='both', which='minor', width=2.0, length=4, direction='in')

for spine in plt.gca().spines.values():
    spine.set_linewidth(2.0)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_74427/2172410972.py:29: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import AutoMinorLocator
import re

target_folder = 'T300' 

if target_folder not in results:
    found = False
    for f in results.keys():
        if '300' in f:
            target_folder = f
            found = True
            break
    if not found:
        raise ValueError(f"CRITICAL ERROR")

w_bare = results[target_folder]['w_bare']
d_interps = results[target_folder]['d_interps']
g_interps = results[target_folder]['g_interps']
nq_irr = results[target_folder]['Nq']
temp_val = float(re.findall(r'\d+', target_folder)[0])

if target_folder in a_map:
    a_val = a_map[target_folder]
elif 300 in a_map:
    a_val = a_map[300]
else:
    a_val = list(a_map.values())[0] 

num_total_modes = len(w_bare)
Nq_total = np.sum(degeneracies)

# --- 1. Setup Global Energy Axis ---
w_max_limit = np.max(w_bare) * 1.4
energy_axis = np.linspace(0, w_max_limit, 1000)

# --- 2. DOS Calculation Containers ---
dos_harmonic = np.zeros_like(energy_axis)
dos_method1 = np.zeros_like(energy_axis)  
dos_method2 = np.zeros_like(energy_axis)  
dos_method3 = np.zeros_like(energy_axis)  

# --- 3. Compute Each Method ---
# Harmonic DOS (Gaussian Broadening)
sigma = 0.05
for i, w_qs in enumerate(w_bare):
    q_irr_idx = i % nq_irr
    weight = degeneracies[q_irr_idx]
    diff = energy_axis - w_qs
    dos_harmonic += weight * np.exp(-0.5 * (diff / sigma)**2) / (sigma * np.sqrt(2 * np.pi))


# LQPA
for i, w_qs in enumerate(w_bare):
    q_irr_idx = i % nq_irr
    weight = degeneracies[q_irr_idx]
    if w_qs < 1e-10: continue
        
    gamma_dynamic = a_val * w_qs
    dw_local = gamma_dynamic / 10.0
    w_min = max(0.001, w_qs + DELTA_FIXED - 100 * gamma_dynamic)
    w_max = w_qs + DELTA_FIXED + 100 * gamma_dynamic
    local_grid = np.arange(w_min, w_max, dw_local)
    
    denom_local = (local_grid - w_qs - DELTA_FIXED)**2 + gamma_dynamic**2
    b_w_local = (1.0 / np.pi) * (gamma_dynamic / denom_local)
    g_w_local = (local_grid / w_qs) * b_w_local
    mode_area = np.sum(g_w_local) * dw_local
    
    denom_global = (energy_axis - w_qs - DELTA_FIXED)**2 + gamma_dynamic**2
    b_w_global = (1.0 / np.pi) * (gamma_dynamic / denom_global)
    g_w_global = (energy_axis / w_qs) * b_w_global
    
    dos_method1 += weight * (g_w_global / mode_area)


# QPA
for i, w_qs in enumerate(w_bare):
    q_irr_idx = i % nq_irr
    weight = degeneracies[q_irr_idx]
    if w_qs < 1e-10: continue

    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    g_floor = max(g_val, 1e-4) 
    
    dw_local = g_floor / 10.0 
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw_local)
    
    denom_local = (local_grid - w_qs - d_val)**2 + g_val**2
    b_w_local = (1.0 / np.pi) * (g_val / denom_local)
    g_w_local = (local_grid / w_qs) * b_w_local
    mode_area = np.sum(g_w_local) * dw_local
    
    denom_global = (energy_axis - w_qs - d_val)**2 + g_val**2
    b_w_global = (1.0 / np.pi) * (g_val / denom_global)
    g_w_global = (energy_axis / w_qs) * b_w_global
    
    dos_method2 += weight * (g_w_global / mode_area)

# BQPA
spectrum_path = os.path.join(target_folder, 'BTE.selfeng3ph_spectrum')
if os.path.exists(spectrum_path):
    spec_data = np.genfromtxt(spectrum_path)
    global_w_min = spec_data[:, 0].min()
    global_w_max = spec_data[:, 0].max()
else:
    global_w_min, global_w_max = 0.0, w_max_limit

for i, w_qs in enumerate(w_bare):
    q_irr_idx = i % nq_irr
    weight = degeneracies[q_irr_idx]
    if w_qs < 1e-10: continue

    g_ref = abs(g_interps[i](w_qs))
    g_floor = max(g_ref, 1e-4)
    dw_local = g_floor / 10.0
    center = w_qs + d_interps[i](w_qs)
    
    w_min = max(global_w_min, center - 100 * g_floor)
    w_max = min(global_w_max, center + 100 * g_floor)
    w_grid_local = np.arange(w_min, w_max, dw_local)
    

    d_ws_local = d_interps[i](w_grid_local)
    g_ws_local = np.abs(g_interps[i](w_grid_local))
    g_ws_safe_local = np.where(g_ws_local < 1e-8, 1e-8, g_ws_local)
    
    denom_local = (w_grid_local - w_qs - d_ws_local)**2 + g_ws_safe_local**2
    b_ws_local = (1.0 / np.pi) * (g_ws_safe_local / denom_local)
    g_w_local = (w_grid_local / w_qs) * b_ws_local
    
    mode_area = np.trapz(g_w_local, w_grid_local)
    if mode_area < 1e-14: continue
    d_ws_global = d_interps[i](energy_axis)
    g_ws_global = np.abs(g_interps[i](energy_axis))
    g_ws_safe_global = np.where(g_ws_global < 1e-8, 1e-8, g_ws_global)
    
    denom_global = (energy_axis - w_qs - d_ws_global)**2 + g_ws_safe_global**2
    b_ws_global = (1.0 / np.pi) * (g_ws_safe_global / denom_global)
    g_w_global = (energy_axis / w_qs) * b_ws_global
    dos_method3 += weight * (g_w_global / mode_area)

dos_harmonic /= Nq_total
dos_method1 /= Nq_total
dos_method2 /= Nq_total
dos_method3 /= Nq_total

plt.figure(figsize=(10, 8))
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'stix'

plt.plot(energy_axis, dos_harmonic, color='#666666', linestyle='--', linewidth=2.5, label='HA', zorder=1)
plt.plot(energy_axis, dos_method1, color='#0047AB', linestyle='-', linewidth=2.5, label='LQPA', zorder=2)
plt.fill_between(energy_axis, 0, dos_method1, color='#0047AB', alpha=0.05)
plt.plot(energy_axis, dos_method2, color='#2E8B57', linestyle='-', linewidth=2.5, label='QPA', zorder=3)
plt.fill_between(energy_axis, 0, dos_method2, color='#2E8B57', alpha=0.05)
plt.plot(energy_axis, dos_method3, color='#DAA520', linestyle='-', linewidth=2.5, label='BQPA', zorder=4)
plt.fill_between(energy_axis, 0, dos_method3, color='#DAA520', alpha=0.1)

plt.xlabel('Frequency (THz)', fontsize=35)
plt.ylabel('Density of States (THz$^{-1}$)', fontsize=35)
plt.xticks([0, 1, 2, 3, 4,], fontsize=35)
plt.yticks([1, 2, 3, 4, 5], fontsize=35)
plt.xlim(0, 4)
plt.ylim(0, 5)

plt.legend(loc='upper right', fontsize=25, edgecolor='black', fancybox=False, ncol=2)
plt.grid(False)

plt.tick_params(axis='both', which='major', width=2.0, length=8, direction='in')
plt.minorticks_on()
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
plt.gca().yaxis.set_minor_locator(AutoMinorLocator(2))
plt.tick_params(axis='both', which='minor', width=2.0, length=4, direction='in')

for spine in plt.gca().spines.values():
    spine.set_linewidth(2.0)
    spine.set_zorder(10)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, AutoMinorLocator

if 'DELTA_FIXED' not in globals():
    DELTA_FIXED = 0.0

# --- 1. Target q-point selection ---
target_q = np.array([0.2, 0, 0])
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)

plt.figure(figsize=(10, 8))

color_m1 = '#0047AB' 
color_m2 = '#2E8B57' 
color_m3 = '#DAA520' 

band_idx = 0
for i in range(len(w_bare)):
    if (i % nq_irr) == target_q_idx:
        w_qs = w_bare[i]
        if w_qs < 1e-10: continue

        # Method 1: LQPA
        gamma_dynamic = a_val * w_qs
        dw_local = gamma_dynamic / 10.0
        w_min = max(0.001, w_qs + DELTA_FIXED - 100 * gamma_dynamic)
        w_max = w_qs + DELTA_FIXED + 100 * gamma_dynamic
        local_grid = np.arange(w_min, w_max, dw_local)
        
        denom_local = (local_grid - w_qs - DELTA_FIXED)**2 + gamma_dynamic**2
        b_w_local = (1.0 / np.pi) * (gamma_dynamic / denom_local)
        g_w_local = (local_grid / w_qs) * b_w_local
        mode_area_m1 = np.sum(g_w_local) * dw_local
        
        denom_global = (energy_axis - w_qs - DELTA_FIXED)**2 + gamma_dynamic**2
        b_w_global = (1.0 / np.pi) * (gamma_dynamic / denom_global)
        g_w_global = (energy_axis / w_qs) * b_w_global
        spectral_m1 = (1.0 / (2.0 * np.pi)) * g_w_global / mode_area_m1
        
        plt.plot(energy_axis, spectral_m1, color=color_m1, linewidth=2.5, zorder=1, alpha=0.7,
                 label='LQPA' if band_idx == 0 else "")

        # Method 2: QPA
        d_val = d_interps[i](w_qs)
        g_val = abs(g_interps[i](w_qs))
        g_floor = max(g_val, 1e-4) 
        
        dw_local = g_floor / 10.0 
        w_min = max(0.001, w_qs + d_val - 100 * g_floor)
        w_max = w_qs + d_val + 100 * g_floor
        local_grid = np.arange(w_min, w_max, dw_local)
        
        denom_local = (local_grid - w_qs - d_val)**2 + g_val**2
        b_w_local = (1.0 / np.pi) * (g_val / denom_local)
        g_w_local = (local_grid / w_qs) * b_w_local
        mode_area_m2 = np.sum(g_w_local) * dw_local
        
        denom_global = (energy_axis - w_qs - d_val)**2 + g_val**2
        b_w_global = (1.0 / np.pi) * (g_val / denom_global)
        g_w_global = (energy_axis / w_qs) * b_w_global
        spectral_m2 = (1.0 / (2.0 * np.pi)) * g_w_global / mode_area_m2
        
        plt.plot(energy_axis, spectral_m2, color=color_m2, linewidth=2.5, zorder=2, alpha=0.7,
                 label='QPA' if band_idx == 0 else "")

        # Method 3: BQPA
        center = w_qs + d_interps[i](w_qs)
        w_min_bte = center - 100 * g_floor
        w_max_bte = center + 100 * g_floor
        if 'global_w_min' in locals() or 'global_w_min' in globals():
            w_min_bte = max(global_w_min, w_min_bte)
            w_max_bte = min(global_w_max, w_max_bte)
        w_grid_local = np.arange(w_min_bte, w_max_bte, dw_local)
        
        d_ws_local = d_interps[i](w_grid_local)
        g_ws_local = np.abs(g_interps[i](w_grid_local))
        g_ws_safe_local = np.where(g_ws_local < 1e-8, 1e-8, g_ws_local)
        
        denom_local = (w_grid_local - w_qs - d_ws_local)**2 + g_ws_safe_local**2
        b_ws_local = (1.0 / np.pi) * (g_ws_safe_local / denom_local)
        g_w_local = (w_grid_local / w_qs) * b_ws_local
        mode_area_m3 = np.trapz(g_w_local, w_grid_local)
        
        if mode_area_m3 > 1e-14:
            d_ws_global = d_interps[i](energy_axis)
            g_ws_global = np.abs(g_interps[i](energy_axis))
            g_ws_safe_global = np.where(g_ws_global < 1e-8, 1e-8, g_ws_global)
            
            denom_global = (energy_axis - w_qs - d_ws_global)**2 + g_ws_safe_global**2
            b_ws_global = (1.0 / np.pi) * (g_ws_safe_global / denom_global)
            g_w_global = (energy_axis / w_qs) * b_ws_global
            spectral_m3 = (1.0 / (2.0 * np.pi)) * g_w_global / mode_area_m3
            
            plt.plot(energy_axis, spectral_m3, color=color_m3, linewidth=2.5, zorder=3, alpha=0.7,
                     label='BQPA' if band_idx == 0 else "")
        
        band_idx += 1

plt.xlabel('Frequency (THz)', fontsize=35)
plt.ylabel('Spectral density', fontsize=35)

plt.xlim(0, 4.0) 
plt.ylim(0, 1.0)

plt.gca().xaxis.set_major_locator(MultipleLocator(1.0))
plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))

plt.xticks(fontsize=35)
plt.yticks([0.5, 1.0], fontsize=35)

plt.legend(loc='upper right', fontsize=25, edgecolor='black', fancybox=False, framealpha=1)

for spine in plt.gca().spines.values():
    spine.set_zorder(10)
    spine.set_linewidth(2.0)

plt.tick_params(axis='both', which='major', width=2.0, length=8, direction='in', zorder=11)
plt.tick_params(axis='both', which='minor', width=2.0, length=4, direction='in', zorder=11)
plt.grid(False)

plt.tight_layout()
plt.show()
