# %%
from ase.io import read
import numpy as np

# 1. Load the POSCAR
# This gives you an Atoms object which knows positions, masses, and cell
atoms = read('POSCAR')
n_atoms = len(atoms)
masses = atoms.get_masses()  # in amu
cell = atoms.get_cell()      # lattice vectors
positions = atoms.get_positions() # Cartesian coordinates
sc_dims = np.array([4, 4, 4])

print(f"Loaded {n_atoms} atoms.")
print(f"{atoms}")
# Out:
# Loaded 2 atoms.
# Atoms(symbols='AgCl', pbc=True, cell=[[0.0, 2.7221417586264813, 2.7221417586264813], [2.7221417586264813, 0.0, 2.7221417586264813], [2.7221417586264813, 2.7221417586264813, 0.0]])

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.omega (Assumed Band-major after flattening) ---
# data_omega shape: (Nq_irr, num_bands) -> e.g., (455, 6)
data_omega = np.loadtxt('BTE.omega') 
Nq = data_omega.shape[0]
num_bands = data_omega.shape[1]

# Replicate your current logic: Band 1 (all q), then Band 2 (all q)...
# Dividing by 2*pi to convert from rad/ps to THz
w_bare = (data_omega.T).flatten() / (2 * np.pi)
num_total_modes = len(w_bare)

print(f"Total modes: {num_total_modes} from BTE.omega")
print(f"Detected Nq (q-points): {Nq}, Bands: {num_bands}")

# --- 2. Load and Parse BTE.selfeng3ph_spectrum (q-major order) ---
# Each block in this file follows: q1_b1, q1_b2... q1_b6, q2_b1...
spec_data = np.genfromtxt('BTE.selfeng3ph_spectrum')

# Calculate the number of frequency grid points per mode block
pts_per_mode = len(spec_data) // num_total_modes

# Initialize lists to store interpolation functions in Band-major order
d_interps = [None] * num_total_modes
g_interps = [None] * num_total_modes

print(f"Parsing blocks and re-mapping q-major file to Band-major w_bare...")

for i in range(num_total_modes):
    # 'i' represents the sequence in the FILE (q-major)
    # q_idx changes slowly, b_idx changes fast
    q_idx = i // num_bands
    b_idx = i % num_bands
    
    # Calculate the 'target_mode_idx' to match the Band-major 'w_bare'
    # In Band-major: b_idx changes slowly, q_idx changes fast
    target_mode_idx = b_idx * Nq + q_idx
    
    # Extract the data block for the current mode
    start = i * pts_per_mode
    end = (i + 1) * pts_per_mode
    mode_block = spec_data[start:end]
    
    w_grid = mode_block[:, 0] # Frequency grid (THz)
    # Convert Delta and Gamma from rad/ps to THz
    d_grid = mode_block[:, 1] / (2 * np.pi) 
    g_grid = mode_block[:, 2] / (2 * np.pi)
    
    # Map the interpolation function to the correct index for w_bare[target_mode_idx]
    d_interps[target_mode_idx] = interp1d(w_grid, d_grid, kind='linear', fill_value="extrapolate")
    g_interps[target_mode_idx] = interp1d(w_grid, g_grid, kind='linear', fill_value="extrapolate")

print("Successfully loaded and re-ordered all interpolation blocks!")
# Out:
# Total modes: 2730 from BTE.omega
# Detected Nq (q-points): 455, Bands: 6
# Parsing blocks and re-mapping q-major file to Band-major w_bare...
# Successfully loaded and re-ordered all interpolation blocks!

# %%
# --- 3. Verification Test ---
# With the transpose, index 'i' now follows (Band_index * Nq + q_index).
# Band 2, first q-point (q=1) is located at index i = 1 * Nq + 0 = Nq.
band = 5
q = 1

band_idx = band - 1
q_idx = q - 1

test_idx = band_idx * Nq + q_idx
if test_idx < num_total_modes:
    test_w = w_bare[test_idx]
    print(f"\nVerification at Index {test_idx} (Band={band}, q={q}):")
    print(f"Bare Frequency (converted to THz): {test_w:.4f}")
    print(f"Delta at bare freq: {d_interps[test_idx](test_w)*(2*np.pi):.6f}")
    print(f"Gamma at bare freq: {g_interps[test_idx](test_w)*(2*np.pi):.6f}")
# Out:
# Verification at Index 1820 (Band=5, q=1):
# Bare Frequency (converted to THz): 3.8168
# Delta at bare freq: -3.310491
# Gamma at bare freq: 2.333829

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.qpoints to get degeneracies ---
q_data = np.genfromtxt('BTE.qpoints')
# Column 2 (index 2) is the degeneracy (multiplicity)
degeneracies = q_data[:, 2] 
Nq_irr = len(degeneracies) # the number of qpoints in irreducible wedge
Nq_total = np.sum(degeneracies) # the number of qpoints in whole BZ
q_coords = q_data[:, 3:6]

print(f"Number of irreducible q-points: {Nq_irr}")
print(f"Total q-points in full BZ (Sum of weights): {Nq_total}")
# Out:
# Number of irreducible q-points: 455
# Total q-points in full BZ (Sum of weights): 15625.0

# %%
for i in range(num_total_modes):
    w_qs = w_bare[i]
    #if w_qs < 1e-5: 
    #    continue

    q_irr_idx = i % Nq_irr
    band_irr_idx = i // Nq_irr
    weight = degeneracies[q_irr_idx]
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    q_coords_test = q_coords[q_irr_idx]

    print(f"i = {i}, q_irr = {q_irr_idx+1}, band_irr = {band_irr_idx+1}, weight = {weight}, w_ha = {w_qs:.4f} THz, {w_qs*(2 * np.pi):.4e} rad/ps, delta = {d_val:.4f}, gamma = {g_val:.4f}, {q_coords_test}")

# i: (b1,q1), (b1, q2), (b1, q3), ...
# Out:
# i = 0, q_irr = 1, band_irr = 1, weight = 1.0, w_ha = 0.0000 THz, 0.0000e+00 rad/ps, delta = 0.0000, gamma = 0.0000, [0. 0. 0.]
# i = 1, q_irr = 2, band_irr = 1, weight = 8.0, w_ha = 0.2211 THz, 1.3894e+00 rad/ps, delta = -0.0226, gamma = 0.0022, [0.04 0.   0.  ]
# i = 2, q_irr = 3, band_irr = 1, weight = 8.0, w_ha = 0.4367 THz, 2.7437e+00 rad/ps, delta = -0.0460, gamma = 0.0077, [0.08 0.   0.  ]
# i = 3, q_irr = 4, band_irr = 1, weight = 8.0, w_ha = 0.6415 THz, 4.0308e+00 rad/ps, delta = -0.0694, gamma = 0.0149, [0.12 0.   0.  ]
# i = 4, q_irr = 5, band_irr = 1, weight = 8.0, w_ha = 0.8317 THz, 5.2257e+00 rad/ps, delta = -0.0936, gamma = 0.0248, [0.16 0.   0.  ]
# i = 5, q_irr = 6, band_irr = 1, weight = 8.0, w_ha = 1.0050 THz, 6.3145e+00 rad/ps, delta = -0.1223, gamma = 0.0358, [0.2 0.  0. ]
# i = 6, q_irr = 7, band_irr = 1, weight = 8.0, w_ha = 1.1618 THz, 7.3000e+00 rad/ps, delta = -0.1526, gamma = 0.0531, [0.24 0.   0.  ]
# i = 7, q_irr = 8, band_irr = 1, weight = 8.0, w_ha = 1.3059 THz, 8.2051e+00 rad/ps, delta = -0.1859, gamma = 0.0737, [0.28 0.   0.  ]
# i = 8, q_irr = 9, band_irr = 1, weight = 8.0, w_ha = 1.4436 THz, 9.0706e+00 rad/ps, delta = -0.2218, gamma = 0.0907, [0.32 0.   0.  ]
# i = 9, q_irr = 10, band_irr = 1, weight = 8.0, w_ha = 1.5829 THz, 9.9457e+00 rad/ps, delta = -0.2586, gamma = 0.1136, [0.36 0.   0.  ]
# i = 10, q_irr = 11, band_irr = 1, weight = 8.0, w_ha = 1.7303 THz, 1.0872e+01 rad/ps, delta = -0.2865, gamma = 0.1363, [0.4 0.  0. ]
# i = 11, q_irr = 12, band_irr = 1, weight = 8.0, w_ha = 1.8889 THz, 1.1868e+01 rad/ps, delta = -0.2966, gamma = 0.1656, [0.44 0.   0.  ]
# i = 12, q_irr = 13, band_irr = 1, weight = 8.0, w_ha = 2.0528 THz, 1.2898e+01 rad/ps, delta = -0.2747, gamma = 0.1647, [0.48 0.   0.  ]
# i = 13, q_irr = 14, band_irr = 1, weight = 6.0, w_ha = 0.1867 THz, 1.1729e+00 rad/ps, delta = -0.0123, gamma = 0.0013, [0.04 0.04 0.  ]
# i = 14, q_irr = 15, band_irr = 1, weight = 24.0, w_ha = 0.3377 THz, 2.1216e+00 rad/ps, delta = -0.0277, gamma = 0.0041, [0.08 0.04 0.  ]
# i = 15, q_irr = 16, band_irr = 1, weight = 24.0, w_ha = 0.5260 THz, 3.3047e+00 rad/ps, delta = -0.0485, gamma = 0.0097, [0.12 0.04 0.  ]
# i = 16, q_irr = 17, band_irr = 1, weight = 24.0, w_ha = 0.7108 THz, 4.4659e+00 rad/ps, delta = -0.0707, gamma = 0.0171, [0.16 0.04 0.  ]
# i = 17, q_irr = 18, band_irr = 1, weight = 24.0, w_ha = 0.8821 THz, 5.5423e+00 rad/ps, delta = -0.0955, gamma = 0.0259, [0.2  0.04 0.  ]
# i = 18, q_irr = 19, band_irr = 1, weight = 24.0, w_ha = 1.0367 THz, 6.5136e+00 rad/ps, delta = -0.1257, gamma = 0.0392, [0.24 0.04 0.  ]
# i = 19, q_irr = 20, band_irr = 1, weight = 24.0, w_ha = 1.1754 THz, 7.3853e+00 rad/ps, delta = -0.1583, gamma = 0.0552, [0.28 0.04 0.  ]
# i = 20, q_irr = 21, band_irr = 1, weight = 24.0, w_ha = 1.3028 THz, 8.1857e+00 rad/ps, delta = -0.1899, gamma = 0.0732, [0.32 0.04 0.  ]
# i = 21, q_irr = 22, band_irr = 1, weight = 24.0, w_ha = 1.4260 THz, 8.9599e+00 rad/ps, delta = -0.2268, gamma = 0.0932, [0.36 0.04 0.  ]
# i = 22, q_irr = 23, band_irr = 1, weight = 24.0, w_ha = 1.5531 THz, 9.7585e+00 rad/ps, delta = -0.2594, gamma = 0.1086, [0.4  0.04 0.  ]
# i = 23, q_irr = 24, band_irr = 1, weight = 24.0, w_ha = 1.6909 THz, 1.0624e+01 rad/ps, delta = -0.2867, gamma = 0.1463, [0.44 0.04 0.  ]
# i = 24, q_irr = 25, band_irr = 1, weight = 24.0, w_ha = 1.8431 THz, 1.1581e+01 rad/ps, delta = -0.2990, gamma = 0.1684, [0.48 0.04 0.  ]
# i = 25, q_irr = 26, band_irr = 1, weight = 24.0, w_ha = 1.9604 THz, 1.2318e+01 rad/ps, delta = -0.2705, gamma = 0.1503, [0.52 0.04 0.  ]
# i = 26, q_irr = 27, band_irr = 1, weight = 24.0, w_ha = 1.7997 THz, 1.1308e+01 rad/ps, delta = -0.2711, gamma = 0.1461, [0.56 0.04 0.  ]
# i = 27, q_irr = 28, band_irr = 1, weight = 24.0, w_ha = 1.6512 THz, 1.0375e+01 rad/ps, delta = -0.2570, gamma = 0.1259, [0.6  0.04 0.  ]
# i = 28, q_irr = 29, band_irr = 1, weight = 24.0, w_ha = 1.5154 THz, 9.5214e+00 rad/ps, delta = -0.2287, gamma = 0.0989, [0.64 0.04 0.  ]
# i = 29, q_irr = 30, band_irr = 1, weight = 24.0, w_ha = 1.3875 THz, 8.7178e+00 rad/ps, delta = -0.1974, gamma = 0.0817, [0.68 0.04 0.  ]
# i = 30, q_irr = 31, band_irr = 1, weight = 24.0, w_ha = 1.2601 THz, 7.9173e+00 rad/ps, delta = -0.1652, gamma = 0.0606, [0.72 0.04 0.  ]
# i = 31, q_irr = 32, band_irr = 1, weight = 24.0, w_ha = 1.1252 THz, 7.0699e+00 rad/ps, delta = -0.1347, gamma = 0.0442, [0.76 0.04 0.  ]
# i = 32, q_irr = 33, band_irr = 1, weight = 24.0, w_ha = 0.9765 THz, 6.1357e+00 rad/ps, delta = -0.1055, gamma = 0.0309, [0.8  0.04 0.  ]
# i = 33, q_irr = 34, band_irr = 1, weight = 24.0, w_ha = 0.8107 THz, 5.0939e+00 rad/ps, delta = -0.0773, gamma = 0.0206, [0.84 0.04 0.  ]
# i = 34, q_irr = 35, band_irr = 1, weight = 24.0, w_ha = 0.6284 THz, 3.9485e+00 rad/ps, delta = -0.0547, gamma = 0.0126, [0.88 0.04 0.  ]
# i = 35, q_irr = 36, band_irr = 1, weight = 24.0, w_ha = 0.4366 THz, 2.7432e+00 rad/ps, delta = -0.0327, gamma = 0.0063, [0.92 0.04 0.  ]
# i = 36, q_irr = 37, band_irr = 1, weight = 12.0, w_ha = 0.2660 THz, 1.6715e+00 rad/ps, delta = -0.0171, gamma = 0.0024, [0.96 0.04 0.  ]
# i = 37, q_irr = 38, band_irr = 1, weight = 6.0, w_ha = 0.3515 THz, 2.2084e+00 rad/ps, delta = -0.0241, gamma = 0.0051, [0.08 0.08 0.  ]
# i = 38, q_irr = 39, band_irr = 1, weight = 24.0, w_ha = 0.4638 THz, 2.9139e+00 rad/ps, delta = -0.0362, gamma = 0.0082, [0.12 0.08 0.  ]
# i = 39, q_irr = 40, band_irr = 1, weight = 24.0, w_ha = 0.6137 THz, 3.8559e+00 rad/ps, delta = -0.0541, gamma = 0.0133, [0.16 0.08 0.  ]
# i = 40, q_irr = 41, band_irr = 1, weight = 24.0, w_ha = 0.7683 THz, 4.8272e+00 rad/ps, delta = -0.0740, gamma = 0.0208, [0.2  0.08 0.  ]
# i = 41, q_irr = 42, band_irr = 1, weight = 24.0, w_ha = 0.9144 THz, 5.7455e+00 rad/ps, delta = -0.0994, gamma = 0.0286, [0.24 0.08 0.  ]
# i = 42, q_irr = 43, band_irr = 1, weight = 24.0, w_ha = 1.0479 THz, 6.5841e+00 rad/ps, delta = -0.1270, gamma = 0.0414, [0.28 0.08 0.  ]
# i = 43, q_irr = 44, band_irr = 1, weight = 24.0, w_ha = 1.1697 THz, 7.3495e+00 rad/ps, delta = -0.1600, gamma = 0.0570, [0.32 0.08 0.  ]
# i = 44, q_irr = 45, band_irr = 1, weight = 24.0, w_ha = 1.2849 THz, 8.0734e+00 rad/ps, delta = -0.1907, gamma = 0.0748, [0.36 0.08 0.  ]
# i = 45, q_irr = 46, band_irr = 1, weight = 24.0, w_ha = 1.4009 THz, 8.8024e+00 rad/ps, delta = -0.2263, gamma = 0.0934, [0.4  0.08 0.  ]
# i = 46, q_irr = 47, band_irr = 1, weight = 24.0, w_ha = 1.5254 THz, 9.5845e+00 rad/ps, delta = -0.2557, gamma = 0.1130, [0.44 0.08 0.  ]
# i = 47, q_irr = 48, band_irr = 1, weight = 24.0, w_ha = 1.6641 THz, 1.0456e+01 rad/ps, delta = -0.2865, gamma = 0.1436, [0.48 0.08 0.  ]
# i = 48, q_irr = 49, band_irr = 1, weight = 24.0, w_ha = 1.8192 THz, 1.1430e+01 rad/ps, delta = -0.3017, gamma = 0.1703, [0.52 0.08 0.  ]
# i = 49, q_irr = 50, band_irr = 1, weight = 24.0, w_ha = 1.7326 THz, 1.0886e+01 rad/ps, delta = -0.2393, gamma = 0.1242, [0.56 0.08 0.  ]
# i = 50, q_irr = 51, band_irr = 1, weight = 24.0, w_ha = 1.5815 THz, 9.9367e+00 rad/ps, delta = -0.2210, gamma = 0.1008, [0.6  0.08 0.  ]
# i = 51, q_irr = 52, band_irr = 1, weight = 24.0, w_ha = 1.4463 THz, 9.0872e+00 rad/ps, delta = -0.1949, gamma = 0.0815, [0.64 0.08 0.  ]
# i = 52, q_irr = 53, band_irr = 1, weight = 24.0, w_ha = 1.3223 THz, 8.3085e+00 rad/ps, delta = -0.1671, gamma = 0.0630, [0.68 0.08 0.  ]
# i = 53, q_irr = 54, band_irr = 1, weight = 24.0, w_ha = 1.2019 THz, 7.5520e+00 rad/ps, delta = -0.1378, gamma = 0.0489, [0.72 0.08 0.  ]
# i = 54, q_irr = 55, band_irr = 1, weight = 24.0, w_ha = 1.0771 THz, 6.7676e+00 rad/ps, delta = -0.1075, gamma = 0.0337, [0.76 0.08 0.  ]
# i = 55, q_irr = 56, band_irr = 1, weight = 24.0, w_ha = 0.9422 THz, 5.9203e+00 rad/ps, delta = -0.0848, gamma = 0.0249, [0.8  0.08 0.  ]
# i = 56, q_irr = 57, band_irr = 1, weight = 24.0, w_ha = 0.7963 THz, 5.0036e+00 rad/ps, delta = -0.0622, gamma = 0.0176, [0.84 0.08 0.  ]
# i = 57, q_irr = 58, band_irr = 1, weight = 24.0, w_ha = 0.6458 THz, 4.0578e+00 rad/ps, delta = -0.0432, gamma = 0.0124, [0.88 0.08 0.  ]
# i = 58, q_irr = 59, band_irr = 1, weight = 12.0, w_ha = 0.5113 THz, 3.2125e+00 rad/ps, delta = -0.0314, gamma = 0.0082, [0.92 0.08 0.  ]
# i = 59, q_irr = 60, band_irr = 1, weight = 6.0, w_ha = 0.4778 THz, 3.0023e+00 rad/ps, delta = -0.0346, gamma = 0.0087, [0.12 0.12 0.  ]
# i = 60, q_irr = 61, band_irr = 1, weight = 24.0, w_ha = 0.5581 THz, 3.5065e+00 rad/ps, delta = -0.0458, gamma = 0.0122, [0.16 0.12 0.  ]
# i = 61, q_irr = 62, band_irr = 1, weight = 24.0, w_ha = 0.6733 THz, 4.2305e+00 rad/ps, delta = -0.0604, gamma = 0.0168, [0.2  0.12 0.  ]
# i = 62, q_irr = 63, band_irr = 1, weight = 24.0, w_ha = 0.7993 THz, 5.0222e+00 rad/ps, delta = -0.0813, gamma = 0.0235, [0.24 0.12 0.  ]
# i = 63, q_irr = 64, band_irr = 1, weight = 24.0, w_ha = 0.9235 THz, 5.8027e+00 rad/ps, delta = -0.1055, gamma = 0.0306, [0.28 0.12 0.  ]
# i = 64, q_irr = 65, band_irr = 1, weight = 24.0, w_ha = 1.0416 THz, 6.5448e+00 rad/ps, delta = -0.1318, gamma = 0.0417, [0.32 0.12 0.  ]
# i = 65, q_irr = 66, band_irr = 1, weight = 24.0, w_ha = 1.1549 THz, 7.2562e+00 rad/ps, delta = -0.1635, gamma = 0.0558, [0.36 0.12 0.  ]
# i = 66, q_irr = 67, band_irr = 1, weight = 24.0, w_ha = 1.2681 THz, 7.9676e+00 rad/ps, delta = -0.1950, gamma = 0.0737, [0.4  0.12 0.  ]
# i = 67, q_irr = 68, band_irr = 1, weight = 24.0, w_ha = 1.3877 THz, 8.7191e+00 rad/ps, delta = -0.2265, gamma = 0.0936, [0.44 0.12 0.  ]
# i = 68, q_irr = 69, band_irr = 1, weight = 24.0, w_ha = 1.5191 THz, 9.5449e+00 rad/ps, delta = -0.2595, gamma = 0.1163, [0.48 0.12 0.  ]
# i = 69, q_irr = 70, band_irr = 1, weight = 24.0, w_ha = 1.6650 THz, 1.0462e+01 rad/ps, delta = -0.2900, gamma = 0.1498, [0.52 0.12 0.  ]
# i = 70, q_irr = 71, band_irr = 1, weight = 24.0, w_ha = 1.6721 THz, 1.0506e+01 rad/ps, delta = -0.2124, gamma = 0.1078, [0.56 0.12 0.  ]
# i = 71, q_irr = 72, band_irr = 1, weight = 24.0, w_ha = 1.5096 THz, 9.4851e+00 rad/ps, delta = -0.1976, gamma = 0.0836, [0.6  0.12 0.  ]
# i = 72, q_irr = 73, band_irr = 1, weight = 24.0, w_ha = 1.3676 THz, 8.5932e+00 rad/ps, delta = -0.1710, gamma = 0.0671, [0.64 0.12 0.  ]
# i = 73, q_irr = 74, band_irr = 1, weight = 24.0, w_ha = 1.2442 THz, 7.8174e+00 rad/ps, delta = -0.1447, gamma = 0.0550, [0.68 0.12 0.  ]
# i = 74, q_irr = 75, band_irr = 1, weight = 24.0, w_ha = 1.1325 THz, 7.1155e+00 rad/ps, delta = -0.1182, gamma = 0.0411, [0.72 0.12 0.  ]
# i = 75, q_irr = 76, band_irr = 1, weight = 24.0, w_ha = 1.0250 THz, 6.4403e+00 rad/ps, delta = -0.0927, gamma = 0.0295, [0.76 0.12 0.  ]
# i = 76, q_irr = 77, band_irr = 1, weight = 24.0, w_ha = 0.9171 THz, 5.7621e+00 rad/ps, delta = -0.0709, gamma = 0.0220, [0.8  0.12 0.  ]
# i = 77, q_irr = 78, band_irr = 1, weight = 24.0, w_ha = 0.8098 THz, 5.0882e+00 rad/ps, delta = -0.0548, gamma = 0.0169, [0.84 0.12 0.  ]
# i = 78, q_irr = 79, band_irr = 1, weight = 12.0, w_ha = 0.7129 THz, 4.4792e+00 rad/ps, delta = -0.0444, gamma = 0.0135, [0.88 0.12 0.  ]
# i = 79, q_irr = 80, band_irr = 1, weight = 6.0, w_ha = 0.5583 THz, 3.5078e+00 rad/ps, delta = -0.0467, gamma = 0.0130, [0.16 0.16 0.  ]
# i = 80, q_irr = 81, band_irr = 1, weight = 24.0, w_ha = 0.6117 THz, 3.8432e+00 rad/ps, delta = -0.0553, gamma = 0.0154, [0.2  0.16 0.  ]
# i = 81, q_irr = 82, band_irr = 1, weight = 24.0, w_ha = 0.7006 THz, 4.4020e+00 rad/ps, delta = -0.0720, gamma = 0.0205, [0.24 0.16 0.  ]
# i = 82, q_irr = 83, band_irr = 1, weight = 24.0, w_ha = 0.8069 THz, 5.0699e+00 rad/ps, delta = -0.0901, gamma = 0.0267, [0.28 0.16 0.  ]
# i = 83, q_irr = 84, band_irr = 1, weight = 24.0, w_ha = 0.9192 THz, 5.7755e+00 rad/ps, delta = -0.1128, gamma = 0.0326, [0.32 0.16 0.  ]
# i = 84, q_irr = 85, band_irr = 1, weight = 24.0, w_ha = 1.0330 THz, 6.4906e+00 rad/ps, delta = -0.1378, gamma = 0.0422, [0.36 0.16 0.  ]
# i = 85, q_irr = 86, band_irr = 1, weight = 24.0, w_ha = 1.1489 THz, 7.2190e+00 rad/ps, delta = -0.1657, gamma = 0.0562, [0.4  0.16 0.  ]
# i = 86, q_irr = 87, band_irr = 1, weight = 24.0, w_ha = 1.2703 THz, 7.9818e+00 rad/ps, delta = -0.1957, gamma = 0.0739, [0.44 0.16 0.  ]
# i = 87, q_irr = 88, band_irr = 1, weight = 24.0, w_ha = 1.4009 THz, 8.8021e+00 rad/ps, delta = -0.2219, gamma = 0.0953, [0.48 0.16 0.  ]
# i = 88, q_irr = 89, band_irr = 1, weight = 24.0, w_ha = 1.5426 THz, 9.6921e+00 rad/ps, delta = -0.2534, gamma = 0.1155, [0.52 0.16 0.  ]
# i = 89, q_irr = 90, band_irr = 1, weight = 24.0, w_ha = 1.6118 THz, 1.0127e+01 rad/ps, delta = -0.1991, gamma = 0.0917, [0.56 0.16 0.  ]
# i = 90, q_irr = 91, band_irr = 1, weight = 24.0, w_ha = 1.4352 THz, 9.0176e+00 rad/ps, delta = -0.1801, gamma = 0.0704, [0.6  0.16 0.  ]
# i = 91, q_irr = 92, band_irr = 1, weight = 24.0, w_ha = 1.2836 THz, 8.0650e+00 rad/ps, delta = -0.1556, gamma = 0.0560, [0.64 0.16 0.  ]
# i = 92, q_irr = 93, band_irr = 1, weight = 24.0, w_ha = 1.1597 THz, 7.2867e+00 rad/ps, delta = -0.1322, gamma = 0.0469, [0.68 0.16 0.  ]
# i = 93, q_irr = 94, band_irr = 1, weight = 24.0, w_ha = 1.0596 THz, 6.6576e+00 rad/ps, delta = -0.1078, gamma = 0.0346, [0.72 0.16 0.  ]
# i = 94, q_irr = 95, band_irr = 1, weight = 24.0, w_ha = 0.9768 THz, 6.1372e+00 rad/ps, delta = -0.0856, gamma = 0.0252, [0.76 0.16 0.  ]
# i = 95, q_irr = 96, band_irr = 1, weight = 24.0, w_ha = 0.9066 THz, 5.6965e+00 rad/ps, delta = -0.0698, gamma = 0.0217, [0.8  0.16 0.  ]
# i = 96, q_irr = 97, band_irr = 1, weight = 12.0, w_ha = 0.8492 THz, 5.3356e+00 rad/ps, delta = -0.0578, gamma = 0.0189, [0.84 0.16 0.  ]
# i = 97, q_irr = 98, band_irr = 1, weight = 6.0, w_ha = 0.5971 THz, 3.7519e+00 rad/ps, delta = -0.0604, gamma = 0.0163, [0.2 0.2 0. ]
# i = 98, q_irr = 99, band_irr = 1, weight = 24.0, w_ha = 0.6328 THz, 3.9761e+00 rad/ps, delta = -0.0705, gamma = 0.0192, [0.24 0.2  0.  ]
# i = 99, q_irr = 100, band_irr = 1, weight = 24.0, w_ha = 0.7080 THz, 4.4485e+00 rad/ps, delta = -0.0816, gamma = 0.0211, [0.28 0.2  0.  ]
# i = 100, q_irr = 101, band_irr = 1, weight = 24.0, w_ha = 0.8074 THz, 5.0733e+00 rad/ps, delta = -0.0994, gamma = 0.0272, [0.32 0.2  0.  ]
# i = 101, q_irr = 102, band_irr = 1, weight = 24.0, w_ha = 0.9198 THz, 5.7795e+00 rad/ps, delta = -0.1179, gamma = 0.0340, [0.36 0.2  0.  ]
# i = 102, q_irr = 103, band_irr = 1, weight = 24.0, w_ha = 1.0397 THz, 6.5329e+00 rad/ps, delta = -0.1433, gamma = 0.0442, [0.4 0.2 0. ]
# i = 103, q_irr = 104, band_irr = 1, weight = 24.0, w_ha = 1.1660 THz, 7.3264e+00 rad/ps, delta = -0.1654, gamma = 0.0574, [0.44 0.2  0.  ]
# i = 104, q_irr = 105, band_irr = 1, weight = 24.0, w_ha = 1.2995 THz, 8.1651e+00 rad/ps, delta = -0.1888, gamma = 0.0739, [0.48 0.2  0.  ]
# i = 105, q_irr = 106, band_irr = 1, weight = 24.0, w_ha = 1.4407 THz, 9.0521e+00 rad/ps, delta = -0.2145, gamma = 0.0886, [0.52 0.2  0.  ]
# i = 106, q_irr = 107, band_irr = 1, weight = 24.0, w_ha = 1.5656 THz, 9.8370e+00 rad/ps, delta = -0.1827, gamma = 0.0786, [0.56 0.2  0.  ]
# i = 107, q_irr = 108, band_irr = 1, weight = 24.0, w_ha = 1.3620 THz, 8.5578e+00 rad/ps, delta = -0.1651, gamma = 0.0638, [0.6 0.2 0. ]
# i = 108, q_irr = 109, band_irr = 1, weight = 24.0, w_ha = 1.2026 THz, 7.5561e+00 rad/ps, delta = -0.1466, gamma = 0.0505, [0.64 0.2  0.  ]
# i = 109, q_irr = 110, band_irr = 1, weight = 24.0, w_ha = 1.0804 THz, 6.7881e+00 rad/ps, delta = -0.1271, gamma = 0.0397, [0.68 0.2  0.  ]
# i = 110, q_irr = 111, band_irr = 1, weight = 24.0, w_ha = 0.9951 THz, 6.2526e+00 rad/ps, delta = -0.1054, gamma = 0.0308, [0.72 0.2  0.  ]
# i = 111, q_irr = 112, band_irr = 1, weight = 24.0, w_ha = 0.9417 THz, 5.9171e+00 rad/ps, delta = -0.0890, gamma = 0.0241, [0.76 0.2  0.  ]
# i = 112, q_irr = 113, band_irr = 1, weight = 12.0, w_ha = 0.9138 THz, 5.7417e+00 rad/ps, delta = -0.0745, gamma = 0.0214, [0.8 0.2 0. ]
# i = 113, q_irr = 114, band_irr = 1, weight = 6.0, w_ha = 0.6114 THz, 3.8413e+00 rad/ps, delta = -0.0752, gamma = 0.0208, [0.24 0.24 0.  ]
# i = 114, q_irr = 115, band_irr = 1, weight = 24.0, w_ha = 0.6423 THz, 4.0358e+00 rad/ps, delta = -0.0851, gamma = 0.0218, [0.28 0.24 0.  ]
# i = 115, q_irr = 116, band_irr = 1, weight = 24.0, w_ha = 0.7171 THz, 4.5055e+00 rad/ps, delta = -0.0946, gamma = 0.0240, [0.32 0.24 0.  ]
# i = 116, q_irr = 117, band_irr = 1, weight = 24.0, w_ha = 0.8204 THz, 5.1550e+00 rad/ps, delta = -0.1057, gamma = 0.0283, [0.36 0.24 0.  ]
# i = 117, q_irr = 118, band_irr = 1, weight = 24.0, w_ha = 0.9403 THz, 5.9078e+00 rad/ps, delta = -0.1225, gamma = 0.0352, [0.4  0.24 0.  ]
# i = 118, q_irr = 119, band_irr = 1, weight = 24.0, w_ha = 1.0698 THz, 6.7218e+00 rad/ps, delta = -0.1432, gamma = 0.0447, [0.44 0.24 0.  ]
# i = 119, q_irr = 120, band_irr = 1, weight = 24.0, w_ha = 1.2062 THz, 7.5791e+00 rad/ps, delta = -0.1605, gamma = 0.0574, [0.48 0.24 0.  ]
# i = 120, q_irr = 121, band_irr = 1, weight = 24.0, w_ha = 1.3481 THz, 8.4702e+00 rad/ps, delta = -0.1799, gamma = 0.0713, [0.52 0.24 0.  ]
# i = 121, q_irr = 122, band_irr = 1, weight = 24.0, w_ha = 1.4934 THz, 9.3834e+00 rad/ps, delta = -0.2106, gamma = 0.0934, [0.56 0.24 0.  ]
# i = 122, q_irr = 123, band_irr = 1, weight = 24.0, w_ha = 1.2942 THz, 8.1315e+00 rad/ps, delta = -0.1507, gamma = 0.0543, [0.6  0.24 0.  ]
# i = 123, q_irr = 124, band_irr = 1, weight = 24.0, w_ha = 1.1335 THz, 7.1221e+00 rad/ps, delta = -0.1383, gamma = 0.0455, [0.64 0.24 0.  ]
# i = 124, q_irr = 125, band_irr = 1, weight = 24.0, w_ha = 1.0186 THz, 6.3997e+00 rad/ps, delta = -0.1234, gamma = 0.0362, [0.68 0.24 0.  ]
# i = 125, q_irr = 126, band_irr = 1, weight = 24.0, w_ha = 0.9524 THz, 5.9842e+00 rad/ps, delta = -0.1053, gamma = 0.0293, [0.72 0.24 0.  ]
# i = 126, q_irr = 127, band_irr = 1, weight = 12.0, w_ha = 0.9301 THz, 5.8437e+00 rad/ps, delta = -0.0945, gamma = 0.0258, [0.76 0.24 0.  ]
# i = 127, q_irr = 128, band_irr = 1, weight = 6.0, w_ha = 0.6257 THz, 3.9316e+00 rad/ps, delta = -0.0881, gamma = 0.0202, [0.28 0.28 0.  ]
# i = 128, q_irr = 129, band_irr = 1, weight = 24.0, w_ha = 0.6633 THz, 4.1674e+00 rad/ps, delta = -0.0943, gamma = 0.0218, [0.32 0.28 0.  ]
# i = 129, q_irr = 130, band_irr = 1, weight = 24.0, w_ha = 0.7449 THz, 4.6802e+00 rad/ps, delta = -0.1011, gamma = 0.0258, [0.36 0.28 0.  ]
# i = 130, q_irr = 131, band_irr = 1, weight = 24.0, w_ha = 0.8549 THz, 5.3713e+00 rad/ps, delta = -0.1111, gamma = 0.0294, [0.4  0.28 0.  ]
# i = 131, q_irr = 132, band_irr = 1, weight = 24.0, w_ha = 0.9811 THz, 6.1641e+00 rad/ps, delta = -0.1210, gamma = 0.0363, [0.44 0.28 0.  ]
# i = 132, q_irr = 133, band_irr = 1, weight = 24.0, w_ha = 1.1164 THz, 7.0143e+00 rad/ps, delta = -0.1376, gamma = 0.0446, [0.48 0.28 0.  ]
# i = 133, q_irr = 134, band_irr = 1, weight = 24.0, w_ha = 1.2568 THz, 7.8968e+00 rad/ps, delta = -0.1550, gamma = 0.0551, [0.52 0.28 0.  ]
# i = 134, q_irr = 135, band_irr = 1, weight = 24.0, w_ha = 1.3994 THz, 8.7927e+00 rad/ps, delta = -0.1756, gamma = 0.0721, [0.56 0.28 0.  ]
# i = 135, q_irr = 136, band_irr = 1, weight = 24.0, w_ha = 1.2367 THz, 7.7704e+00 rad/ps, delta = -0.1401, gamma = 0.0479, [0.6  0.28 0.  ]
# i = 136, q_irr = 137, band_irr = 1, weight = 24.0, w_ha = 1.0861 THz, 6.8239e+00 rad/ps, delta = -0.1317, gamma = 0.0435, [0.64 0.28 0.  ]
# i = 137, q_irr = 138, band_irr = 1, weight = 24.0, w_ha = 0.9878 THz, 6.2066e+00 rad/ps, delta = -0.1214, gamma = 0.0355, [0.68 0.28 0.  ]
# i = 138, q_irr = 139, band_irr = 1, weight = 12.0, w_ha = 0.9456 THz, 5.9415e+00 rad/ps, delta = -0.1121, gamma = 0.0298, [0.72 0.28 0.  ]
# i = 139, q_irr = 140, band_irr = 1, weight = 6.0, w_ha = 0.6591 THz, 4.1411e+00 rad/ps, delta = -0.0948, gamma = 0.0217, [0.32 0.32 0.  ]
# i = 140, q_irr = 141, band_irr = 1, weight = 24.0, w_ha = 0.7057 THz, 4.4342e+00 rad/ps, delta = -0.0979, gamma = 0.0222, [0.36 0.32 0.  ]
# i = 141, q_irr = 142, band_irr = 1, weight = 24.0, w_ha = 0.7920 THz, 4.9764e+00 rad/ps, delta = -0.1029, gamma = 0.0259, [0.4  0.32 0.  ]
# i = 142, q_irr = 143, band_irr = 1, weight = 24.0, w_ha = 0.9037 THz, 5.6782e+00 rad/ps, delta = -0.1102, gamma = 0.0319, [0.44 0.32 0.  ]
# i = 143, q_irr = 144, band_irr = 1, weight = 24.0, w_ha = 1.0300 THz, 6.4717e+00 rad/ps, delta = -0.1185, gamma = 0.0379, [0.48 0.32 0.  ]
# i = 144, q_irr = 145, band_irr = 1, weight = 24.0, w_ha = 1.1641 THz, 7.3140e+00 rad/ps, delta = -0.1344, gamma = 0.0453, [0.52 0.32 0.  ]
# i = 145, q_irr = 146, band_irr = 1, weight = 24.0, w_ha = 1.3012 THz, 8.1754e+00 rad/ps, delta = -0.1579, gamma = 0.0599, [0.56 0.32 0.  ]
# i = 146, q_irr = 147, band_irr = 1, weight = 24.0, w_ha = 1.2084 THz, 7.5927e+00 rad/ps, delta = -0.1271, gamma = 0.0431, [0.6  0.32 0.  ]
# i = 147, q_irr = 148, band_irr = 1, weight = 24.0, w_ha = 1.0720 THz, 6.7358e+00 rad/ps, delta = -0.1227, gamma = 0.0416, [0.64 0.32 0.  ]
# i = 148, q_irr = 149, band_irr = 1, weight = 12.0, w_ha = 1.0022 THz, 6.2971e+00 rad/ps, delta = -0.1210, gamma = 0.0370, [0.68 0.32 0.  ]
# i = 149, q_irr = 150, band_irr = 1, weight = 6.0, w_ha = 0.7116 THz, 4.4714e+00 rad/ps, delta = -0.0979, gamma = 0.0220, [0.36 0.36 0.  ]
# i = 150, q_irr = 151, band_irr = 1, weight = 24.0, w_ha = 0.7614 THz, 4.7837e+00 rad/ps, delta = -0.0984, gamma = 0.0233, [0.4  0.36 0.  ]
# i = 151, q_irr = 152, band_irr = 1, weight = 24.0, w_ha = 0.8452 THz, 5.3104e+00 rad/ps, delta = -0.1012, gamma = 0.0270, [0.44 0.36 0.  ]
# i = 152, q_irr = 153, band_irr = 1, weight = 24.0, w_ha = 0.9517 THz, 5.9797e+00 rad/ps, delta = -0.1081, gamma = 0.0317, [0.48 0.36 0.  ]
# i = 153, q_irr = 154, band_irr = 1, weight = 24.0, w_ha = 1.0718 THz, 6.7341e+00 rad/ps, delta = -0.1179, gamma = 0.0367, [0.52 0.36 0.  ]
# i = 154, q_irr = 155, band_irr = 1, weight = 24.0, w_ha = 1.1985 THz, 7.5307e+00 rad/ps, delta = -0.1343, gamma = 0.0466, [0.56 0.36 0.  ]
# i = 155, q_irr = 156, band_irr = 1, weight = 24.0, w_ha = 1.1922 THz, 7.4908e+00 rad/ps, delta = -0.1212, gamma = 0.0387, [0.6  0.36 0.  ]
# i = 156, q_irr = 157, band_irr = 1, weight = 12.0, w_ha = 1.1038 THz, 6.9352e+00 rad/ps, delta = -0.1183, gamma = 0.0384, [0.64 0.36 0.  ]
# i = 157, q_irr = 158, band_irr = 1, weight = 6.0, w_ha = 0.7689 THz, 4.8313e+00 rad/ps, delta = -0.0967, gamma = 0.0237, [0.4 0.4 0. ]
# i = 158, q_irr = 159, band_irr = 1, weight = 24.0, w_ha = 0.8137 THz, 5.1127e+00 rad/ps, delta = -0.0957, gamma = 0.0264, [0.44 0.4  0.  ]
# i = 159, q_irr = 160, band_irr = 1, weight = 24.0, w_ha = 0.8889 THz, 5.5848e+00 rad/ps, delta = -0.1015, gamma = 0.0271, [0.48 0.4  0.  ]
# i = 160, q_irr = 161, band_irr = 1, weight = 24.0, w_ha = 0.9855 THz, 6.1919e+00 rad/ps, delta = -0.1061, gamma = 0.0305, [0.52 0.4  0.  ]
# i = 161, q_irr = 162, band_irr = 1, weight = 24.0, w_ha = 1.0952 THz, 6.8816e+00 rad/ps, delta = -0.1177, gamma = 0.0359, [0.56 0.4  0.  ]
# i = 162, q_irr = 163, band_irr = 1, weight = 12.0, w_ha = 1.2110 THz, 7.6088e+00 rad/ps, delta = -0.1329, gamma = 0.0455, [0.6 0.4 0. ]
# i = 163, q_irr = 164, band_irr = 1, weight = 6.0, w_ha = 0.8150 THz, 5.1208e+00 rad/ps, delta = -0.0914, gamma = 0.0243, [0.44 0.44 0.  ]
# i = 164, q_irr = 165, band_irr = 1, weight = 24.0, w_ha = 0.8496 THz, 5.3379e+00 rad/ps, delta = -0.0924, gamma = 0.0234, [0.48 0.44 0.  ]
# i = 165, q_irr = 166, band_irr = 1, weight = 24.0, w_ha = 0.9129 THz, 5.7356e+00 rad/ps, delta = -0.0979, gamma = 0.0250, [0.52 0.44 0.  ]
# i = 166, q_irr = 167, band_irr = 1, weight = 12.0, w_ha = 0.9975 THz, 6.2673e+00 rad/ps, delta = -0.1067, gamma = 0.0280, [0.56 0.44 0.  ]
# i = 167, q_irr = 168, band_irr = 1, weight = 6.0, w_ha = 0.8400 THz, 5.2779e+00 rad/ps, delta = -0.0893, gamma = 0.0207, [0.48 0.48 0.  ]
# i = 168, q_irr = 169, band_irr = 1, weight = 12.0, w_ha = 0.8621 THz, 5.4169e+00 rad/ps, delta = -0.0903, gamma = 0.0219, [0.52 0.48 0.  ]
# i = 169, q_irr = 170, band_irr = 1, weight = 24.0, w_ha = 0.4029 THz, 2.5315e+00 rad/ps, delta = -0.0262, gamma = 0.0056, [0.12 0.08 0.04]
# i = 170, q_irr = 171, band_irr = 1, weight = 48.0, w_ha = 0.5463 THz, 3.4322e+00 rad/ps, delta = -0.0395, gamma = 0.0097, [0.16 0.08 0.04]
# i = 171, q_irr = 172, band_irr = 1, weight = 48.0, w_ha = 0.7118 THz, 4.4725e+00 rad/ps, delta = -0.0587, gamma = 0.0149, [0.2  0.08 0.04]
# i = 172, q_irr = 173, band_irr = 1, weight = 48.0, w_ha = 0.8718 THz, 5.4776e+00 rad/ps, delta = -0.0819, gamma = 0.0228, [0.24 0.08 0.04]
# i = 173, q_irr = 174, band_irr = 1, weight = 48.0, w_ha = 1.0177 THz, 6.3945e+00 rad/ps, delta = -0.1091, gamma = 0.0346, [0.28 0.08 0.04]
# i = 174, q_irr = 175, band_irr = 1, weight = 48.0, w_ha = 1.1492 THz, 7.2207e+00 rad/ps, delta = -0.1389, gamma = 0.0478, [0.32 0.08 0.04]
# i = 175, q_irr = 176, band_irr = 1, weight = 48.0, w_ha = 1.2707 THz, 7.9838e+00 rad/ps, delta = -0.1722, gamma = 0.0659, [0.36 0.08 0.04]
# i = 176, q_irr = 177, band_irr = 1, weight = 48.0, w_ha = 1.3895 THz, 8.7303e+00 rad/ps, delta = -0.2042, gamma = 0.0846, [0.4  0.08 0.04]
# i = 177, q_irr = 178, band_irr = 1, weight = 48.0, w_ha = 1.5138 THz, 9.5118e+00 rad/ps, delta = -0.2359, gamma = 0.1022, [0.44 0.08 0.04]
# i = 178, q_irr = 179, band_irr = 1, weight = 48.0, w_ha = 1.6499 THz, 1.0367e+01 rad/ps, delta = -0.2618, gamma = 0.1331, [0.48 0.08 0.04]
# i = 179, q_irr = 180, band_irr = 1, weight = 48.0, w_ha = 1.7952 THz, 1.1280e+01 rad/ps, delta = -0.2789, gamma = 0.1624, [0.52 0.08 0.04]
# i = 180, q_irr = 181, band_irr = 1, weight = 24.0, w_ha = 0.5204 THz, 3.2697e+00 rad/ps, delta = -0.0357, gamma = 0.0101, [0.16 0.12 0.04]
# i = 181, q_irr = 182, band_irr = 1, weight = 48.0, w_ha = 0.6337 THz, 3.9816e+00 rad/ps, delta = -0.0463, gamma = 0.0126, [0.2  0.12 0.04]
# i = 182, q_irr = 183, band_irr = 1, weight = 48.0, w_ha = 0.7690 THz, 4.8319e+00 rad/ps, delta = -0.0660, gamma = 0.0199, [0.24 0.12 0.04]
# i = 183, q_irr = 184, band_irr = 1, weight = 48.0, w_ha = 0.9028 THz, 5.6727e+00 rad/ps, delta = -0.0897, gamma = 0.0269, [0.28 0.12 0.04]
# i = 184, q_irr = 185, band_irr = 1, weight = 48.0, w_ha = 1.0273 THz, 6.4547e+00 rad/ps, delta = -0.1158, gamma = 0.0359, [0.32 0.12 0.04]
# i = 185, q_irr = 186, band_irr = 1, weight = 48.0, w_ha = 1.1429 THz, 7.1809e+00 rad/ps, delta = -0.1499, gamma = 0.0516, [0.36 0.12 0.04]
# i = 186, q_irr = 187, band_irr = 1, weight = 48.0, w_ha = 1.2548 THz, 7.8840e+00 rad/ps, delta = -0.1806, gamma = 0.0686, [0.4  0.12 0.04]
# i = 187, q_irr = 188, band_irr = 1, weight = 48.0, w_ha = 1.3702 THz, 8.6092e+00 rad/ps, delta = -0.2132, gamma = 0.0858, [0.44 0.12 0.04]
# i = 188, q_irr = 189, band_irr = 1, weight = 48.0, w_ha = 1.4952 THz, 9.3948e+00 rad/ps, delta = -0.2500, gamma = 0.1110, [0.48 0.12 0.04]
# i = 189, q_irr = 190, band_irr = 1, weight = 48.0, w_ha = 1.6285 THz, 1.0232e+01 rad/ps, delta = -0.2847, gamma = 0.1413, [0.52 0.12 0.04]
# i = 190, q_irr = 191, band_irr = 1, weight = 48.0, w_ha = 1.7019 THz, 1.0693e+01 rad/ps, delta = -0.2810, gamma = 0.1579, [0.56 0.12 0.04]
# i = 191, q_irr = 192, band_irr = 1, weight = 48.0, w_ha = 1.5863 THz, 9.9671e+00 rad/ps, delta = -0.2468, gamma = 0.1143, [0.6  0.12 0.04]
# i = 192, q_irr = 193, band_irr = 1, weight = 48.0, w_ha = 1.4493 THz, 9.1063e+00 rad/ps, delta = -0.2040, gamma = 0.0852, [0.64 0.12 0.04]
# i = 193, q_irr = 194, band_irr = 1, weight = 48.0, w_ha = 1.3245 THz, 8.3221e+00 rad/ps, delta = -0.1797, gamma = 0.0692, [0.68 0.12 0.04]
# i = 194, q_irr = 195, band_irr = 1, weight = 48.0, w_ha = 1.2095 THz, 7.5993e+00 rad/ps, delta = -0.1479, gamma = 0.0531, [0.72 0.12 0.04]
# i = 195, q_irr = 196, band_irr = 1, weight = 48.0, w_ha = 1.0968 THz, 6.8914e+00 rad/ps, delta = -0.1170, gamma = 0.0394, [0.76 0.12 0.04]
# i = 196, q_irr = 197, band_irr = 1, weight = 48.0, w_ha = 0.9797 THz, 6.1557e+00 rad/ps, delta = -0.0903, gamma = 0.0276, [0.8  0.12 0.04]
# i = 197, q_irr = 198, band_irr = 1, weight = 48.0, w_ha = 0.8555 THz, 5.3755e+00 rad/ps, delta = -0.0682, gamma = 0.0212, [0.84 0.12 0.04]
# i = 198, q_irr = 199, band_irr = 1, weight = 48.0, w_ha = 0.7289 THz, 4.5800e+00 rad/ps, delta = -0.0491, gamma = 0.0150, [0.88 0.12 0.04]
# i = 199, q_irr = 200, band_irr = 1, weight = 24.0, w_ha = 0.6159 THz, 3.8696e+00 rad/ps, delta = -0.0387, gamma = 0.0112, [0.92 0.12 0.04]
# i = 200, q_irr = 201, band_irr = 1, weight = 24.0, w_ha = 0.5980 THz, 3.7573e+00 rad/ps, delta = -0.0467, gamma = 0.0123, [0.2  0.16 0.04]
# i = 201, q_irr = 202, band_irr = 1, weight = 48.0, w_ha = 0.6850 THz, 4.3042e+00 rad/ps, delta = -0.0562, gamma = 0.0178, [0.24 0.16 0.04]
# i = 202, q_irr = 203, band_irr = 1, weight = 48.0, w_ha = 0.7951 THz, 4.9960e+00 rad/ps, delta = -0.0735, gamma = 0.0219, [0.28 0.16 0.04]
# i = 203, q_irr = 204, band_irr = 1, weight = 48.0, w_ha = 0.9092 THz, 5.7128e+00 rad/ps, delta = -0.0978, gamma = 0.0292, [0.32 0.16 0.04]
# i = 204, q_irr = 205, band_irr = 1, weight = 48.0, w_ha = 1.0210 THz, 6.4151e+00 rad/ps, delta = -0.1263, gamma = 0.0397, [0.36 0.16 0.04]
# i = 205, q_irr = 206, band_irr = 1, weight = 48.0, w_ha = 1.1313 THz, 7.1081e+00 rad/ps, delta = -0.1585, gamma = 0.0538, [0.4  0.16 0.04]
# i = 206, q_irr = 207, band_irr = 1, weight = 48.0, w_ha = 1.2445 THz, 7.8192e+00 rad/ps, delta = -0.1884, gamma = 0.0706, [0.44 0.16 0.04]
# i = 207, q_irr = 208, band_irr = 1, weight = 48.0, w_ha = 1.3651 THz, 8.5773e+00 rad/ps, delta = -0.2169, gamma = 0.0881, [0.48 0.16 0.04]
# i = 208, q_irr = 209, band_irr = 1, weight = 48.0, w_ha = 1.4928 THz, 9.3793e+00 rad/ps, delta = -0.2528, gamma = 0.1061, [0.52 0.16 0.04]
# i = 209, q_irr = 210, band_irr = 1, weight = 48.0, w_ha = 1.5931 THz, 1.0010e+01 rad/ps, delta = -0.2762, gamma = 0.1287, [0.56 0.16 0.04]
# i = 210, q_irr = 211, band_irr = 1, weight = 48.0, w_ha = 1.5139 THz, 9.5123e+00 rad/ps, delta = -0.2277, gamma = 0.0944, [0.6  0.16 0.04]
# i = 211, q_irr = 212, band_irr = 1, weight = 48.0, w_ha = 1.3734 THz, 8.6293e+00 rad/ps, delta = -0.1936, gamma = 0.0722, [0.64 0.16 0.04]
# i = 212, q_irr = 213, band_irr = 1, weight = 48.0, w_ha = 1.2457 THz, 7.8272e+00 rad/ps, delta = -0.1606, gamma = 0.0580, [0.68 0.16 0.04]
# i = 213, q_irr = 214, band_irr = 1, weight = 48.0, w_ha = 1.1356 THz, 7.1350e+00 rad/ps, delta = -0.1309, gamma = 0.0437, [0.72 0.16 0.04]
# i = 214, q_irr = 215, band_irr = 1, weight = 48.0, w_ha = 1.0376 THz, 6.5192e+00 rad/ps, delta = -0.1028, gamma = 0.0322, [0.76 0.16 0.04]
# i = 215, q_irr = 216, band_irr = 1, weight = 48.0, w_ha = 0.9459 THz, 5.9432e+00 rad/ps, delta = -0.0796, gamma = 0.0241, [0.8  0.16 0.04]
# i = 216, q_irr = 217, band_irr = 1, weight = 48.0, w_ha = 0.8590 THz, 5.3971e+00 rad/ps, delta = -0.0616, gamma = 0.0194, [0.84 0.16 0.04]
# i = 217, q_irr = 218, band_irr = 1, weight = 24.0, w_ha = 0.7824 THz, 4.9159e+00 rad/ps, delta = -0.0516, gamma = 0.0155, [0.88 0.16 0.04]
# i = 218, q_irr = 219, band_irr = 1, weight = 24.0, w_ha = 0.6365 THz, 3.9991e+00 rad/ps, delta = -0.0583, gamma = 0.0161, [0.24 0.2  0.04]
# i = 219, q_irr = 220, band_irr = 1, weight = 48.0, w_ha = 0.7061 THz, 4.4363e+00 rad/ps, delta = -0.0697, gamma = 0.0198, [0.28 0.2  0.04]
# i = 220, q_irr = 221, band_irr = 1, weight = 48.0, w_ha = 0.8020 THz, 5.0391e+00 rad/ps, delta = -0.0853, gamma = 0.0238, [0.32 0.2  0.04]
# i = 221, q_irr = 222, band_irr = 1, weight = 48.0, w_ha = 0.9085 THz, 5.7082e+00 rad/ps, delta = -0.1066, gamma = 0.0296, [0.36 0.2  0.04]
# i = 222, q_irr = 223, band_irr = 1, weight = 48.0, w_ha = 1.0197 THz, 6.4072e+00 rad/ps, delta = -0.1321, gamma = 0.0419, [0.4  0.2  0.04]
# i = 223, q_irr = 224, band_irr = 1, weight = 48.0, w_ha = 1.1355 THz, 7.1342e+00 rad/ps, delta = -0.1583, gamma = 0.0522, [0.44 0.2  0.04]
# i = 224, q_irr = 225, band_irr = 1, weight = 48.0, w_ha = 1.2573 THz, 7.9001e+00 rad/ps, delta = -0.1860, gamma = 0.0702, [0.48 0.2  0.04]
# i = 225, q_irr = 226, band_irr = 1, weight = 48.0, w_ha = 1.3845 THz, 8.6991e+00 rad/ps, delta = -0.2158, gamma = 0.0835, [0.52 0.2  0.04]
# i = 226, q_irr = 227, band_irr = 1, weight = 48.0, w_ha = 1.4951 THz, 9.3938e+00 rad/ps, delta = -0.2439, gamma = 0.1041, [0.56 0.2  0.04]
# i = 227, q_irr = 228, band_irr = 1, weight = 48.0, w_ha = 1.4437 THz, 9.0709e+00 rad/ps, delta = -0.2119, gamma = 0.0857, [0.6  0.2  0.04]
# i = 228, q_irr = 229, band_irr = 1, weight = 48.0, w_ha = 1.2973 THz, 8.1512e+00 rad/ps, delta = -0.1749, gamma = 0.0633, [0.64 0.2  0.04]
# i = 229, q_irr = 230, band_irr = 1, weight = 48.0, w_ha = 1.1660 THz, 7.3263e+00 rad/ps, delta = -0.1469, gamma = 0.0482, [0.68 0.2  0.04]
# i = 230, q_irr = 231, band_irr = 1, weight = 48.0, w_ha = 1.0625 THz, 6.6756e+00 rad/ps, delta = -0.1213, gamma = 0.0379, [0.72 0.2  0.04]
# i = 231, q_irr = 232, band_irr = 1, weight = 48.0, w_ha = 0.9840 THz, 6.1826e+00 rad/ps, delta = -0.0964, gamma = 0.0293, [0.76 0.2  0.04]
# i = 232, q_irr = 233, band_irr = 1, weight = 48.0, w_ha = 0.9252 THz, 5.8134e+00 rad/ps, delta = -0.0776, gamma = 0.0225, [0.8  0.2  0.04]
# i = 233, q_irr = 234, band_irr = 1, weight = 24.0, w_ha = 0.8832 THz, 5.5494e+00 rad/ps, delta = -0.0650, gamma = 0.0190, [0.84 0.2  0.04]
# i = 234, q_irr = 235, band_irr = 1, weight = 24.0, w_ha = 0.6513 THz, 4.0922e+00 rad/ps, delta = -0.0711, gamma = 0.0187, [0.28 0.24 0.04]
# i = 235, q_irr = 236, band_irr = 1, weight = 48.0, w_ha = 0.7159 THz, 4.4980e+00 rad/ps, delta = -0.0802, gamma = 0.0199, [0.32 0.24 0.04]
# i = 236, q_irr = 237, band_irr = 1, weight = 48.0, w_ha = 0.8103 THz, 5.0915e+00 rad/ps, delta = -0.0964, gamma = 0.0263, [0.36 0.24 0.04]
# i = 237, q_irr = 238, band_irr = 1, weight = 48.0, w_ha = 0.9202 THz, 5.7816e+00 rad/ps, delta = -0.1136, gamma = 0.0322, [0.4  0.24 0.04]
# i = 238, q_irr = 239, band_irr = 1, weight = 48.0, w_ha = 1.0388 THz, 6.5271e+00 rad/ps, delta = -0.1352, gamma = 0.0429, [0.44 0.24 0.04]
# i = 239, q_irr = 240, band_irr = 1, weight = 48.0, w_ha = 1.1640 THz, 7.3135e+00 rad/ps, delta = -0.1565, gamma = 0.0542, [0.48 0.24 0.04]
# i = 240, q_irr = 241, band_irr = 1, weight = 48.0, w_ha = 1.2933 THz, 8.1261e+00 rad/ps, delta = -0.1795, gamma = 0.0668, [0.52 0.24 0.04]
# i = 241, q_irr = 242, band_irr = 1, weight = 48.0, w_ha = 1.4114 THz, 8.8680e+00 rad/ps, delta = -0.2032, gamma = 0.0836, [0.56 0.24 0.04]
# i = 242, q_irr = 243, band_irr = 1, weight = 48.0, w_ha = 1.3808 THz, 8.6759e+00 rad/ps, delta = -0.1864, gamma = 0.0698, [0.6  0.24 0.04]
# i = 243, q_irr = 244, band_irr = 1, weight = 48.0, w_ha = 1.2288 THz, 7.7209e+00 rad/ps, delta = -0.1603, gamma = 0.0554, [0.64 0.24 0.04]
# i = 244, q_irr = 245, band_irr = 1, weight = 48.0, w_ha = 1.0965 THz, 6.8896e+00 rad/ps, delta = -0.1367, gamma = 0.0435, [0.68 0.24 0.04]
# i = 245, q_irr = 246, band_irr = 1, weight = 48.0, w_ha = 1.0029 THz, 6.3012e+00 rad/ps, delta = -0.1149, gamma = 0.0348, [0.72 0.24 0.04]
# i = 246, q_irr = 247, band_irr = 1, weight = 48.0, w_ha = 0.9474 THz, 5.9524e+00 rad/ps, delta = -0.0983, gamma = 0.0267, [0.76 0.24 0.04]
# i = 247, q_irr = 248, band_irr = 1, weight = 24.0, w_ha = 0.9238 THz, 5.8043e+00 rad/ps, delta = -0.0848, gamma = 0.0234, [0.8  0.24 0.04]
# i = 248, q_irr = 249, band_irr = 1, weight = 24.0, w_ha = 0.6660 THz, 4.1847e+00 rad/ps, delta = -0.0858, gamma = 0.0208, [0.32 0.28 0.04]
# i = 249, q_irr = 250, band_irr = 1, weight = 48.0, w_ha = 0.7361 THz, 4.6253e+00 rad/ps, delta = -0.0903, gamma = 0.0221, [0.36 0.28 0.04]
# i = 250, q_irr = 251, band_irr = 1, weight = 48.0, w_ha = 0.8364 THz, 5.2555e+00 rad/ps, delta = -0.1012, gamma = 0.0272, [0.4  0.28 0.04]
# i = 251, q_irr = 252, band_irr = 1, weight = 48.0, w_ha = 0.9531 THz, 5.9886e+00 rad/ps, delta = -0.1146, gamma = 0.0349, [0.44 0.28 0.04]
# i = 252, q_irr = 253, band_irr = 1, weight = 48.0, w_ha = 1.0790 THz, 6.7795e+00 rad/ps, delta = -0.1331, gamma = 0.0432, [0.48 0.28 0.04]
# i = 253, q_irr = 254, band_irr = 1, weight = 48.0, w_ha = 1.2096 THz, 7.6001e+00 rad/ps, delta = -0.1524, gamma = 0.0523, [0.52 0.28 0.04]
# i = 254, q_irr = 255, band_irr = 1, weight = 48.0, w_ha = 1.3338 THz, 8.3805e+00 rad/ps, delta = -0.1738, gamma = 0.0658, [0.56 0.28 0.04]
# i = 255, q_irr = 256, band_irr = 1, weight = 48.0, w_ha = 1.3403 THz, 8.4213e+00 rad/ps, delta = -0.1673, gamma = 0.0627, [0.6  0.28 0.04]
# i = 256, q_irr = 257, band_irr = 1, weight = 48.0, w_ha = 1.1731 THz, 7.3706e+00 rad/ps, delta = -0.1446, gamma = 0.0493, [0.64 0.28 0.04]
# i = 257, q_irr = 258, band_irr = 1, weight = 48.0, w_ha = 1.0470 THz, 6.5785e+00 rad/ps, delta = -0.1276, gamma = 0.0392, [0.68 0.28 0.04]
# i = 258, q_irr = 259, band_irr = 1, weight = 48.0, w_ha = 0.9690 THz, 6.0885e+00 rad/ps, delta = -0.1115, gamma = 0.0310, [0.72 0.28 0.04]
# i = 259, q_irr = 260, band_irr = 1, weight = 24.0, w_ha = 0.9387 THz, 5.8978e+00 rad/ps, delta = -0.1030, gamma = 0.0275, [0.76 0.28 0.04]
# i = 260, q_irr = 261, band_irr = 1, weight = 24.0, w_ha = 0.6987 THz, 4.3902e+00 rad/ps, delta = -0.0911, gamma = 0.0207, [0.36 0.32 0.04]
# i = 261, q_irr = 262, band_irr = 1, weight = 48.0, w_ha = 0.7765 THz, 4.8790e+00 rad/ps, delta = -0.0956, gamma = 0.0237, [0.4  0.32 0.04]
# i = 262, q_irr = 263, band_irr = 1, weight = 48.0, w_ha = 0.8812 THz, 5.5370e+00 rad/ps, delta = -0.1033, gamma = 0.0282, [0.44 0.32 0.04]
# i = 263, q_irr = 264, band_irr = 1, weight = 48.0, w_ha = 1.0008 THz, 6.2883e+00 rad/ps, delta = -0.1136, gamma = 0.0342, [0.48 0.32 0.04]
# i = 264, q_irr = 265, band_irr = 1, weight = 48.0, w_ha = 1.1281 THz, 7.0878e+00 rad/ps, delta = -0.1288, gamma = 0.0425, [0.52 0.32 0.04]
# i = 265, q_irr = 266, band_irr = 1, weight = 48.0, w_ha = 1.2547 THz, 7.8836e+00 rad/ps, delta = -0.1479, gamma = 0.0518, [0.56 0.32 0.04]
# i = 266, q_irr = 267, band_irr = 1, weight = 48.0, w_ha = 1.2891 THz, 8.0995e+00 rad/ps, delta = -0.1467, gamma = 0.0546, [0.6  0.32 0.04]
# i = 267, q_irr = 268, band_irr = 1, weight = 48.0, w_ha = 1.1364 THz, 7.1402e+00 rad/ps, delta = -0.1282, gamma = 0.0437, [0.64 0.32 0.04]
# i = 268, q_irr = 269, band_irr = 1, weight = 48.0, w_ha = 1.0284 THz, 6.4617e+00 rad/ps, delta = -0.1236, gamma = 0.0375, [0.68 0.32 0.04]
# i = 269, q_irr = 270, band_irr = 1, weight = 24.0, w_ha = 0.9738 THz, 6.1183e+00 rad/ps, delta = -0.1155, gamma = 0.0335, [0.72 0.32 0.04]
# i = 270, q_irr = 271, band_irr = 1, weight = 24.0, w_ha = 0.7499 THz, 4.7118e+00 rad/ps, delta = -0.0966, gamma = 0.0237, [0.4  0.36 0.04]
# i = 271, q_irr = 272, band_irr = 1, weight = 48.0, w_ha = 0.8297 THz, 5.2131e+00 rad/ps, delta = -0.0966, gamma = 0.0245, [0.44 0.36 0.04]
# i = 272, q_irr = 273, band_irr = 1, weight = 48.0, w_ha = 0.9325 THz, 5.8590e+00 rad/ps, delta = -0.1015, gamma = 0.0301, [0.48 0.36 0.04]
# i = 273, q_irr = 274, band_irr = 1, weight = 48.0, w_ha = 1.0485 THz, 6.5882e+00 rad/ps, delta = -0.1109, gamma = 0.0351, [0.52 0.36 0.04]
# i = 274, q_irr = 275, band_irr = 1, weight = 48.0, w_ha = 1.1706 THz, 7.3552e+00 rad/ps, delta = -0.1274, gamma = 0.0415, [0.56 0.36 0.04]
# i = 275, q_irr = 276, band_irr = 1, weight = 48.0, w_ha = 1.2475 THz, 7.8381e+00 rad/ps, delta = -0.1353, gamma = 0.0473, [0.6  0.36 0.04]
# i = 276, q_irr = 277, band_irr = 1, weight = 48.0, w_ha = 1.1289 THz, 7.0933e+00 rad/ps, delta = -0.1205, gamma = 0.0380, [0.64 0.36 0.04]
# i = 277, q_irr = 278, band_irr = 1, weight = 24.0, w_ha = 1.0529 THz, 6.6157e+00 rad/ps, delta = -0.1173, gamma = 0.0370, [0.68 0.36 0.04]
# i = 278, q_irr = 279, band_irr = 1, weight = 24.0, w_ha = 0.8058 THz, 5.0632e+00 rad/ps, delta = -0.0945, gamma = 0.0246, [0.44 0.4  0.04]
# i = 279, q_irr = 280, band_irr = 1, weight = 48.0, w_ha = 0.8802 THz, 5.5307e+00 rad/ps, delta = -0.0933, gamma = 0.0258, [0.48 0.4  0.04]
# i = 280, q_irr = 281, band_irr = 1, weight = 48.0, w_ha = 0.9753 THz, 6.1277e+00 rad/ps, delta = -0.0984, gamma = 0.0285, [0.52 0.4  0.04]
# i = 281, q_irr = 282, band_irr = 1, weight = 48.0, w_ha = 1.0832 THz, 6.8062e+00 rad/ps, delta = -0.1111, gamma = 0.0324, [0.56 0.4  0.04]
# i = 282, q_irr = 283, band_irr = 1, weight = 48.0, w_ha = 1.1967 THz, 7.5193e+00 rad/ps, delta = -0.1280, gamma = 0.0409, [0.6  0.4  0.04]
# i = 283, q_irr = 284, band_irr = 1, weight = 24.0, w_ha = 1.1663 THz, 7.3278e+00 rad/ps, delta = -0.1173, gamma = 0.0354, [0.64 0.4  0.04]
# i = 284, q_irr = 285, band_irr = 1, weight = 24.0, w_ha = 0.8510 THz, 5.3473e+00 rad/ps, delta = -0.0900, gamma = 0.0238, [0.48 0.44 0.04]
# i = 285, q_irr = 286, band_irr = 1, weight = 48.0, w_ha = 0.9152 THz, 5.7501e+00 rad/ps, delta = -0.0928, gamma = 0.0234, [0.52 0.44 0.04]
# i = 286, q_irr = 287, band_irr = 1, weight = 48.0, w_ha = 0.9993 THz, 6.2786e+00 rad/ps, delta = -0.1003, gamma = 0.0267, [0.56 0.44 0.04]
# i = 287, q_irr = 288, band_irr = 1, weight = 24.0, w_ha = 1.0967 THz, 6.8910e+00 rad/ps, delta = -0.1116, gamma = 0.0326, [0.6  0.44 0.04]
# i = 288, q_irr = 289, band_irr = 1, weight = 24.0, w_ha = 0.8757 THz, 5.5020e+00 rad/ps, delta = -0.0894, gamma = 0.0225, [0.52 0.48 0.04]
# i = 289, q_irr = 290, band_irr = 1, weight = 24.0, w_ha = 0.9275 THz, 5.8276e+00 rad/ps, delta = -0.0921, gamma = 0.0223, [0.56 0.48 0.04]
# i = 290, q_irr = 291, band_irr = 1, weight = 24.0, w_ha = 0.6888 THz, 4.3279e+00 rad/ps, delta = -0.0467, gamma = 0.0143, [0.24 0.16 0.08]
# i = 291, q_irr = 292, band_irr = 1, weight = 48.0, w_ha = 0.7793 THz, 4.8963e+00 rad/ps, delta = -0.0591, gamma = 0.0180, [0.28 0.16 0.08]
# i = 292, q_irr = 293, band_irr = 1, weight = 48.0, w_ha = 0.8832 THz, 5.5490e+00 rad/ps, delta = -0.0769, gamma = 0.0232, [0.32 0.16 0.08]
# i = 293, q_irr = 294, band_irr = 1, weight = 48.0, w_ha = 0.9879 THz, 6.2073e+00 rad/ps, delta = -0.1008, gamma = 0.0310, [0.36 0.16 0.08]
# i = 294, q_irr = 295, band_irr = 1, weight = 48.0, w_ha = 1.0911 THz, 6.8553e+00 rad/ps, delta = -0.1294, gamma = 0.0441, [0.4  0.16 0.08]
# i = 295, q_irr = 296, band_irr = 1, weight = 48.0, w_ha = 1.1964 THz, 7.5170e+00 rad/ps, delta = -0.1633, gamma = 0.0573, [0.44 0.16 0.08]
# i = 296, q_irr = 297, band_irr = 1, weight = 48.0, w_ha = 1.3096 THz, 8.2285e+00 rad/ps, delta = -0.1963, gamma = 0.0762, [0.48 0.16 0.08]
# i = 297, q_irr = 298, band_irr = 1, weight = 48.0, w_ha = 1.4324 THz, 8.9997e+00 rad/ps, delta = -0.2366, gamma = 0.0956, [0.52 0.16 0.08]
# i = 298, q_irr = 299, band_irr = 1, weight = 48.0, w_ha = 1.5445 THz, 9.7042e+00 rad/ps, delta = -0.2756, gamma = 0.1237, [0.56 0.16 0.08]
# i = 299, q_irr = 300, band_irr = 1, weight = 24.0, w_ha = 0.7265 THz, 4.5650e+00 rad/ps, delta = -0.0580, gamma = 0.0179, [0.28 0.2  0.08]
# i = 300, q_irr = 301, band_irr = 1, weight = 48.0, w_ha = 0.8009 THz, 5.0320e+00 rad/ps, delta = -0.0681, gamma = 0.0208, [0.32 0.2  0.08]
# i = 301, q_irr = 302, band_irr = 1, weight = 48.0, w_ha = 0.8908 THz, 5.5970e+00 rad/ps, delta = -0.0873, gamma = 0.0251, [0.36 0.2  0.08]
# i = 302, q_irr = 303, band_irr = 1, weight = 48.0, w_ha = 0.9866 THz, 6.1990e+00 rad/ps, delta = -0.1131, gamma = 0.0342, [0.4  0.2  0.08]
# i = 303, q_irr = 304, band_irr = 1, weight = 48.0, w_ha = 1.0868 THz, 6.8284e+00 rad/ps, delta = -0.1399, gamma = 0.0445, [0.44 0.2  0.08]
# i = 304, q_irr = 305, band_irr = 1, weight = 48.0, w_ha = 1.1939 THz, 7.5014e+00 rad/ps, delta = -0.1721, gamma = 0.0613, [0.48 0.2  0.08]
# i = 305, q_irr = 306, band_irr = 1, weight = 48.0, w_ha = 1.3088 THz, 8.2236e+00 rad/ps, delta = -0.2036, gamma = 0.0762, [0.52 0.2  0.08]
# i = 306, q_irr = 307, band_irr = 1, weight = 48.0, w_ha = 1.4185 THz, 8.9128e+00 rad/ps, delta = -0.2422, gamma = 0.0961, [0.56 0.2  0.08]
# i = 307, q_irr = 308, band_irr = 1, weight = 48.0, w_ha = 1.4533 THz, 9.1311e+00 rad/ps, delta = -0.2564, gamma = 0.1031, [0.6  0.2  0.08]
# i = 308, q_irr = 309, band_irr = 1, weight = 48.0, w_ha = 1.3596 THz, 8.5426e+00 rad/ps, delta = -0.2180, gamma = 0.0833, [0.64 0.2  0.08]
# i = 309, q_irr = 310, band_irr = 1, weight = 48.0, w_ha = 1.2385 THz, 7.7819e+00 rad/ps, delta = -0.1799, gamma = 0.0614, [0.68 0.2  0.08]
# i = 310, q_irr = 311, band_irr = 1, weight = 48.0, w_ha = 1.1289 THz, 7.0930e+00 rad/ps, delta = -0.1478, gamma = 0.0481, [0.72 0.2  0.08]
# i = 311, q_irr = 312, band_irr = 1, weight = 48.0, w_ha = 1.0348 THz, 6.5020e+00 rad/ps, delta = -0.1183, gamma = 0.0356, [0.76 0.2  0.08]
# i = 312, q_irr = 313, band_irr = 1, weight = 48.0, w_ha = 0.9526 THz, 5.9856e+00 rad/ps, delta = -0.0923, gamma = 0.0280, [0.8  0.2  0.08]
# i = 313, q_irr = 314, band_irr = 1, weight = 48.0, w_ha = 0.8797 THz, 5.5271e+00 rad/ps, delta = -0.0709, gamma = 0.0206, [0.84 0.2  0.08]
# i = 314, q_irr = 315, band_irr = 1, weight = 24.0, w_ha = 0.8188 THz, 5.1449e+00 rad/ps, delta = -0.0600, gamma = 0.0181, [0.88 0.2  0.08]
# i = 315, q_irr = 316, band_irr = 1, weight = 24.0, w_ha = 0.7422 THz, 4.6637e+00 rad/ps, delta = -0.0707, gamma = 0.0196, [0.32 0.24 0.08]
# i = 316, q_irr = 317, band_irr = 1, weight = 48.0, w_ha = 0.8116 THz, 5.0995e+00 rad/ps, delta = -0.0797, gamma = 0.0226, [0.36 0.24 0.08]
# i = 317, q_irr = 318, band_irr = 1, weight = 48.0, w_ha = 0.8995 THz, 5.6516e+00 rad/ps, delta = -0.0960, gamma = 0.0279, [0.4  0.24 0.08]
# i = 318, q_irr = 319, band_irr = 1, weight = 48.0, w_ha = 0.9973 THz, 6.2663e+00 rad/ps, delta = -0.1192, gamma = 0.0364, [0.44 0.24 0.08]
# i = 319, q_irr = 320, band_irr = 1, weight = 48.0, w_ha = 1.1028 THz, 6.9292e+00 rad/ps, delta = -0.1449, gamma = 0.0462, [0.48 0.24 0.08]
# i = 320, q_irr = 321, band_irr = 1, weight = 48.0, w_ha = 1.2149 THz, 7.6335e+00 rad/ps, delta = -0.1711, gamma = 0.0614, [0.52 0.24 0.08]
# i = 321, q_irr = 322, band_irr = 1, weight = 48.0, w_ha = 1.3242 THz, 8.3200e+00 rad/ps, delta = -0.1993, gamma = 0.0751, [0.56 0.24 0.08]
# i = 322, q_irr = 323, band_irr = 1, weight = 48.0, w_ha = 1.3813 THz, 8.6787e+00 rad/ps, delta = -0.2243, gamma = 0.0874, [0.6  0.24 0.08]
# i = 323, q_irr = 324, band_irr = 1, weight = 48.0, w_ha = 1.2952 THz, 8.1379e+00 rad/ps, delta = -0.1969, gamma = 0.0689, [0.64 0.24 0.08]
# i = 324, q_irr = 325, band_irr = 1, weight = 48.0, w_ha = 1.1735 THz, 7.3731e+00 rad/ps, delta = -0.1633, gamma = 0.0530, [0.68 0.24 0.08]
# i = 325, q_irr = 326, band_irr = 1, weight = 48.0, w_ha = 1.0684 THz, 6.7132e+00 rad/ps, delta = -0.1359, gamma = 0.0414, [0.72 0.24 0.08]
# i = 326, q_irr = 327, band_irr = 1, weight = 48.0, w_ha = 0.9891 THz, 6.2146e+00 rad/ps, delta = -0.1078, gamma = 0.0307, [0.76 0.24 0.08]
# i = 327, q_irr = 328, band_irr = 1, weight = 48.0, w_ha = 0.9329 THz, 5.8619e+00 rad/ps, delta = -0.0885, gamma = 0.0248, [0.8  0.24 0.08]
# i = 328, q_irr = 329, band_irr = 1, weight = 24.0, w_ha = 0.8966 THz, 5.6335e+00 rad/ps, delta = -0.0750, gamma = 0.0218, [0.84 0.24 0.08]
# i = 329, q_irr = 330, band_irr = 1, weight = 24.0, w_ha = 0.7575 THz, 4.7596e+00 rad/ps, delta = -0.0800, gamma = 0.0205, [0.36 0.28 0.08]
# i = 330, q_irr = 331, band_irr = 1, weight = 48.0, w_ha = 0.8319 THz, 5.2270e+00 rad/ps, delta = -0.0888, gamma = 0.0237, [0.4  0.28 0.08]
# i = 331, q_irr = 332, band_irr = 1, weight = 48.0, w_ha = 0.9253 THz, 5.8140e+00 rad/ps, delta = -0.1023, gamma = 0.0291, [0.44 0.28 0.08]
# i = 332, q_irr = 333, band_irr = 1, weight = 48.0, w_ha = 1.0296 THz, 6.4691e+00 rad/ps, delta = -0.1193, gamma = 0.0366, [0.48 0.28 0.08]
# i = 333, q_irr = 334, band_irr = 1, weight = 48.0, w_ha = 1.1406 THz, 7.1665e+00 rad/ps, delta = -0.1412, gamma = 0.0486, [0.52 0.28 0.08]
# i = 334, q_irr = 335, band_irr = 1, weight = 48.0, w_ha = 1.2507 THz, 7.8586e+00 rad/ps, delta = -0.1680, gamma = 0.0600, [0.56 0.28 0.08]
# i = 335, q_irr = 336, band_irr = 1, weight = 48.0, w_ha = 1.3211 THz, 8.3010e+00 rad/ps, delta = -0.1916, gamma = 0.0706, [0.6  0.28 0.08]
# i = 336, q_irr = 337, band_irr = 1, weight = 48.0, w_ha = 1.2445 THz, 7.8197e+00 rad/ps, delta = -0.1696, gamma = 0.0583, [0.64 0.28 0.08]
# i = 337, q_irr = 338, band_irr = 1, weight = 48.0, w_ha = 1.1227 THz, 7.0539e+00 rad/ps, delta = -0.1456, gamma = 0.0462, [0.68 0.28 0.08]
# i = 338, q_irr = 339, band_irr = 1, weight = 48.0, w_ha = 1.0253 THz, 6.4422e+00 rad/ps, delta = -0.1266, gamma = 0.0370, [0.72 0.28 0.08]
# i = 339, q_irr = 340, band_irr = 1, weight = 48.0, w_ha = 0.9637 THz, 6.0554e+00 rad/ps, delta = -0.1040, gamma = 0.0306, [0.76 0.28 0.08]
# i = 340, q_irr = 341, band_irr = 1, weight = 24.0, w_ha = 0.9349 THz, 5.8744e+00 rad/ps, delta = -0.0946, gamma = 0.0256, [0.8  0.28 0.08]
# i = 341, q_irr = 342, band_irr = 1, weight = 24.0, w_ha = 0.7891 THz, 4.9580e+00 rad/ps, delta = -0.0861, gamma = 0.0221, [0.4  0.32 0.08]
# i = 342, q_irr = 343, band_irr = 1, weight = 48.0, w_ha = 0.8710 THz, 5.4727e+00 rad/ps, delta = -0.0929, gamma = 0.0239, [0.44 0.32 0.08]
# i = 343, q_irr = 344, band_irr = 1, weight = 48.0, w_ha = 0.9695 THz, 6.0918e+00 rad/ps, delta = -0.1028, gamma = 0.0295, [0.48 0.32 0.08]
# i = 344, q_irr = 345, band_irr = 1, weight = 48.0, w_ha = 1.0771 THz, 6.7676e+00 rad/ps, delta = -0.1181, gamma = 0.0373, [0.52 0.32 0.08]
# i = 345, q_irr = 346, band_irr = 1, weight = 48.0, w_ha = 1.1869 THz, 7.4574e+00 rad/ps, delta = -0.1384, gamma = 0.0461, [0.56 0.32 0.08]
# i = 346, q_irr = 347, band_irr = 1, weight = 48.0, w_ha = 1.2704 THz, 7.9824e+00 rad/ps, delta = -0.1627, gamma = 0.0575, [0.6  0.32 0.08]
# ...
# i = 2616, q_irr = 342, band_irr = 6, weight = 24.0, w_ha = 5.5508 THz, 3.4877e+01 rad/ps, delta = -0.1523, gamma = 0.2178, [0.4  0.32 0.08]
# i = 2617, q_irr = 343, band_irr = 6, weight = 48.0, w_ha = 5.6395 THz, 3.5434e+01 rad/ps, delta = -0.1691, gamma = 0.2481, [0.44 0.32 0.08]
# i = 2618, q_irr = 344, band_irr = 6, weight = 48.0, w_ha = 5.7234 THz, 3.5961e+01 rad/ps, delta = -0.1760, gamma = 0.2965, [0.48 0.32 0.08]
# i = 2619, q_irr = 345, band_irr = 6, weight = 48.0, w_ha = 5.7909 THz, 3.6386e+01 rad/ps, delta = -0.1260, gamma = 0.3472, [0.52 0.32 0.08]
# i = 2620, q_irr = 346, band_irr = 6, weight = 48.0, w_ha = 5.8341 THz, 3.6657e+01 rad/ps, delta = -0.1109, gamma = 0.3472, [0.56 0.32 0.08]
# i = 2621, q_irr = 347, band_irr = 6, weight = 48.0, w_ha = 5.8463 THz, 3.6734e+01 rad/ps, delta = -0.1004, gamma = 0.3696, [0.6  0.32 0.08]
# i = 2622, q_irr = 348, band_irr = 6, weight = 48.0, w_ha = 5.8058 THz, 3.6479e+01 rad/ps, delta = -0.0449, gamma = 0.3666, [0.64 0.32 0.08]
# i = 2623, q_irr = 349, band_irr = 6, weight = 48.0, w_ha = 5.7363 THz, 3.6042e+01 rad/ps, delta = -0.0792, gamma = 0.3515, [0.68 0.32 0.08]
# i = 2624, q_irr = 350, band_irr = 6, weight = 48.0, w_ha = 5.6447 THz, 3.5466e+01 rad/ps, delta = -0.1029, gamma = 0.2888, [0.72 0.32 0.08]
# i = 2625, q_irr = 351, band_irr = 6, weight = 24.0, w_ha = 5.5952 THz, 3.5156e+01 rad/ps, delta = -0.1301, gamma = 0.2259, [0.76 0.32 0.08]
# i = 2626, q_irr = 352, band_irr = 6, weight = 24.0, w_ha = 5.6782 THz, 3.5677e+01 rad/ps, delta = -0.2101, gamma = 0.2512, [0.44 0.36 0.08]
# i = 2627, q_irr = 353, band_irr = 6, weight = 48.0, w_ha = 5.7399 THz, 3.6065e+01 rad/ps, delta = -0.1907, gamma = 0.3157, [0.48 0.36 0.08]
# i = 2628, q_irr = 354, band_irr = 6, weight = 48.0, w_ha = 5.7854 THz, 3.6351e+01 rad/ps, delta = -0.1428, gamma = 0.3878, [0.52 0.36 0.08]
# i = 2629, q_irr = 355, band_irr = 6, weight = 48.0, w_ha = 5.8089 THz, 3.6498e+01 rad/ps, delta = -0.0899, gamma = 0.3947, [0.56 0.36 0.08]
# i = 2630, q_irr = 356, band_irr = 6, weight = 48.0, w_ha = 5.8041 THz, 3.6468e+01 rad/ps, delta = -0.0356, gamma = 0.4332, [0.6  0.36 0.08]
# i = 2631, q_irr = 357, band_irr = 6, weight = 48.0, w_ha = 5.7633 THz, 3.6212e+01 rad/ps, delta = 0.0086, gamma = 0.4793, [0.64 0.36 0.08]
# i = 2632, q_irr = 358, band_irr = 6, weight = 48.0, w_ha = 5.6473 THz, 3.5483e+01 rad/ps, delta = -0.0470, gamma = 0.4544, [0.68 0.36 0.08]
# i = 2633, q_irr = 359, band_irr = 6, weight = 24.0, w_ha = 5.5637 THz, 3.4958e+01 rad/ps, delta = -0.1270, gamma = 0.2495, [0.72 0.36 0.08]
# i = 2634, q_irr = 360, band_irr = 6, weight = 24.0, w_ha = 5.8032 THz, 3.6462e+01 rad/ps, delta = -0.1728, gamma = 0.4030, [0.48 0.4  0.08]
# i = 2635, q_irr = 361, band_irr = 6, weight = 48.0, w_ha = 5.8334 THz, 3.6652e+01 rad/ps, delta = -0.0713, gamma = 0.4541, [0.52 0.4  0.08]
# i = 2636, q_irr = 362, band_irr = 6, weight = 48.0, w_ha = 5.8385 THz, 3.6684e+01 rad/ps, delta = -0.0092, gamma = 0.4311, [0.56 0.4  0.08]
# i = 2637, q_irr = 363, band_irr = 6, weight = 48.0, w_ha = 5.8159 THz, 3.6542e+01 rad/ps, delta = 0.0318, gamma = 0.4922, [0.6  0.4  0.08]
# i = 2638, q_irr = 364, band_irr = 6, weight = 48.0, w_ha = 5.7628 THz, 3.6209e+01 rad/ps, delta = 0.0881, gamma = 0.5529, [0.64 0.4  0.08]
# i = 2639, q_irr = 365, band_irr = 6, weight = 24.0, w_ha = 5.6564 THz, 3.5540e+01 rad/ps, delta = 0.0733, gamma = 0.5946, [0.68 0.4  0.08]
# i = 2640, q_irr = 366, band_irr = 6, weight = 24.0, w_ha = 5.9044 THz, 3.7098e+01 rad/ps, delta = 0.0311, gamma = 0.5000, [0.52 0.44 0.08]
# i = 2641, q_irr = 367, band_irr = 6, weight = 48.0, w_ha = 5.9016 THz, 3.7081e+01 rad/ps, delta = 0.1134, gamma = 0.4941, [0.56 0.44 0.08]
# i = 2642, q_irr = 368, band_irr = 6, weight = 48.0, w_ha = 5.8706 THz, 3.6886e+01 rad/ps, delta = 0.1261, gamma = 0.5285, [0.6  0.44 0.08]
# i = 2643, q_irr = 369, band_irr = 6, weight = 24.0, w_ha = 5.8169 THz, 3.6549e+01 rad/ps, delta = 0.1287, gamma = 0.5427, [0.64 0.44 0.08]
# i = 2644, q_irr = 370, band_irr = 6, weight = 24.0, w_ha = 5.9613 THz, 3.7456e+01 rad/ps, delta = 0.1395, gamma = 0.4458, [0.56 0.48 0.08]
# i = 2645, q_irr = 371, band_irr = 6, weight = 24.0, w_ha = 5.9270 THz, 3.7241e+01 rad/ps, delta = 0.1663, gamma = 0.5003, [0.6  0.48 0.08]
# i = 2646, q_irr = 372, band_irr = 6, weight = 24.0, w_ha = 5.4579 THz, 3.4293e+01 rad/ps, delta = -0.1243, gamma = 0.2236, [0.36 0.24 0.12]
# i = 2647, q_irr = 373, band_irr = 6, weight = 48.0, w_ha = 5.5359 THz, 3.4783e+01 rad/ps, delta = -0.1087, gamma = 0.2335, [0.4  0.24 0.12]
# i = 2648, q_irr = 374, band_irr = 6, weight = 48.0, w_ha = 5.6507 THz, 3.5504e+01 rad/ps, delta = -0.0959, gamma = 0.2664, [0.44 0.24 0.12]
# i = 2649, q_irr = 375, band_irr = 6, weight = 48.0, w_ha = 5.7683 THz, 3.6243e+01 rad/ps, delta = -0.1152, gamma = 0.2748, [0.48 0.24 0.12]
# i = 2650, q_irr = 376, band_irr = 6, weight = 48.0, w_ha = 5.8658 THz, 3.6856e+01 rad/ps, delta = -0.1137, gamma = 0.2777, [0.52 0.24 0.12]
# i = 2651, q_irr = 377, band_irr = 6, weight = 48.0, w_ha = 5.9335 THz, 3.7281e+01 rad/ps, delta = -0.1250, gamma = 0.2637, [0.56 0.24 0.12]
# i = 2652, q_irr = 378, band_irr = 6, weight = 48.0, w_ha = 5.9680 THz, 3.7498e+01 rad/ps, delta = -0.1289, gamma = 0.2658, [0.6  0.24 0.12]
# i = 2653, q_irr = 379, band_irr = 6, weight = 24.0, w_ha = 5.5119 THz, 3.4632e+01 rad/ps, delta = -0.1284, gamma = 0.2343, [0.4  0.28 0.12]
# i = 2654, q_irr = 380, band_irr = 6, weight = 48.0, w_ha = 5.5907 THz, 3.5127e+01 rad/ps, delta = -0.1308, gamma = 0.2463, [0.44 0.28 0.12]
# i = 2655, q_irr = 381, band_irr = 6, weight = 48.0, w_ha = 5.6928 THz, 3.5769e+01 rad/ps, delta = -0.1360, gamma = 0.2693, [0.48 0.28 0.12]
# i = 2656, q_irr = 382, band_irr = 6, weight = 48.0, w_ha = 5.7899 THz, 3.6379e+01 rad/ps, delta = -0.1179, gamma = 0.2890, [0.52 0.28 0.12]
# i = 2657, q_irr = 383, band_irr = 6, weight = 48.0, w_ha = 5.8639 THz, 3.6844e+01 rad/ps, delta = -0.1224, gamma = 0.2856, [0.56 0.28 0.12]
# i = 2658, q_irr = 384, band_irr = 6, weight = 48.0, w_ha = 5.9061 THz, 3.7109e+01 rad/ps, delta = -0.1147, gamma = 0.2993, [0.6  0.28 0.12]
# i = 2659, q_irr = 385, band_irr = 6, weight = 48.0, w_ha = 5.9094 THz, 3.7130e+01 rad/ps, delta = -0.1244, gamma = 0.3038, [0.64 0.28 0.12]
# i = 2660, q_irr = 386, band_irr = 6, weight = 48.0, w_ha = 5.8768 THz, 3.6925e+01 rad/ps, delta = -0.1043, gamma = 0.3003, [0.68 0.28 0.12]
# i = 2661, q_irr = 387, band_irr = 6, weight = 48.0, w_ha = 5.8091 THz, 3.6499e+01 rad/ps, delta = -0.0910, gamma = 0.2863, [0.72 0.28 0.12]
# i = 2662, q_irr = 388, band_irr = 6, weight = 48.0, w_ha = 5.7139 THz, 3.5902e+01 rad/ps, delta = -0.1049, gamma = 0.2668, [0.76 0.28 0.12]
# i = 2663, q_irr = 389, band_irr = 6, weight = 48.0, w_ha = 5.6135 THz, 3.5270e+01 rad/ps, delta = -0.1287, gamma = 0.2328, [0.8  0.28 0.12]
# i = 2664, q_irr = 390, band_irr = 6, weight = 24.0, w_ha = 5.5475 THz, 3.4856e+01 rad/ps, delta = -0.1415, gamma = 0.2209, [0.84 0.28 0.12]
# i = 2665, q_irr = 391, band_irr = 6, weight = 24.0, w_ha = 5.5889 THz, 3.5116e+01 rad/ps, delta = -0.1630, gamma = 0.2406, [0.44 0.32 0.12]
# i = 2666, q_irr = 392, band_irr = 6, weight = 48.0, w_ha = 5.6543 THz, 3.5527e+01 rad/ps, delta = -0.1813, gamma = 0.2809, [0.48 0.32 0.12]
# i = 2667, q_irr = 393, band_irr = 6, weight = 48.0, w_ha = 5.7303 THz, 3.6004e+01 rad/ps, delta = -0.1466, gamma = 0.3147, [0.52 0.32 0.12]
# i = 2668, q_irr = 394, band_irr = 6, weight = 48.0, w_ha = 5.7961 THz, 3.6418e+01 rad/ps, delta = -0.1125, gamma = 0.3226, [0.56 0.32 0.12]
# i = 2669, q_irr = 395, band_irr = 6, weight = 48.0, w_ha = 5.8366 THz, 3.6673e+01 rad/ps, delta = -0.0935, gamma = 0.3275, [0.6  0.32 0.12]
# i = 2670, q_irr = 396, band_irr = 6, weight = 48.0, w_ha = 5.8431 THz, 3.6713e+01 rad/ps, delta = -0.0835, gamma = 0.3553, [0.64 0.32 0.12]
# i = 2671, q_irr = 397, band_irr = 6, weight = 48.0, w_ha = 5.8017 THz, 3.6453e+01 rad/ps, delta = -0.0779, gamma = 0.3432, [0.68 0.32 0.12]
# i = 2672, q_irr = 398, band_irr = 6, weight = 48.0, w_ha = 5.7334 THz, 3.6024e+01 rad/ps, delta = -0.0934, gamma = 0.3264, [0.72 0.32 0.12]
# i = 2673, q_irr = 399, band_irr = 6, weight = 48.0, w_ha = 5.6513 THz, 3.5508e+01 rad/ps, delta = -0.1265, gamma = 0.2618, [0.76 0.32 0.12]
# i = 2674, q_irr = 400, band_irr = 6, weight = 24.0, w_ha = 5.6030 THz, 3.5205e+01 rad/ps, delta = -0.1557, gamma = 0.2279, [0.8  0.32 0.12]
# i = 2675, q_irr = 401, band_irr = 6, weight = 24.0, w_ha = 5.6766 THz, 3.5667e+01 rad/ps, delta = -0.2050, gamma = 0.2723, [0.48 0.36 0.12]
# i = 2676, q_irr = 402, band_irr = 6, weight = 48.0, w_ha = 5.7191 THz, 3.5934e+01 rad/ps, delta = -0.1706, gamma = 0.3456, [0.52 0.36 0.12]
# i = 2677, q_irr = 403, band_irr = 6, weight = 48.0, w_ha = 5.7587 THz, 3.6183e+01 rad/ps, delta = -0.1104, gamma = 0.3589, [0.56 0.36 0.12]
# i = 2678, q_irr = 404, band_irr = 6, weight = 48.0, w_ha = 5.7816 THz, 3.6327e+01 rad/ps, delta = -0.0769, gamma = 0.3767, [0.6  0.36 0.12]
# i = 2679, q_irr = 405, band_irr = 6, weight = 48.0, w_ha = 5.7757 THz, 3.6290e+01 rad/ps, delta = -0.0572, gamma = 0.4204, [0.64 0.36 0.12]
# i = 2680, q_irr = 406, band_irr = 6, weight = 48.0, w_ha = 5.7172 THz, 3.5922e+01 rad/ps, delta = -0.0455, gamma = 0.4187, [0.68 0.36 0.12]
# i = 2681, q_irr = 407, band_irr = 6, weight = 48.0, w_ha = 5.6409 THz, 3.5443e+01 rad/ps, delta = -0.0812, gamma = 0.3335, [0.72 0.36 0.12]
# i = 2682, q_irr = 408, band_irr = 6, weight = 24.0, w_ha = 5.6054 THz, 3.5220e+01 rad/ps, delta = -0.1487, gamma = 0.2612, [0.76 0.36 0.12]
# i = 2683, q_irr = 409, band_irr = 6, weight = 24.0, w_ha = 5.7643 THz, 3.6218e+01 rad/ps, delta = -0.1426, gamma = 0.4173, [0.52 0.4  0.12]
# i = 2684, q_irr = 410, band_irr = 6, weight = 48.0, w_ha = 5.7783 THz, 3.6306e+01 rad/ps, delta = -0.0920, gamma = 0.4201, [0.56 0.4  0.12]
# i = 2685, q_irr = 411, band_irr = 6, weight = 48.0, w_ha = 5.7758 THz, 3.6290e+01 rad/ps, delta = -0.0267, gamma = 0.4322, [0.6  0.4  0.12]
# i = 2686, q_irr = 412, band_irr = 6, weight = 48.0, w_ha = 5.7476 THz, 3.6113e+01 rad/ps, delta = 0.0146, gamma = 0.4862, [0.64 0.4  0.12]
# i = 2687, q_irr = 413, band_irr = 6, weight = 48.0, w_ha = 5.6657 THz, 3.5599e+01 rad/ps, delta = 0.0135, gamma = 0.5401, [0.68 0.4  0.12]
# i = 2688, q_irr = 414, band_irr = 6, weight = 24.0, w_ha = 5.5422 THz, 3.4823e+01 rad/ps, delta = 0.0141, gamma = 0.6217, [0.72 0.4  0.12]
# i = 2689, q_irr = 415, band_irr = 6, weight = 24.0, w_ha = 5.8385 THz, 3.6684e+01 rad/ps, delta = -0.0156, gamma = 0.4858, [0.56 0.44 0.12]
# i = 2690, q_irr = 416, band_irr = 6, weight = 48.0, w_ha = 5.8223 THz, 3.6583e+01 rad/ps, delta = 0.0331, gamma = 0.4996, [0.6  0.44 0.12]
# i = 2691, q_irr = 417, band_irr = 6, weight = 48.0, w_ha = 5.7828 THz, 3.6334e+01 rad/ps, delta = 0.1054, gamma = 0.5158, [0.64 0.44 0.12]
# i = 2692, q_irr = 418, band_irr = 6, weight = 24.0, w_ha = 5.7226 THz, 3.5956e+01 rad/ps, delta = 0.1121, gamma = 0.5474, [0.68 0.44 0.12]
# i = 2693, q_irr = 419, band_irr = 6, weight = 24.0, w_ha = 5.8821 THz, 3.6958e+01 rad/ps, delta = 0.1228, gamma = 0.5016, [0.6  0.48 0.12]
# i = 2694, q_irr = 420, band_irr = 6, weight = 24.0, w_ha = 5.8393 THz, 3.6690e+01 rad/ps, delta = 0.1688, gamma = 0.5060, [0.64 0.48 0.12]
# i = 2695, q_irr = 421, band_irr = 6, weight = 24.0, w_ha = 5.6030 THz, 3.5205e+01 rad/ps, delta = -0.1642, gamma = 0.2277, [0.48 0.32 0.16]
# i = 2696, q_irr = 422, band_irr = 6, weight = 48.0, w_ha = 5.6559 THz, 3.5537e+01 rad/ps, delta = -0.1487, gamma = 0.2652, [0.52 0.32 0.16]
# i = 2697, q_irr = 423, band_irr = 6, weight = 48.0, w_ha = 5.7323 THz, 3.6017e+01 rad/ps, delta = -0.1120, gamma = 0.3095, [0.56 0.32 0.16]
# i = 2698, q_irr = 424, band_irr = 6, weight = 48.0, w_ha = 5.7992 THz, 3.6437e+01 rad/ps, delta = -0.0797, gamma = 0.3254, [0.6  0.32 0.16]
# i = 2699, q_irr = 425, band_irr = 6, weight = 48.0, w_ha = 5.8370 THz, 3.6675e+01 rad/ps, delta = -0.0869, gamma = 0.3407, [0.64 0.32 0.16]
# i = 2700, q_irr = 426, band_irr = 6, weight = 24.0, w_ha = 5.6616 THz, 3.5573e+01 rad/ps, delta = -0.1857, gamma = 0.2784, [0.52 0.36 0.16]
# i = 2701, q_irr = 427, band_irr = 6, weight = 48.0, w_ha = 5.6923 THz, 3.5766e+01 rad/ps, delta = -0.1479, gamma = 0.3319, [0.56 0.36 0.16]
# i = 2702, q_irr = 428, band_irr = 6, weight = 48.0, w_ha = 5.7338 THz, 3.6027e+01 rad/ps, delta = -0.0841, gamma = 0.3521, [0.6  0.36 0.16]
# i = 2703, q_irr = 429, band_irr = 6, weight = 48.0, w_ha = 5.7614 THz, 3.6200e+01 rad/ps, delta = -0.0705, gamma = 0.3762, [0.64 0.36 0.16]
# i = 2704, q_irr = 430, band_irr = 6, weight = 48.0, w_ha = 5.7544 THz, 3.6156e+01 rad/ps, delta = -0.0476, gamma = 0.4157, [0.68 0.36 0.16]
# i = 2705, q_irr = 431, band_irr = 6, weight = 48.0, w_ha = 5.7167 THz, 3.5919e+01 rad/ps, delta = -0.0706, gamma = 0.3839, [0.72 0.36 0.16]
# i = 2706, q_irr = 432, band_irr = 6, weight = 48.0, w_ha = 5.6639 THz, 3.5587e+01 rad/ps, delta = -0.1199, gamma = 0.3073, [0.76 0.36 0.16]
# i = 2707, q_irr = 433, band_irr = 6, weight = 24.0, w_ha = 5.6373 THz, 3.5420e+01 rad/ps, delta = -0.1586, gamma = 0.2701, [0.8  0.36 0.16]
# i = 2708, q_irr = 434, band_irr = 6, weight = 24.0, w_ha = 5.7170 THz, 3.5921e+01 rad/ps, delta = -0.1235, gamma = 0.3689, [0.56 0.4  0.16]
# i = 2709, q_irr = 435, band_irr = 6, weight = 48.0, w_ha = 5.7193 THz, 3.5935e+01 rad/ps, delta = -0.0702, gamma = 0.3922, [0.6  0.4  0.16]
# i = 2710, q_irr = 436, band_irr = 6, weight = 48.0, w_ha = 5.7156 THz, 3.5912e+01 rad/ps, delta = -0.0472, gamma = 0.4428, [0.64 0.4  0.16]
# i = 2711, q_irr = 437, band_irr = 6, weight = 48.0, w_ha = 5.6899 THz, 3.5751e+01 rad/ps, delta = -0.0035, gamma = 0.4871, [0.68 0.4  0.16]
# i = 2712, q_irr = 438, band_irr = 6, weight = 48.0, w_ha = 5.6240 THz, 3.5336e+01 rad/ps, delta = -0.0373, gamma = 0.4563, [0.72 0.4  0.16]
# i = 2713, q_irr = 439, band_irr = 6, weight = 24.0, w_ha = 5.6037 THz, 3.5209e+01 rad/ps, delta = -0.1257, gamma = 0.3131, [0.76 0.4  0.16]
# i = 2714, q_irr = 440, band_irr = 6, weight = 24.0, w_ha = 5.7627 THz, 3.6208e+01 rad/ps, delta = -0.0491, gamma = 0.4586, [0.6  0.44 0.16]
# i = 2715, q_irr = 441, band_irr = 6, weight = 48.0, w_ha = 5.7353 THz, 3.6036e+01 rad/ps, delta = 0.0144, gamma = 0.4870, [0.64 0.44 0.16]
# i = 2716, q_irr = 442, band_irr = 6, weight = 48.0, w_ha = 5.6879 THz, 3.5738e+01 rad/ps, delta = 0.0751, gamma = 0.5318, [0.68 0.44 0.16]
# i = 2717, q_irr = 443, band_irr = 6, weight = 24.0, w_ha = 5.6038 THz, 3.5210e+01 rad/ps, delta = 0.0710, gamma = 0.5745, [0.72 0.44 0.16]
# i = 2718, q_irr = 444, band_irr = 6, weight = 24.0, w_ha = 5.7898 THz, 3.6379e+01 rad/ps, delta = 0.1126, gamma = 0.5178, [0.64 0.48 0.16]
# i = 2719, q_irr = 445, band_irr = 6, weight = 24.0, w_ha = 5.7410 THz, 3.6072e+01 rad/ps, delta = 0.1280, gamma = 0.5088, [0.68 0.48 0.16]
# i = 2720, q_irr = 446, band_irr = 6, weight = 24.0, w_ha = 5.6638 THz, 3.5587e+01 rad/ps, delta = -0.1323, gamma = 0.3482, [0.6 0.4 0.2]
# i = 2721, q_irr = 447, band_irr = 6, weight = 48.0, w_ha = 5.6612 THz, 3.5570e+01 rad/ps, delta = -0.0848, gamma = 0.3989, [0.64 0.4  0.2 ]
# i = 2722, q_irr = 448, band_irr = 6, weight = 48.0, w_ha = 5.6734 THz, 3.5647e+01 rad/ps, delta = 0.0010, gamma = 0.4566, [0.68 0.4  0.2 ]
# i = 2723, q_irr = 449, band_irr = 6, weight = 24.0, w_ha = 5.6811 THz, 3.5695e+01 rad/ps, delta = -0.0534, gamma = 0.4301, [0.64 0.44 0.2 ]
# i = 2724, q_irr = 450, band_irr = 6, weight = 48.0, w_ha = 5.6454 THz, 3.5471e+01 rad/ps, delta = 0.0094, gamma = 0.5045, [0.68 0.44 0.2 ]
# i = 2725, q_irr = 451, band_irr = 6, weight = 48.0, w_ha = 5.5982 THz, 3.5174e+01 rad/ps, delta = 0.0493, gamma = 0.5193, [0.72 0.44 0.2 ]
# i = 2726, q_irr = 452, band_irr = 6, weight = 24.0, w_ha = 5.5924 THz, 3.5138e+01 rad/ps, delta = -0.0695, gamma = 0.4358, [0.76 0.44 0.2 ]
# i = 2727, q_irr = 453, band_irr = 6, weight = 24.0, w_ha = 5.6895 THz, 3.5748e+01 rad/ps, delta = 0.1029, gamma = 0.5422, [0.68 0.48 0.2 ]
# i = 2728, q_irr = 454, band_irr = 6, weight = 24.0, w_ha = 5.6340 THz, 3.5399e+01 rad/ps, delta = 0.1449, gamma = 0.5642, [0.72 0.48 0.2 ]
# i = 2729, q_irr = 455, band_irr = 6, weight = 24.0, w_ha = 5.5808 THz, 3.5065e+01 rad/ps, delta = 0.0725, gamma = 0.5357, [0.72 0.48 0.24]

# %%
total_cv_weighted = 0.0
frequencies_qpa_d0 = []
cv_contributions_qpa_d0 = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
T = 200.0                # Temperature in Kelvin
integrated_modes_count = 0

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight
    integrated_modes_count += 1

    frequencies_qpa_d0.append(w_qs)
    cv_contributions_qpa_d0.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23
print(f"Modes used (integrated): {integrated_modes_count}")
print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Modes used (integrated): 2730
# Cv of unitcell(mol of unitcell): 45.4322 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Spectral Density at a specific Q-point ---
#target_q = np.array([0.2, 0, 0])

# Find the closest index in your q_coords
#q_diffs = np.linalg.norm(q_coords - target_q, axis=1)
#target_q_idx = np.argmin(q_diffs)

target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)  # the closest q-point index

print(f"Plotting for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: Band-major order means i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # Define a local frequency range around the peak for a smooth plot
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    #plt.plot(w_plot, b_w, label=f"Band {b+1} ($\omega_0$={w_qs:.2f})")
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_val:.2f})")
    
print(f"Plot width = {plot_width:.3f} THz for g_val = {g_val}")
plt.title(f"Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{{\\mathbf{{q}},s}}(\\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()


for b in range(num_bands):
    # Mapping: Band-major order
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # We use the same w_plot logic from your plotting script
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    # Numerical Integration of the Lorentzian peak
    integral = np.trapz(b_w, w_plot)
    
    print(f"Band {b+1}: Integral = {integral:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting for Q-point: [0.2 0.  0. ] (Index: 5)
# Plot width = 2.073 THz for g_val = 0.4146756046475402
# Band 1: Integral = 0.9886 (Bare w0 = 1.00)
# Band 2: Integral = 0.9885 (Bare w0 = 1.00)
# Band 3: Integral = 0.9862 (Bare w0 = 1.94)
# Band 4: Integral = 0.8743 (Bare w0 = 3.54)
# Band 5: Integral = 0.8743 (Bare w0 = 3.54)
# Band 6: Integral = 0.8743 (Bare w0 = 5.70)

# %%
total_cv_weighted = 0.0
frequencies_qpa = []
cv_contributions_qpa = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
#T = 100.0                # Temperature in Kelvin

for i in range(num_total_modes):
    # Mapping the global index 'i' back to the irreducible q-point index
    # Since w_bare is (num_bands * Nq_irr), the q-index repeats every Nq_irr
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    d_val = d_interps[i](w_qs)
    #d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight

    frequencies_qpa.append(w_qs)
    cv_contributions_qpa.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Cv of unitcell(mol of unitcell): 45.5745 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Extract Gamma values for all modes ---
gamma_values = []
frequencies_for_gamma = []

for i in range(num_total_modes):
    w_qs = w_bare[i]
    g_val = abs(g_interps[i](w_qs))
    
    gamma_values.append(g_val)
    frequencies_for_gamma.append(w_qs)

# --- 2. Plotting ---
plt.figure(figsize=(10, 6))
plt.scatter(frequencies_for_gamma, gamma_values, s=10, alpha=0.5, color='green', label='Mode Gamma ($\Gamma$)')

# Add a trend line (polynomial fit) to see the overall behavior
z = np.polyfit(frequencies_for_gamma, gamma_values, 2)
p = np.poly1d(z)
freq_range = np.linspace(min(frequencies_for_gamma), max(frequencies_for_gamma), 100)
#plt.plot(freq_range, p(freq_range), "r--", linewidth=2, label='Trend line ($\Gamma \propto \omega^n$)')

plt.title('Phonon Mode Gamma ($\Gamma$) vs. Frequency', fontsize=15)
plt.xlabel('Harmonic Frequency (THz)', fontsize=12)
plt.ylabel('Gamma (THz)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()

print(f"Average Gamma: {np.mean(gamma_values):.4f} THz")
print(f"Max Gamma: {np.max(gamma_values):.4f} THz at {frequencies_for_gamma[np.argmax(gamma_values)]:.2f} THz")
# Out:
# Average Gamma: 0.2402 THz
# Max Gamma: 0.8002 THz at 4.95 THz

# %%
import matplotlib.pyplot as plt


cv_contributions_qpa_d0 = np.array(cv_contributions_qpa_d0)
cv_contributions_qpa = np.array(cv_contributions_qpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='blue', label='QPA, delta=0')

plt.scatter(frequencies_qpa, cv_contributions_qpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='green', label='QPA')

# Constant
#const1_conv = 45.1754 / 6
#const2_conv = 45.2270 / 6

#plt.axhline(const1_conv, color='blue', linestyle='--', linewidth=2, label='Cv/mode of qpa(delta=0)')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode of qpa')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'QPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
plt.ylim(6, 8.5)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87677/370526515.py:28: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Reshape harmonic frequencies ---
# w_harmonic shape: (Nq_irr, num_bands)
w_harmonic = w_bare.reshape(num_bands, Nq_irr).T 

# --- 2. DOS Calculation Function ---
def calculate_harmonic_dos(frequencies, weights, energy_grid, sigma=0.05):
    """
    frequencies: (Nq_irr, num_bands)
    weights: (Nq_irr,) - Multiplicity of each q-point
    energy_grid: Frequency axis for the DOS plot
    sigma: Gaussian broadening width (THz)
    """
    dos = np.zeros_like(energy_grid)
    for i in range(len(weights)):
        for j in range(frequencies.shape[1]):
            # Add Gaussian contribution for each mode: weight * G(omega - w_ij)
            diff = energy_grid - frequencies[i, j]
            dos += weights[i] * np.exp(-0.5 * (diff / sigma)**2) / (sigma * np.sqrt(2 * np.pi))
    
    # Normalize by total number of q-points in full BZ
    return dos / np.sum(weights)

# --- 3. Setup Grid and Compute ---
# Create a frequency axis from 0 to slightly above max frequency
w_max = np.max(w_harmonic) * 1.05
energy_axis = np.linspace(0, w_max, 1000)

# Calculate DOS (You can adjust sigma for smoothness)
dos_harmonic = calculate_harmonic_dos(w_harmonic, degeneracies, energy_axis, sigma=0.04)

# --- 4. Plotting ---
plt.figure(figsize=(9, 6))
plt.plot(energy_axis, dos_harmonic, color='blue', linewidth=2, label='Harmonic DOS')
plt.fill_between(energy_axis, 0, dos_harmonic, color='blue', alpha=0.2)

plt.title('Harmonic Phonon Density of States (DOS)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States (States/THz)', fontsize=12)
plt.xlim(0, w_max)
plt.ylim(0, np.max(dos_harmonic) * 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print(f"Harmonic DOS plot complete.")
print(f"Frequency range: 0.0 to {np.max(w_harmonic):.3f} THz")
# Out:
# Harmonic DOS plot complete.
# Frequency range: 0.0 to 6.080 THz

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import numpy as np

total_cv_full = 0.0
frequencies_bqpa = []
cv_contributions_bqpa = []

# Define global frequency bounds from the loaded spectrum file
global_w_min = spec_data[:, 0].min()
global_w_max = spec_data[:, 0].max()

print(f"Starting Full Frequency-Dependent BQPA integration...")

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    if w_qs < 1e-10: continue

    # Local step size based on broadening at resonance
    g_ref = abs(g_interps[i](w_qs))
    dw = max(g_ref, 1e-4) / 10.0
    
    # Integration grid for this mode
    w_grid = np.arange(global_w_min, global_w_max, dw)
    
    # Evaluate frequency-dependent Delta and Gamma
    d_ws = d_interps[i](w_grid)
    g_ws = np.abs(g_interps[i](w_grid))
    
    # Spectral Density b_qs(w)
    denoms = (w_grid - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denoms)
    
    # Heat Capacity Kernel with Singularity Fix
    x = (w_grid * THz_to_eV) / (kB * T)
    cv_kernels = np.zeros_like(x)
    
    # Handle x=0 limit (kB) and general case
    m_zero = (x < 1e-7)
    m_finite = (x >= 1e-7) & (x < 50)
    
    cv_kernels[m_zero] = kB
    cv_kernels[m_finite] = kB * (x[m_finite]**2 * np.exp(x[m_finite])) / (np.exp(x[m_finite]) - 1)**2
    
    # Mode contribution (Area under b_w * Cv_kernel)
    mode_integral = np.sum(b_ws * cv_kernels) * dw
    total_cv_weighted = mode_integral * weight
    
    total_cv_full += total_cv_weighted
    frequencies_bqpa.append(w_qs)
    cv_contributions_bqpa.append(mode_integral)

# Final Normalization
cv_per_cell = total_cv_full / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Full Frequency-Dependent Cv: {cv_j_mol:.4f} J/K/mol")
# Out:
# Starting Full Frequency-Dependent BQPA integration...
# Full Frequency-Dependent Cv: 47.5195 J/K/mol

# %%
import matplotlib.pyplot as plt

cv_contributions_bqpa = np.array(cv_contributions_bqpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
#plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
 #           color='blue', label='QPA, delta=0')

plt.scatter(frequencies_bqpa, cv_contributions_bqpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='purple', label='BQPA')

# Constant
#const1_conv = 49.2084 / 6
#const2_conv = 48.761459 / 6

#plt.axhline(const1_conv, color='purple', linestyle='--', linewidth=2, label='Cv/mode of BQPA')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode at gamma=1.0')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'BQPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
#plt.ylim(7.5, 10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87677/703786594.py:26: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Full Spectral Density at a specific Q-point ---
target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)

print(f"Plotting Full Spectral Density for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]

    g_ref = abs(g_interps[mode_idx](w_qs))
    d_ref = d_interps[mode_idx](w_qs)
    
    # Define a local frequency range around the renormalized peak
    plot_width = max(g_ref * 5, 20.0) 
    w_plot = np.linspace(w_qs + d_ref - plot_width, w_qs + d_ref + plot_width, 1000)
    
    # Clip to ensure we stay within the BTE spectrum file bounds
    w_plot = np.clip(w_plot, global_w_min, global_w_max)
    
    # --- Full Frequency-Dependent Calculation ---
    # Evaluate d(w) and g(w) at every point in the plot range
    d_ws = d_interps[mode_idx](w_plot)
    g_ws = np.abs(g_interps[mode_idx](w_plot))
    
    # Spectral Density b(w) = (1/pi) * [ g(w) / ( (w - w_qs - d(w))^2 + g(w)^2 ) ]
    denom = (w_plot - w_qs - d_ws)**2 + g_ws**2
    b_w = (1/np.pi) * (g_ws / denom)
    
    # Plotting the result for the band
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_ref:.2f})")

plt.title(f"Full Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{\mathbf{q},s}(\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()

for b in range(num_bands):
    mode_idx = b * Nq_irr + target_q_idx
    w_qs = w_bare[mode_idx]
    
    # We must integrate over the FULL range of your data to capture 
    # the weight of broad/flat modes.
    w_val = np.arange(global_w_min, global_w_max, 0.01) # Use a fine constant grid
    
    # Evaluate full frequency-dependent d and g
    d_ws = d_interps[mode_idx](w_val)
    g_ws = np.abs(g_interps[mode_idx](w_val))
    
    # Calculate b(w)
    denom = (w_val - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denom)
    
    # Numerical integration (Area)
    area = np.trapz(b_ws, w_val)
    
    print(f"Band {b+1}: Integral = {area:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting Full Spectral Density for Q-point: [0.2 0.  0. ] (Index: 5)
# Band 1: Integral = 1.0105 (Bare w0 = 1.00)
# Band 2: Integral = 1.0110 (Bare w0 = 1.00)
# Band 3: Integral = 1.0049 (Bare w0 = 1.94)
# Band 4: Integral = 1.0165 (Bare w0 = 3.54)
# Band 5: Integral = 1.0168 (Bare w0 = 3.54)
# Band 6: Integral = 1.0062 (Bare w0 = 5.70)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_normalized_modes_simple(file_path):
    with open(file_path, 'r') as f:
        content = f.read().strip().split('\n')
    
    modes_list = []
    current_mode = {}
    temp_grid_density = []

    for line in content:
        parts = line.split()
        if len(parts) == 1:
            if current_mode:
                half = len(temp_grid_density) // 2
                current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
                current_mode['y'] = np.array(temp_grid_density[half:])
                modes_list.append(current_mode)
            current_mode = {'center': float(parts[0]) / (2 * np.pi)}
            temp_grid_density = []
        else:
            temp_grid_density.extend([float(p) for p in parts])

    if current_mode:
        half = len(temp_grid_density) // 2
        current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
        current_mode['y'] = np.array(temp_grid_density[half:])
        modes_list.append(current_mode)

    plt.figure(figsize=(10, 6))

    for idx, m in enumerate(modes_list):
        norm_factor = np.trapz(m['y'], m['x'])
        y_norm = m['y'] / norm_factor
        plt.plot(m['x'], y_norm/ (2 * np.pi), label=f'Mode {idx+1}')

    plt.xlabel('Frequency (THz)')
    plt.ylabel('Normalized Spectral Density')
    plt.title('Normalized Vibrational Modes')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()


plot_normalized_modes_simple('bspec_omega_5.dat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 46
#      42     plt.legend()
#      43     plt.show()
# ---> 46 plot_normalized_modes_simple('bspec_omega_5.dat')
#
# Cell In[17], line 5, in plot_normalized_modes_simple(file_path)
#       4 def plot_normalized_modes_simple(file_path):
# ----> 5     with open(file_path, 'r') as f:
#       6         content = f.read().strip().split('\n')
#       8     modes_list = []
#
# File /opt/anaconda3/envs/phonopy/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bspec_omega_5.dat'

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Setup Energy Grid ---
# Use the global bounds from your spectrum data
energy_axis = np.linspace(global_w_min, global_w_max, 1000)
dos_bqpa_full = np.zeros_like(energy_axis)

print("Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...")

# --- 2. Accumulate Full Spectral Density for each mode ---
for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    # 1. Evaluate Delta(w) and Gamma(w) on the entire energy axis
    d_ws = d_interps[i](energy_axis)
    g_ws = np.abs(g_interps[i](energy_axis))
    
    # 2. Calculate the Full Spectral Density b_qs(w)
    # This reflects the true shape of the phonon state in an anharmonic potential
    denoms = (energy_axis - w_qs - d_ws)**2 + g_ws**2
    
    # Avoid division by zero for very stable modes
    g_ws_safe = np.where(g_ws < 1e-6, 1e-6, g_ws)
    b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
    
    # 3. Add to total DOS with degeneracy weight
    dos_bqpa_full += weight * b_ws

# --- 3. Final Normalization ---
dos_bqpa_full /= Nq_total

# --- 4. Plotting Comparison: Harmonic vs QPA vs BQPA ---
plt.figure(figsize=(12, 7))

# 1. Harmonic DOS (Reference)
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.3)

# 2. QPA DOS (From previous step - if you have the variable)
#if 'dos_qpa_varied' in locals():
#    plt.plot(energy_axis, dos_qpa_varied, color='green', label='QPA DOS (Single-point $\Sigma$)', alpha=0.5)

# 3. Full BQPA DOS
plt.plot(energy_axis, dos_bqpa_full, color='purple', linewidth=2.5, label='Full BQPA DOS (Freq-dependent $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_bqpa_full, color='purple', alpha=0.15)

plt.title('Phonon DOS: Full BQPA Comparison', fontsize=16)
plt.xlabel('Frequency (THz)', fontsize=13)
plt.ylabel('Density of States', fontsize=13)
plt.xlim(0, global_w_max)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87677/737035693.py:27: RuntimeWarning: divide by zero encountered in divide
#   b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
