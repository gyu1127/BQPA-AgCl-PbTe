# %%
from ase.io import read
import numpy as np

# 1. Load the POSCAR
# This gives you an Atoms object which knows positions, masses, and cell
atoms = read('POSCAR')
n_atoms = len(atoms)
masses = atoms.get_masses()  # in amu
cell = atoms.get_cell()      # lattice vectors
positions = atoms.get_positions() # Cartesian coordinates
sc_dims = np.array([4, 4, 4])

print(f"Loaded {n_atoms} atoms.")
print(f"{atoms}")
# Out:
# Loaded 2 atoms.
# Atoms(symbols='AgCl', pbc=True, cell=[[0.0, 2.7221417586264813, 2.7221417586264813], [2.7221417586264813, 0.0, 2.7221417586264813], [2.7221417586264813, 2.7221417586264813, 0.0]])

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.omega (Assumed Band-major after flattening) ---
# data_omega shape: (Nq_irr, num_bands) -> e.g., (455, 6)
data_omega = np.loadtxt('BTE.omega') 
Nq = data_omega.shape[0]
num_bands = data_omega.shape[1]

# Replicate your current logic: Band 1 (all q), then Band 2 (all q)...
# Dividing by 2*pi to convert from rad/ps to THz
w_bare = (data_omega.T).flatten() / (2 * np.pi)
num_total_modes = len(w_bare)

print(f"Total modes: {num_total_modes} from BTE.omega")
print(f"Detected Nq (q-points): {Nq}, Bands: {num_bands}")

# --- 2. Load and Parse BTE.selfeng3ph_spectrum (q-major order) ---
# Each block in this file follows: q1_b1, q1_b2... q1_b6, q2_b1...
spec_data = np.genfromtxt('BTE.selfeng3ph_spectrum')

# Calculate the number of frequency grid points per mode block
pts_per_mode = len(spec_data) // num_total_modes

# Initialize lists to store interpolation functions in Band-major order
d_interps = [None] * num_total_modes
g_interps = [None] * num_total_modes

print(f"Parsing blocks and re-mapping q-major file to Band-major w_bare...")

for i in range(num_total_modes):
    # 'i' represents the sequence in the FILE (q-major)
    # q_idx changes slowly, b_idx changes fast
    q_idx = i // num_bands
    b_idx = i % num_bands
    
    # Calculate the 'target_mode_idx' to match the Band-major 'w_bare'
    # In Band-major: b_idx changes slowly, q_idx changes fast
    target_mode_idx = b_idx * Nq + q_idx
    
    # Extract the data block for the current mode
    start = i * pts_per_mode
    end = (i + 1) * pts_per_mode
    mode_block = spec_data[start:end]
    
    w_grid = mode_block[:, 0] # Frequency grid (THz)
    # Convert Delta and Gamma from rad/ps to THz
    d_grid = mode_block[:, 1] / (2 * np.pi) 
    g_grid = mode_block[:, 2] / (2 * np.pi)
    
    # Map the interpolation function to the correct index for w_bare[target_mode_idx]
    d_interps[target_mode_idx] = interp1d(w_grid, d_grid, kind='linear', fill_value="extrapolate")
    g_interps[target_mode_idx] = interp1d(w_grid, g_grid, kind='linear', fill_value="extrapolate")

print("Successfully loaded and re-ordered all interpolation blocks!")
# Out:
# Total modes: 2730 from BTE.omega
# Detected Nq (q-points): 455, Bands: 6
# Parsing blocks and re-mapping q-major file to Band-major w_bare...
# Successfully loaded and re-ordered all interpolation blocks!

# %%
# --- 3. Verification Test ---
# With the transpose, index 'i' now follows (Band_index * Nq + q_index).
# Band 2, first q-point (q=1) is located at index i = 1 * Nq + 0 = Nq.
band = 5
q = 1

band_idx = band - 1
q_idx = q - 1

test_idx = band_idx * Nq + q_idx
if test_idx < num_total_modes:
    test_w = w_bare[test_idx]
    print(f"\nVerification at Index {test_idx} (Band={band}, q={q}):")
    print(f"Bare Frequency (converted to THz): {test_w:.4f}")
    print(f"Delta at bare freq: {d_interps[test_idx](test_w)*(2*np.pi):.6f}")
    print(f"Gamma at bare freq: {g_interps[test_idx](test_w)*(2*np.pi):.6f}")
# Out:
# Verification at Index 1820 (Band=5, q=1):
# Bare Frequency (converted to THz): 3.8685
# Delta at bare freq: -3.756097
# Gamma at bare freq: 2.673210

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.qpoints to get degeneracies ---
q_data = np.genfromtxt('BTE.qpoints')
# Column 2 (index 2) is the degeneracy (multiplicity)
degeneracies = q_data[:, 2] 
Nq_irr = len(degeneracies) # the number of qpoints in irreducible wedge
Nq_total = np.sum(degeneracies) # the number of qpoints in whole BZ
q_coords = q_data[:, 3:6]

print(f"Number of irreducible q-points: {Nq_irr}")
print(f"Total q-points in full BZ (Sum of weights): {Nq_total}")
# Out:
# Number of irreducible q-points: 455
# Total q-points in full BZ (Sum of weights): 15625.0

# %%
for i in range(num_total_modes):
    w_qs = w_bare[i]
    #if w_qs < 1e-5: 
    #    continue

    q_irr_idx = i % Nq_irr
    band_irr_idx = i // Nq_irr
    weight = degeneracies[q_irr_idx]
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    q_coords_test = q_coords[q_irr_idx]

    print(f"i = {i}, q_irr = {q_irr_idx+1}, band_irr = {band_irr_idx+1}, weight = {weight}, w_ha = {w_qs:.4f} THz, {w_qs*(2 * np.pi):.4e} rad/ps, delta = {d_val:.4f}, gamma = {g_val:.4f}, {q_coords_test}")

# i: (b1,q1), (b1, q2), (b1, q3), ...
# Out:
# i = 0, q_irr = 1, band_irr = 1, weight = 1.0, w_ha = 0.0000 THz, 0.0000e+00 rad/ps, delta = 0.0000, gamma = 0.0000, [0. 0. 0.]
# i = 1, q_irr = 2, band_irr = 1, weight = 8.0, w_ha = 0.2286 THz, 1.4364e+00 rad/ps, delta = -0.0262, gamma = 0.0026, [0.04 0.   0.  ]
# i = 2, q_irr = 3, band_irr = 1, weight = 8.0, w_ha = 0.4512 THz, 2.8348e+00 rad/ps, delta = -0.0528, gamma = 0.0089, [0.08 0.   0.  ]
# i = 3, q_irr = 4, band_irr = 1, weight = 8.0, w_ha = 0.6622 THz, 4.1605e+00 rad/ps, delta = -0.0797, gamma = 0.0175, [0.12 0.   0.  ]
# i = 4, q_irr = 5, band_irr = 1, weight = 8.0, w_ha = 0.8573 THz, 5.3863e+00 rad/ps, delta = -0.1099, gamma = 0.0310, [0.16 0.   0.  ]
# i = 5, q_irr = 6, band_irr = 1, weight = 8.0, w_ha = 1.0341 THz, 6.4976e+00 rad/ps, delta = -0.1427, gamma = 0.0449, [0.2 0.  0. ]
# i = 6, q_irr = 7, band_irr = 1, weight = 8.0, w_ha = 1.1935 THz, 7.4989e+00 rad/ps, delta = -0.1768, gamma = 0.0633, [0.24 0.   0.  ]
# i = 7, q_irr = 8, band_irr = 1, weight = 8.0, w_ha = 1.3397 THz, 8.4174e+00 rad/ps, delta = -0.2184, gamma = 0.0890, [0.28 0.   0.  ]
# i = 8, q_irr = 9, band_irr = 1, weight = 8.0, w_ha = 1.4801 THz, 9.2997e+00 rad/ps, delta = -0.2544, gamma = 0.1094, [0.32 0.   0.  ]
# i = 9, q_irr = 10, band_irr = 1, weight = 8.0, w_ha = 1.6230 THz, 1.0198e+01 rad/ps, delta = -0.2948, gamma = 0.1402, [0.36 0.   0.  ]
# i = 10, q_irr = 11, band_irr = 1, weight = 8.0, w_ha = 1.7745 THz, 1.1150e+01 rad/ps, delta = -0.3179, gamma = 0.1678, [0.4 0.  0. ]
# i = 11, q_irr = 12, band_irr = 1, weight = 8.0, w_ha = 1.9353 THz, 1.2160e+01 rad/ps, delta = -0.3243, gamma = 0.1827, [0.44 0.   0.  ]
# i = 12, q_irr = 13, band_irr = 1, weight = 8.0, w_ha = 2.0891 THz, 1.3126e+01 rad/ps, delta = -0.2840, gamma = 0.1838, [0.48 0.   0.  ]
# i = 13, q_irr = 14, band_irr = 1, weight = 6.0, w_ha = 0.1945 THz, 1.2223e+00 rad/ps, delta = -0.0146, gamma = 0.0016, [0.04 0.04 0.  ]
# i = 14, q_irr = 15, band_irr = 1, weight = 24.0, w_ha = 0.3503 THz, 2.2013e+00 rad/ps, delta = -0.0324, gamma = 0.0048, [0.08 0.04 0.  ]
# i = 15, q_irr = 16, band_irr = 1, weight = 24.0, w_ha = 0.5440 THz, 3.4182e+00 rad/ps, delta = -0.0571, gamma = 0.0118, [0.12 0.04 0.  ]
# i = 16, q_irr = 17, band_irr = 1, weight = 24.0, w_ha = 0.7334 THz, 4.6083e+00 rad/ps, delta = -0.0827, gamma = 0.0209, [0.16 0.04 0.  ]
# i = 17, q_irr = 18, band_irr = 1, weight = 24.0, w_ha = 0.9081 THz, 5.7056e+00 rad/ps, delta = -0.1109, gamma = 0.0314, [0.2  0.04 0.  ]
# i = 18, q_irr = 19, band_irr = 1, weight = 24.0, w_ha = 1.0647 THz, 6.6898e+00 rad/ps, delta = -0.1463, gamma = 0.0472, [0.24 0.04 0.  ]
# i = 19, q_irr = 20, band_irr = 1, weight = 24.0, w_ha = 1.2047 THz, 7.5692e+00 rad/ps, delta = -0.1835, gamma = 0.0680, [0.28 0.04 0.  ]
# i = 20, q_irr = 21, band_irr = 1, weight = 24.0, w_ha = 1.3332 THz, 8.3770e+00 rad/ps, delta = -0.2187, gamma = 0.0888, [0.32 0.04 0.  ]
# i = 21, q_irr = 22, band_irr = 1, weight = 24.0, w_ha = 1.4585 THz, 9.1642e+00 rad/ps, delta = -0.2586, gamma = 0.1134, [0.36 0.04 0.  ]
# i = 22, q_irr = 23, band_irr = 1, weight = 24.0, w_ha = 1.5892 THz, 9.9851e+00 rad/ps, delta = -0.2913, gamma = 0.1385, [0.4  0.04 0.  ]
# i = 23, q_irr = 24, band_irr = 1, weight = 24.0, w_ha = 1.7317 THz, 1.0881e+01 rad/ps, delta = -0.3069, gamma = 0.1708, [0.44 0.04 0.  ]
# i = 24, q_irr = 25, band_irr = 1, weight = 24.0, w_ha = 1.8887 THz, 1.1867e+01 rad/ps, delta = -0.3169, gamma = 0.1881, [0.48 0.04 0.  ]
# i = 25, q_irr = 26, band_irr = 1, weight = 24.0, w_ha = 1.9983 THz, 1.2556e+01 rad/ps, delta = -0.3001, gamma = 0.1721, [0.52 0.04 0.  ]
# i = 26, q_irr = 27, band_irr = 1, weight = 24.0, w_ha = 1.8374 THz, 1.1545e+01 rad/ps, delta = -0.2991, gamma = 0.1729, [0.56 0.04 0.  ]
# i = 27, q_irr = 28, band_irr = 1, weight = 24.0, w_ha = 1.6855 THz, 1.0590e+01 rad/ps, delta = -0.2903, gamma = 0.1497, [0.6  0.04 0.  ]
# i = 28, q_irr = 29, band_irr = 1, weight = 24.0, w_ha = 1.5465 THz, 9.7169e+00 rad/ps, delta = -0.2664, gamma = 0.1182, [0.64 0.04 0.  ]
# i = 29, q_irr = 30, band_irr = 1, weight = 24.0, w_ha = 1.4165 THz, 8.9004e+00 rad/ps, delta = -0.2297, gamma = 0.0956, [0.68 0.04 0.  ]
# i = 30, q_irr = 31, band_irr = 1, weight = 24.0, w_ha = 1.2882 THz, 8.0937e+00 rad/ps, delta = -0.1930, gamma = 0.0758, [0.72 0.04 0.  ]
# i = 31, q_irr = 32, band_irr = 1, weight = 24.0, w_ha = 1.1527 THz, 7.2425e+00 rad/ps, delta = -0.1555, gamma = 0.0546, [0.76 0.04 0.  ]
# i = 32, q_irr = 33, band_irr = 1, weight = 24.0, w_ha = 1.0029 THz, 6.3012e+00 rad/ps, delta = -0.1222, gamma = 0.0374, [0.8  0.04 0.  ]
# i = 33, q_irr = 34, band_irr = 1, weight = 24.0, w_ha = 0.8348 THz, 5.2454e+00 rad/ps, delta = -0.0919, gamma = 0.0252, [0.84 0.04 0.  ]
# i = 34, q_irr = 35, band_irr = 1, weight = 24.0, w_ha = 0.6490 THz, 4.0775e+00 rad/ps, delta = -0.0635, gamma = 0.0150, [0.88 0.04 0.  ]
# i = 35, q_irr = 36, band_irr = 1, weight = 24.0, w_ha = 0.4525 THz, 2.8430e+00 rad/ps, delta = -0.0387, gamma = 0.0078, [0.92 0.04 0.  ]
# i = 36, q_irr = 37, band_irr = 1, weight = 12.0, w_ha = 0.2770 THz, 1.7402e+00 rad/ps, delta = -0.0207, gamma = 0.0030, [0.96 0.04 0.  ]
# i = 37, q_irr = 38, band_irr = 1, weight = 6.0, w_ha = 0.3652 THz, 2.2945e+00 rad/ps, delta = -0.0283, gamma = 0.0057, [0.08 0.08 0.  ]
# i = 38, q_irr = 39, band_irr = 1, weight = 24.0, w_ha = 0.4801 THz, 3.0169e+00 rad/ps, delta = -0.0436, gamma = 0.0099, [0.12 0.08 0.  ]
# i = 39, q_irr = 40, band_irr = 1, weight = 24.0, w_ha = 0.6331 THz, 3.9780e+00 rad/ps, delta = -0.0637, gamma = 0.0152, [0.16 0.08 0.  ]
# i = 40, q_irr = 41, band_irr = 1, weight = 24.0, w_ha = 0.7902 THz, 4.9649e+00 rad/ps, delta = -0.0876, gamma = 0.0239, [0.2  0.08 0.  ]
# i = 41, q_irr = 42, band_irr = 1, weight = 24.0, w_ha = 0.9378 THz, 5.8926e+00 rad/ps, delta = -0.1178, gamma = 0.0352, [0.24 0.08 0.  ]
# i = 42, q_irr = 43, band_irr = 1, weight = 24.0, w_ha = 1.0718 THz, 6.7346e+00 rad/ps, delta = -0.1491, gamma = 0.0511, [0.28 0.08 0.  ]
# i = 43, q_irr = 44, band_irr = 1, weight = 24.0, w_ha = 1.1939 THz, 7.5015e+00 rad/ps, delta = -0.1842, gamma = 0.0683, [0.32 0.08 0.  ]
# i = 44, q_irr = 45, band_irr = 1, weight = 24.0, w_ha = 1.3100 THz, 8.2310e+00 rad/ps, delta = -0.2246, gamma = 0.0886, [0.36 0.08 0.  ]
# i = 45, q_irr = 46, band_irr = 1, weight = 24.0, w_ha = 1.4287 THz, 8.9766e+00 rad/ps, delta = -0.2604, gamma = 0.1162, [0.4  0.08 0.  ]
# i = 46, q_irr = 47, band_irr = 1, weight = 24.0, w_ha = 1.5582 THz, 9.7906e+00 rad/ps, delta = -0.2930, gamma = 0.1414, [0.44 0.08 0.  ]
# i = 47, q_irr = 48, band_irr = 1, weight = 24.0, w_ha = 1.7042 THz, 1.0708e+01 rad/ps, delta = -0.3128, gamma = 0.1808, [0.48 0.08 0.  ]
# i = 48, q_irr = 49, band_irr = 1, weight = 24.0, w_ha = 1.8680 THz, 1.1737e+01 rad/ps, delta = -0.3268, gamma = 0.1975, [0.52 0.08 0.  ]
# i = 49, q_irr = 50, band_irr = 1, weight = 24.0, w_ha = 1.7574 THz, 1.1042e+01 rad/ps, delta = -0.2623, gamma = 0.1496, [0.56 0.08 0.  ]
# i = 50, q_irr = 51, band_irr = 1, weight = 24.0, w_ha = 1.6022 THz, 1.0067e+01 rad/ps, delta = -0.2596, gamma = 0.1315, [0.6  0.08 0.  ]
# i = 51, q_irr = 52, band_irr = 1, weight = 24.0, w_ha = 1.4645 THz, 9.2019e+00 rad/ps, delta = -0.2274, gamma = 0.0999, [0.64 0.08 0.  ]
# i = 52, q_irr = 53, band_irr = 1, weight = 24.0, w_ha = 1.3401 THz, 8.4201e+00 rad/ps, delta = -0.1971, gamma = 0.0795, [0.68 0.08 0.  ]
# i = 53, q_irr = 54, band_irr = 1, weight = 24.0, w_ha = 1.2206 THz, 7.6693e+00 rad/ps, delta = -0.1610, gamma = 0.0600, [0.72 0.08 0.  ]
# i = 54, q_irr = 55, band_irr = 1, weight = 24.0, w_ha = 1.0971 THz, 6.8935e+00 rad/ps, delta = -0.1288, gamma = 0.0435, [0.76 0.08 0.  ]
# i = 55, q_irr = 56, band_irr = 1, weight = 24.0, w_ha = 0.9632 THz, 6.0521e+00 rad/ps, delta = -0.0997, gamma = 0.0317, [0.8  0.08 0.  ]
# i = 56, q_irr = 57, band_irr = 1, weight = 24.0, w_ha = 0.8173 THz, 5.1351e+00 rad/ps, delta = -0.0735, gamma = 0.0214, [0.84 0.08 0.  ]
# i = 57, q_irr = 58, band_irr = 1, weight = 24.0, w_ha = 0.6657 THz, 4.1825e+00 rad/ps, delta = -0.0511, gamma = 0.0136, [0.88 0.08 0.  ]
# i = 58, q_irr = 59, band_irr = 1, weight = 12.0, w_ha = 0.5293 THz, 3.3256e+00 rad/ps, delta = -0.0379, gamma = 0.0096, [0.92 0.08 0.  ]
# i = 59, q_irr = 60, band_irr = 1, weight = 6.0, w_ha = 0.4935 THz, 3.1009e+00 rad/ps, delta = -0.0428, gamma = 0.0110, [0.12 0.12 0.  ]
# i = 60, q_irr = 61, band_irr = 1, weight = 24.0, w_ha = 0.5740 THz, 3.6063e+00 rad/ps, delta = -0.0550, gamma = 0.0147, [0.16 0.12 0.  ]
# i = 61, q_irr = 62, band_irr = 1, weight = 24.0, w_ha = 0.6899 THz, 4.3346e+00 rad/ps, delta = -0.0723, gamma = 0.0210, [0.2  0.12 0.  ]
# i = 62, q_irr = 63, band_irr = 1, weight = 24.0, w_ha = 0.8164 THz, 5.1298e+00 rad/ps, delta = -0.0968, gamma = 0.0277, [0.24 0.12 0.  ]
# i = 63, q_irr = 64, band_irr = 1, weight = 24.0, w_ha = 0.9408 THz, 5.9110e+00 rad/ps, delta = -0.1259, gamma = 0.0383, [0.28 0.12 0.  ]
# i = 64, q_irr = 65, band_irr = 1, weight = 24.0, w_ha = 1.0588 THz, 6.6524e+00 rad/ps, delta = -0.1558, gamma = 0.0517, [0.32 0.12 0.  ]
# i = 65, q_irr = 66, band_irr = 1, weight = 24.0, w_ha = 1.1724 THz, 7.3665e+00 rad/ps, delta = -0.1928, gamma = 0.0665, [0.36 0.12 0.  ]
# i = 66, q_irr = 67, band_irr = 1, weight = 24.0, w_ha = 1.2878 THz, 8.0912e+00 rad/ps, delta = -0.2321, gamma = 0.0920, [0.4  0.12 0.  ]
# i = 67, q_irr = 68, band_irr = 1, weight = 24.0, w_ha = 1.4122 THz, 8.8730e+00 rad/ps, delta = -0.2633, gamma = 0.1136, [0.44 0.12 0.  ]
# i = 68, q_irr = 69, band_irr = 1, weight = 24.0, w_ha = 1.5515 THz, 9.7487e+00 rad/ps, delta = -0.2992, gamma = 0.1415, [0.48 0.12 0.  ]
# i = 69, q_irr = 70, band_irr = 1, weight = 24.0, w_ha = 1.7080 THz, 1.0732e+01 rad/ps, delta = -0.3183, gamma = 0.1726, [0.52 0.12 0.  ]
# i = 70, q_irr = 71, band_irr = 1, weight = 24.0, w_ha = 1.6856 THz, 1.0591e+01 rad/ps, delta = -0.2502, gamma = 0.1333, [0.56 0.12 0.  ]
# i = 71, q_irr = 72, band_irr = 1, weight = 24.0, w_ha = 1.5180 THz, 9.5376e+00 rad/ps, delta = -0.2296, gamma = 0.1020, [0.6  0.12 0.  ]
# i = 72, q_irr = 73, band_irr = 1, weight = 24.0, w_ha = 1.3733 THz, 8.6288e+00 rad/ps, delta = -0.2108, gamma = 0.0831, [0.64 0.12 0.  ]
# i = 73, q_irr = 74, band_irr = 1, weight = 24.0, w_ha = 1.2499 THz, 7.8535e+00 rad/ps, delta = -0.1801, gamma = 0.0653, [0.68 0.12 0.  ]
# i = 74, q_irr = 75, band_irr = 1, weight = 24.0, w_ha = 1.1404 THz, 7.1652e+00 rad/ps, delta = -0.1404, gamma = 0.0470, [0.72 0.12 0.  ]
# i = 75, q_irr = 76, band_irr = 1, weight = 24.0, w_ha = 1.0361 THz, 6.5098e+00 rad/ps, delta = -0.1110, gamma = 0.0353, [0.76 0.12 0.  ]
# i = 76, q_irr = 77, band_irr = 1, weight = 24.0, w_ha = 0.9313 THz, 5.8513e+00 rad/ps, delta = -0.0881, gamma = 0.0264, [0.8  0.12 0.  ]
# i = 77, q_irr = 78, band_irr = 1, weight = 24.0, w_ha = 0.8266 THz, 5.1935e+00 rad/ps, delta = -0.0659, gamma = 0.0203, [0.84 0.12 0.  ]
# i = 78, q_irr = 79, band_irr = 1, weight = 12.0, w_ha = 0.7315 THz, 4.5963e+00 rad/ps, delta = -0.0539, gamma = 0.0173, [0.88 0.12 0.  ]
# i = 79, q_irr = 80, band_irr = 1, weight = 6.0, w_ha = 0.5708 THz, 3.5862e+00 rad/ps, delta = -0.0576, gamma = 0.0156, [0.16 0.16 0.  ]
# i = 80, q_irr = 81, band_irr = 1, weight = 24.0, w_ha = 0.6217 THz, 3.9065e+00 rad/ps, delta = -0.0678, gamma = 0.0177, [0.2  0.16 0.  ]
# i = 81, q_irr = 82, band_irr = 1, weight = 24.0, w_ha = 0.7095 THz, 4.4579e+00 rad/ps, delta = -0.0868, gamma = 0.0256, [0.24 0.16 0.  ]
# i = 82, q_irr = 83, band_irr = 1, weight = 24.0, w_ha = 0.8154 THz, 5.1232e+00 rad/ps, delta = -0.1090, gamma = 0.0322, [0.28 0.16 0.  ]
# i = 83, q_irr = 84, band_irr = 1, weight = 24.0, w_ha = 0.9277 THz, 5.8291e+00 rad/ps, delta = -0.1348, gamma = 0.0406, [0.32 0.16 0.  ]
# i = 84, q_irr = 85, band_irr = 1, weight = 24.0, w_ha = 1.0424 THz, 6.5494e+00 rad/ps, delta = -0.1635, gamma = 0.0524, [0.36 0.16 0.  ]
# i = 85, q_irr = 86, band_irr = 1, weight = 24.0, w_ha = 1.1607 THz, 7.2928e+00 rad/ps, delta = -0.1967, gamma = 0.0683, [0.4  0.16 0.  ]
# i = 86, q_irr = 87, band_irr = 1, weight = 24.0, w_ha = 1.2870 THz, 8.0865e+00 rad/ps, delta = -0.2259, gamma = 0.0886, [0.44 0.16 0.  ]
# i = 87, q_irr = 88, band_irr = 1, weight = 24.0, w_ha = 1.4256 THz, 8.9572e+00 rad/ps, delta = -0.2610, gamma = 0.1153, [0.48 0.16 0.  ]
# i = 88, q_irr = 89, band_irr = 1, weight = 24.0, w_ha = 1.5782 THz, 9.9159e+00 rad/ps, delta = -0.2922, gamma = 0.1398, [0.52 0.16 0.  ]
# i = 89, q_irr = 90, band_irr = 1, weight = 24.0, w_ha = 1.6165 THz, 1.0157e+01 rad/ps, delta = -0.2332, gamma = 0.1142, [0.56 0.16 0.  ]
# i = 90, q_irr = 91, band_irr = 1, weight = 24.0, w_ha = 1.4334 THz, 9.0061e+00 rad/ps, delta = -0.2161, gamma = 0.0883, [0.6  0.16 0.  ]
# i = 91, q_irr = 92, band_irr = 1, weight = 24.0, w_ha = 1.2781 THz, 8.0306e+00 rad/ps, delta = -0.1922, gamma = 0.0696, [0.64 0.16 0.  ]
# i = 92, q_irr = 93, band_irr = 1, weight = 24.0, w_ha = 1.1540 THz, 7.2506e+00 rad/ps, delta = -0.1620, gamma = 0.0555, [0.68 0.16 0.  ]
# i = 93, q_irr = 94, band_irr = 1, weight = 24.0, w_ha = 1.0565 THz, 6.6383e+00 rad/ps, delta = -0.1320, gamma = 0.0424, [0.72 0.16 0.  ]
# i = 94, q_irr = 95, band_irr = 1, weight = 24.0, w_ha = 0.9782 THz, 6.1463e+00 rad/ps, delta = -0.1065, gamma = 0.0327, [0.76 0.16 0.  ]
# i = 95, q_irr = 96, band_irr = 1, weight = 24.0, w_ha = 0.9133 THz, 5.7383e+00 rad/ps, delta = -0.0841, gamma = 0.0247, [0.8  0.16 0.  ]
# i = 96, q_irr = 97, band_irr = 1, weight = 12.0, w_ha = 0.8611 THz, 5.4104e+00 rad/ps, delta = -0.0710, gamma = 0.0219, [0.84 0.16 0.  ]
# i = 97, q_irr = 98, band_irr = 1, weight = 6.0, w_ha = 0.6009 THz, 3.7754e+00 rad/ps, delta = -0.0736, gamma = 0.0211, [0.2 0.2 0. ]
# i = 98, q_irr = 99, band_irr = 1, weight = 24.0, w_ha = 0.6322 THz, 3.9721e+00 rad/ps, delta = -0.0873, gamma = 0.0240, [0.24 0.2  0.  ]
# i = 99, q_irr = 100, band_irr = 1, weight = 24.0, w_ha = 0.7057 THz, 4.4340e+00 rad/ps, delta = -0.1016, gamma = 0.0284, [0.28 0.2  0.  ]
# i = 100, q_irr = 101, band_irr = 1, weight = 24.0, w_ha = 0.8056 THz, 5.0615e+00 rad/ps, delta = -0.1208, gamma = 0.0332, [0.32 0.2  0.  ]
# i = 101, q_irr = 102, band_irr = 1, weight = 24.0, w_ha = 0.9199 THz, 5.7797e+00 rad/ps, delta = -0.1450, gamma = 0.0413, [0.36 0.2  0.  ]
# i = 102, q_irr = 103, band_irr = 1, weight = 24.0, w_ha = 1.0432 THz, 6.5549e+00 rad/ps, delta = -0.1706, gamma = 0.0539, [0.4 0.2 0. ]
# i = 103, q_irr = 104, band_irr = 1, weight = 24.0, w_ha = 1.1751 THz, 7.3837e+00 rad/ps, delta = -0.1955, gamma = 0.0685, [0.44 0.2  0.  ]
# i = 104, q_irr = 105, band_irr = 1, weight = 24.0, w_ha = 1.3169 THz, 8.2742e+00 rad/ps, delta = -0.2230, gamma = 0.0923, [0.48 0.2  0.  ]
# i = 105, q_irr = 106, band_irr = 1, weight = 24.0, w_ha = 1.4690 THz, 9.2297e+00 rad/ps, delta = -0.2499, gamma = 0.1102, [0.52 0.2  0.  ]
# i = 106, q_irr = 107, band_irr = 1, weight = 24.0, w_ha = 1.5630 THz, 9.8205e+00 rad/ps, delta = -0.2167, gamma = 0.0970, [0.56 0.2  0.  ]
# i = 107, q_irr = 108, band_irr = 1, weight = 24.0, w_ha = 1.3517 THz, 8.4927e+00 rad/ps, delta = -0.2011, gamma = 0.0771, [0.6 0.2 0. ]
# i = 108, q_irr = 109, band_irr = 1, weight = 24.0, w_ha = 1.1874 THz, 7.4608e+00 rad/ps, delta = -0.1816, gamma = 0.0618, [0.64 0.2  0.  ]
# i = 109, q_irr = 110, band_irr = 1, weight = 24.0, w_ha = 1.0641 THz, 6.6857e+00 rad/ps, delta = -0.1571, gamma = 0.0486, [0.68 0.2  0.  ]
# i = 110, q_irr = 111, band_irr = 1, weight = 24.0, w_ha = 0.9815 THz, 6.1669e+00 rad/ps, delta = -0.1310, gamma = 0.0376, [0.72 0.2  0.  ]
# i = 111, q_irr = 112, band_irr = 1, weight = 24.0, w_ha = 0.9336 THz, 5.8660e+00 rad/ps, delta = -0.1093, gamma = 0.0304, [0.76 0.2  0.  ]
# i = 112, q_irr = 113, band_irr = 1, weight = 12.0, w_ha = 0.9128 THz, 5.7353e+00 rad/ps, delta = -0.0932, gamma = 0.0263, [0.8 0.2 0. ]
# i = 113, q_irr = 114, band_irr = 1, weight = 6.0, w_ha = 0.6023 THz, 3.7841e+00 rad/ps, delta = -0.0949, gamma = 0.0231, [0.24 0.24 0.  ]
# i = 114, q_irr = 115, band_irr = 1, weight = 24.0, w_ha = 0.6287 THz, 3.9504e+00 rad/ps, delta = -0.1054, gamma = 0.0249, [0.28 0.24 0.  ]
# i = 115, q_irr = 116, band_irr = 1, weight = 24.0, w_ha = 0.7035 THz, 4.4204e+00 rad/ps, delta = -0.1178, gamma = 0.0317, [0.32 0.24 0.  ]
# i = 116, q_irr = 117, band_irr = 1, weight = 24.0, w_ha = 0.8101 THz, 5.0898e+00 rad/ps, delta = -0.1299, gamma = 0.0336, [0.36 0.24 0.  ]
# i = 117, q_irr = 118, band_irr = 1, weight = 24.0, w_ha = 0.9350 THz, 5.8747e+00 rad/ps, delta = -0.1500, gamma = 0.0440, [0.4  0.24 0.  ]
# i = 118, q_irr = 119, band_irr = 1, weight = 24.0, w_ha = 1.0714 THz, 6.7316e+00 rad/ps, delta = -0.1702, gamma = 0.0528, [0.44 0.24 0.  ]
# i = 119, q_irr = 120, band_irr = 1, weight = 24.0, w_ha = 1.2165 THz, 7.6438e+00 rad/ps, delta = -0.1911, gamma = 0.0701, [0.48 0.24 0.  ]
# i = 120, q_irr = 121, band_irr = 1, weight = 24.0, w_ha = 1.3692 THz, 8.6029e+00 rad/ps, delta = -0.2162, gamma = 0.0877, [0.52 0.24 0.  ]
# i = 121, q_irr = 122, band_irr = 1, weight = 24.0, w_ha = 1.4936 THz, 9.3847e+00 rad/ps, delta = -0.2038, gamma = 0.0880, [0.56 0.24 0.  ]
# i = 122, q_irr = 123, band_irr = 1, weight = 24.0, w_ha = 1.2764 THz, 8.0200e+00 rad/ps, delta = -0.1839, gamma = 0.0661, [0.6  0.24 0.  ]
# i = 123, q_irr = 124, band_irr = 1, weight = 24.0, w_ha = 1.1100 THz, 6.9744e+00 rad/ps, delta = -0.1703, gamma = 0.0553, [0.64 0.24 0.  ]
# i = 124, q_irr = 125, band_irr = 1, weight = 24.0, w_ha = 0.9931 THz, 6.2395e+00 rad/ps, delta = -0.1545, gamma = 0.0424, [0.68 0.24 0.  ]
# i = 125, q_irr = 126, band_irr = 1, weight = 24.0, w_ha = 0.9294 THz, 5.8395e+00 rad/ps, delta = -0.1353, gamma = 0.0387, [0.72 0.24 0.  ]
# i = 126, q_irr = 127, band_irr = 1, weight = 12.0, w_ha = 0.9133 THz, 5.7385e+00 rad/ps, delta = -0.1197, gamma = 0.0322, [0.76 0.24 0.  ]
# i = 127, q_irr = 128, band_irr = 1, weight = 6.0, w_ha = 0.6038 THz, 3.7941e+00 rad/ps, delta = -0.1126, gamma = 0.0259, [0.28 0.28 0.  ]
# i = 128, q_irr = 129, band_irr = 1, weight = 24.0, w_ha = 0.6393 THz, 4.0165e+00 rad/ps, delta = -0.1195, gamma = 0.0288, [0.32 0.28 0.  ]
# i = 129, q_irr = 130, band_irr = 1, weight = 24.0, w_ha = 0.7242 THz, 4.5506e+00 rad/ps, delta = -0.1287, gamma = 0.0313, [0.36 0.28 0.  ]
# i = 130, q_irr = 131, band_irr = 1, weight = 24.0, w_ha = 0.8407 THz, 5.2822e+00 rad/ps, delta = -0.1368, gamma = 0.0350, [0.4  0.28 0.  ]
# i = 131, q_irr = 132, band_irr = 1, weight = 24.0, w_ha = 0.9749 THz, 6.1255e+00 rad/ps, delta = -0.1492, gamma = 0.0441, [0.44 0.28 0.  ]
# i = 132, q_irr = 133, band_irr = 1, weight = 24.0, w_ha = 1.1195 THz, 7.0343e+00 rad/ps, delta = -0.1656, gamma = 0.0547, [0.48 0.28 0.  ]
# i = 133, q_irr = 134, band_irr = 1, weight = 24.0, w_ha = 1.2707 THz, 7.9841e+00 rad/ps, delta = -0.1871, gamma = 0.0688, [0.52 0.28 0.  ]
# i = 134, q_irr = 135, band_irr = 1, weight = 24.0, w_ha = 1.4217 THz, 8.9328e+00 rad/ps, delta = -0.1880, gamma = 0.0758, [0.56 0.28 0.  ]
# i = 135, q_irr = 136, band_irr = 1, weight = 24.0, w_ha = 1.2125 THz, 7.6181e+00 rad/ps, delta = -0.1692, gamma = 0.0599, [0.6  0.28 0.  ]
# i = 136, q_irr = 137, band_irr = 1, weight = 24.0, w_ha = 1.0558 THz, 6.6339e+00 rad/ps, delta = -0.1648, gamma = 0.0502, [0.64 0.28 0.  ]
# i = 137, q_irr = 138, band_irr = 1, weight = 24.0, w_ha = 0.9554 THz, 6.0027e+00 rad/ps, delta = -0.1516, gamma = 0.0420, [0.68 0.28 0.  ]
# i = 138, q_irr = 139, band_irr = 1, weight = 12.0, w_ha = 0.9158 THz, 5.7540e+00 rad/ps, delta = -0.1431, gamma = 0.0383, [0.72 0.28 0.  ]
# i = 139, q_irr = 140, band_irr = 1, weight = 6.0, w_ha = 0.6296 THz, 3.9560e+00 rad/ps, delta = -0.1229, gamma = 0.0287, [0.32 0.32 0.  ]
# i = 140, q_irr = 141, band_irr = 1, weight = 24.0, w_ha = 0.6776 THz, 4.2575e+00 rad/ps, delta = -0.1274, gamma = 0.0297, [0.36 0.32 0.  ]
# i = 141, q_irr = 142, band_irr = 1, weight = 24.0, w_ha = 0.7701 THz, 4.8386e+00 rad/ps, delta = -0.1282, gamma = 0.0311, [0.4  0.32 0.  ]
# i = 142, q_irr = 143, band_irr = 1, weight = 24.0, w_ha = 0.8902 THz, 5.5935e+00 rad/ps, delta = -0.1345, gamma = 0.0373, [0.44 0.32 0.  ]
# i = 143, q_irr = 144, band_irr = 1, weight = 24.0, w_ha = 1.0261 THz, 6.4470e+00 rad/ps, delta = -0.1452, gamma = 0.0438, [0.48 0.32 0.  ]
# i = 144, q_irr = 145, band_irr = 1, weight = 24.0, w_ha = 1.1705 THz, 7.3548e+00 rad/ps, delta = -0.1619, gamma = 0.0538, [0.52 0.32 0.  ]
# i = 145, q_irr = 146, band_irr = 1, weight = 24.0, w_ha = 1.3189 THz, 8.2870e+00 rad/ps, delta = -0.1856, gamma = 0.0700, [0.56 0.32 0.  ]
# i = 146, q_irr = 147, band_irr = 1, weight = 24.0, w_ha = 1.1791 THz, 7.4088e+00 rad/ps, delta = -0.1600, gamma = 0.0543, [0.6  0.32 0.  ]
# i = 147, q_irr = 148, band_irr = 1, weight = 24.0, w_ha = 1.0374 THz, 6.5184e+00 rad/ps, delta = -0.1527, gamma = 0.0504, [0.64 0.32 0.  ]
# i = 148, q_irr = 149, band_irr = 1, weight = 12.0, w_ha = 0.9664 THz, 6.0723e+00 rad/ps, delta = -0.1528, gamma = 0.0452, [0.68 0.32 0.  ]
# i = 149, q_irr = 150, band_irr = 1, weight = 6.0, w_ha = 0.6815 THz, 4.2819e+00 rad/ps, delta = -0.1240, gamma = 0.0272, [0.36 0.36 0.  ]
# i = 150, q_irr = 151, band_irr = 1, weight = 24.0, w_ha = 0.7348 THz, 4.6169e+00 rad/ps, delta = -0.1235, gamma = 0.0274, [0.4  0.36 0.  ]
# i = 151, q_irr = 152, band_irr = 1, weight = 24.0, w_ha = 0.8258 THz, 5.1887e+00 rad/ps, delta = -0.1289, gamma = 0.0331, [0.44 0.36 0.  ]
# i = 152, q_irr = 153, band_irr = 1, weight = 24.0, w_ha = 0.9412 THz, 5.9135e+00 rad/ps, delta = -0.1317, gamma = 0.0388, [0.48 0.36 0.  ]
# i = 153, q_irr = 154, band_irr = 1, weight = 24.0, w_ha = 1.0709 THz, 6.7285e+00 rad/ps, delta = -0.1433, gamma = 0.0436, [0.52 0.36 0.  ]
# i = 154, q_irr = 155, band_irr = 1, weight = 24.0, w_ha = 1.2079 THz, 7.5896e+00 rad/ps, delta = -0.1607, gamma = 0.0549, [0.56 0.36 0.  ]
# i = 155, q_irr = 156, band_irr = 1, weight = 24.0, w_ha = 1.1593 THz, 7.2839e+00 rad/ps, delta = -0.1523, gamma = 0.0475, [0.6  0.36 0.  ]
# i = 156, q_irr = 157, band_irr = 1, weight = 12.0, w_ha = 1.0681 THz, 6.7113e+00 rad/ps, delta = -0.1490, gamma = 0.0490, [0.64 0.36 0.  ]
# i = 157, q_irr = 158, band_irr = 1, weight = 6.0, w_ha = 0.7423 THz, 4.6638e+00 rad/ps, delta = -0.1234, gamma = 0.0266, [0.4 0.4 0. ]
# i = 158, q_irr = 159, band_irr = 1, weight = 24.0, w_ha = 0.7911 THz, 4.9707e+00 rad/ps, delta = -0.1213, gamma = 0.0310, [0.44 0.4  0.  ]
# i = 159, q_irr = 160, band_irr = 1, weight = 24.0, w_ha = 0.8730 THz, 5.4851e+00 rad/ps, delta = -0.1208, gamma = 0.0327, [0.48 0.4  0.  ]
# i = 160, q_irr = 161, band_irr = 1, weight = 24.0, w_ha = 0.9777 THz, 6.1431e+00 rad/ps, delta = -0.1292, gamma = 0.0351, [0.52 0.4  0.  ]
# i = 161, q_irr = 162, band_irr = 1, weight = 24.0, w_ha = 1.0964 THz, 6.8886e+00 rad/ps, delta = -0.1415, gamma = 0.0437, [0.56 0.4  0.  ]
# i = 162, q_irr = 163, band_irr = 1, weight = 12.0, w_ha = 1.1870 THz, 7.4579e+00 rad/ps, delta = -0.1508, gamma = 0.0421, [0.6 0.4 0. ]
# i = 163, q_irr = 164, band_irr = 1, weight = 6.0, w_ha = 0.7926 THz, 4.9799e+00 rad/ps, delta = -0.1153, gamma = 0.0306, [0.44 0.44 0.  ]
# i = 164, q_irr = 165, band_irr = 1, weight = 24.0, w_ha = 0.8304 THz, 5.2177e+00 rad/ps, delta = -0.1123, gamma = 0.0283, [0.48 0.44 0.  ]
# i = 165, q_irr = 166, band_irr = 1, weight = 24.0, w_ha = 0.8993 THz, 5.6502e+00 rad/ps, delta = -0.1211, gamma = 0.0290, [0.52 0.44 0.  ]
# i = 166, q_irr = 167, band_irr = 1, weight = 12.0, w_ha = 0.9908 THz, 6.2254e+00 rad/ps, delta = -0.1329, gamma = 0.0340, [0.56 0.44 0.  ]
# i = 167, q_irr = 168, band_irr = 1, weight = 6.0, w_ha = 0.8202 THz, 5.1536e+00 rad/ps, delta = -0.1108, gamma = 0.0242, [0.48 0.48 0.  ]
# i = 168, q_irr = 169, band_irr = 1, weight = 12.0, w_ha = 0.8443 THz, 5.3051e+00 rad/ps, delta = -0.1152, gamma = 0.0249, [0.52 0.48 0.  ]
# i = 169, q_irr = 170, band_irr = 1, weight = 24.0, w_ha = 0.4182 THz, 2.6278e+00 rad/ps, delta = -0.0313, gamma = 0.0069, [0.12 0.08 0.04]
# i = 170, q_irr = 171, band_irr = 1, weight = 48.0, w_ha = 0.5647 THz, 3.5479e+00 rad/ps, delta = -0.0467, gamma = 0.0117, [0.16 0.08 0.04]
# i = 171, q_irr = 172, band_irr = 1, weight = 48.0, w_ha = 0.7330 THz, 4.6053e+00 rad/ps, delta = -0.0701, gamma = 0.0184, [0.2  0.08 0.04]
# i = 172, q_irr = 173, band_irr = 1, weight = 48.0, w_ha = 0.8947 THz, 5.6217e+00 rad/ps, delta = -0.0980, gamma = 0.0277, [0.24 0.08 0.04]
# i = 173, q_irr = 174, band_irr = 1, weight = 48.0, w_ha = 1.0414 THz, 6.5432e+00 rad/ps, delta = -0.1286, gamma = 0.0413, [0.28 0.08 0.04]
# i = 174, q_irr = 175, band_irr = 1, weight = 48.0, w_ha = 1.1729 THz, 7.3694e+00 rad/ps, delta = -0.1608, gamma = 0.0576, [0.32 0.08 0.04]
# i = 175, q_irr = 176, band_irr = 1, weight = 48.0, w_ha = 1.2944 THz, 8.1331e+00 rad/ps, delta = -0.2021, gamma = 0.0787, [0.36 0.08 0.04]
# i = 176, q_irr = 177, band_irr = 1, weight = 48.0, w_ha = 1.4144 THz, 8.8871e+00 rad/ps, delta = -0.2388, gamma = 0.1007, [0.4  0.08 0.04]
# i = 177, q_irr = 178, band_irr = 1, weight = 48.0, w_ha = 1.5418 THz, 9.6874e+00 rad/ps, delta = -0.2737, gamma = 0.1272, [0.44 0.08 0.04]
# i = 178, q_irr = 179, band_irr = 1, weight = 48.0, w_ha = 1.6828 THz, 1.0573e+01 rad/ps, delta = -0.2891, gamma = 0.1572, [0.48 0.08 0.04]
# i = 179, q_irr = 180, band_irr = 1, weight = 48.0, w_ha = 1.8345 THz, 1.1527e+01 rad/ps, delta = -0.3120, gamma = 0.1856, [0.52 0.08 0.04]
# i = 180, q_irr = 181, band_irr = 1, weight = 24.0, w_ha = 0.5372 THz, 3.3752e+00 rad/ps, delta = -0.0432, gamma = 0.0108, [0.16 0.12 0.04]
# i = 181, q_irr = 182, band_irr = 1, weight = 48.0, w_ha = 0.6512 THz, 4.0916e+00 rad/ps, delta = -0.0565, gamma = 0.0165, [0.2  0.12 0.04]
# i = 182, q_irr = 183, band_irr = 1, weight = 48.0, w_ha = 0.7873 THz, 4.9465e+00 rad/ps, delta = -0.0781, gamma = 0.0226, [0.24 0.12 0.04]
# i = 183, q_irr = 184, band_irr = 1, weight = 48.0, w_ha = 0.9213 THz, 5.7887e+00 rad/ps, delta = -0.1063, gamma = 0.0325, [0.28 0.12 0.04]
# i = 184, q_irr = 185, band_irr = 1, weight = 48.0, w_ha = 1.0454 THz, 6.5686e+00 rad/ps, delta = -0.1387, gamma = 0.0435, [0.32 0.12 0.04]
# i = 185, q_irr = 186, band_irr = 1, weight = 48.0, w_ha = 1.1607 THz, 7.2928e+00 rad/ps, delta = -0.1767, gamma = 0.0604, [0.36 0.12 0.04]
# i = 186, q_irr = 187, band_irr = 1, weight = 48.0, w_ha = 1.2733 THz, 8.0003e+00 rad/ps, delta = -0.2166, gamma = 0.0828, [0.4  0.12 0.04]
# i = 187, q_irr = 188, band_irr = 1, weight = 48.0, w_ha = 1.3915 THz, 8.7432e+00 rad/ps, delta = -0.2544, gamma = 0.1052, [0.44 0.12 0.04]
# i = 188, q_irr = 189, band_irr = 1, weight = 48.0, w_ha = 1.5221 THz, 9.5635e+00 rad/ps, delta = -0.2855, gamma = 0.1290, [0.48 0.12 0.04]
# i = 189, q_irr = 190, band_irr = 1, weight = 48.0, w_ha = 1.6630 THz, 1.0449e+01 rad/ps, delta = -0.3168, gamma = 0.1735, [0.52 0.12 0.04]
# i = 190, q_irr = 191, band_irr = 1, weight = 48.0, w_ha = 1.7344 THz, 1.0898e+01 rad/ps, delta = -0.3082, gamma = 0.1795, [0.56 0.12 0.04]
# i = 191, q_irr = 192, band_irr = 1, weight = 48.0, w_ha = 1.6073 THz, 1.0099e+01 rad/ps, delta = -0.2869, gamma = 0.1406, [0.6  0.12 0.04]
# i = 192, q_irr = 193, band_irr = 1, weight = 48.0, w_ha = 1.4648 THz, 9.2037e+00 rad/ps, delta = -0.2447, gamma = 0.1062, [0.64 0.12 0.04]
# i = 193, q_irr = 194, band_irr = 1, weight = 48.0, w_ha = 1.3376 THz, 8.4041e+00 rad/ps, delta = -0.2144, gamma = 0.0844, [0.68 0.12 0.04]
# i = 194, q_irr = 195, band_irr = 1, weight = 48.0, w_ha = 1.2225 THz, 7.6810e+00 rad/ps, delta = -0.1760, gamma = 0.0644, [0.72 0.12 0.04]
# i = 195, q_irr = 196, band_irr = 1, weight = 48.0, w_ha = 1.1112 THz, 6.9820e+00 rad/ps, delta = -0.1394, gamma = 0.0475, [0.76 0.12 0.04]
# i = 196, q_irr = 197, band_irr = 1, weight = 48.0, w_ha = 0.9960 THz, 6.2578e+00 rad/ps, delta = -0.1075, gamma = 0.0332, [0.8  0.12 0.04]
# i = 197, q_irr = 198, band_irr = 1, weight = 48.0, w_ha = 0.8732 THz, 5.4867e+00 rad/ps, delta = -0.0796, gamma = 0.0240, [0.84 0.12 0.04]
# i = 198, q_irr = 199, band_irr = 1, weight = 48.0, w_ha = 0.7474 THz, 4.6958e+00 rad/ps, delta = -0.0588, gamma = 0.0177, [0.88 0.12 0.04]
# i = 199, q_irr = 200, band_irr = 1, weight = 24.0, w_ha = 0.6345 THz, 3.9864e+00 rad/ps, delta = -0.0476, gamma = 0.0140, [0.92 0.12 0.04]
# i = 200, q_irr = 201, band_irr = 1, weight = 24.0, w_ha = 0.6115 THz, 3.8422e+00 rad/ps, delta = -0.0579, gamma = 0.0163, [0.2  0.16 0.04]
# i = 201, q_irr = 202, band_irr = 1, weight = 48.0, w_ha = 0.6970 THz, 4.3796e+00 rad/ps, delta = -0.0699, gamma = 0.0205, [0.24 0.16 0.04]
# i = 202, q_irr = 203, band_irr = 1, weight = 48.0, w_ha = 0.8064 THz, 5.0667e+00 rad/ps, delta = -0.0893, gamma = 0.0250, [0.28 0.16 0.04]
# i = 203, q_irr = 204, band_irr = 1, weight = 48.0, w_ha = 0.9200 THz, 5.7803e+00 rad/ps, delta = -0.1174, gamma = 0.0354, [0.32 0.16 0.04]
# i = 204, q_irr = 205, band_irr = 1, weight = 48.0, w_ha = 1.0315 THz, 6.4809e+00 rad/ps, delta = -0.1507, gamma = 0.0479, [0.36 0.16 0.04]
# i = 205, q_irr = 206, band_irr = 1, weight = 48.0, w_ha = 1.1425 THz, 7.1783e+00 rad/ps, delta = -0.1851, gamma = 0.0671, [0.4  0.16 0.04]
# i = 206, q_irr = 207, band_irr = 1, weight = 48.0, w_ha = 1.2584 THz, 7.9065e+00 rad/ps, delta = -0.2225, gamma = 0.0828, [0.44 0.16 0.04]
# i = 207, q_irr = 208, band_irr = 1, weight = 48.0, w_ha = 1.3845 THz, 8.6989e+00 rad/ps, delta = -0.2579, gamma = 0.1069, [0.48 0.16 0.04]
# i = 208, q_irr = 209, band_irr = 1, weight = 48.0, w_ha = 1.5198 THz, 9.5492e+00 rad/ps, delta = -0.2946, gamma = 0.1366, [0.52 0.16 0.04]
# i = 209, q_irr = 210, band_irr = 1, weight = 48.0, w_ha = 1.6209 THz, 1.0185e+01 rad/ps, delta = -0.3134, gamma = 0.1606, [0.56 0.16 0.04]
# i = 210, q_irr = 211, band_irr = 1, weight = 48.0, w_ha = 1.5245 THz, 9.5787e+00 rad/ps, delta = -0.2689, gamma = 0.1153, [0.6  0.16 0.04]
# i = 211, q_irr = 212, band_irr = 1, weight = 48.0, w_ha = 1.3770 THz, 8.6520e+00 rad/ps, delta = -0.2317, gamma = 0.0917, [0.64 0.16 0.04]
# i = 212, q_irr = 213, band_irr = 1, weight = 48.0, w_ha = 1.2467 THz, 7.8330e+00 rad/ps, delta = -0.1940, gamma = 0.0708, [0.68 0.16 0.04]
# i = 213, q_irr = 214, band_irr = 1, weight = 48.0, w_ha = 1.1370 THz, 7.1439e+00 rad/ps, delta = -0.1578, gamma = 0.0552, [0.72 0.16 0.04]
# i = 214, q_irr = 215, band_irr = 1, weight = 48.0, w_ha = 1.0416 THz, 6.5448e+00 rad/ps, delta = -0.1258, gamma = 0.0404, [0.76 0.16 0.04]
# i = 215, q_irr = 216, band_irr = 1, weight = 48.0, w_ha = 0.9536 THz, 5.9917e+00 rad/ps, delta = -0.0982, gamma = 0.0302, [0.8  0.16 0.04]
# i = 216, q_irr = 217, band_irr = 1, weight = 48.0, w_ha = 0.8705 THz, 5.4697e+00 rad/ps, delta = -0.0768, gamma = 0.0232, [0.84 0.16 0.04]
# i = 217, q_irr = 218, band_irr = 1, weight = 24.0, w_ha = 0.7976 THz, 5.0112e+00 rad/ps, delta = -0.0636, gamma = 0.0193, [0.88 0.16 0.04]
# i = 218, q_irr = 219, band_irr = 1, weight = 24.0, w_ha = 0.6416 THz, 4.0310e+00 rad/ps, delta = -0.0756, gamma = 0.0204, [0.24 0.2  0.04]
# i = 219, q_irr = 220, band_irr = 1, weight = 48.0, w_ha = 0.7082 THz, 4.4498e+00 rad/ps, delta = -0.0837, gamma = 0.0232, [0.28 0.2  0.04]
# i = 220, q_irr = 221, band_irr = 1, weight = 48.0, w_ha = 0.8033 THz, 5.0470e+00 rad/ps, delta = -0.1049, gamma = 0.0318, [0.32 0.2  0.04]
# i = 221, q_irr = 222, band_irr = 1, weight = 48.0, w_ha = 0.9101 THz, 5.7182e+00 rad/ps, delta = -0.1278, gamma = 0.0391, [0.36 0.2  0.04]
# i = 222, q_irr = 223, band_irr = 1, weight = 48.0, w_ha = 1.0228 THz, 6.4265e+00 rad/ps, delta = -0.1551, gamma = 0.0494, [0.4  0.2  0.04]
# i = 223, q_irr = 224, band_irr = 1, weight = 48.0, w_ha = 1.1418 THz, 7.1739e+00 rad/ps, delta = -0.1903, gamma = 0.0659, [0.44 0.2  0.04]
# i = 224, q_irr = 225, band_irr = 1, weight = 48.0, w_ha = 1.2693 THz, 7.9750e+00 rad/ps, delta = -0.2226, gamma = 0.0835, [0.48 0.2  0.04]
# i = 225, q_irr = 226, band_irr = 1, weight = 48.0, w_ha = 1.4040 THz, 8.8217e+00 rad/ps, delta = -0.2479, gamma = 0.1058, [0.52 0.2  0.04]
# i = 226, q_irr = 227, band_irr = 1, weight = 48.0, w_ha = 1.5171 THz, 9.5323e+00 rad/ps, delta = -0.2789, gamma = 0.1263, [0.56 0.2  0.04]
# i = 227, q_irr = 228, band_irr = 1, weight = 48.0, w_ha = 1.4452 THz, 9.0804e+00 rad/ps, delta = -0.2482, gamma = 0.1035, [0.6  0.2  0.04]
# i = 228, q_irr = 229, band_irr = 1, weight = 48.0, w_ha = 1.2904 THz, 8.1075e+00 rad/ps, delta = -0.2130, gamma = 0.0786, [0.64 0.2  0.04]
# i = 229, q_irr = 230, band_irr = 1, weight = 48.0, w_ha = 1.1557 THz, 7.2616e+00 rad/ps, delta = -0.1778, gamma = 0.0610, [0.68 0.2  0.04]
# i = 230, q_irr = 231, band_irr = 1, weight = 48.0, w_ha = 1.0526 THz, 6.6139e+00 rad/ps, delta = -0.1493, gamma = 0.0460, [0.72 0.2  0.04]
# i = 231, q_irr = 232, band_irr = 1, weight = 48.0, w_ha = 0.9776 THz, 6.1425e+00 rad/ps, delta = -0.1215, gamma = 0.0363, [0.76 0.2  0.04]
# i = 232, q_irr = 233, band_irr = 1, weight = 48.0, w_ha = 0.9241 THz, 5.8066e+00 rad/ps, delta = -0.0970, gamma = 0.0277, [0.8  0.2  0.04]
# i = 233, q_irr = 234, band_irr = 1, weight = 24.0, w_ha = 0.8883 THz, 5.5815e+00 rad/ps, delta = -0.0823, gamma = 0.0242, [0.84 0.2  0.04]
# i = 234, q_irr = 235, band_irr = 1, weight = 24.0, w_ha = 0.6442 THz, 4.0475e+00 rad/ps, delta = -0.0938, gamma = 0.0245, [0.28 0.24 0.04]
# i = 235, q_irr = 236, band_irr = 1, weight = 48.0, w_ha = 0.7063 THz, 4.4376e+00 rad/ps, delta = -0.1016, gamma = 0.0262, [0.32 0.24 0.04]
# i = 236, q_irr = 237, band_irr = 1, weight = 48.0, w_ha = 0.8016 THz, 5.0366e+00 rad/ps, delta = -0.1173, gamma = 0.0310, [0.36 0.24 0.04]
# i = 237, q_irr = 238, band_irr = 1, weight = 48.0, w_ha = 0.9143 THz, 5.7447e+00 rad/ps, delta = -0.1408, gamma = 0.0412, [0.4  0.24 0.04]
# i = 238, q_irr = 239, band_irr = 1, weight = 48.0, w_ha = 1.0374 THz, 6.5184e+00 rad/ps, delta = -0.1631, gamma = 0.0502, [0.44 0.24 0.04]
# i = 239, q_irr = 240, band_irr = 1, weight = 48.0, w_ha = 1.1689 THz, 7.3442e+00 rad/ps, delta = -0.1884, gamma = 0.0690, [0.48 0.24 0.04]
# i = 240, q_irr = 241, band_irr = 1, weight = 48.0, w_ha = 1.3060 THz, 8.2056e+00 rad/ps, delta = -0.2131, gamma = 0.0829, [0.52 0.24 0.04]
# i = 241, q_irr = 242, band_irr = 1, weight = 48.0, w_ha = 1.4279 THz, 8.9719e+00 rad/ps, delta = -0.2470, gamma = 0.1009, [0.56 0.24 0.04]
# i = 242, q_irr = 243, band_irr = 1, weight = 48.0, w_ha = 1.3742 THz, 8.6343e+00 rad/ps, delta = -0.2199, gamma = 0.0849, [0.6  0.24 0.04]
# i = 243, q_irr = 244, band_irr = 1, weight = 48.0, w_ha = 1.2127 THz, 7.6197e+00 rad/ps, delta = -0.1912, gamma = 0.0635, [0.64 0.24 0.04]
# i = 244, q_irr = 245, band_irr = 1, weight = 48.0, w_ha = 1.0763 THz, 6.7628e+00 rad/ps, delta = -0.1689, gamma = 0.0517, [0.68 0.24 0.04]
# i = 245, q_irr = 246, band_irr = 1, weight = 48.0, w_ha = 0.9828 THz, 6.1753e+00 rad/ps, delta = -0.1461, gamma = 0.0430, [0.72 0.24 0.04]
# i = 246, q_irr = 247, band_irr = 1, weight = 48.0, w_ha = 0.9313 THz, 5.8515e+00 rad/ps, delta = -0.1213, gamma = 0.0345, [0.76 0.24 0.04]
# i = 247, q_irr = 248, band_irr = 1, weight = 24.0, w_ha = 0.9144 THz, 5.7455e+00 rad/ps, delta = -0.1062, gamma = 0.0296, [0.8  0.24 0.04]
# i = 248, q_irr = 249, band_irr = 1, weight = 24.0, w_ha = 0.6468 THz, 4.0638e+00 rad/ps, delta = -0.1059, gamma = 0.0233, [0.32 0.28 0.04]
# i = 249, q_irr = 250, band_irr = 1, weight = 48.0, w_ha = 0.7170 THz, 4.5047e+00 rad/ps, delta = -0.1166, gamma = 0.0299, [0.36 0.28 0.04]
# i = 250, q_irr = 251, band_irr = 1, weight = 48.0, w_ha = 0.8212 THz, 5.1600e+00 rad/ps, delta = -0.1253, gamma = 0.0338, [0.4  0.28 0.04]
# i = 251, q_irr = 252, band_irr = 1, weight = 48.0, w_ha = 0.9439 THz, 5.9306e+00 rad/ps, delta = -0.1425, gamma = 0.0416, [0.44 0.28 0.04]
# i = 252, q_irr = 253, band_irr = 1, weight = 48.0, w_ha = 1.0770 THz, 6.7672e+00 rad/ps, delta = -0.1588, gamma = 0.0518, [0.48 0.28 0.04]
# i = 253, q_irr = 254, band_irr = 1, weight = 48.0, w_ha = 1.2159 THz, 7.6396e+00 rad/ps, delta = -0.1803, gamma = 0.0643, [0.52 0.28 0.04]
# i = 254, q_irr = 255, band_irr = 1, weight = 48.0, w_ha = 1.3455 THz, 8.4541e+00 rad/ps, delta = -0.2099, gamma = 0.0810, [0.56 0.28 0.04]
# i = 255, q_irr = 256, band_irr = 1, weight = 48.0, w_ha = 1.3278 THz, 8.3429e+00 rad/ps, delta = -0.2033, gamma = 0.0786, [0.6  0.28 0.04]
# i = 256, q_irr = 257, band_irr = 1, weight = 48.0, w_ha = 1.1493 THz, 7.2210e+00 rad/ps, delta = -0.1760, gamma = 0.0567, [0.64 0.28 0.04]
# i = 257, q_irr = 258, band_irr = 1, weight = 48.0, w_ha = 1.0188 THz, 6.4011e+00 rad/ps, delta = -0.1628, gamma = 0.0470, [0.68 0.28 0.04]
# i = 258, q_irr = 259, band_irr = 1, weight = 48.0, w_ha = 0.9408 THz, 5.9109e+00 rad/ps, delta = -0.1444, gamma = 0.0399, [0.72 0.28 0.04]
# i = 259, q_irr = 260, band_irr = 1, weight = 24.0, w_ha = 0.9148 THz, 5.7481e+00 rad/ps, delta = -0.1276, gamma = 0.0336, [0.76 0.28 0.04]
# i = 260, q_irr = 261, band_irr = 1, weight = 24.0, w_ha = 0.6721 THz, 4.2229e+00 rad/ps, delta = -0.1179, gamma = 0.0275, [0.36 0.32 0.04]
# i = 261, q_irr = 262, band_irr = 1, weight = 48.0, w_ha = 0.7531 THz, 4.7321e+00 rad/ps, delta = -0.1199, gamma = 0.0278, [0.4  0.32 0.04]
# i = 262, q_irr = 263, band_irr = 1, weight = 48.0, w_ha = 0.8645 THz, 5.4319e+00 rad/ps, delta = -0.1284, gamma = 0.0349, [0.44 0.32 0.04]
# i = 263, q_irr = 264, band_irr = 1, weight = 48.0, w_ha = 0.9921 THz, 6.2337e+00 rad/ps, delta = -0.1395, gamma = 0.0424, [0.48 0.32 0.04]
# i = 264, q_irr = 265, band_irr = 1, weight = 48.0, w_ha = 1.1281 THz, 7.0881e+00 rad/ps, delta = -0.1548, gamma = 0.0514, [0.52 0.32 0.04]
# i = 265, q_irr = 266, band_irr = 1, weight = 48.0, w_ha = 1.2619 THz, 7.9288e+00 rad/ps, delta = -0.1764, gamma = 0.0665, [0.56 0.32 0.04]
# i = 266, q_irr = 267, band_irr = 1, weight = 48.0, w_ha = 1.2704 THz, 7.9824e+00 rad/ps, delta = -0.1790, gamma = 0.0635, [0.6  0.32 0.04]
# i = 267, q_irr = 268, band_irr = 1, weight = 48.0, w_ha = 1.1066 THz, 6.9528e+00 rad/ps, delta = -0.1647, gamma = 0.0545, [0.64 0.32 0.04]
# i = 268, q_irr = 269, band_irr = 1, weight = 48.0, w_ha = 0.9947 THz, 6.2496e+00 rad/ps, delta = -0.1539, gamma = 0.0460, [0.68 0.32 0.04]
# i = 269, q_irr = 270, band_irr = 1, weight = 24.0, w_ha = 0.9405 THz, 5.9096e+00 rad/ps, delta = -0.1482, gamma = 0.0394, [0.72 0.32 0.04]
# i = 270, q_irr = 271, band_irr = 1, weight = 24.0, w_ha = 0.7222 THz, 4.5376e+00 rad/ps, delta = -0.1206, gamma = 0.0275, [0.4  0.36 0.04]
# i = 271, q_irr = 272, band_irr = 1, weight = 48.0, w_ha = 0.8071 THz, 5.0714e+00 rad/ps, delta = -0.1217, gamma = 0.0301, [0.44 0.36 0.04]
# i = 272, q_irr = 273, band_irr = 1, weight = 48.0, w_ha = 0.9177 THz, 5.7659e+00 rad/ps, delta = -0.1260, gamma = 0.0352, [0.48 0.36 0.04]
# i = 273, q_irr = 274, band_irr = 1, weight = 48.0, w_ha = 1.0424 THz, 6.5495e+00 rad/ps, delta = -0.1352, gamma = 0.0409, [0.52 0.36 0.04]
# i = 274, q_irr = 275, band_irr = 1, weight = 48.0, w_ha = 1.1729 THz, 7.3693e+00 rad/ps, delta = -0.1535, gamma = 0.0488, [0.56 0.36 0.04]
# i = 275, q_irr = 276, band_irr = 1, weight = 48.0, w_ha = 1.2252 THz, 7.6983e+00 rad/ps, delta = -0.1637, gamma = 0.0555, [0.6  0.36 0.04]
# i = 276, q_irr = 277, band_irr = 1, weight = 48.0, w_ha = 1.0953 THz, 6.8819e+00 rad/ps, delta = -0.1514, gamma = 0.0484, [0.64 0.36 0.04]
# i = 277, q_irr = 278, band_irr = 1, weight = 24.0, w_ha = 1.0172 THz, 6.3913e+00 rad/ps, delta = -0.1527, gamma = 0.0466, [0.68 0.36 0.04]
# i = 278, q_irr = 279, band_irr = 1, weight = 24.0, w_ha = 0.7810 THz, 4.9074e+00 rad/ps, delta = -0.1190, gamma = 0.0296, [0.44 0.4  0.04]
# i = 279, q_irr = 280, band_irr = 1, weight = 48.0, w_ha = 0.8608 THz, 5.4087e+00 rad/ps, delta = -0.1169, gamma = 0.0313, [0.48 0.4  0.04]
# i = 280, q_irr = 281, band_irr = 1, weight = 48.0, w_ha = 0.9633 THz, 6.0528e+00 rad/ps, delta = -0.1228, gamma = 0.0340, [0.52 0.4  0.04]
# i = 281, q_irr = 282, band_irr = 1, weight = 48.0, w_ha = 1.0796 THz, 6.7835e+00 rad/ps, delta = -0.1340, gamma = 0.0407, [0.56 0.4  0.04]
# i = 282, q_irr = 283, band_irr = 1, weight = 48.0, w_ha = 1.1946 THz, 7.5059e+00 rad/ps, delta = -0.1519, gamma = 0.0471, [0.6  0.4  0.04]
# i = 283, q_irr = 284, band_irr = 1, weight = 24.0, w_ha = 1.1319 THz, 7.1118e+00 rad/ps, delta = -0.1495, gamma = 0.0441, [0.64 0.4  0.04]
# i = 284, q_irr = 285, band_irr = 1, weight = 24.0, w_ha = 0.8300 THz, 5.2151e+00 rad/ps, delta = -0.1119, gamma = 0.0294, [0.48 0.44 0.04]
# i = 285, q_irr = 286, band_irr = 1, weight = 48.0, w_ha = 0.8987 THz, 5.6464e+00 rad/ps, delta = -0.1147, gamma = 0.0287, [0.52 0.44 0.04]
# i = 286, q_irr = 287, band_irr = 1, weight = 48.0, w_ha = 0.9894 THz, 6.2164e+00 rad/ps, delta = -0.1249, gamma = 0.0314, [0.56 0.44 0.04]
# i = 287, q_irr = 288, band_irr = 1, weight = 24.0, w_ha = 1.0946 THz, 6.8776e+00 rad/ps, delta = -0.1396, gamma = 0.0378, [0.6  0.44 0.04]
# i = 288, q_irr = 289, band_irr = 1, weight = 24.0, w_ha = 0.8570 THz, 5.3849e+00 rad/ps, delta = -0.1099, gamma = 0.0247, [0.52 0.48 0.04]
# i = 289, q_irr = 290, band_irr = 1, weight = 24.0, w_ha = 0.9121 THz, 5.7311e+00 rad/ps, delta = -0.1155, gamma = 0.0250, [0.56 0.48 0.04]
# i = 290, q_irr = 291, band_irr = 1, weight = 24.0, w_ha = 0.7040 THz, 4.4234e+00 rad/ps, delta = -0.0581, gamma = 0.0190, [0.24 0.16 0.08]
# i = 291, q_irr = 292, band_irr = 1, weight = 48.0, w_ha = 0.7923 THz, 4.9782e+00 rad/ps, delta = -0.0726, gamma = 0.0211, [0.28 0.16 0.08]
# i = 292, q_irr = 293, band_irr = 1, weight = 48.0, w_ha = 0.8942 THz, 5.6182e+00 rad/ps, delta = -0.0937, gamma = 0.0285, [0.32 0.16 0.08]
# i = 293, q_irr = 294, band_irr = 1, weight = 48.0, w_ha = 0.9970 THz, 6.2642e+00 rad/ps, delta = -0.1225, gamma = 0.0398, [0.36 0.16 0.08]
# i = 294, q_irr = 295, band_irr = 1, weight = 48.0, w_ha = 1.0987 THz, 6.9033e+00 rad/ps, delta = -0.1571, gamma = 0.0520, [0.4  0.16 0.08]
# i = 295, q_irr = 296, band_irr = 1, weight = 48.0, w_ha = 1.2041 THz, 7.5653e+00 rad/ps, delta = -0.1975, gamma = 0.0703, [0.44 0.16 0.08]
# i = 296, q_irr = 297, band_irr = 1, weight = 48.0, w_ha = 1.3198 THz, 8.2928e+00 rad/ps, delta = -0.2346, gamma = 0.0889, [0.48 0.16 0.08]
# i = 297, q_irr = 298, band_irr = 1, weight = 48.0, w_ha = 1.4481 THz, 9.0988e+00 rad/ps, delta = -0.2726, gamma = 0.1172, [0.52 0.16 0.08]
# i = 298, q_irr = 299, band_irr = 1, weight = 48.0, w_ha = 1.5677 THz, 9.8502e+00 rad/ps, delta = -0.3206, gamma = 0.1531, [0.56 0.16 0.08]
# i = 299, q_irr = 300, band_irr = 1, weight = 24.0, w_ha = 0.7339 THz, 4.6112e+00 rad/ps, delta = -0.0721, gamma = 0.0209, [0.28 0.2  0.08]
# i = 300, q_irr = 301, band_irr = 1, weight = 48.0, w_ha = 0.8049 THz, 5.0571e+00 rad/ps, delta = -0.0851, gamma = 0.0241, [0.32 0.2  0.08]
# i = 301, q_irr = 302, band_irr = 1, weight = 48.0, w_ha = 0.8926 THz, 5.6086e+00 rad/ps, delta = -0.1069, gamma = 0.0307, [0.36 0.2  0.08]
# i = 302, q_irr = 303, band_irr = 1, weight = 48.0, w_ha = 0.9873 THz, 6.2034e+00 rad/ps, delta = -0.1363, gamma = 0.0423, [0.4  0.2  0.08]
# i = 303, q_irr = 304, band_irr = 1, weight = 48.0, w_ha = 1.0878 THz, 6.8347e+00 rad/ps, delta = -0.1730, gamma = 0.0560, [0.44 0.2  0.08]
# i = 304, q_irr = 305, band_irr = 1, weight = 48.0, w_ha = 1.1974 THz, 7.5233e+00 rad/ps, delta = -0.2025, gamma = 0.0740, [0.48 0.2  0.08]
# i = 305, q_irr = 306, band_irr = 1, weight = 48.0, w_ha = 1.3172 THz, 8.2765e+00 rad/ps, delta = -0.2419, gamma = 0.0966, [0.52 0.2  0.08]
# i = 306, q_irr = 307, band_irr = 1, weight = 48.0, w_ha = 1.4327 THz, 9.0017e+00 rad/ps, delta = -0.2828, gamma = 0.1181, [0.56 0.2  0.08]
# i = 307, q_irr = 308, band_irr = 1, weight = 48.0, w_ha = 1.4655 THz, 9.2083e+00 rad/ps, delta = -0.2977, gamma = 0.1226, [0.6  0.2  0.08]
# i = 308, q_irr = 309, band_irr = 1, weight = 48.0, w_ha = 1.3637 THz, 8.5684e+00 rad/ps, delta = -0.2541, gamma = 0.0948, [0.64 0.2  0.08]
# i = 309, q_irr = 310, band_irr = 1, weight = 48.0, w_ha = 1.2369 THz, 7.7718e+00 rad/ps, delta = -0.2166, gamma = 0.0730, [0.68 0.2  0.08]
# i = 310, q_irr = 311, band_irr = 1, weight = 48.0, w_ha = 1.1249 THz, 7.0679e+00 rad/ps, delta = -0.1794, gamma = 0.0564, [0.72 0.2  0.08]
# i = 311, q_irr = 312, band_irr = 1, weight = 48.0, w_ha = 1.0314 THz, 6.4806e+00 rad/ps, delta = -0.1439, gamma = 0.0438, [0.76 0.2  0.08]
# i = 312, q_irr = 313, band_irr = 1, weight = 48.0, w_ha = 0.9519 THz, 5.9809e+00 rad/ps, delta = -0.1122, gamma = 0.0341, [0.8  0.2  0.08]
# i = 313, q_irr = 314, band_irr = 1, weight = 48.0, w_ha = 0.8828 THz, 5.5469e+00 rad/ps, delta = -0.0890, gamma = 0.0250, [0.84 0.2  0.08]
# i = 314, q_irr = 315, band_irr = 1, weight = 24.0, w_ha = 0.8267 THz, 5.1942e+00 rad/ps, delta = -0.0763, gamma = 0.0219, [0.88 0.2  0.08]
# i = 315, q_irr = 316, band_irr = 1, weight = 24.0, w_ha = 0.7386 THz, 4.6407e+00 rad/ps, delta = -0.0866, gamma = 0.0238, [0.32 0.24 0.08]
# i = 316, q_irr = 317, band_irr = 1, weight = 48.0, w_ha = 0.8050 THz, 5.0580e+00 rad/ps, delta = -0.0993, gamma = 0.0258, [0.36 0.24 0.08]
# i = 317, q_irr = 318, band_irr = 1, weight = 48.0, w_ha = 0.8922 THz, 5.6059e+00 rad/ps, delta = -0.1179, gamma = 0.0345, [0.4  0.24 0.08]
# i = 318, q_irr = 319, band_irr = 1, weight = 48.0, w_ha = 0.9912 THz, 6.2277e+00 rad/ps, delta = -0.1453, gamma = 0.0447, [0.44 0.24 0.08]
# i = 319, q_irr = 320, band_irr = 1, weight = 48.0, w_ha = 1.0996 THz, 6.9089e+00 rad/ps, delta = -0.1742, gamma = 0.0570, [0.48 0.24 0.08]
# i = 320, q_irr = 321, band_irr = 1, weight = 48.0, w_ha = 1.2164 THz, 7.6429e+00 rad/ps, delta = -0.2087, gamma = 0.0735, [0.52 0.24 0.08]
# i = 321, q_irr = 322, band_irr = 1, weight = 48.0, w_ha = 1.3306 THz, 8.3603e+00 rad/ps, delta = -0.2398, gamma = 0.0935, [0.56 0.24 0.08]
# i = 322, q_irr = 323, band_irr = 1, weight = 48.0, w_ha = 1.3853 THz, 8.7040e+00 rad/ps, delta = -0.2673, gamma = 0.1036, [0.6  0.24 0.08]
# i = 323, q_irr = 324, band_irr = 1, weight = 48.0, w_ha = 1.2887 THz, 8.0973e+00 rad/ps, delta = -0.2315, gamma = 0.0807, [0.64 0.24 0.08]
# i = 324, q_irr = 325, band_irr = 1, weight = 48.0, w_ha = 1.1610 THz, 7.2946e+00 rad/ps, delta = -0.2006, gamma = 0.0652, [0.68 0.24 0.08]
# i = 325, q_irr = 326, band_irr = 1, weight = 48.0, w_ha = 1.0536 THz, 6.6197e+00 rad/ps, delta = -0.1646, gamma = 0.0505, [0.72 0.24 0.08]
# i = 326, q_irr = 327, band_irr = 1, weight = 48.0, w_ha = 0.9753 THz, 6.1280e+00 rad/ps, delta = -0.1345, gamma = 0.0374, [0.76 0.24 0.08]
# i = 327, q_irr = 328, band_irr = 1, weight = 48.0, w_ha = 0.9230 THz, 5.7996e+00 rad/ps, delta = -0.1101, gamma = 0.0315, [0.8  0.24 0.08]
# i = 328, q_irr = 329, band_irr = 1, weight = 24.0, w_ha = 0.8926 THz, 5.6081e+00 rad/ps, delta = -0.0951, gamma = 0.0268, [0.84 0.24 0.08]
# i = 329, q_irr = 330, band_irr = 1, weight = 24.0, w_ha = 0.7430 THz, 4.6682e+00 rad/ps, delta = -0.1025, gamma = 0.0280, [0.36 0.28 0.08]
# i = 330, q_irr = 331, band_irr = 1, weight = 48.0, w_ha = 0.8166 THz, 5.1307e+00 rad/ps, delta = -0.1112, gamma = 0.0295, [0.4  0.28 0.08]
# i = 331, q_irr = 332, band_irr = 1, weight = 48.0, w_ha = 0.9120 THz, 5.7306e+00 rad/ps, delta = -0.1253, gamma = 0.0366, [0.44 0.28 0.08]
# i = 332, q_irr = 333, band_irr = 1, weight = 48.0, w_ha = 1.0201 THz, 6.4097e+00 rad/ps, delta = -0.1473, gamma = 0.0445, [0.48 0.28 0.08]
# i = 333, q_irr = 334, band_irr = 1, weight = 48.0, w_ha = 1.1362 THz, 7.1392e+00 rad/ps, delta = -0.1721, gamma = 0.0576, [0.52 0.28 0.08]
# i = 334, q_irr = 335, band_irr = 1, weight = 48.0, w_ha = 1.2513 THz, 7.8620e+00 rad/ps, delta = -0.2010, gamma = 0.0714, [0.56 0.28 0.08]
# i = 335, q_irr = 336, band_irr = 1, weight = 48.0, w_ha = 1.3188 THz, 8.2864e+00 rad/ps, delta = -0.2274, gamma = 0.0857, [0.6  0.28 0.08]
# i = 336, q_irr = 337, band_irr = 1, weight = 48.0, w_ha = 1.2292 THz, 7.7235e+00 rad/ps, delta = -0.2068, gamma = 0.0709, [0.64 0.28 0.08]
# i = 337, q_irr = 338, band_irr = 1, weight = 48.0, w_ha = 1.1011 THz, 6.9184e+00 rad/ps, delta = -0.1788, gamma = 0.0543, [0.68 0.28 0.08]
# i = 338, q_irr = 339, band_irr = 1, weight = 48.0, w_ha = 1.0014 THz, 6.2918e+00 rad/ps, delta = -0.1554, gamma = 0.0453, [0.72 0.28 0.08]
# i = 339, q_irr = 340, band_irr = 1, weight = 48.0, w_ha = 0.9414 THz, 5.9147e+00 rad/ps, delta = -0.1345, gamma = 0.0366, [0.76 0.28 0.08]
# i = 340, q_irr = 341, band_irr = 1, weight = 24.0, w_ha = 0.9175 THz, 5.7648e+00 rad/ps, delta = -0.1175, gamma = 0.0302, [0.8  0.28 0.08]
# i = 341, q_irr = 342, band_irr = 1, weight = 24.0, w_ha = 0.7675 THz, 4.8226e+00 rad/ps, delta = -0.1097, gamma = 0.0262, [0.4  0.32 0.08]
# i = 342, q_irr = 343, band_irr = 1, weight = 48.0, w_ha = 0.8515 THz, 5.3499e+00 rad/ps, delta = -0.1136, gamma = 0.0302, [0.44 0.32 0.08]
# i = 343, q_irr = 344, band_irr = 1, weight = 48.0, w_ha = 0.9545 THz, 5.9971e+00 rad/ps, delta = -0.1271, gamma = 0.0356, [0.48 0.32 0.08]
# i = 344, q_irr = 345, band_irr = 1, weight = 48.0, w_ha = 1.0677 THz, 6.7085e+00 rad/ps, delta = -0.1448, gamma = 0.0450, [0.52 0.32 0.08]
# i = 345, q_irr = 346, band_irr = 1, weight = 48.0, w_ha = 1.1829 THz, 7.4326e+00 rad/ps, delta = -0.1685, gamma = 0.0565, [0.56 0.32 0.08]
# i = 346, q_irr = 347, band_irr = 1, weight = 48.0, w_ha = 1.2642 THz, 7.9431e+00 rad/ps, delta = -0.1930, gamma = 0.0676, [0.6  0.32 0.08]
# ...
# i = 2616, q_irr = 342, band_irr = 6, weight = 24.0, w_ha = 5.5949 THz, 3.5154e+01 rad/ps, delta = -0.1628, gamma = 0.2552, [0.4  0.32 0.08]
# i = 2617, q_irr = 343, band_irr = 6, weight = 48.0, w_ha = 5.6845 THz, 3.5716e+01 rad/ps, delta = -0.1972, gamma = 0.2943, [0.44 0.32 0.08]
# i = 2618, q_irr = 344, band_irr = 6, weight = 48.0, w_ha = 5.7690 THz, 3.6248e+01 rad/ps, delta = -0.2151, gamma = 0.3307, [0.48 0.32 0.08]
# i = 2619, q_irr = 345, band_irr = 6, weight = 48.0, w_ha = 5.8372 THz, 3.6676e+01 rad/ps, delta = -0.1809, gamma = 0.3793, [0.52 0.32 0.08]
# i = 2620, q_irr = 346, band_irr = 6, weight = 48.0, w_ha = 5.8809 THz, 3.6951e+01 rad/ps, delta = -0.1433, gamma = 0.4073, [0.56 0.32 0.08]
# i = 2621, q_irr = 347, band_irr = 6, weight = 48.0, w_ha = 5.8935 THz, 3.7030e+01 rad/ps, delta = -0.1056, gamma = 0.4250, [0.6  0.32 0.08]
# i = 2622, q_irr = 348, band_irr = 6, weight = 48.0, w_ha = 5.8530 THz, 3.6775e+01 rad/ps, delta = -0.0847, gamma = 0.4286, [0.64 0.32 0.08]
# i = 2623, q_irr = 349, band_irr = 6, weight = 48.0, w_ha = 5.7828 THz, 3.6334e+01 rad/ps, delta = -0.0949, gamma = 0.4274, [0.68 0.32 0.08]
# i = 2624, q_irr = 350, band_irr = 6, weight = 48.0, w_ha = 5.6889 THz, 3.5744e+01 rad/ps, delta = -0.1055, gamma = 0.3476, [0.72 0.32 0.08]
# i = 2625, q_irr = 351, band_irr = 6, weight = 24.0, w_ha = 5.6360 THz, 3.5412e+01 rad/ps, delta = -0.1691, gamma = 0.2641, [0.76 0.32 0.08]
# i = 2626, q_irr = 352, band_irr = 6, weight = 24.0, w_ha = 5.7261 THz, 3.5978e+01 rad/ps, delta = -0.2244, gamma = 0.3054, [0.44 0.36 0.08]
# i = 2627, q_irr = 353, band_irr = 6, weight = 48.0, w_ha = 5.7888 THz, 3.6372e+01 rad/ps, delta = -0.2357, gamma = 0.3659, [0.48 0.36 0.08]
# i = 2628, q_irr = 354, band_irr = 6, weight = 48.0, w_ha = 5.8352 THz, 3.6664e+01 rad/ps, delta = -0.1716, gamma = 0.4464, [0.52 0.36 0.08]
# i = 2629, q_irr = 355, band_irr = 6, weight = 48.0, w_ha = 5.8594 THz, 3.6816e+01 rad/ps, delta = -0.1027, gamma = 0.4743, [0.56 0.36 0.08]
# i = 2630, q_irr = 356, band_irr = 6, weight = 48.0, w_ha = 5.8553 THz, 3.6790e+01 rad/ps, delta = -0.0349, gamma = 0.4997, [0.6  0.36 0.08]
# i = 2631, q_irr = 357, band_irr = 6, weight = 48.0, w_ha = 5.8151 THz, 3.6537e+01 rad/ps, delta = 0.0002, gamma = 0.5392, [0.64 0.36 0.08]
# i = 2632, q_irr = 358, band_irr = 6, weight = 48.0, w_ha = 5.6990 THz, 3.5808e+01 rad/ps, delta = -0.0479, gamma = 0.5315, [0.68 0.36 0.08]
# i = 2633, q_irr = 359, band_irr = 6, weight = 24.0, w_ha = 5.6102 THz, 3.5250e+01 rad/ps, delta = -0.1709, gamma = 0.2916, [0.72 0.36 0.08]
# i = 2634, q_irr = 360, band_irr = 6, weight = 24.0, w_ha = 5.8551 THz, 3.6789e+01 rad/ps, delta = -0.2238, gamma = 0.5100, [0.48 0.4  0.08]
# i = 2635, q_irr = 361, band_irr = 6, weight = 48.0, w_ha = 5.8864 THz, 3.6985e+01 rad/ps, delta = -0.1157, gamma = 0.5156, [0.52 0.4  0.08]
# i = 2636, q_irr = 362, band_irr = 6, weight = 48.0, w_ha = 5.8923 THz, 3.7023e+01 rad/ps, delta = -0.0241, gamma = 0.5784, [0.56 0.4  0.08]
# i = 2637, q_irr = 363, band_irr = 6, weight = 48.0, w_ha = 5.8705 THz, 3.6885e+01 rad/ps, delta = 0.0140, gamma = 0.5794, [0.6  0.4  0.08]
# i = 2638, q_irr = 364, band_irr = 6, weight = 48.0, w_ha = 5.8182 THz, 3.6557e+01 rad/ps, delta = 0.0846, gamma = 0.6684, [0.64 0.4  0.08]
# i = 2639, q_irr = 365, band_irr = 6, weight = 24.0, w_ha = 5.7128 THz, 3.5894e+01 rad/ps, delta = 0.0231, gamma = 0.7376, [0.68 0.4  0.08]
# i = 2640, q_irr = 366, band_irr = 6, weight = 24.0, w_ha = 5.9597 THz, 3.7446e+01 rad/ps, delta = 0.0167, gamma = 0.5699, [0.52 0.44 0.08]
# i = 2641, q_irr = 367, band_irr = 6, weight = 48.0, w_ha = 5.9576 THz, 3.7433e+01 rad/ps, delta = 0.1189, gamma = 0.5771, [0.56 0.44 0.08]
# i = 2642, q_irr = 368, band_irr = 6, weight = 48.0, w_ha = 5.9271 THz, 3.7241e+01 rad/ps, delta = 0.1123, gamma = 0.6139, [0.6  0.44 0.08]
# i = 2643, q_irr = 369, band_irr = 6, weight = 24.0, w_ha = 5.8734 THz, 3.6903e+01 rad/ps, delta = 0.1632, gamma = 0.6809, [0.64 0.44 0.08]
# i = 2644, q_irr = 370, band_irr = 6, weight = 24.0, w_ha = 6.0185 THz, 3.7815e+01 rad/ps, delta = 0.1773, gamma = 0.5383, [0.56 0.48 0.08]
# i = 2645, q_irr = 371, band_irr = 6, weight = 24.0, w_ha = 5.9841 THz, 3.7599e+01 rad/ps, delta = 0.1781, gamma = 0.5854, [0.6  0.48 0.08]
# i = 2646, q_irr = 372, band_irr = 6, weight = 24.0, w_ha = 5.4950 THz, 3.4526e+01 rad/ps, delta = -0.1495, gamma = 0.2741, [0.36 0.24 0.12]
# i = 2647, q_irr = 373, band_irr = 6, weight = 48.0, w_ha = 5.5731 THz, 3.5017e+01 rad/ps, delta = -0.1318, gamma = 0.2743, [0.4  0.24 0.12]
# i = 2648, q_irr = 374, band_irr = 6, weight = 48.0, w_ha = 5.6883 THz, 3.5741e+01 rad/ps, delta = -0.1193, gamma = 0.3138, [0.44 0.24 0.12]
# i = 2649, q_irr = 375, band_irr = 6, weight = 48.0, w_ha = 5.8064 THz, 3.6483e+01 rad/ps, delta = -0.1428, gamma = 0.3154, [0.48 0.24 0.12]
# i = 2650, q_irr = 376, band_irr = 6, weight = 48.0, w_ha = 5.9044 THz, 3.7098e+01 rad/ps, delta = -0.1452, gamma = 0.3111, [0.52 0.24 0.12]
# i = 2651, q_irr = 377, band_irr = 6, weight = 48.0, w_ha = 5.9723 THz, 3.7525e+01 rad/ps, delta = -0.1402, gamma = 0.3136, [0.56 0.24 0.12]
# i = 2652, q_irr = 378, band_irr = 6, weight = 48.0, w_ha = 6.0070 THz, 3.7743e+01 rad/ps, delta = -0.1476, gamma = 0.3089, [0.6  0.24 0.12]
# i = 2653, q_irr = 379, band_irr = 6, weight = 24.0, w_ha = 5.5512 THz, 3.4879e+01 rad/ps, delta = -0.1563, gamma = 0.2649, [0.4  0.28 0.12]
# i = 2654, q_irr = 380, band_irr = 6, weight = 48.0, w_ha = 5.6306 THz, 3.5378e+01 rad/ps, delta = -0.1410, gamma = 0.2850, [0.44 0.28 0.12]
# i = 2655, q_irr = 381, band_irr = 6, weight = 48.0, w_ha = 5.7335 THz, 3.6024e+01 rad/ps, delta = -0.1368, gamma = 0.3166, [0.48 0.28 0.12]
# i = 2656, q_irr = 382, band_irr = 6, weight = 48.0, w_ha = 5.8314 THz, 3.6640e+01 rad/ps, delta = -0.1286, gamma = 0.3392, [0.52 0.28 0.12]
# i = 2657, q_irr = 383, band_irr = 6, weight = 48.0, w_ha = 5.9059 THz, 3.7108e+01 rad/ps, delta = -0.1318, gamma = 0.3450, [0.56 0.28 0.12]
# i = 2658, q_irr = 384, band_irr = 6, weight = 48.0, w_ha = 5.9485 THz, 3.7375e+01 rad/ps, delta = -0.1361, gamma = 0.3420, [0.6  0.28 0.12]
# i = 2659, q_irr = 385, band_irr = 6, weight = 48.0, w_ha = 5.9519 THz, 3.7397e+01 rad/ps, delta = -0.1350, gamma = 0.3621, [0.64 0.28 0.12]
# i = 2660, q_irr = 386, band_irr = 6, weight = 48.0, w_ha = 5.9189 THz, 3.7190e+01 rad/ps, delta = -0.1152, gamma = 0.3443, [0.68 0.28 0.12]
# i = 2661, q_irr = 387, band_irr = 6, weight = 48.0, w_ha = 5.8505 THz, 3.6760e+01 rad/ps, delta = -0.1147, gamma = 0.3370, [0.72 0.28 0.12]
# i = 2662, q_irr = 388, band_irr = 6, weight = 48.0, w_ha = 5.7543 THz, 3.6155e+01 rad/ps, delta = -0.1235, gamma = 0.3213, [0.76 0.28 0.12]
# i = 2663, q_irr = 389, band_irr = 6, weight = 48.0, w_ha = 5.6523 THz, 3.5514e+01 rad/ps, delta = -0.1596, gamma = 0.2855, [0.8  0.28 0.12]
# i = 2664, q_irr = 390, band_irr = 6, weight = 24.0, w_ha = 5.5851 THz, 3.5093e+01 rad/ps, delta = -0.1610, gamma = 0.2525, [0.84 0.28 0.12]
# i = 2665, q_irr = 391, band_irr = 6, weight = 24.0, w_ha = 5.6313 THz, 3.5383e+01 rad/ps, delta = -0.1764, gamma = 0.2736, [0.44 0.32 0.12]
# i = 2666, q_irr = 392, band_irr = 6, weight = 48.0, w_ha = 5.6978 THz, 3.5800e+01 rad/ps, delta = -0.1953, gamma = 0.2932, [0.48 0.32 0.12]
# i = 2667, q_irr = 393, band_irr = 6, weight = 48.0, w_ha = 5.7748 THz, 3.6284e+01 rad/ps, delta = -0.1853, gamma = 0.3587, [0.52 0.32 0.12]
# i = 2668, q_irr = 394, band_irr = 6, weight = 48.0, w_ha = 5.8414 THz, 3.6703e+01 rad/ps, delta = -0.1202, gamma = 0.3824, [0.56 0.32 0.12]
# i = 2669, q_irr = 395, band_irr = 6, weight = 48.0, w_ha = 5.8826 THz, 3.6961e+01 rad/ps, delta = -0.1135, gamma = 0.3969, [0.6  0.32 0.12]
# i = 2670, q_irr = 396, band_irr = 6, weight = 48.0, w_ha = 5.8894 THz, 3.7004e+01 rad/ps, delta = -0.0953, gamma = 0.4197, [0.64 0.32 0.12]
# i = 2671, q_irr = 397, band_irr = 6, weight = 48.0, w_ha = 5.8476 THz, 3.6742e+01 rad/ps, delta = -0.0912, gamma = 0.4110, [0.68 0.32 0.12]
# i = 2672, q_irr = 398, band_irr = 6, weight = 48.0, w_ha = 5.7783 THz, 3.6306e+01 rad/ps, delta = -0.1099, gamma = 0.3688, [0.72 0.32 0.12]
# i = 2673, q_irr = 399, band_irr = 6, weight = 48.0, w_ha = 5.6941 THz, 3.5777e+01 rad/ps, delta = -0.1639, gamma = 0.3162, [0.76 0.32 0.12]
# i = 2674, q_irr = 400, band_irr = 6, weight = 24.0, w_ha = 5.6434 THz, 3.5458e+01 rad/ps, delta = -0.1762, gamma = 0.2579, [0.8  0.32 0.12]
# i = 2675, q_irr = 401, band_irr = 6, weight = 24.0, w_ha = 5.7229 THz, 3.5958e+01 rad/ps, delta = -0.2250, gamma = 0.3106, [0.48 0.36 0.12]
# i = 2676, q_irr = 402, band_irr = 6, weight = 48.0, w_ha = 5.7667 THz, 3.6233e+01 rad/ps, delta = -0.2258, gamma = 0.3892, [0.52 0.36 0.12]
# i = 2677, q_irr = 403, band_irr = 6, weight = 48.0, w_ha = 5.8074 THz, 3.6489e+01 rad/ps, delta = -0.1333, gamma = 0.4252, [0.56 0.36 0.12]
# i = 2678, q_irr = 404, band_irr = 6, weight = 48.0, w_ha = 5.8313 THz, 3.6639e+01 rad/ps, delta = -0.1192, gamma = 0.4524, [0.6  0.36 0.12]
# i = 2679, q_irr = 405, band_irr = 6, weight = 48.0, w_ha = 5.8259 THz, 3.6605e+01 rad/ps, delta = -0.0374, gamma = 0.5179, [0.64 0.36 0.12]
# i = 2680, q_irr = 406, band_irr = 6, weight = 48.0, w_ha = 5.7673 THz, 3.6237e+01 rad/ps, delta = -0.0567, gamma = 0.4986, [0.68 0.36 0.12]
# i = 2681, q_irr = 407, band_irr = 6, weight = 48.0, w_ha = 5.6895 THz, 3.5748e+01 rad/ps, delta = -0.0953, gamma = 0.4017, [0.72 0.36 0.12]
# i = 2682, q_irr = 408, band_irr = 6, weight = 24.0, w_ha = 5.6505 THz, 3.5503e+01 rad/ps, delta = -0.1765, gamma = 0.3054, [0.76 0.36 0.12]
# i = 2683, q_irr = 409, band_irr = 6, weight = 24.0, w_ha = 5.8149 THz, 3.6536e+01 rad/ps, delta = -0.1880, gamma = 0.4500, [0.52 0.4  0.12]
# i = 2684, q_irr = 410, band_irr = 6, weight = 48.0, w_ha = 5.8303 THz, 3.6633e+01 rad/ps, delta = -0.1360, gamma = 0.4684, [0.56 0.4  0.12]
# i = 2685, q_irr = 411, band_irr = 6, weight = 48.0, w_ha = 5.8288 THz, 3.6624e+01 rad/ps, delta = -0.0335, gamma = 0.5328, [0.6  0.4  0.12]
# i = 2686, q_irr = 412, band_irr = 6, weight = 48.0, w_ha = 5.8016 THz, 3.6452e+01 rad/ps, delta = 0.0392, gamma = 0.5772, [0.64 0.4  0.12]
# i = 2687, q_irr = 413, band_irr = 6, weight = 48.0, w_ha = 5.7205 THz, 3.5943e+01 rad/ps, delta = 0.0526, gamma = 0.6480, [0.68 0.4  0.12]
# i = 2688, q_irr = 414, band_irr = 6, weight = 24.0, w_ha = 5.5991 THz, 3.5180e+01 rad/ps, delta = 0.0422, gamma = 0.7432, [0.72 0.4  0.12]
# i = 2689, q_irr = 415, band_irr = 6, weight = 24.0, w_ha = 5.8929 THz, 3.7026e+01 rad/ps, delta = -0.0128, gamma = 0.5786, [0.56 0.44 0.12]
# i = 2690, q_irr = 416, band_irr = 6, weight = 48.0, w_ha = 5.8777 THz, 3.6931e+01 rad/ps, delta = 0.0090, gamma = 0.5778, [0.6  0.44 0.12]
# i = 2691, q_irr = 417, band_irr = 6, weight = 48.0, w_ha = 5.8389 THz, 3.6687e+01 rad/ps, delta = 0.0879, gamma = 0.6249, [0.64 0.44 0.12]
# i = 2692, q_irr = 418, band_irr = 6, weight = 24.0, w_ha = 5.7791 THz, 3.6311e+01 rad/ps, delta = 0.1390, gamma = 0.6699, [0.68 0.44 0.12]
# i = 2693, q_irr = 419, band_irr = 6, weight = 24.0, w_ha = 5.9388 THz, 3.7314e+01 rad/ps, delta = 0.1549, gamma = 0.6011, [0.6  0.48 0.12]
# i = 2694, q_irr = 420, band_irr = 6, weight = 24.0, w_ha = 5.8961 THz, 3.7046e+01 rad/ps, delta = 0.1991, gamma = 0.6177, [0.64 0.48 0.12]
# i = 2695, q_irr = 421, band_irr = 6, weight = 24.0, w_ha = 5.6440 THz, 3.5462e+01 rad/ps, delta = -0.1802, gamma = 0.2677, [0.48 0.32 0.16]
# i = 2696, q_irr = 422, band_irr = 6, weight = 48.0, w_ha = 5.6985 THz, 3.5805e+01 rad/ps, delta = -0.1744, gamma = 0.2954, [0.52 0.32 0.16]
# i = 2697, q_irr = 423, band_irr = 6, weight = 48.0, w_ha = 5.7765 THz, 3.6295e+01 rad/ps, delta = -0.1326, gamma = 0.3591, [0.56 0.32 0.16]
# i = 2698, q_irr = 424, band_irr = 6, weight = 48.0, w_ha = 5.8445 THz, 3.6722e+01 rad/ps, delta = -0.0976, gamma = 0.3823, [0.6  0.32 0.16]
# i = 2699, q_irr = 425, band_irr = 6, weight = 48.0, w_ha = 5.8828 THz, 3.6963e+01 rad/ps, delta = -0.0985, gamma = 0.3793, [0.64 0.32 0.16]
# i = 2700, q_irr = 426, band_irr = 6, weight = 24.0, w_ha = 5.7067 THz, 3.5856e+01 rad/ps, delta = -0.2302, gamma = 0.3223, [0.52 0.36 0.16]
# i = 2701, q_irr = 427, band_irr = 6, weight = 48.0, w_ha = 5.7392 THz, 3.6061e+01 rad/ps, delta = -0.1601, gamma = 0.3470, [0.56 0.36 0.16]
# i = 2702, q_irr = 428, band_irr = 6, weight = 48.0, w_ha = 5.7822 THz, 3.6331e+01 rad/ps, delta = -0.1180, gamma = 0.4247, [0.6  0.36 0.16]
# i = 2703, q_irr = 429, band_irr = 6, weight = 48.0, w_ha = 5.8107 THz, 3.6510e+01 rad/ps, delta = -0.0781, gamma = 0.4618, [0.64 0.36 0.16]
# i = 2704, q_irr = 430, band_irr = 6, weight = 48.0, w_ha = 5.8038 THz, 3.6467e+01 rad/ps, delta = -0.0629, gamma = 0.4845, [0.68 0.36 0.16]
# i = 2705, q_irr = 431, band_irr = 6, weight = 48.0, w_ha = 5.7656 THz, 3.6226e+01 rad/ps, delta = -0.0927, gamma = 0.4451, [0.72 0.36 0.16]
# i = 2706, q_irr = 432, band_irr = 6, weight = 48.0, w_ha = 5.7110 THz, 3.5883e+01 rad/ps, delta = -0.1294, gamma = 0.3788, [0.76 0.36 0.16]
# i = 2707, q_irr = 433, band_irr = 6, weight = 24.0, w_ha = 5.6820 THz, 3.5701e+01 rad/ps, delta = -0.1930, gamma = 0.3121, [0.8  0.36 0.16]
# i = 2708, q_irr = 434, band_irr = 6, weight = 24.0, w_ha = 5.7667 THz, 3.6233e+01 rad/ps, delta = -0.1616, gamma = 0.4122, [0.56 0.4  0.16]
# i = 2709, q_irr = 435, band_irr = 6, weight = 48.0, w_ha = 5.7707 THz, 3.6259e+01 rad/ps, delta = -0.1104, gamma = 0.4675, [0.6  0.4  0.16]
# i = 2710, q_irr = 436, band_irr = 6, weight = 48.0, w_ha = 5.7683 THz, 3.6243e+01 rad/ps, delta = -0.0381, gamma = 0.5076, [0.64 0.4  0.16]
# i = 2711, q_irr = 437, band_irr = 6, weight = 48.0, w_ha = 5.7432 THz, 3.6085e+01 rad/ps, delta = 0.0085, gamma = 0.5745, [0.68 0.4  0.16]
# i = 2712, q_irr = 438, band_irr = 6, weight = 48.0, w_ha = 5.6767 THz, 3.5668e+01 rad/ps, delta = -0.0672, gamma = 0.5211, [0.72 0.4  0.16]
# i = 2713, q_irr = 439, band_irr = 6, weight = 24.0, w_ha = 5.6535 THz, 3.5522e+01 rad/ps, delta = -0.1579, gamma = 0.3703, [0.76 0.4  0.16]
# i = 2714, q_irr = 440, band_irr = 6, weight = 24.0, w_ha = 5.8166 THz, 3.6546e+01 rad/ps, delta = -0.0777, gamma = 0.5177, [0.6  0.44 0.16]
# i = 2715, q_irr = 441, band_irr = 6, weight = 48.0, w_ha = 5.7906 THz, 3.6383e+01 rad/ps, delta = 0.0191, gamma = 0.5863, [0.64 0.44 0.16]
# i = 2716, q_irr = 442, band_irr = 6, weight = 48.0, w_ha = 5.7441 THz, 3.6091e+01 rad/ps, delta = 0.0947, gamma = 0.6363, [0.68 0.44 0.16]
# i = 2717, q_irr = 443, band_irr = 6, weight = 24.0, w_ha = 5.6609 THz, 3.5568e+01 rad/ps, delta = 0.0707, gamma = 0.7369, [0.72 0.44 0.16]
# i = 2718, q_irr = 444, band_irr = 6, weight = 24.0, w_ha = 5.8462 THz, 3.6733e+01 rad/ps, delta = 0.1214, gamma = 0.5783, [0.64 0.48 0.16]
# i = 2719, q_irr = 445, band_irr = 6, weight = 24.0, w_ha = 5.7978 THz, 3.6429e+01 rad/ps, delta = 0.1359, gamma = 0.6377, [0.68 0.48 0.16]
# i = 2720, q_irr = 446, band_irr = 6, weight = 24.0, w_ha = 5.7132 THz, 3.5897e+01 rad/ps, delta = -0.1648, gamma = 0.4083, [0.6 0.4 0.2]
# i = 2721, q_irr = 447, band_irr = 6, weight = 48.0, w_ha = 5.7127 THz, 3.5894e+01 rad/ps, delta = -0.1172, gamma = 0.4935, [0.64 0.4  0.2 ]
# i = 2722, q_irr = 448, band_irr = 6, weight = 48.0, w_ha = 5.7260 THz, 3.5978e+01 rad/ps, delta = -0.0209, gamma = 0.5324, [0.68 0.4  0.2 ]
# i = 2723, q_irr = 449, band_irr = 6, weight = 24.0, w_ha = 5.7348 THz, 3.6033e+01 rad/ps, delta = -0.0691, gamma = 0.5118, [0.64 0.44 0.2 ]
# i = 2724, q_irr = 450, band_irr = 6, weight = 48.0, w_ha = 5.7007 THz, 3.5819e+01 rad/ps, delta = 0.0027, gamma = 0.6048, [0.68 0.44 0.2 ]
# i = 2725, q_irr = 451, band_irr = 6, weight = 48.0, w_ha = 5.6540 THz, 3.5525e+01 rad/ps, delta = 0.0864, gamma = 0.6407, [0.72 0.44 0.2 ]
# i = 2726, q_irr = 452, band_irr = 6, weight = 24.0, w_ha = 5.6465 THz, 3.5478e+01 rad/ps, delta = -0.0862, gamma = 0.5334, [0.76 0.44 0.2 ]
# i = 2727, q_irr = 453, band_irr = 6, weight = 24.0, w_ha = 5.7461 THz, 3.6104e+01 rad/ps, delta = 0.1000, gamma = 0.6277, [0.68 0.48 0.2 ]
# i = 2728, q_irr = 454, band_irr = 6, weight = 24.0, w_ha = 5.6911 THz, 3.5758e+01 rad/ps, delta = 0.1487, gamma = 0.6767, [0.72 0.48 0.2 ]
# i = 2729, q_irr = 455, band_irr = 6, weight = 24.0, w_ha = 5.6378 THz, 3.5423e+01 rad/ps, delta = 0.0772, gamma = 0.6596, [0.72 0.48 0.24]

# %%
total_cv_weighted = 0.0
frequencies_qpa_d0 = []
cv_contributions_qpa_d0 = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
T = 250.0                # Temperature in Kelvin
integrated_modes_count = 0

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight
    integrated_modes_count += 1

    frequencies_qpa_d0.append(w_qs)
    cv_contributions_qpa_d0.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23
print(f"Modes used (integrated): {integrated_modes_count}")
print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Modes used (integrated): 2730
# Cv of unitcell(mol of unitcell): 46.2011 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Spectral Density at a specific Q-point ---
#target_q = np.array([0.2, 0, 0])

# Find the closest index in your q_coords
#q_diffs = np.linalg.norm(q_coords - target_q, axis=1)
#target_q_idx = np.argmin(q_diffs)

target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)  # the closest q-point index

print(f"Plotting for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: Band-major order means i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # Define a local frequency range around the peak for a smooth plot
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    #plt.plot(w_plot, b_w, label=f"Band {b+1} ($\omega_0$={w_qs:.2f})")
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_val:.2f})")
    
print(f"Plot width = {plot_width:.3f} THz for g_val = {g_val}")
plt.title(f"Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{{\\mathbf{{q}},s}}(\\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()


for b in range(num_bands):
    # Mapping: Band-major order
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # We use the same w_plot logic from your plotting script
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    # Numerical Integration of the Lorentzian peak
    integral = np.trapz(b_w, w_plot)
    
    print(f"Band {b+1}: Integral = {integral:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting for Q-point: [0.2 0.  0. ] (Index: 5)
# Plot width = 2.217 THz for g_val = 0.443345770741688
# Band 1: Integral = 0.9857 (Bare w0 = 1.03)
# Band 2: Integral = 0.9862 (Bare w0 = 1.03)
# Band 3: Integral = 0.9813 (Bare w0 = 1.94)
# Band 4: Integral = 0.8743 (Bare w0 = 3.59)
# Band 5: Integral = 0.8743 (Bare w0 = 3.59)
# Band 6: Integral = 0.8743 (Bare w0 = 5.73)

# %%
total_cv_weighted = 0.0
frequencies_qpa = []
cv_contributions_qpa = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
#T = 100.0                # Temperature in Kelvin

for i in range(num_total_modes):
    # Mapping the global index 'i' back to the irreducible q-point index
    # Since w_bare is (num_bands * Nq_irr), the q-index repeats every Nq_irr
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    d_val = d_interps[i](w_qs)
    #d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight

    frequencies_qpa.append(w_qs)
    cv_contributions_qpa.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Cv of unitcell(mol of unitcell): 46.2599 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Extract Gamma values for all modes ---
gamma_values = []
frequencies_for_gamma = []

for i in range(num_total_modes):
    w_qs = w_bare[i]
    g_val = abs(g_interps[i](w_qs))
    
    gamma_values.append(g_val)
    frequencies_for_gamma.append(w_qs)

# --- 2. Plotting ---
plt.figure(figsize=(10, 6))
plt.scatter(frequencies_for_gamma, gamma_values, s=10, alpha=0.5, color='green', label='Mode Gamma ($\Gamma$)')

# Add a trend line (polynomial fit) to see the overall behavior
z = np.polyfit(frequencies_for_gamma, gamma_values, 2)
p = np.poly1d(z)
freq_range = np.linspace(min(frequencies_for_gamma), max(frequencies_for_gamma), 100)
#plt.plot(freq_range, p(freq_range), "r--", linewidth=2, label='Trend line ($\Gamma \propto \omega^n$)')

plt.title('Phonon Mode Gamma ($\Gamma$) vs. Frequency', fontsize=15)
plt.xlabel('Harmonic Frequency (THz)', fontsize=12)
plt.ylabel('Gamma (THz)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()

print(f"Average Gamma: {np.mean(gamma_values):.4f} THz")
print(f"Max Gamma: {np.max(gamma_values):.4f} THz at {frequencies_for_gamma[np.argmax(gamma_values)]:.2f} THz")
# Out:
# Average Gamma: 0.2820 THz
# Max Gamma: 0.8807 THz at 5.11 THz

# %%
import matplotlib.pyplot as plt


cv_contributions_qpa_d0 = np.array(cv_contributions_qpa_d0)
cv_contributions_qpa = np.array(cv_contributions_qpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='blue', label='QPA, delta=0')

plt.scatter(frequencies_qpa, cv_contributions_qpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='green', label='QPA')

# Constant
#const1_conv = 45.1754 / 6
#const2_conv = 45.2270 / 6

#plt.axhline(const1_conv, color='blue', linestyle='--', linewidth=2, label='Cv/mode of qpa(delta=0)')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode of qpa')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'QPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
plt.ylim(6, 8.5)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87730/370526515.py:28: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Reshape harmonic frequencies ---
# w_harmonic shape: (Nq_irr, num_bands)
w_harmonic = w_bare.reshape(num_bands, Nq_irr).T 

# --- 2. DOS Calculation Function ---
def calculate_harmonic_dos(frequencies, weights, energy_grid, sigma=0.05):
    """
    frequencies: (Nq_irr, num_bands)
    weights: (Nq_irr,) - Multiplicity of each q-point
    energy_grid: Frequency axis for the DOS plot
    sigma: Gaussian broadening width (THz)
    """
    dos = np.zeros_like(energy_grid)
    for i in range(len(weights)):
        for j in range(frequencies.shape[1]):
            # Add Gaussian contribution for each mode: weight * G(omega - w_ij)
            diff = energy_grid - frequencies[i, j]
            dos += weights[i] * np.exp(-0.5 * (diff / sigma)**2) / (sigma * np.sqrt(2 * np.pi))
    
    # Normalize by total number of q-points in full BZ
    return dos / np.sum(weights)

# --- 3. Setup Grid and Compute ---
# Create a frequency axis from 0 to slightly above max frequency
w_max = np.max(w_harmonic) * 1.05
energy_axis = np.linspace(0, w_max, 1000)

# Calculate DOS (You can adjust sigma for smoothness)
dos_harmonic = calculate_harmonic_dos(w_harmonic, degeneracies, energy_axis, sigma=0.04)

# --- 4. Plotting ---
plt.figure(figsize=(9, 6))
plt.plot(energy_axis, dos_harmonic, color='blue', linewidth=2, label='Harmonic DOS')
plt.fill_between(energy_axis, 0, dos_harmonic, color='blue', alpha=0.2)

plt.title('Harmonic Phonon Density of States (DOS)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States (States/THz)', fontsize=12)
plt.xlim(0, w_max)
plt.ylim(0, np.max(dos_harmonic) * 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print(f"Harmonic DOS plot complete.")
print(f"Frequency range: 0.0 to {np.max(w_harmonic):.3f} THz")
# Out:
# Harmonic DOS plot complete.
# Frequency range: 0.0 to 6.110 THz

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import numpy as np

total_cv_full = 0.0
frequencies_bqpa = []
cv_contributions_bqpa = []

# Define global frequency bounds from the loaded spectrum file
global_w_min = spec_data[:, 0].min()
global_w_max = spec_data[:, 0].max()

print(f"Starting Full Frequency-Dependent BQPA integration...")

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    if w_qs < 1e-10: continue

    # Local step size based on broadening at resonance
    g_ref = abs(g_interps[i](w_qs))
    dw = max(g_ref, 1e-4) / 10.0
    
    # Integration grid for this mode
    w_grid = np.arange(global_w_min, global_w_max, dw)
    
    # Evaluate frequency-dependent Delta and Gamma
    d_ws = d_interps[i](w_grid)
    g_ws = np.abs(g_interps[i](w_grid))
    
    # Spectral Density b_qs(w)
    denoms = (w_grid - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denoms)
    
    # Heat Capacity Kernel with Singularity Fix
    x = (w_grid * THz_to_eV) / (kB * T)
    cv_kernels = np.zeros_like(x)
    
    # Handle x=0 limit (kB) and general case
    m_zero = (x < 1e-7)
    m_finite = (x >= 1e-7) & (x < 50)
    
    cv_kernels[m_zero] = kB
    cv_kernels[m_finite] = kB * (x[m_finite]**2 * np.exp(x[m_finite])) / (np.exp(x[m_finite]) - 1)**2
    
    # Mode contribution (Area under b_w * Cv_kernel)
    mode_integral = np.sum(b_ws * cv_kernels) * dw
    total_cv_weighted = mode_integral * weight
    
    total_cv_full += total_cv_weighted
    frequencies_bqpa.append(w_qs)
    cv_contributions_bqpa.append(mode_integral)

# Final Normalization
cv_per_cell = total_cv_full / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Full Frequency-Dependent Cv: {cv_j_mol:.4f} J/K/mol")
# Out:
# Starting Full Frequency-Dependent BQPA integration...
# Full Frequency-Dependent Cv: 48.5687 J/K/mol

# %%
import matplotlib.pyplot as plt

cv_contributions_bqpa = np.array(cv_contributions_bqpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
#plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
 #           color='blue', label='QPA, delta=0')

plt.scatter(frequencies_bqpa, cv_contributions_bqpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='purple', label='BQPA')

# Constant
#const1_conv = 49.2084 / 6
#const2_conv = 48.761459 / 6

#plt.axhline(const1_conv, color='purple', linestyle='--', linewidth=2, label='Cv/mode of BQPA')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode at gamma=1.0')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'BQPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
#plt.ylim(7.5, 10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87730/703786594.py:26: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Full Spectral Density at a specific Q-point ---
target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)

print(f"Plotting Full Spectral Density for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]

    g_ref = abs(g_interps[mode_idx](w_qs))
    d_ref = d_interps[mode_idx](w_qs)
    
    # Define a local frequency range around the renormalized peak
    plot_width = max(g_ref * 5, 20.0) 
    w_plot = np.linspace(w_qs + d_ref - plot_width, w_qs + d_ref + plot_width, 1000)
    
    # Clip to ensure we stay within the BTE spectrum file bounds
    w_plot = np.clip(w_plot, global_w_min, global_w_max)
    
    # --- Full Frequency-Dependent Calculation ---
    # Evaluate d(w) and g(w) at every point in the plot range
    d_ws = d_interps[mode_idx](w_plot)
    g_ws = np.abs(g_interps[mode_idx](w_plot))
    
    # Spectral Density b(w) = (1/pi) * [ g(w) / ( (w - w_qs - d(w))^2 + g(w)^2 ) ]
    denom = (w_plot - w_qs - d_ws)**2 + g_ws**2
    b_w = (1/np.pi) * (g_ws / denom)
    
    # Plotting the result for the band
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_ref:.2f})")

plt.title(f"Full Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{\mathbf{q},s}(\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()

for b in range(num_bands):
    mode_idx = b * Nq_irr + target_q_idx
    w_qs = w_bare[mode_idx]
    
    # We must integrate over the FULL range of your data to capture 
    # the weight of broad/flat modes.
    w_val = np.arange(global_w_min, global_w_max, 0.01) # Use a fine constant grid
    
    # Evaluate full frequency-dependent d and g
    d_ws = d_interps[mode_idx](w_val)
    g_ws = np.abs(g_interps[mode_idx](w_val))
    
    # Calculate b(w)
    denom = (w_val - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denom)
    
    # Numerical integration (Area)
    area = np.trapz(b_ws, w_val)
    
    print(f"Band {b+1}: Integral = {area:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting Full Spectral Density for Q-point: [0.2 0.  0. ] (Index: 5)
# Band 1: Integral = 1.0133 (Bare w0 = 1.03)
# Band 2: Integral = 1.0131 (Bare w0 = 1.03)
# Band 3: Integral = 1.0076 (Bare w0 = 1.94)
# Band 4: Integral = 1.0194 (Bare w0 = 3.59)
# Band 5: Integral = 1.0193 (Bare w0 = 3.59)
# Band 6: Integral = 1.0072 (Bare w0 = 5.73)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_normalized_modes_simple(file_path):
    with open(file_path, 'r') as f:
        content = f.read().strip().split('\n')
    
    modes_list = []
    current_mode = {}
    temp_grid_density = []

    for line in content:
        parts = line.split()
        if len(parts) == 1:
            if current_mode:
                half = len(temp_grid_density) // 2
                current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
                current_mode['y'] = np.array(temp_grid_density[half:])
                modes_list.append(current_mode)
            current_mode = {'center': float(parts[0]) / (2 * np.pi)}
            temp_grid_density = []
        else:
            temp_grid_density.extend([float(p) for p in parts])

    if current_mode:
        half = len(temp_grid_density) // 2
        current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
        current_mode['y'] = np.array(temp_grid_density[half:])
        modes_list.append(current_mode)

    plt.figure(figsize=(10, 6))

    for idx, m in enumerate(modes_list):
        norm_factor = np.trapz(m['y'], m['x'])
        y_norm = m['y'] / norm_factor
        plt.plot(m['x'], y_norm/ (2 * np.pi), label=f'Mode {idx+1}')

    plt.xlabel('Frequency (THz)')
    plt.ylabel('Normalized Spectral Density')
    plt.title('Normalized Vibrational Modes')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()


plot_normalized_modes_simple('bspec_omega_5.dat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 46
#      42     plt.legend()
#      43     plt.show()
# ---> 46 plot_normalized_modes_simple('bspec_omega_5.dat')
#
# Cell In[17], line 5, in plot_normalized_modes_simple(file_path)
#       4 def plot_normalized_modes_simple(file_path):
# ----> 5     with open(file_path, 'r') as f:
#       6         content = f.read().strip().split('\n')
#       8     modes_list = []
#
# File /opt/anaconda3/envs/phonopy/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bspec_omega_5.dat'

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Setup Energy Grid ---
# Use the global bounds from your spectrum data
energy_axis = np.linspace(global_w_min, global_w_max, 1000)
dos_bqpa_full = np.zeros_like(energy_axis)

print("Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...")

# --- 2. Accumulate Full Spectral Density for each mode ---
for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    # 1. Evaluate Delta(w) and Gamma(w) on the entire energy axis
    d_ws = d_interps[i](energy_axis)
    g_ws = np.abs(g_interps[i](energy_axis))
    
    # 2. Calculate the Full Spectral Density b_qs(w)
    # This reflects the true shape of the phonon state in an anharmonic potential
    denoms = (energy_axis - w_qs - d_ws)**2 + g_ws**2
    
    # Avoid division by zero for very stable modes
    g_ws_safe = np.where(g_ws < 1e-6, 1e-6, g_ws)
    b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
    
    # 3. Add to total DOS with degeneracy weight
    dos_bqpa_full += weight * b_ws

# --- 3. Final Normalization ---
dos_bqpa_full /= Nq_total

# --- 4. Plotting Comparison: Harmonic vs QPA vs BQPA ---
plt.figure(figsize=(12, 7))

# 1. Harmonic DOS (Reference)
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.3)

# 2. QPA DOS (From previous step - if you have the variable)
#if 'dos_qpa_varied' in locals():
#    plt.plot(energy_axis, dos_qpa_varied, color='green', label='QPA DOS (Single-point $\Sigma$)', alpha=0.5)

# 3. Full BQPA DOS
plt.plot(energy_axis, dos_bqpa_full, color='purple', linewidth=2.5, label='Full BQPA DOS (Freq-dependent $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_bqpa_full, color='purple', alpha=0.15)

plt.title('Phonon DOS: Full BQPA Comparison', fontsize=16)
plt.xlabel('Frequency (THz)', fontsize=13)
plt.ylabel('Density of States', fontsize=13)
plt.xlim(0, global_w_max)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87730/737035693.py:27: RuntimeWarning: divide by zero encountered in divide
#   b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
