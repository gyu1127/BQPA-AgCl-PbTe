# %%
from ase.io import read
import numpy as np

# 1. Load the POSCAR
# This gives you an Atoms object which knows positions, masses, and cell
atoms = read('POSCAR')
n_atoms = len(atoms)
masses = atoms.get_masses()  # in amu
cell = atoms.get_cell()      # lattice vectors
positions = atoms.get_positions() # Cartesian coordinates
sc_dims = np.array([4, 4, 4])

print(f"Loaded {n_atoms} atoms.")
print(f"{atoms}")
# Out:
# Loaded 2 atoms.
# Atoms(symbols='AgCl', pbc=True, cell=[[0.0, 2.7221417586264813, 2.7221417586264813], [2.7221417586264813, 0.0, 2.7221417586264813], [2.7221417586264813, 2.7221417586264813, 0.0]])

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.omega (Assumed Band-major after flattening) ---
# data_omega shape: (Nq_irr, num_bands) -> e.g., (455, 6)
data_omega = np.loadtxt('BTE.omega') 
Nq = data_omega.shape[0]
num_bands = data_omega.shape[1]

# Replicate your current logic: Band 1 (all q), then Band 2 (all q)...
# Dividing by 2*pi to convert from rad/ps to THz
w_bare = (data_omega.T).flatten() / (2 * np.pi)
num_total_modes = len(w_bare)

print(f"Total modes: {num_total_modes} from BTE.omega")
print(f"Detected Nq (q-points): {Nq}, Bands: {num_bands}")

# --- 2. Load and Parse BTE.selfeng3ph_spectrum (q-major order) ---
# Each block in this file follows: q1_b1, q1_b2... q1_b6, q2_b1...
spec_data = np.genfromtxt('BTE.selfeng3ph_spectrum')

# Calculate the number of frequency grid points per mode block
pts_per_mode = len(spec_data) // num_total_modes

# Initialize lists to store interpolation functions in Band-major order
d_interps = [None] * num_total_modes
g_interps = [None] * num_total_modes

print(f"Parsing blocks and re-mapping q-major file to Band-major w_bare...")

for i in range(num_total_modes):
    # 'i' represents the sequence in the FILE (q-major)
    # q_idx changes slowly, b_idx changes fast
    q_idx = i // num_bands
    b_idx = i % num_bands
    
    # Calculate the 'target_mode_idx' to match the Band-major 'w_bare'
    # In Band-major: b_idx changes slowly, q_idx changes fast
    target_mode_idx = b_idx * Nq + q_idx
    
    # Extract the data block for the current mode
    start = i * pts_per_mode
    end = (i + 1) * pts_per_mode
    mode_block = spec_data[start:end]
    
    w_grid = mode_block[:, 0] # Frequency grid (THz)
    # Convert Delta and Gamma from rad/ps to THz
    d_grid = mode_block[:, 1] / (2 * np.pi) 
    g_grid = mode_block[:, 2] / (2 * np.pi)
    
    # Map the interpolation function to the correct index for w_bare[target_mode_idx]
    d_interps[target_mode_idx] = interp1d(w_grid, d_grid, kind='linear', fill_value="extrapolate")
    g_interps[target_mode_idx] = interp1d(w_grid, g_grid, kind='linear', fill_value="extrapolate")

print("Successfully loaded and re-ordered all interpolation blocks!")
# Out:
# Total modes: 2730 from BTE.omega
# Detected Nq (q-points): 455, Bands: 6
# Parsing blocks and re-mapping q-major file to Band-major w_bare...
# Successfully loaded and re-ordered all interpolation blocks!

# %%
# --- 3. Verification Test ---
# With the transpose, index 'i' now follows (Band_index * Nq + q_index).
# Band 2, first q-point (q=1) is located at index i = 1 * Nq + 0 = Nq.
band = 5
q = 1

band_idx = band - 1
q_idx = q - 1

test_idx = band_idx * Nq + q_idx
if test_idx < num_total_modes:
    test_w = w_bare[test_idx]
    print(f"\nVerification at Index {test_idx} (Band={band}, q={q}):")
    print(f"Bare Frequency (converted to THz): {test_w:.4f}")
    print(f"Delta at bare freq: {d_interps[test_idx](test_w)*(2*np.pi):.6f}")
    print(f"Gamma at bare freq: {g_interps[test_idx](test_w)*(2*np.pi):.6f}")
# Out:
# Verification at Index 1820 (Band=5, q=1):
# Bare Frequency (converted to THz): 3.7616
# Delta at bare freq: -2.867296
# Gamma at bare freq: 1.856282

# %%
import numpy as np
from scipy.interpolate import interp1d

# --- 1. Load BTE.qpoints to get degeneracies ---
q_data = np.genfromtxt('BTE.qpoints')
# Column 2 (index 2) is the degeneracy (multiplicity)
degeneracies = q_data[:, 2] 
Nq_irr = len(degeneracies) # the number of qpoints in irreducible wedge
Nq_total = np.sum(degeneracies) # the number of qpoints in whole BZ
q_coords = q_data[:, 3:6]

print(f"Number of irreducible q-points: {Nq_irr}")
print(f"Total q-points in full BZ (Sum of weights): {Nq_total}")
# Out:
# Number of irreducible q-points: 455
# Total q-points in full BZ (Sum of weights): 15625.0

# %%
for i in range(num_total_modes):
    w_qs = w_bare[i]
    #if w_qs < 1e-5: 
    #    continue

    q_irr_idx = i % Nq_irr
    band_irr_idx = i // Nq_irr
    weight = degeneracies[q_irr_idx]
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    q_coords_test = q_coords[q_irr_idx]

    print(f"i = {i}, q_irr = {q_irr_idx+1}, band_irr = {band_irr_idx+1}, weight = {weight}, w_ha = {w_qs:.4f} THz, {w_qs*(2 * np.pi):.4e} rad/ps, delta = {d_val:.4f}, gamma = {g_val:.4f}, {q_coords_test}")

# i: (b1,q1), (b1, q2), (b1, q3), ...
# Out:
# i = 0, q_irr = 1, band_irr = 1, weight = 1.0, w_ha = 0.0000 THz, 0.0000e+00 rad/ps, delta = 0.0000, gamma = 0.0000, [0. 0. 0.]
# i = 1, q_irr = 2, band_irr = 1, weight = 8.0, w_ha = 0.2132 THz, 1.3396e+00 rad/ps, delta = -0.0183, gamma = 0.0017, [0.04 0.   0.  ]
# i = 2, q_irr = 3, band_irr = 1, weight = 8.0, w_ha = 0.4213 THz, 2.6470e+00 rad/ps, delta = -0.0370, gamma = 0.0056, [0.08 0.   0.  ]
# i = 3, q_irr = 4, band_irr = 1, weight = 8.0, w_ha = 0.6196 THz, 3.8932e+00 rad/ps, delta = -0.0563, gamma = 0.0113, [0.12 0.   0.  ]
# i = 4, q_irr = 5, band_irr = 1, weight = 8.0, w_ha = 0.8046 THz, 5.0553e+00 rad/ps, delta = -0.0777, gamma = 0.0189, [0.16 0.   0.  ]
# i = 5, q_irr = 6, band_irr = 1, weight = 8.0, w_ha = 0.9741 THz, 6.1205e+00 rad/ps, delta = -0.0996, gamma = 0.0272, [0.2 0.  0. ]
# i = 6, q_irr = 7, band_irr = 1, weight = 8.0, w_ha = 1.1283 THz, 7.0894e+00 rad/ps, delta = -0.1263, gamma = 0.0408, [0.24 0.   0.  ]
# i = 7, q_irr = 8, band_irr = 1, weight = 8.0, w_ha = 1.2700 THz, 7.9799e+00 rad/ps, delta = -0.1546, gamma = 0.0552, [0.28 0.   0.  ]
# i = 8, q_irr = 9, band_irr = 1, weight = 8.0, w_ha = 1.4047 THz, 8.8260e+00 rad/ps, delta = -0.1881, gamma = 0.0731, [0.32 0.   0.  ]
# i = 9, q_irr = 10, band_irr = 1, weight = 8.0, w_ha = 1.5393 THz, 9.6718e+00 rad/ps, delta = -0.2118, gamma = 0.0881, [0.36 0.   0.  ]
# i = 10, q_irr = 11, band_irr = 1, weight = 8.0, w_ha = 1.6806 THz, 1.0559e+01 rad/ps, delta = -0.2474, gamma = 0.1080, [0.4 0.  0. ]
# i = 11, q_irr = 12, band_irr = 1, weight = 8.0, w_ha = 1.8332 THz, 1.1518e+01 rad/ps, delta = -0.2717, gamma = 0.1364, [0.44 0.   0.  ]
# i = 12, q_irr = 13, band_irr = 1, weight = 8.0, w_ha = 1.9991 THz, 1.2561e+01 rad/ps, delta = -0.2837, gamma = 0.1557, [0.48 0.   0.  ]
# i = 13, q_irr = 14, band_irr = 1, weight = 6.0, w_ha = 0.1784 THz, 1.1209e+00 rad/ps, delta = -0.0098, gamma = 0.0010, [0.04 0.04 0.  ]
# i = 14, q_irr = 15, band_irr = 1, weight = 24.0, w_ha = 0.3243 THz, 2.0375e+00 rad/ps, delta = -0.0222, gamma = 0.0031, [0.08 0.04 0.  ]
# i = 15, q_irr = 16, band_irr = 1, weight = 24.0, w_ha = 0.5069 THz, 3.1849e+00 rad/ps, delta = -0.0394, gamma = 0.0073, [0.12 0.04 0.  ]
# i = 16, q_irr = 17, band_irr = 1, weight = 24.0, w_ha = 0.6868 THz, 4.3155e+00 rad/ps, delta = -0.0569, gamma = 0.0127, [0.16 0.04 0.  ]
# i = 17, q_irr = 18, band_irr = 1, weight = 24.0, w_ha = 0.8546 THz, 5.3695e+00 rad/ps, delta = -0.0777, gamma = 0.0197, [0.2  0.04 0.  ]
# i = 18, q_irr = 19, band_irr = 1, weight = 24.0, w_ha = 1.0070 THz, 6.3271e+00 rad/ps, delta = -0.1013, gamma = 0.0286, [0.24 0.04 0.  ]
# i = 19, q_irr = 20, band_irr = 1, weight = 24.0, w_ha = 1.1444 THz, 7.1908e+00 rad/ps, delta = -0.1271, gamma = 0.0418, [0.28 0.04 0.  ]
# i = 20, q_irr = 21, band_irr = 1, weight = 24.0, w_ha = 1.2705 THz, 7.9826e+00 rad/ps, delta = -0.1524, gamma = 0.0542, [0.32 0.04 0.  ]
# i = 21, q_irr = 22, band_irr = 1, weight = 24.0, w_ha = 1.3911 THz, 8.7404e+00 rad/ps, delta = -0.1818, gamma = 0.0691, [0.36 0.04 0.  ]
# i = 22, q_irr = 23, band_irr = 1, weight = 24.0, w_ha = 1.5136 THz, 9.5099e+00 rad/ps, delta = -0.2118, gamma = 0.0856, [0.4  0.04 0.  ]
# i = 23, q_irr = 24, band_irr = 1, weight = 24.0, w_ha = 1.6446 THz, 1.0333e+01 rad/ps, delta = -0.2448, gamma = 0.1096, [0.44 0.04 0.  ]
# i = 24, q_irr = 25, band_irr = 1, weight = 24.0, w_ha = 1.7890 THz, 1.1241e+01 rad/ps, delta = -0.2666, gamma = 0.1337, [0.48 0.04 0.  ]
# i = 25, q_irr = 26, band_irr = 1, weight = 24.0, w_ha = 1.9136 THz, 1.2024e+01 rad/ps, delta = -0.2367, gamma = 0.1291, [0.52 0.04 0.  ]
# i = 26, q_irr = 27, band_irr = 1, weight = 24.0, w_ha = 1.7560 THz, 1.1033e+01 rad/ps, delta = -0.2356, gamma = 0.1161, [0.56 0.04 0.  ]
# i = 27, q_irr = 28, band_irr = 1, weight = 24.0, w_ha = 1.6128 THz, 1.0134e+01 rad/ps, delta = -0.2115, gamma = 0.0909, [0.6  0.04 0.  ]
# i = 28, q_irr = 29, band_irr = 1, weight = 24.0, w_ha = 1.4815 THz, 9.3086e+00 rad/ps, delta = -0.1855, gamma = 0.0755, [0.64 0.04 0.  ]
# i = 29, q_irr = 30, band_irr = 1, weight = 24.0, w_ha = 1.3564 THz, 8.5225e+00 rad/ps, delta = -0.1610, gamma = 0.0608, [0.68 0.04 0.  ]
# i = 30, q_irr = 31, band_irr = 1, weight = 24.0, w_ha = 1.2303 THz, 7.7301e+00 rad/ps, delta = -0.1342, gamma = 0.0466, [0.72 0.04 0.  ]
# i = 31, q_irr = 32, band_irr = 1, weight = 24.0, w_ha = 1.0962 THz, 6.8873e+00 rad/ps, delta = -0.1095, gamma = 0.0341, [0.76 0.04 0.  ]
# i = 32, q_irr = 33, band_irr = 1, weight = 24.0, w_ha = 0.9487 THz, 5.9607e+00 rad/ps, delta = -0.0847, gamma = 0.0232, [0.8  0.04 0.  ]
# i = 33, q_irr = 34, band_irr = 1, weight = 24.0, w_ha = 0.7853 THz, 4.9340e+00 rad/ps, delta = -0.0638, gamma = 0.0154, [0.84 0.04 0.  ]
# i = 34, q_irr = 35, band_irr = 1, weight = 24.0, w_ha = 0.6068 THz, 3.8125e+00 rad/ps, delta = -0.0442, gamma = 0.0098, [0.88 0.04 0.  ]
# i = 35, q_irr = 36, band_irr = 1, weight = 24.0, w_ha = 0.4199 THz, 2.6381e+00 rad/ps, delta = -0.0265, gamma = 0.0049, [0.92 0.04 0.  ]
# i = 36, q_irr = 37, band_irr = 1, weight = 12.0, w_ha = 0.2545 THz, 1.5993e+00 rad/ps, delta = -0.0134, gamma = 0.0018, [0.96 0.04 0.  ]
# i = 37, q_irr = 38, band_irr = 1, weight = 6.0, w_ha = 0.3371 THz, 2.1181e+00 rad/ps, delta = -0.0191, gamma = 0.0037, [0.08 0.08 0.  ]
# i = 38, q_irr = 39, band_irr = 1, weight = 24.0, w_ha = 0.4466 THz, 2.8058e+00 rad/ps, delta = -0.0286, gamma = 0.0061, [0.12 0.08 0.  ]
# i = 39, q_irr = 40, band_irr = 1, weight = 24.0, w_ha = 0.5932 THz, 3.7275e+00 rad/ps, delta = -0.0435, gamma = 0.0107, [0.16 0.08 0.  ]
# i = 40, q_irr = 41, band_irr = 1, weight = 24.0, w_ha = 0.7452 THz, 4.6821e+00 rad/ps, delta = -0.0595, gamma = 0.0153, [0.2  0.08 0.  ]
# i = 41, q_irr = 42, band_irr = 1, weight = 24.0, w_ha = 0.8897 THz, 5.5904e+00 rad/ps, delta = -0.0806, gamma = 0.0216, [0.24 0.08 0.  ]
# i = 42, q_irr = 43, band_irr = 1, weight = 24.0, w_ha = 1.0226 THz, 6.4251e+00 rad/ps, delta = -0.1036, gamma = 0.0320, [0.28 0.08 0.  ]
# i = 43, q_irr = 44, band_irr = 1, weight = 24.0, w_ha = 1.1441 THz, 7.1885e+00 rad/ps, delta = -0.1291, gamma = 0.0428, [0.32 0.08 0.  ]
# i = 44, q_irr = 45, band_irr = 1, weight = 24.0, w_ha = 1.2582 THz, 7.9054e+00 rad/ps, delta = -0.1559, gamma = 0.0559, [0.36 0.08 0.  ]
# i = 45, q_irr = 46, band_irr = 1, weight = 24.0, w_ha = 1.3710 THz, 8.6143e+00 rad/ps, delta = -0.1819, gamma = 0.0693, [0.4  0.08 0.  ]
# i = 46, q_irr = 47, band_irr = 1, weight = 24.0, w_ha = 1.4894 THz, 9.3580e+00 rad/ps, delta = -0.2137, gamma = 0.0882, [0.44 0.08 0.  ]
# i = 47, q_irr = 48, band_irr = 1, weight = 24.0, w_ha = 1.6189 THz, 1.0172e+01 rad/ps, delta = -0.2472, gamma = 0.1138, [0.48 0.08 0.  ]
# i = 48, q_irr = 49, band_irr = 1, weight = 24.0, w_ha = 1.7629 THz, 1.1077e+01 rad/ps, delta = -0.2663, gamma = 0.1404, [0.52 0.08 0.  ]
# i = 49, q_irr = 50, band_irr = 1, weight = 24.0, w_ha = 1.7047 THz, 1.0711e+01 rad/ps, delta = -0.1978, gamma = 0.0967, [0.56 0.08 0.  ]
# i = 50, q_irr = 51, band_irr = 1, weight = 24.0, w_ha = 1.5584 THz, 9.7916e+00 rad/ps, delta = -0.1805, gamma = 0.0770, [0.6  0.08 0.  ]
# i = 51, q_irr = 52, band_irr = 1, weight = 24.0, w_ha = 1.4263 THz, 8.9614e+00 rad/ps, delta = -0.1591, gamma = 0.0629, [0.64 0.08 0.  ]
# i = 52, q_irr = 53, band_irr = 1, weight = 24.0, w_ha = 1.3032 THz, 8.1883e+00 rad/ps, delta = -0.1334, gamma = 0.0493, [0.68 0.08 0.  ]
# i = 53, q_irr = 54, band_irr = 1, weight = 24.0, w_ha = 1.1821 THz, 7.4272e+00 rad/ps, delta = -0.1108, gamma = 0.0372, [0.72 0.08 0.  ]
# i = 54, q_irr = 55, band_irr = 1, weight = 24.0, w_ha = 1.0559 THz, 6.6346e+00 rad/ps, delta = -0.0886, gamma = 0.0277, [0.76 0.08 0.  ]
# i = 55, q_irr = 56, band_irr = 1, weight = 24.0, w_ha = 0.9202 THz, 5.7817e+00 rad/ps, delta = -0.0682, gamma = 0.0198, [0.8  0.08 0.  ]
# i = 56, q_irr = 57, band_irr = 1, weight = 24.0, w_ha = 0.7744 THz, 4.8658e+00 rad/ps, delta = -0.0486, gamma = 0.0131, [0.84 0.08 0.  ]
# i = 57, q_irr = 58, band_irr = 1, weight = 24.0, w_ha = 0.6251 THz, 3.9275e+00 rad/ps, delta = -0.0339, gamma = 0.0086, [0.88 0.08 0.  ]
# i = 58, q_irr = 59, band_irr = 1, weight = 12.0, w_ha = 0.4924 THz, 3.0941e+00 rad/ps, delta = -0.0244, gamma = 0.0060, [0.92 0.08 0.  ]
# i = 59, q_irr = 60, band_irr = 1, weight = 6.0, w_ha = 0.4615 THz, 2.8994e+00 rad/ps, delta = -0.0272, gamma = 0.0069, [0.12 0.12 0.  ]
# i = 60, q_irr = 61, band_irr = 1, weight = 24.0, w_ha = 0.5415 THz, 3.4024e+00 rad/ps, delta = -0.0354, gamma = 0.0090, [0.16 0.12 0.  ]
# i = 61, q_irr = 62, band_irr = 1, weight = 24.0, w_ha = 0.6560 THz, 4.1216e+00 rad/ps, delta = -0.0479, gamma = 0.0124, [0.2  0.12 0.  ]
# i = 62, q_irr = 63, band_irr = 1, weight = 24.0, w_ha = 0.7813 THz, 4.9092e+00 rad/ps, delta = -0.0645, gamma = 0.0170, [0.24 0.12 0.  ]
# i = 63, q_irr = 64, band_irr = 1, weight = 24.0, w_ha = 0.9054 THz, 5.6886e+00 rad/ps, delta = -0.0845, gamma = 0.0232, [0.28 0.12 0.  ]
# i = 64, q_irr = 65, band_irr = 1, weight = 24.0, w_ha = 1.0235 THz, 6.4310e+00 rad/ps, delta = -0.1066, gamma = 0.0318, [0.32 0.12 0.  ]
# i = 65, q_irr = 66, band_irr = 1, weight = 24.0, w_ha = 1.1362 THz, 7.1389e+00 rad/ps, delta = -0.1307, gamma = 0.0432, [0.36 0.12 0.  ]
# i = 66, q_irr = 67, band_irr = 1, weight = 24.0, w_ha = 1.2470 THz, 7.8352e+00 rad/ps, delta = -0.1563, gamma = 0.0551, [0.4  0.12 0.  ]
# i = 67, q_irr = 68, band_irr = 1, weight = 24.0, w_ha = 1.3612 THz, 8.5528e+00 rad/ps, delta = -0.1838, gamma = 0.0712, [0.44 0.12 0.  ]
# i = 68, q_irr = 69, band_irr = 1, weight = 24.0, w_ha = 1.4837 THz, 9.3224e+00 rad/ps, delta = -0.2109, gamma = 0.0892, [0.48 0.12 0.  ]
# i = 69, q_irr = 70, band_irr = 1, weight = 24.0, w_ha = 1.6176 THz, 1.0164e+01 rad/ps, delta = -0.2476, gamma = 0.1125, [0.52 0.12 0.  ]
# i = 70, q_irr = 71, band_irr = 1, weight = 24.0, w_ha = 1.6567 THz, 1.0410e+01 rad/ps, delta = -0.1783, gamma = 0.0799, [0.56 0.12 0.  ]
# i = 71, q_irr = 72, band_irr = 1, weight = 24.0, w_ha = 1.4998 THz, 9.4237e+00 rad/ps, delta = -0.1549, gamma = 0.0638, [0.6  0.12 0.  ]
# i = 72, q_irr = 73, band_irr = 1, weight = 24.0, w_ha = 1.3609 THz, 8.5507e+00 rad/ps, delta = -0.1359, gamma = 0.0519, [0.64 0.12 0.  ]
# i = 73, q_irr = 74, band_irr = 1, weight = 24.0, w_ha = 1.2376 THz, 7.7758e+00 rad/ps, delta = -0.1166, gamma = 0.0396, [0.68 0.12 0.  ]
# i = 74, q_irr = 75, band_irr = 1, weight = 24.0, w_ha = 1.1238 THz, 7.0611e+00 rad/ps, delta = -0.0936, gamma = 0.0309, [0.72 0.12 0.  ]
# i = 75, q_irr = 76, band_irr = 1, weight = 24.0, w_ha = 1.0133 THz, 6.3665e+00 rad/ps, delta = -0.0730, gamma = 0.0229, [0.76 0.12 0.  ]
# i = 76, q_irr = 77, band_irr = 1, weight = 24.0, w_ha = 0.9022 THz, 5.6689e+00 rad/ps, delta = -0.0562, gamma = 0.0169, [0.8  0.12 0.  ]
# i = 77, q_irr = 78, band_irr = 1, weight = 24.0, w_ha = 0.7924 THz, 4.9789e+00 rad/ps, delta = -0.0414, gamma = 0.0121, [0.84 0.12 0.  ]
# i = 78, q_irr = 79, band_irr = 1, weight = 12.0, w_ha = 0.6936 THz, 4.3577e+00 rad/ps, delta = -0.0340, gamma = 0.0104, [0.88 0.12 0.  ]
# i = 79, q_irr = 80, band_irr = 1, weight = 6.0, w_ha = 0.5453 THz, 3.4265e+00 rad/ps, delta = -0.0354, gamma = 0.0097, [0.16 0.16 0.  ]
# i = 80, q_irr = 81, band_irr = 1, weight = 24.0, w_ha = 0.6012 THz, 3.7774e+00 rad/ps, delta = -0.0441, gamma = 0.0116, [0.2  0.16 0.  ]
# i = 81, q_irr = 82, band_irr = 1, weight = 24.0, w_ha = 0.6913 THz, 4.3434e+00 rad/ps, delta = -0.0554, gamma = 0.0147, [0.24 0.16 0.  ]
# i = 82, q_irr = 83, band_irr = 1, weight = 24.0, w_ha = 0.7979 THz, 5.0135e+00 rad/ps, delta = -0.0708, gamma = 0.0197, [0.28 0.16 0.  ]
# i = 83, q_irr = 84, band_irr = 1, weight = 24.0, w_ha = 0.9100 THz, 5.7180e+00 rad/ps, delta = -0.0882, gamma = 0.0248, [0.32 0.16 0.  ]
# i = 84, q_irr = 85, band_irr = 1, weight = 24.0, w_ha = 1.0229 THz, 6.4273e+00 rad/ps, delta = -0.1096, gamma = 0.0328, [0.36 0.16 0.  ]
# i = 85, q_irr = 86, band_irr = 1, weight = 24.0, w_ha = 1.1363 THz, 7.1396e+00 rad/ps, delta = -0.1322, gamma = 0.0428, [0.4  0.16 0.  ]
# i = 86, q_irr = 87, band_irr = 1, weight = 24.0, w_ha = 1.2525 THz, 7.8695e+00 rad/ps, delta = -0.1546, gamma = 0.0552, [0.44 0.16 0.  ]
# i = 87, q_irr = 88, band_irr = 1, weight = 24.0, w_ha = 1.3744 THz, 8.6356e+00 rad/ps, delta = -0.1776, gamma = 0.0712, [0.48 0.16 0.  ]
# i = 88, q_irr = 89, band_irr = 1, weight = 24.0, w_ha = 1.5041 THz, 9.4507e+00 rad/ps, delta = -0.2091, gamma = 0.0892, [0.52 0.16 0.  ]
# i = 89, q_irr = 90, band_irr = 1, weight = 24.0, w_ha = 1.6059 THz, 1.0090e+01 rad/ps, delta = -0.1616, gamma = 0.0681, [0.56 0.16 0.  ]
# i = 90, q_irr = 91, band_irr = 1, weight = 24.0, w_ha = 1.4360 THz, 9.0228e+00 rad/ps, delta = -0.1412, gamma = 0.0542, [0.6  0.16 0.  ]
# i = 91, q_irr = 92, band_irr = 1, weight = 24.0, w_ha = 1.2882 THz, 8.0943e+00 rad/ps, delta = -0.1231, gamma = 0.0437, [0.64 0.16 0.  ]
# i = 92, q_irr = 93, band_irr = 1, weight = 24.0, w_ha = 1.1648 THz, 7.3185e+00 rad/ps, delta = -0.1053, gamma = 0.0340, [0.68 0.16 0.  ]
# i = 93, q_irr = 94, band_irr = 1, weight = 24.0, w_ha = 1.0621 THz, 6.6736e+00 rad/ps, delta = -0.0843, gamma = 0.0259, [0.72 0.16 0.  ]
# i = 94, q_irr = 95, band_irr = 1, weight = 24.0, w_ha = 0.9749 THz, 6.1257e+00 rad/ps, delta = -0.0659, gamma = 0.0196, [0.76 0.16 0.  ]
# i = 95, q_irr = 96, band_irr = 1, weight = 24.0, w_ha = 0.8996 THz, 5.6524e+00 rad/ps, delta = -0.0528, gamma = 0.0149, [0.8  0.16 0.  ]
# i = 96, q_irr = 97, band_irr = 1, weight = 12.0, w_ha = 0.8369 THz, 5.2583e+00 rad/ps, delta = -0.0438, gamma = 0.0133, [0.84 0.16 0.  ]
# i = 97, q_irr = 98, band_irr = 1, weight = 6.0, w_ha = 0.5932 THz, 3.7274e+00 rad/ps, delta = -0.0450, gamma = 0.0121, [0.2 0.2 0. ]
# i = 98, q_irr = 99, band_irr = 1, weight = 24.0, w_ha = 0.6333 THz, 3.9790e+00 rad/ps, delta = -0.0540, gamma = 0.0143, [0.24 0.2  0.  ]
# i = 99, q_irr = 100, band_irr = 1, weight = 24.0, w_ha = 0.7101 THz, 4.4614e+00 rad/ps, delta = -0.0630, gamma = 0.0165, [0.28 0.2  0.  ]
# i = 100, q_irr = 101, band_irr = 1, weight = 24.0, w_ha = 0.8090 THz, 5.0831e+00 rad/ps, delta = -0.0773, gamma = 0.0202, [0.32 0.2  0.  ]
# i = 101, q_irr = 102, band_irr = 1, weight = 24.0, w_ha = 0.9194 THz, 5.7766e+00 rad/ps, delta = -0.0939, gamma = 0.0261, [0.36 0.2  0.  ]
# i = 102, q_irr = 103, band_irr = 1, weight = 24.0, w_ha = 1.0356 THz, 6.5072e+00 rad/ps, delta = -0.1099, gamma = 0.0330, [0.4 0.2 0. ]
# i = 103, q_irr = 104, band_irr = 1, weight = 24.0, w_ha = 1.1561 THz, 7.2640e+00 rad/ps, delta = -0.1298, gamma = 0.0421, [0.44 0.2  0.  ]
# i = 104, q_irr = 105, band_irr = 1, weight = 24.0, w_ha = 1.2809 THz, 8.0484e+00 rad/ps, delta = -0.1534, gamma = 0.0568, [0.48 0.2  0.  ]
# i = 105, q_irr = 106, band_irr = 1, weight = 24.0, w_ha = 1.4105 THz, 8.8625e+00 rad/ps, delta = -0.1742, gamma = 0.0680, [0.52 0.2  0.  ]
# i = 106, q_irr = 107, band_irr = 1, weight = 24.0, w_ha = 1.5443 THz, 9.7033e+00 rad/ps, delta = -0.2035, gamma = 0.0852, [0.56 0.2  0.  ]
# i = 107, q_irr = 108, band_irr = 1, weight = 24.0, w_ha = 1.3715 THz, 8.6172e+00 rad/ps, delta = -0.1301, gamma = 0.0471, [0.6 0.2 0. ]
# i = 108, q_irr = 109, band_irr = 1, weight = 24.0, w_ha = 1.2169 THz, 7.6462e+00 rad/ps, delta = -0.1143, gamma = 0.0383, [0.64 0.2  0.  ]
# i = 109, q_irr = 110, band_irr = 1, weight = 24.0, w_ha = 1.0959 THz, 6.8857e+00 rad/ps, delta = -0.0976, gamma = 0.0311, [0.68 0.2  0.  ]
# i = 110, q_irr = 111, band_irr = 1, weight = 24.0, w_ha = 1.0082 THz, 6.3347e+00 rad/ps, delta = -0.0801, gamma = 0.0234, [0.72 0.2  0.  ]
# i = 111, q_irr = 112, band_irr = 1, weight = 24.0, w_ha = 0.9495 THz, 5.9659e+00 rad/ps, delta = -0.0661, gamma = 0.0197, [0.76 0.2  0.  ]
# i = 112, q_irr = 113, band_irr = 1, weight = 12.0, w_ha = 0.9146 THz, 5.7465e+00 rad/ps, delta = -0.0558, gamma = 0.0161, [0.8 0.2 0. ]
# i = 113, q_irr = 114, band_irr = 1, weight = 6.0, w_ha = 0.6202 THz, 3.8971e+00 rad/ps, delta = -0.0561, gamma = 0.0147, [0.24 0.24 0.  ]
# i = 114, q_irr = 115, band_irr = 1, weight = 24.0, w_ha = 0.6556 THz, 4.1190e+00 rad/ps, delta = -0.0638, gamma = 0.0159, [0.28 0.24 0.  ]
# i = 115, q_irr = 116, band_irr = 1, weight = 24.0, w_ha = 0.7302 THz, 4.5881e+00 rad/ps, delta = -0.0714, gamma = 0.0190, [0.32 0.24 0.  ]
# i = 116, q_irr = 117, band_irr = 1, weight = 24.0, w_ha = 0.8304 THz, 5.2177e+00 rad/ps, delta = -0.0828, gamma = 0.0210, [0.36 0.24 0.  ]
# i = 117, q_irr = 118, band_irr = 1, weight = 24.0, w_ha = 0.9451 THz, 5.9382e+00 rad/ps, delta = -0.0963, gamma = 0.0277, [0.4  0.24 0.  ]
# i = 118, q_irr = 119, band_irr = 1, weight = 24.0, w_ha = 1.0677 THz, 6.7086e+00 rad/ps, delta = -0.1108, gamma = 0.0336, [0.44 0.24 0.  ]
# i = 119, q_irr = 120, band_irr = 1, weight = 24.0, w_ha = 1.1951 THz, 7.5091e+00 rad/ps, delta = -0.1273, gamma = 0.0426, [0.48 0.24 0.  ]
# i = 120, q_irr = 121, band_irr = 1, weight = 24.0, w_ha = 1.3256 THz, 8.3291e+00 rad/ps, delta = -0.1450, gamma = 0.0553, [0.52 0.24 0.  ]
# i = 121, q_irr = 122, band_irr = 1, weight = 24.0, w_ha = 1.4576 THz, 9.1586e+00 rad/ps, delta = -0.1664, gamma = 0.0650, [0.56 0.24 0.  ]
# i = 122, q_irr = 123, band_irr = 1, weight = 24.0, w_ha = 1.3110 THz, 8.2370e+00 rad/ps, delta = -0.1178, gamma = 0.0426, [0.6  0.24 0.  ]
# i = 123, q_irr = 124, band_irr = 1, weight = 24.0, w_ha = 1.1560 THz, 7.2633e+00 rad/ps, delta = -0.1052, gamma = 0.0358, [0.64 0.24 0.  ]
# i = 124, q_irr = 125, band_irr = 1, weight = 24.0, w_ha = 1.0430 THz, 6.5533e+00 rad/ps, delta = -0.0922, gamma = 0.0274, [0.68 0.24 0.  ]
# i = 125, q_irr = 126, band_irr = 1, weight = 24.0, w_ha = 0.9746 THz, 6.1233e+00 rad/ps, delta = -0.0798, gamma = 0.0229, [0.72 0.24 0.  ]
# i = 126, q_irr = 127, band_irr = 1, weight = 12.0, w_ha = 0.9462 THz, 5.9452e+00 rad/ps, delta = -0.0698, gamma = 0.0195, [0.76 0.24 0.  ]
# i = 127, q_irr = 128, band_irr = 1, weight = 6.0, w_ha = 0.6469 THz, 4.0643e+00 rad/ps, delta = -0.0642, gamma = 0.0152, [0.28 0.28 0.  ]
# i = 128, q_irr = 129, band_irr = 1, weight = 24.0, w_ha = 0.6864 THz, 4.3129e+00 rad/ps, delta = -0.0699, gamma = 0.0168, [0.32 0.28 0.  ]
# i = 129, q_irr = 130, band_irr = 1, weight = 24.0, w_ha = 0.7648 THz, 4.8056e+00 rad/ps, delta = -0.0755, gamma = 0.0182, [0.36 0.28 0.  ]
# i = 130, q_irr = 131, band_irr = 1, weight = 24.0, w_ha = 0.8686 THz, 5.4575e+00 rad/ps, delta = -0.0845, gamma = 0.0230, [0.4  0.28 0.  ]
# i = 131, q_irr = 132, band_irr = 1, weight = 24.0, w_ha = 0.9868 THz, 6.2000e+00 rad/ps, delta = -0.0949, gamma = 0.0278, [0.44 0.28 0.  ]
# i = 132, q_irr = 133, band_irr = 1, weight = 24.0, w_ha = 1.1126 THz, 6.9905e+00 rad/ps, delta = -0.1077, gamma = 0.0327, [0.48 0.28 0.  ]
# i = 133, q_irr = 134, band_irr = 1, weight = 24.0, w_ha = 1.2420 THz, 7.8035e+00 rad/ps, delta = -0.1249, gamma = 0.0424, [0.52 0.28 0.  ]
# i = 134, q_irr = 135, band_irr = 1, weight = 24.0, w_ha = 1.3719 THz, 8.6202e+00 rad/ps, delta = -0.1446, gamma = 0.0542, [0.56 0.28 0.  ]
# i = 135, q_irr = 136, band_irr = 1, weight = 24.0, w_ha = 1.2598 THz, 7.9157e+00 rad/ps, delta = -0.1070, gamma = 0.0367, [0.6  0.28 0.  ]
# i = 136, q_irr = 137, band_irr = 1, weight = 24.0, w_ha = 1.1150 THz, 7.0055e+00 rad/ps, delta = -0.0978, gamma = 0.0334, [0.64 0.28 0.  ]
# i = 137, q_irr = 138, band_irr = 1, weight = 24.0, w_ha = 1.0188 THz, 6.4014e+00 rad/ps, delta = -0.0892, gamma = 0.0276, [0.68 0.28 0.  ]
# i = 138, q_irr = 139, band_irr = 1, weight = 12.0, w_ha = 0.9742 THz, 6.1210e+00 rad/ps, delta = -0.0836, gamma = 0.0235, [0.72 0.28 0.  ]
# i = 139, q_irr = 140, band_irr = 1, weight = 6.0, w_ha = 0.6873 THz, 4.3183e+00 rad/ps, delta = -0.0711, gamma = 0.0169, [0.32 0.32 0.  ]
# i = 140, q_irr = 141, band_irr = 1, weight = 24.0, w_ha = 0.7327 THz, 4.6039e+00 rad/ps, delta = -0.0727, gamma = 0.0170, [0.36 0.32 0.  ]
# i = 141, q_irr = 142, band_irr = 1, weight = 24.0, w_ha = 0.8132 THz, 5.1097e+00 rad/ps, delta = -0.0785, gamma = 0.0204, [0.4  0.32 0.  ]
# i = 142, q_irr = 143, band_irr = 1, weight = 24.0, w_ha = 0.9167 THz, 5.7598e+00 rad/ps, delta = -0.0842, gamma = 0.0233, [0.44 0.32 0.  ]
# i = 143, q_irr = 144, band_irr = 1, weight = 24.0, w_ha = 1.0335 THz, 6.4934e+00 rad/ps, delta = -0.0935, gamma = 0.0278, [0.48 0.32 0.  ]
# i = 144, q_irr = 145, band_irr = 1, weight = 24.0, w_ha = 1.1569 THz, 7.2690e+00 rad/ps, delta = -0.1053, gamma = 0.0338, [0.52 0.32 0.  ]
# i = 145, q_irr = 146, band_irr = 1, weight = 24.0, w_ha = 1.2823 THz, 8.0569e+00 rad/ps, delta = -0.1246, gamma = 0.0444, [0.56 0.32 0.  ]
# i = 146, q_irr = 147, band_irr = 1, weight = 24.0, w_ha = 1.2364 THz, 7.7686e+00 rad/ps, delta = -0.0977, gamma = 0.0338, [0.6  0.32 0.  ]
# i = 147, q_irr = 148, band_irr = 1, weight = 24.0, w_ha = 1.1050 THz, 6.9431e+00 rad/ps, delta = -0.0909, gamma = 0.0296, [0.64 0.32 0.  ]
# i = 148, q_irr = 149, band_irr = 1, weight = 12.0, w_ha = 1.0363 THz, 6.5113e+00 rad/ps, delta = -0.0881, gamma = 0.0276, [0.68 0.32 0.  ]
# i = 149, q_irr = 150, band_irr = 1, weight = 6.0, w_ha = 0.7406 THz, 4.6532e+00 rad/ps, delta = -0.0727, gamma = 0.0170, [0.36 0.36 0.  ]
# i = 150, q_irr = 151, band_irr = 1, weight = 24.0, w_ha = 0.7869 THz, 4.9445e+00 rad/ps, delta = -0.0743, gamma = 0.0184, [0.4  0.36 0.  ]
# i = 151, q_irr = 152, band_irr = 1, weight = 24.0, w_ha = 0.8639 THz, 5.4282e+00 rad/ps, delta = -0.0770, gamma = 0.0206, [0.44 0.36 0.  ]
# i = 152, q_irr = 153, band_irr = 1, weight = 24.0, w_ha = 0.9618 THz, 6.0431e+00 rad/ps, delta = -0.0836, gamma = 0.0242, [0.48 0.36 0.  ]
# i = 153, q_irr = 154, band_irr = 1, weight = 24.0, w_ha = 1.0721 THz, 6.7365e+00 rad/ps, delta = -0.0922, gamma = 0.0275, [0.52 0.36 0.  ]
# i = 154, q_irr = 155, band_irr = 1, weight = 24.0, w_ha = 1.1884 THz, 7.4669e+00 rad/ps, delta = -0.1051, gamma = 0.0349, [0.56 0.36 0.  ]
# i = 155, q_irr = 156, band_irr = 1, weight = 24.0, w_ha = 1.2237 THz, 7.6885e+00 rad/ps, delta = -0.0920, gamma = 0.0299, [0.6  0.36 0.  ]
# i = 156, q_irr = 157, band_irr = 1, weight = 12.0, w_ha = 1.1377 THz, 7.1486e+00 rad/ps, delta = -0.0892, gamma = 0.0285, [0.64 0.36 0.  ]
# i = 157, q_irr = 158, band_irr = 1, weight = 6.0, w_ha = 0.7946 THz, 4.9927e+00 rad/ps, delta = -0.0723, gamma = 0.0191, [0.4 0.4 0. ]
# i = 158, q_irr = 159, band_irr = 1, weight = 24.0, w_ha = 0.8356 THz, 5.2499e+00 rad/ps, delta = -0.0712, gamma = 0.0202, [0.44 0.4  0.  ]
# i = 159, q_irr = 160, band_irr = 1, weight = 24.0, w_ha = 0.9042 THz, 5.6812e+00 rad/ps, delta = -0.0756, gamma = 0.0212, [0.48 0.4  0.  ]
# i = 160, q_irr = 161, band_irr = 1, weight = 24.0, w_ha = 0.9928 THz, 6.2379e+00 rad/ps, delta = -0.0823, gamma = 0.0241, [0.52 0.4  0.  ]
# i = 161, q_irr = 162, band_irr = 1, weight = 24.0, w_ha = 1.0936 THz, 6.8713e+00 rad/ps, delta = -0.0953, gamma = 0.0281, [0.56 0.4  0.  ]
# i = 162, q_irr = 163, band_irr = 1, weight = 12.0, w_ha = 1.1997 THz, 7.5378e+00 rad/ps, delta = -0.1061, gamma = 0.0334, [0.6 0.4 0. ]
# i = 163, q_irr = 164, band_irr = 1, weight = 6.0, w_ha = 0.8367 THz, 5.2569e+00 rad/ps, delta = -0.0691, gamma = 0.0195, [0.44 0.44 0.  ]
# i = 164, q_irr = 165, band_irr = 1, weight = 24.0, w_ha = 0.8680 THz, 5.4541e+00 rad/ps, delta = -0.0702, gamma = 0.0187, [0.48 0.44 0.  ]
# i = 165, q_irr = 166, band_irr = 1, weight = 24.0, w_ha = 0.9260 THz, 5.8180e+00 rad/ps, delta = -0.0745, gamma = 0.0187, [0.52 0.44 0.  ]
# i = 166, q_irr = 167, band_irr = 1, weight = 12.0, w_ha = 1.0037 THz, 6.3065e+00 rad/ps, delta = -0.0823, gamma = 0.0220, [0.56 0.44 0.  ]
# i = 167, q_irr = 168, band_irr = 1, weight = 6.0, w_ha = 0.8591 THz, 5.3980e+00 rad/ps, delta = -0.0682, gamma = 0.0170, [0.48 0.48 0.  ]
# i = 168, q_irr = 169, band_irr = 1, weight = 12.0, w_ha = 0.8793 THz, 5.5249e+00 rad/ps, delta = -0.0699, gamma = 0.0167, [0.52 0.48 0.  ]
# i = 169, q_irr = 170, band_irr = 1, weight = 24.0, w_ha = 0.3868 THz, 2.4306e+00 rad/ps, delta = -0.0205, gamma = 0.0043, [0.12 0.08 0.04]
# i = 170, q_irr = 171, band_irr = 1, weight = 48.0, w_ha = 0.5269 THz, 3.3109e+00 rad/ps, delta = -0.0312, gamma = 0.0074, [0.16 0.08 0.04]
# i = 171, q_irr = 172, band_irr = 1, weight = 48.0, w_ha = 0.6896 THz, 4.3329e+00 rad/ps, delta = -0.0468, gamma = 0.0118, [0.2  0.08 0.04]
# i = 172, q_irr = 173, band_irr = 1, weight = 48.0, w_ha = 0.8476 THz, 5.3257e+00 rad/ps, delta = -0.0658, gamma = 0.0180, [0.24 0.08 0.04]
# i = 173, q_irr = 174, band_irr = 1, weight = 48.0, w_ha = 0.9927 THz, 6.2374e+00 rad/ps, delta = -0.0879, gamma = 0.0260, [0.28 0.08 0.04]
# i = 174, q_irr = 175, band_irr = 1, weight = 48.0, w_ha = 1.1241 THz, 7.0630e+00 rad/ps, delta = -0.1133, gamma = 0.0356, [0.32 0.08 0.04]
# i = 175, q_irr = 176, band_irr = 1, weight = 48.0, w_ha = 1.2453 THz, 7.8242e+00 rad/ps, delta = -0.1402, gamma = 0.0497, [0.36 0.08 0.04]
# i = 176, q_irr = 177, band_irr = 1, weight = 48.0, w_ha = 1.3624 THz, 8.5604e+00 rad/ps, delta = -0.1676, gamma = 0.0634, [0.4  0.08 0.04]
# i = 177, q_irr = 178, band_irr = 1, weight = 48.0, w_ha = 1.4829 THz, 9.3173e+00 rad/ps, delta = -0.1961, gamma = 0.0773, [0.44 0.08 0.04]
# i = 178, q_irr = 179, band_irr = 1, weight = 48.0, w_ha = 1.6125 THz, 1.0132e+01 rad/ps, delta = -0.2271, gamma = 0.0996, [0.48 0.08 0.04]
# i = 179, q_irr = 180, band_irr = 1, weight = 48.0, w_ha = 1.7488 THz, 1.0988e+01 rad/ps, delta = -0.2503, gamma = 0.1349, [0.52 0.08 0.04]
# i = 180, q_irr = 181, band_irr = 1, weight = 24.0, w_ha = 0.5029 THz, 3.1597e+00 rad/ps, delta = -0.0268, gamma = 0.0075, [0.16 0.12 0.04]
# i = 181, q_irr = 182, band_irr = 1, weight = 48.0, w_ha = 0.6154 THz, 3.8667e+00 rad/ps, delta = -0.0369, gamma = 0.0104, [0.2  0.12 0.04]
# i = 182, q_irr = 183, band_irr = 1, weight = 48.0, w_ha = 0.7499 THz, 4.7118e+00 rad/ps, delta = -0.0518, gamma = 0.0137, [0.24 0.12 0.04]
# i = 183, q_irr = 184, band_irr = 1, weight = 48.0, w_ha = 0.8834 THz, 5.5505e+00 rad/ps, delta = -0.0716, gamma = 0.0198, [0.28 0.12 0.04]
# i = 184, q_irr = 185, band_irr = 1, weight = 48.0, w_ha = 1.0081 THz, 6.3340e+00 rad/ps, delta = -0.0951, gamma = 0.0295, [0.32 0.12 0.04]
# i = 185, q_irr = 186, band_irr = 1, weight = 48.0, w_ha = 1.1239 THz, 7.0615e+00 rad/ps, delta = -0.1205, gamma = 0.0402, [0.36 0.12 0.04]
# i = 186, q_irr = 187, band_irr = 1, weight = 48.0, w_ha = 1.2348 THz, 7.7585e+00 rad/ps, delta = -0.1464, gamma = 0.0501, [0.4  0.12 0.04]
# i = 187, q_irr = 188, band_irr = 1, weight = 48.0, w_ha = 1.3469 THz, 8.4625e+00 rad/ps, delta = -0.1747, gamma = 0.0652, [0.44 0.12 0.04]
# i = 188, q_irr = 189, band_irr = 1, weight = 48.0, w_ha = 1.4653 THz, 9.2070e+00 rad/ps, delta = -0.2053, gamma = 0.0819, [0.48 0.12 0.04]
# i = 189, q_irr = 190, band_irr = 1, weight = 48.0, w_ha = 1.5894 THz, 9.9863e+00 rad/ps, delta = -0.2406, gamma = 0.1039, [0.52 0.12 0.04]
# i = 190, q_irr = 191, band_irr = 1, weight = 48.0, w_ha = 1.6631 THz, 1.0450e+01 rad/ps, delta = -0.2491, gamma = 0.1260, [0.56 0.12 0.04]
# i = 191, q_irr = 192, band_irr = 1, weight = 48.0, w_ha = 1.5618 THz, 9.8129e+00 rad/ps, delta = -0.2034, gamma = 0.0844, [0.6  0.12 0.04]
# i = 192, q_irr = 193, band_irr = 1, weight = 48.0, w_ha = 1.4315 THz, 8.9946e+00 rad/ps, delta = -0.1715, gamma = 0.0688, [0.64 0.12 0.04]
# i = 193, q_irr = 194, band_irr = 1, weight = 48.0, w_ha = 1.3099 THz, 8.2304e+00 rad/ps, delta = -0.1466, gamma = 0.0536, [0.68 0.12 0.04]
# i = 194, q_irr = 195, band_irr = 1, weight = 48.0, w_ha = 1.1953 THz, 7.5102e+00 rad/ps, delta = -0.1205, gamma = 0.0411, [0.72 0.12 0.04]
# i = 195, q_irr = 196, band_irr = 1, weight = 48.0, w_ha = 1.0814 THz, 6.7945e+00 rad/ps, delta = -0.0942, gamma = 0.0299, [0.76 0.12 0.04]
# i = 196, q_irr = 197, band_irr = 1, weight = 48.0, w_ha = 0.9626 THz, 6.0481e+00 rad/ps, delta = -0.0716, gamma = 0.0206, [0.8  0.12 0.04]
# i = 197, q_irr = 198, band_irr = 1, weight = 48.0, w_ha = 0.8371 THz, 5.2594e+00 rad/ps, delta = -0.0535, gamma = 0.0163, [0.84 0.12 0.04]
# i = 198, q_irr = 199, band_irr = 1, weight = 48.0, w_ha = 0.7097 THz, 4.4594e+00 rad/ps, delta = -0.0392, gamma = 0.0115, [0.88 0.12 0.04]
# i = 199, q_irr = 200, band_irr = 1, weight = 24.0, w_ha = 0.5965 THz, 3.7478e+00 rad/ps, delta = -0.0297, gamma = 0.0086, [0.92 0.12 0.04]
# i = 200, q_irr = 201, band_irr = 1, weight = 24.0, w_ha = 0.5840 THz, 3.6693e+00 rad/ps, delta = -0.0361, gamma = 0.0101, [0.2  0.16 0.04]
# i = 201, q_irr = 202, band_irr = 1, weight = 48.0, w_ha = 0.6726 THz, 4.2259e+00 rad/ps, delta = -0.0435, gamma = 0.0124, [0.24 0.16 0.04]
# i = 202, q_irr = 203, band_irr = 1, weight = 48.0, w_ha = 0.7833 THz, 4.9218e+00 rad/ps, delta = -0.0591, gamma = 0.0164, [0.28 0.16 0.04]
# i = 203, q_irr = 204, band_irr = 1, weight = 48.0, w_ha = 0.8978 THz, 5.6412e+00 rad/ps, delta = -0.0777, gamma = 0.0219, [0.32 0.16 0.04]
# i = 204, q_irr = 205, band_irr = 1, weight = 48.0, w_ha = 1.0097 THz, 6.3443e+00 rad/ps, delta = -0.1009, gamma = 0.0313, [0.36 0.16 0.04]
# i = 205, q_irr = 206, band_irr = 1, weight = 48.0, w_ha = 1.1191 THz, 7.0318e+00 rad/ps, delta = -0.1223, gamma = 0.0391, [0.4  0.16 0.04]
# i = 206, q_irr = 207, band_irr = 1, weight = 48.0, w_ha = 1.2293 THz, 7.7240e+00 rad/ps, delta = -0.1495, gamma = 0.0535, [0.44 0.16 0.04]
# i = 207, q_irr = 208, band_irr = 1, weight = 48.0, w_ha = 1.3439 THz, 8.4441e+00 rad/ps, delta = -0.1725, gamma = 0.0660, [0.48 0.16 0.04]
# i = 208, q_irr = 209, band_irr = 1, weight = 48.0, w_ha = 1.4629 THz, 9.1915e+00 rad/ps, delta = -0.2040, gamma = 0.0818, [0.52 0.16 0.04]
# i = 209, q_irr = 210, band_irr = 1, weight = 48.0, w_ha = 1.5603 THz, 9.8035e+00 rad/ps, delta = -0.2301, gamma = 0.1003, [0.56 0.16 0.04]
# i = 210, q_irr = 211, band_irr = 1, weight = 48.0, w_ha = 1.5004 THz, 9.4273e+00 rad/ps, delta = -0.1886, gamma = 0.0733, [0.6  0.16 0.04]
# i = 211, q_irr = 212, band_irr = 1, weight = 48.0, w_ha = 1.3681 THz, 8.5961e+00 rad/ps, delta = -0.1557, gamma = 0.0572, [0.64 0.16 0.04]
# i = 212, q_irr = 213, band_irr = 1, weight = 48.0, w_ha = 1.2437 THz, 7.8142e+00 rad/ps, delta = -0.1287, gamma = 0.0436, [0.68 0.16 0.04]
# i = 213, q_irr = 214, band_irr = 1, weight = 48.0, w_ha = 1.1333 THz, 7.1209e+00 rad/ps, delta = -0.1038, gamma = 0.0337, [0.72 0.16 0.04]
# i = 214, q_irr = 215, band_irr = 1, weight = 48.0, w_ha = 1.0329 THz, 6.4899e+00 rad/ps, delta = -0.0819, gamma = 0.0250, [0.76 0.16 0.04]
# i = 215, q_irr = 216, band_irr = 1, weight = 48.0, w_ha = 0.9377 THz, 5.8918e+00 rad/ps, delta = -0.0615, gamma = 0.0184, [0.8  0.16 0.04]
# i = 216, q_irr = 217, band_irr = 1, weight = 48.0, w_ha = 0.8470 THz, 5.3218e+00 rad/ps, delta = -0.0471, gamma = 0.0140, [0.84 0.16 0.04]
# i = 217, q_irr = 218, band_irr = 1, weight = 24.0, w_ha = 0.7667 THz, 4.8173e+00 rad/ps, delta = -0.0399, gamma = 0.0120, [0.88 0.16 0.04]
# i = 218, q_irr = 219, band_irr = 1, weight = 24.0, w_ha = 0.6312 THz, 3.9660e+00 rad/ps, delta = -0.0452, gamma = 0.0129, [0.24 0.2  0.04]
# i = 219, q_irr = 220, band_irr = 1, weight = 48.0, w_ha = 0.7037 THz, 4.4214e+00 rad/ps, delta = -0.0536, gamma = 0.0155, [0.28 0.2  0.04]
# i = 220, q_irr = 221, band_irr = 1, weight = 48.0, w_ha = 0.8004 THz, 5.0290e+00 rad/ps, delta = -0.0669, gamma = 0.0184, [0.32 0.2  0.04]
# i = 221, q_irr = 222, band_irr = 1, weight = 48.0, w_ha = 0.9064 THz, 5.6953e+00 rad/ps, delta = -0.0840, gamma = 0.0239, [0.36 0.2  0.04]
# i = 222, q_irr = 223, band_irr = 1, weight = 48.0, w_ha = 1.0160 THz, 6.3840e+00 rad/ps, delta = -0.1033, gamma = 0.0311, [0.4  0.2  0.04]
# i = 223, q_irr = 224, band_irr = 1, weight = 48.0, w_ha = 1.1283 THz, 7.0894e+00 rad/ps, delta = -0.1248, gamma = 0.0400, [0.44 0.2  0.04]
# i = 224, q_irr = 225, band_irr = 1, weight = 48.0, w_ha = 1.2442 THz, 7.8178e+00 rad/ps, delta = -0.1492, gamma = 0.0518, [0.48 0.2  0.04]
# i = 225, q_irr = 226, band_irr = 1, weight = 48.0, w_ha = 1.3631 THz, 8.5647e+00 rad/ps, delta = -0.1699, gamma = 0.0647, [0.52 0.2  0.04]
# i = 226, q_irr = 227, band_irr = 1, weight = 48.0, w_ha = 1.4691 THz, 9.2306e+00 rad/ps, delta = -0.2017, gamma = 0.0775, [0.56 0.2  0.04]
# i = 227, q_irr = 228, band_irr = 1, weight = 48.0, w_ha = 1.4395 THz, 9.0445e+00 rad/ps, delta = -0.1696, gamma = 0.0652, [0.6  0.2  0.04]
# i = 228, q_irr = 229, band_irr = 1, weight = 48.0, w_ha = 1.3029 THz, 8.1866e+00 rad/ps, delta = -0.1401, gamma = 0.0469, [0.64 0.2  0.04]
# i = 229, q_irr = 230, band_irr = 1, weight = 48.0, w_ha = 1.1754 THz, 7.3850e+00 rad/ps, delta = -0.1169, gamma = 0.0377, [0.68 0.2  0.04]
# i = 230, q_irr = 231, band_irr = 1, weight = 48.0, w_ha = 1.0716 THz, 6.7331e+00 rad/ps, delta = -0.0956, gamma = 0.0301, [0.72 0.2  0.04]
# i = 231, q_irr = 232, band_irr = 1, weight = 48.0, w_ha = 0.9899 THz, 6.2199e+00 rad/ps, delta = -0.0736, gamma = 0.0213, [0.76 0.2  0.04]
# i = 232, q_irr = 233, band_irr = 1, weight = 48.0, w_ha = 0.9260 THz, 5.8184e+00 rad/ps, delta = -0.0595, gamma = 0.0169, [0.8  0.2  0.04]
# i = 233, q_irr = 234, band_irr = 1, weight = 24.0, w_ha = 0.8778 THz, 5.5156e+00 rad/ps, delta = -0.0489, gamma = 0.0149, [0.84 0.2  0.04]
# i = 234, q_irr = 235, band_irr = 1, weight = 24.0, w_ha = 0.6582 THz, 4.1358e+00 rad/ps, delta = -0.0537, gamma = 0.0148, [0.28 0.24 0.04]
# i = 235, q_irr = 236, band_irr = 1, weight = 48.0, w_ha = 0.7252 THz, 4.5567e+00 rad/ps, delta = -0.0617, gamma = 0.0161, [0.32 0.24 0.04]
# i = 236, q_irr = 237, band_irr = 1, weight = 48.0, w_ha = 0.8187 THz, 5.1440e+00 rad/ps, delta = -0.0727, gamma = 0.0193, [0.36 0.24 0.04]
# i = 237, q_irr = 238, band_irr = 1, weight = 48.0, w_ha = 0.9256 THz, 5.8156e+00 rad/ps, delta = -0.0879, gamma = 0.0251, [0.4  0.24 0.04]
# i = 238, q_irr = 239, band_irr = 1, weight = 48.0, w_ha = 1.0396 THz, 6.5322e+00 rad/ps, delta = -0.1048, gamma = 0.0312, [0.44 0.24 0.04]
# i = 239, q_irr = 240, band_irr = 1, weight = 48.0, w_ha = 1.1583 THz, 7.2775e+00 rad/ps, delta = -0.1241, gamma = 0.0406, [0.48 0.24 0.04]
# i = 240, q_irr = 241, band_irr = 1, weight = 48.0, w_ha = 1.2793 THz, 8.0379e+00 rad/ps, delta = -0.1446, gamma = 0.0520, [0.52 0.24 0.04]
# i = 241, q_irr = 242, band_irr = 1, weight = 48.0, w_ha = 1.3916 THz, 8.7437e+00 rad/ps, delta = -0.1670, gamma = 0.0629, [0.56 0.24 0.04]
# i = 242, q_irr = 243, band_irr = 1, weight = 48.0, w_ha = 1.3848 THz, 8.7010e+00 rad/ps, delta = -0.1532, gamma = 0.0555, [0.6  0.24 0.04]
# i = 243, q_irr = 244, band_irr = 1, weight = 48.0, w_ha = 1.2438 THz, 7.8147e+00 rad/ps, delta = -0.1254, gamma = 0.0436, [0.64 0.24 0.04]
# i = 244, q_irr = 245, band_irr = 1, weight = 48.0, w_ha = 1.1157 THz, 7.0101e+00 rad/ps, delta = -0.1053, gamma = 0.0336, [0.68 0.24 0.04]
# i = 245, q_irr = 246, band_irr = 1, weight = 48.0, w_ha = 1.0221 THz, 6.4218e+00 rad/ps, delta = -0.0879, gamma = 0.0263, [0.72 0.24 0.04]
# i = 246, q_irr = 247, band_irr = 1, weight = 48.0, w_ha = 0.9628 THz, 6.0497e+00 rad/ps, delta = -0.0740, gamma = 0.0209, [0.76 0.24 0.04]
# i = 247, q_irr = 248, band_irr = 1, weight = 24.0, w_ha = 0.9328 THz, 5.8607e+00 rad/ps, delta = -0.0637, gamma = 0.0188, [0.8  0.24 0.04]
# i = 248, q_irr = 249, band_irr = 1, weight = 24.0, w_ha = 0.6847 THz, 4.3020e+00 rad/ps, delta = -0.0633, gamma = 0.0162, [0.32 0.28 0.04]
# i = 249, q_irr = 250, band_irr = 1, weight = 48.0, w_ha = 0.7547 THz, 4.7421e+00 rad/ps, delta = -0.0683, gamma = 0.0178, [0.36 0.28 0.04]
# i = 250, q_irr = 251, band_irr = 1, weight = 48.0, w_ha = 0.8511 THz, 5.3477e+00 rad/ps, delta = -0.0775, gamma = 0.0204, [0.4  0.28 0.04]
# i = 251, q_irr = 252, band_irr = 1, weight = 48.0, w_ha = 0.9619 THz, 6.0435e+00 rad/ps, delta = -0.0897, gamma = 0.0255, [0.44 0.28 0.04]
# i = 252, q_irr = 253, band_irr = 1, weight = 48.0, w_ha = 1.0803 THz, 6.7878e+00 rad/ps, delta = -0.1041, gamma = 0.0327, [0.48 0.28 0.04]
# i = 253, q_irr = 254, band_irr = 1, weight = 48.0, w_ha = 1.2022 THz, 7.5539e+00 rad/ps, delta = -0.1195, gamma = 0.0398, [0.52 0.28 0.04]
# i = 254, q_irr = 255, band_irr = 1, weight = 48.0, w_ha = 1.3194 THz, 8.2902e+00 rad/ps, delta = -0.1398, gamma = 0.0509, [0.56 0.28 0.04]
# i = 255, q_irr = 256, band_irr = 1, weight = 48.0, w_ha = 1.3493 THz, 8.4782e+00 rad/ps, delta = -0.1363, gamma = 0.0501, [0.6  0.28 0.04]
# i = 256, q_irr = 257, band_irr = 1, weight = 48.0, w_ha = 1.1956 THz, 7.5124e+00 rad/ps, delta = -0.1071, gamma = 0.0366, [0.64 0.28 0.04]
# i = 257, q_irr = 258, band_irr = 1, weight = 48.0, w_ha = 1.0740 THz, 6.7481e+00 rad/ps, delta = -0.0983, gamma = 0.0295, [0.68 0.28 0.04]
# i = 258, q_irr = 259, band_irr = 1, weight = 48.0, w_ha = 0.9961 THz, 6.2587e+00 rad/ps, delta = -0.0853, gamma = 0.0261, [0.72 0.28 0.04]
# i = 259, q_irr = 260, band_irr = 1, weight = 24.0, w_ha = 0.9616 THz, 6.0420e+00 rad/ps, delta = -0.0755, gamma = 0.0212, [0.76 0.28 0.04]
# i = 260, q_irr = 261, band_irr = 1, weight = 24.0, w_ha = 0.7244 THz, 4.5514e+00 rad/ps, delta = -0.0676, gamma = 0.0168, [0.36 0.32 0.04]
# i = 261, q_irr = 262, band_irr = 1, weight = 48.0, w_ha = 0.7991 THz, 5.0210e+00 rad/ps, delta = -0.0724, gamma = 0.0193, [0.4  0.32 0.04]
# i = 262, q_irr = 263, band_irr = 1, weight = 48.0, w_ha = 0.8974 THz, 5.6385e+00 rad/ps, delta = -0.0786, gamma = 0.0219, [0.44 0.32 0.04]
# i = 263, q_irr = 264, band_irr = 1, weight = 48.0, w_ha = 1.0089 THz, 6.3393e+00 rad/ps, delta = -0.0881, gamma = 0.0272, [0.48 0.32 0.04]
# i = 264, q_irr = 265, band_irr = 1, weight = 48.0, w_ha = 1.1272 THz, 7.0824e+00 rad/ps, delta = -0.1029, gamma = 0.0324, [0.52 0.32 0.04]
# i = 265, q_irr = 266, band_irr = 1, weight = 48.0, w_ha = 1.2455 THz, 7.8259e+00 rad/ps, delta = -0.1196, gamma = 0.0392, [0.56 0.32 0.04]
# i = 266, q_irr = 267, band_irr = 1, weight = 48.0, w_ha = 1.3033 THz, 8.1888e+00 rad/ps, delta = -0.1189, gamma = 0.0435, [0.6  0.32 0.04]
# i = 267, q_irr = 268, band_irr = 1, weight = 48.0, w_ha = 1.1648 THz, 7.3188e+00 rad/ps, delta = -0.0982, gamma = 0.0328, [0.64 0.32 0.04]
# i = 268, q_irr = 269, band_irr = 1, weight = 48.0, w_ha = 1.0606 THz, 6.6640e+00 rad/ps, delta = -0.0912, gamma = 0.0290, [0.68 0.32 0.04]
# i = 269, q_irr = 270, band_irr = 1, weight = 24.0, w_ha = 1.0055 THz, 6.3177e+00 rad/ps, delta = -0.0861, gamma = 0.0256, [0.72 0.32 0.04]
# i = 270, q_irr = 271, band_irr = 1, weight = 24.0, w_ha = 0.7766 THz, 4.8796e+00 rad/ps, delta = -0.0709, gamma = 0.0179, [0.4  0.36 0.04]
# i = 271, q_irr = 272, band_irr = 1, weight = 48.0, w_ha = 0.8515 THz, 5.3503e+00 rad/ps, delta = -0.0727, gamma = 0.0189, [0.44 0.36 0.04]
# i = 272, q_irr = 273, band_irr = 1, weight = 48.0, w_ha = 0.9467 THz, 5.9486e+00 rad/ps, delta = -0.0767, gamma = 0.0226, [0.48 0.36 0.04]
# i = 273, q_irr = 274, band_irr = 1, weight = 48.0, w_ha = 1.0541 THz, 6.6228e+00 rad/ps, delta = -0.0873, gamma = 0.0258, [0.52 0.36 0.04]
# i = 274, q_irr = 275, band_irr = 1, weight = 48.0, w_ha = 1.1671 THz, 7.3332e+00 rad/ps, delta = -0.0994, gamma = 0.0311, [0.56 0.36 0.04]
# i = 275, q_irr = 276, band_irr = 1, weight = 48.0, w_ha = 1.2607 THz, 7.9211e+00 rad/ps, delta = -0.1092, gamma = 0.0359, [0.6  0.36 0.04]
# i = 276, q_irr = 277, band_irr = 1, weight = 48.0, w_ha = 1.1610 THz, 7.2948e+00 rad/ps, delta = -0.0916, gamma = 0.0304, [0.64 0.36 0.04]
# i = 277, q_irr = 278, band_irr = 1, weight = 24.0, w_ha = 1.0870 THz, 6.8295e+00 rad/ps, delta = -0.0872, gamma = 0.0274, [0.68 0.36 0.04]
# i = 278, q_irr = 279, band_irr = 1, weight = 24.0, w_ha = 0.8298 THz, 5.2139e+00 rad/ps, delta = -0.0718, gamma = 0.0197, [0.44 0.4  0.04]
# i = 279, q_irr = 280, band_irr = 1, weight = 48.0, w_ha = 0.8990 THz, 5.6488e+00 rad/ps, delta = -0.0704, gamma = 0.0202, [0.48 0.4  0.04]
# i = 280, q_irr = 281, band_irr = 1, weight = 48.0, w_ha = 0.9866 THz, 6.1992e+00 rad/ps, delta = -0.0774, gamma = 0.0232, [0.52 0.4  0.04]
# i = 281, q_irr = 282, band_irr = 1, weight = 48.0, w_ha = 1.0861 THz, 6.8243e+00 rad/ps, delta = -0.0868, gamma = 0.0252, [0.56 0.4  0.04]
# i = 282, q_irr = 283, band_irr = 1, weight = 48.0, w_ha = 1.1919 THz, 7.4889e+00 rad/ps, delta = -0.0993, gamma = 0.0314, [0.6  0.4  0.04]
# i = 283, q_irr = 284, band_irr = 1, weight = 24.0, w_ha = 1.1991 THz, 7.5341e+00 rad/ps, delta = -0.0877, gamma = 0.0282, [0.64 0.4  0.04]
# i = 284, q_irr = 285, band_irr = 1, weight = 24.0, w_ha = 0.8714 THz, 5.4753e+00 rad/ps, delta = -0.0682, gamma = 0.0195, [0.48 0.44 0.04]
# i = 285, q_irr = 286, band_irr = 1, weight = 48.0, w_ha = 0.9311 THz, 5.8503e+00 rad/ps, delta = -0.0701, gamma = 0.0192, [0.52 0.44 0.04]
# i = 286, q_irr = 287, band_irr = 1, weight = 48.0, w_ha = 1.0086 THz, 6.3374e+00 rad/ps, delta = -0.0766, gamma = 0.0205, [0.56 0.44 0.04]
# i = 287, q_irr = 288, band_irr = 1, weight = 24.0, w_ha = 1.0982 THz, 6.9005e+00 rad/ps, delta = -0.0869, gamma = 0.0254, [0.6  0.44 0.04]
# i = 288, q_irr = 289, band_irr = 1, weight = 24.0, w_ha = 0.8937 THz, 5.6154e+00 rad/ps, delta = -0.0678, gamma = 0.0178, [0.52 0.48 0.04]
# i = 289, q_irr = 290, band_irr = 1, weight = 24.0, w_ha = 0.9423 THz, 5.9207e+00 rad/ps, delta = -0.0699, gamma = 0.0173, [0.56 0.48 0.04]
# i = 290, q_irr = 291, band_irr = 1, weight = 24.0, w_ha = 0.6731 THz, 4.2289e+00 rad/ps, delta = -0.0368, gamma = 0.0115, [0.24 0.16 0.08]
# i = 291, q_irr = 292, band_irr = 1, weight = 48.0, w_ha = 0.7657 THz, 4.8112e+00 rad/ps, delta = -0.0440, gamma = 0.0129, [0.28 0.16 0.08]
# i = 292, q_irr = 293, band_irr = 1, weight = 48.0, w_ha = 0.8716 THz, 5.4764e+00 rad/ps, delta = -0.0599, gamma = 0.0176, [0.32 0.16 0.08]
# i = 293, q_irr = 294, band_irr = 1, weight = 48.0, w_ha = 0.9782 THz, 6.1462e+00 rad/ps, delta = -0.0805, gamma = 0.0243, [0.36 0.16 0.08]
# i = 294, q_irr = 295, band_irr = 1, weight = 48.0, w_ha = 1.0826 THz, 6.8019e+00 rad/ps, delta = -0.1042, gamma = 0.0341, [0.4  0.16 0.08]
# i = 295, q_irr = 296, band_irr = 1, weight = 48.0, w_ha = 1.1875 THz, 7.4613e+00 rad/ps, delta = -0.1311, gamma = 0.0439, [0.44 0.16 0.08]
# i = 296, q_irr = 297, band_irr = 1, weight = 48.0, w_ha = 1.2977 THz, 8.1535e+00 rad/ps, delta = -0.1607, gamma = 0.0576, [0.48 0.16 0.08]
# i = 297, q_irr = 298, band_irr = 1, weight = 48.0, w_ha = 1.4141 THz, 8.8849e+00 rad/ps, delta = -0.1944, gamma = 0.0742, [0.52 0.16 0.08]
# i = 298, q_irr = 299, band_irr = 1, weight = 48.0, w_ha = 1.5177 THz, 9.5357e+00 rad/ps, delta = -0.2296, gamma = 0.0926, [0.56 0.16 0.08]
# i = 299, q_irr = 300, band_irr = 1, weight = 24.0, w_ha = 0.7189 THz, 4.5173e+00 rad/ps, delta = -0.0446, gamma = 0.0138, [0.28 0.2  0.08]
# i = 300, q_irr = 301, band_irr = 1, weight = 48.0, w_ha = 0.7966 THz, 5.0052e+00 rad/ps, delta = -0.0531, gamma = 0.0155, [0.32 0.2  0.08]
# i = 301, q_irr = 302, band_irr = 1, weight = 48.0, w_ha = 0.8886 THz, 5.5831e+00 rad/ps, delta = -0.0674, gamma = 0.0202, [0.36 0.2  0.08]
# i = 302, q_irr = 303, band_irr = 1, weight = 48.0, w_ha = 0.9853 THz, 6.1911e+00 rad/ps, delta = -0.0880, gamma = 0.0262, [0.4  0.2  0.08]
# i = 303, q_irr = 304, band_irr = 1, weight = 48.0, w_ha = 1.0850 THz, 6.8172e+00 rad/ps, delta = -0.1113, gamma = 0.0338, [0.44 0.2  0.08]
# i = 304, q_irr = 305, band_irr = 1, weight = 48.0, w_ha = 1.1893 THz, 7.4728e+00 rad/ps, delta = -0.1349, gamma = 0.0456, [0.48 0.2  0.08]
# i = 305, q_irr = 306, band_irr = 1, weight = 48.0, w_ha = 1.2989 THz, 8.1609e+00 rad/ps, delta = -0.1648, gamma = 0.0582, [0.52 0.2  0.08]
# i = 306, q_irr = 307, band_irr = 1, weight = 48.0, w_ha = 1.4021 THz, 8.8099e+00 rad/ps, delta = -0.1935, gamma = 0.0742, [0.56 0.2  0.08]
# i = 307, q_irr = 308, band_irr = 1, weight = 48.0, w_ha = 1.4383 THz, 9.0372e+00 rad/ps, delta = -0.2067, gamma = 0.0751, [0.6  0.2  0.08]
# i = 308, q_irr = 309, band_irr = 1, weight = 48.0, w_ha = 1.3536 THz, 8.5048e+00 rad/ps, delta = -0.1789, gamma = 0.0667, [0.64 0.2  0.08]
# i = 309, q_irr = 310, band_irr = 1, weight = 48.0, w_ha = 1.2388 THz, 7.7838e+00 rad/ps, delta = -0.1426, gamma = 0.0480, [0.68 0.2  0.08]
# i = 310, q_irr = 311, band_irr = 1, weight = 48.0, w_ha = 1.1320 THz, 7.1124e+00 rad/ps, delta = -0.1171, gamma = 0.0358, [0.72 0.2  0.08]
# i = 311, q_irr = 312, band_irr = 1, weight = 48.0, w_ha = 1.0376 THz, 6.5196e+00 rad/ps, delta = -0.0925, gamma = 0.0270, [0.76 0.2  0.08]
# i = 312, q_irr = 313, band_irr = 1, weight = 48.0, w_ha = 0.9530 THz, 5.9878e+00 rad/ps, delta = -0.0707, gamma = 0.0211, [0.8  0.2  0.08]
# i = 313, q_irr = 314, band_irr = 1, weight = 48.0, w_ha = 0.8762 THz, 5.5055e+00 rad/ps, delta = -0.0540, gamma = 0.0157, [0.84 0.2  0.08]
# i = 314, q_irr = 315, band_irr = 1, weight = 24.0, w_ha = 0.8107 THz, 5.0939e+00 rad/ps, delta = -0.0457, gamma = 0.0131, [0.88 0.2  0.08]
# i = 315, q_irr = 316, band_irr = 1, weight = 24.0, w_ha = 0.7458 THz, 4.6858e+00 rad/ps, delta = -0.0519, gamma = 0.0145, [0.32 0.24 0.08]
# i = 316, q_irr = 317, band_irr = 1, weight = 48.0, w_ha = 0.8180 THz, 5.1396e+00 rad/ps, delta = -0.0604, gamma = 0.0168, [0.36 0.24 0.08]
# i = 317, q_irr = 318, band_irr = 1, weight = 48.0, w_ha = 0.9063 THz, 5.6948e+00 rad/ps, delta = -0.0734, gamma = 0.0210, [0.4  0.24 0.08]
# i = 318, q_irr = 319, band_irr = 1, weight = 48.0, w_ha = 1.0029 THz, 6.3015e+00 rad/ps, delta = -0.0919, gamma = 0.0276, [0.44 0.24 0.08]
# i = 319, q_irr = 320, band_irr = 1, weight = 48.0, w_ha = 1.1053 THz, 6.9449e+00 rad/ps, delta = -0.1124, gamma = 0.0357, [0.48 0.24 0.08]
# i = 320, q_irr = 321, band_irr = 1, weight = 48.0, w_ha = 1.2123 THz, 7.6174e+00 rad/ps, delta = -0.1361, gamma = 0.0452, [0.52 0.24 0.08]
# i = 321, q_irr = 322, band_irr = 1, weight = 48.0, w_ha = 1.3161 THz, 8.2693e+00 rad/ps, delta = -0.1621, gamma = 0.0572, [0.56 0.24 0.08]
# i = 322, q_irr = 323, band_irr = 1, weight = 48.0, w_ha = 1.3749 THz, 8.6387e+00 rad/ps, delta = -0.1768, gamma = 0.0646, [0.6  0.24 0.08]
# i = 323, q_irr = 324, band_irr = 1, weight = 48.0, w_ha = 1.3001 THz, 8.1690e+00 rad/ps, delta = -0.1542, gamma = 0.0520, [0.64 0.24 0.08]
# i = 324, q_irr = 325, band_irr = 1, weight = 48.0, w_ha = 1.1849 THz, 7.4448e+00 rad/ps, delta = -0.1294, gamma = 0.0413, [0.68 0.24 0.08]
# i = 325, q_irr = 326, band_irr = 1, weight = 48.0, w_ha = 1.0825 THz, 6.8013e+00 rad/ps, delta = -0.1049, gamma = 0.0316, [0.72 0.24 0.08]
# i = 326, q_irr = 327, band_irr = 1, weight = 48.0, w_ha = 1.0023 THz, 6.2975e+00 rad/ps, delta = -0.0825, gamma = 0.0252, [0.76 0.24 0.08]
# i = 327, q_irr = 328, band_irr = 1, weight = 48.0, w_ha = 0.9425 THz, 5.9218e+00 rad/ps, delta = -0.0669, gamma = 0.0193, [0.8  0.24 0.08]
# i = 328, q_irr = 329, band_irr = 1, weight = 24.0, w_ha = 0.9004 THz, 5.6575e+00 rad/ps, delta = -0.0577, gamma = 0.0169, [0.84 0.24 0.08]
# i = 329, q_irr = 330, band_irr = 1, weight = 24.0, w_ha = 0.7717 THz, 4.8490e+00 rad/ps, delta = -0.0615, gamma = 0.0157, [0.36 0.28 0.08]
# i = 330, q_irr = 331, band_irr = 1, weight = 48.0, w_ha = 0.8468 THz, 5.3207e+00 rad/ps, delta = -0.0662, gamma = 0.0189, [0.4  0.28 0.08]
# i = 331, q_irr = 332, band_irr = 1, weight = 48.0, w_ha = 0.9381 THz, 5.8944e+00 rad/ps, delta = -0.0777, gamma = 0.0230, [0.44 0.28 0.08]
# i = 332, q_irr = 333, band_irr = 1, weight = 48.0, w_ha = 1.0384 THz, 6.5247e+00 rad/ps, delta = -0.0918, gamma = 0.0284, [0.48 0.28 0.08]
# i = 333, q_irr = 334, band_irr = 1, weight = 48.0, w_ha = 1.1441 THz, 7.1884e+00 rad/ps, delta = -0.1112, gamma = 0.0360, [0.52 0.28 0.08]
# i = 334, q_irr = 335, band_irr = 1, weight = 48.0, w_ha = 1.2488 THz, 7.8462e+00 rad/ps, delta = -0.1310, gamma = 0.0432, [0.56 0.28 0.08]
# i = 335, q_irr = 336, band_irr = 1, weight = 48.0, w_ha = 1.3210 THz, 8.3002e+00 rad/ps, delta = -0.1508, gamma = 0.0525, [0.6  0.28 0.08]
# i = 336, q_irr = 337, band_irr = 1, weight = 48.0, w_ha = 1.2584 THz, 7.9070e+00 rad/ps, delta = -0.1346, gamma = 0.0457, [0.64 0.28 0.08]
# i = 337, q_irr = 338, band_irr = 1, weight = 48.0, w_ha = 1.1431 THz, 7.1824e+00 rad/ps, delta = -0.1112, gamma = 0.0356, [0.68 0.28 0.08]
# i = 338, q_irr = 339, band_irr = 1, weight = 48.0, w_ha = 1.0482 THz, 6.5861e+00 rad/ps, delta = -0.0938, gamma = 0.0276, [0.72 0.28 0.08]
# i = 339, q_irr = 340, band_irr = 1, weight = 48.0, w_ha = 0.9853 THz, 6.1909e+00 rad/ps, delta = -0.0784, gamma = 0.0223, [0.76 0.28 0.08]
# i = 340, q_irr = 341, band_irr = 1, weight = 24.0, w_ha = 0.9518 THz, 5.9803e+00 rad/ps, delta = -0.0704, gamma = 0.0197, [0.8  0.28 0.08]
# i = 341, q_irr = 342, band_irr = 1, weight = 24.0, w_ha = 0.8100 THz, 5.0896e+00 rad/ps, delta = -0.0653, gamma = 0.0170, [0.4  0.32 0.08]
# i = 342, q_irr = 343, band_irr = 1, weight = 48.0, w_ha = 0.8900 THz, 5.5920e+00 rad/ps, delta = -0.0689, gamma = 0.0198, [0.44 0.32 0.08]
# i = 343, q_irr = 344, band_irr = 1, weight = 48.0, w_ha = 0.9840 THz, 6.1829e+00 rad/ps, delta = -0.0777, gamma = 0.0224, [0.48 0.32 0.08]
# i = 344, q_irr = 345, band_irr = 1, weight = 48.0, w_ha = 1.0858 THz, 6.8220e+00 rad/ps, delta = -0.0912, gamma = 0.0285, [0.52 0.32 0.08]
# i = 345, q_irr = 346, band_irr = 1, weight = 48.0, w_ha = 1.1896 THz, 7.4745e+00 rad/ps, delta = -0.1088, gamma = 0.0358, [0.56 0.32 0.08]
# i = 346, q_irr = 347, band_irr = 1, weight = 48.0, w_ha = 1.2739 THz, 8.0042e+00 rad/ps, delta = -0.1265, gamma = 0.0436, [0.6  0.32 0.08]
# ...
# i = 2616, q_irr = 342, band_irr = 6, weight = 24.0, w_ha = 5.5050 THz, 3.4589e+01 rad/ps, delta = -0.1299, gamma = 0.1769, [0.4  0.32 0.08]
# i = 2617, q_irr = 343, band_irr = 6, weight = 48.0, w_ha = 5.5929 THz, 3.5141e+01 rad/ps, delta = -0.1488, gamma = 0.2028, [0.44 0.32 0.08]
# i = 2618, q_irr = 344, band_irr = 6, weight = 48.0, w_ha = 5.6760 THz, 3.5663e+01 rad/ps, delta = -0.1344, gamma = 0.2539, [0.48 0.32 0.08]
# i = 2619, q_irr = 345, band_irr = 6, weight = 48.0, w_ha = 5.7429 THz, 3.6084e+01 rad/ps, delta = -0.1092, gamma = 0.2726, [0.52 0.32 0.08]
# i = 2620, q_irr = 346, band_irr = 6, weight = 48.0, w_ha = 5.7856 THz, 3.6352e+01 rad/ps, delta = -0.1032, gamma = 0.2958, [0.56 0.32 0.08]
# i = 2621, q_irr = 347, band_irr = 6, weight = 48.0, w_ha = 5.7974 THz, 3.6426e+01 rad/ps, delta = -0.0759, gamma = 0.2890, [0.6  0.32 0.08]
# i = 2622, q_irr = 348, band_irr = 6, weight = 48.0, w_ha = 5.7569 THz, 3.6172e+01 rad/ps, delta = -0.0461, gamma = 0.2839, [0.64 0.32 0.08]
# i = 2623, q_irr = 349, band_irr = 6, weight = 48.0, w_ha = 5.6881 THz, 3.5739e+01 rad/ps, delta = -0.0655, gamma = 0.2708, [0.68 0.32 0.08]
# i = 2624, q_irr = 350, band_irr = 6, weight = 48.0, w_ha = 5.5988 THz, 3.5178e+01 rad/ps, delta = -0.0972, gamma = 0.2361, [0.72 0.32 0.08]
# i = 2625, q_irr = 351, band_irr = 6, weight = 24.0, w_ha = 5.5528 THz, 3.4889e+01 rad/ps, delta = -0.1061, gamma = 0.1875, [0.76 0.32 0.08]
# i = 2626, q_irr = 352, band_irr = 6, weight = 24.0, w_ha = 5.6284 THz, 3.5365e+01 rad/ps, delta = -0.1682, gamma = 0.2180, [0.44 0.36 0.08]
# i = 2627, q_irr = 353, band_irr = 6, weight = 48.0, w_ha = 5.6890 THz, 3.5745e+01 rad/ps, delta = -0.1692, gamma = 0.2736, [0.48 0.36 0.08]
# i = 2628, q_irr = 354, band_irr = 6, weight = 48.0, w_ha = 5.7337 THz, 3.6026e+01 rad/ps, delta = -0.1119, gamma = 0.3232, [0.52 0.36 0.08]
# i = 2629, q_irr = 355, band_irr = 6, weight = 48.0, w_ha = 5.7564 THz, 3.6169e+01 rad/ps, delta = -0.0719, gamma = 0.3289, [0.56 0.36 0.08]
# i = 2630, q_irr = 356, band_irr = 6, weight = 48.0, w_ha = 5.7509 THz, 3.6134e+01 rad/ps, delta = -0.0283, gamma = 0.3497, [0.6  0.36 0.08]
# i = 2631, q_irr = 357, band_irr = 6, weight = 48.0, w_ha = 5.7096 THz, 3.5874e+01 rad/ps, delta = -0.0172, gamma = 0.3730, [0.64 0.36 0.08]
# i = 2632, q_irr = 358, band_irr = 6, weight = 48.0, w_ha = 5.5937 THz, 3.5146e+01 rad/ps, delta = -0.0347, gamma = 0.3676, [0.68 0.36 0.08]
# i = 2633, q_irr = 359, band_irr = 6, weight = 24.0, w_ha = 5.5155 THz, 3.4655e+01 rad/ps, delta = -0.1260, gamma = 0.2035, [0.72 0.36 0.08]
# i = 2634, q_irr = 360, band_irr = 6, weight = 24.0, w_ha = 5.7493 THz, 3.6124e+01 rad/ps, delta = -0.1515, gamma = 0.3415, [0.48 0.4  0.08]
# i = 2635, q_irr = 361, band_irr = 6, weight = 48.0, w_ha = 5.7784 THz, 3.6307e+01 rad/ps, delta = -0.0766, gamma = 0.3574, [0.52 0.4  0.08]
# i = 2636, q_irr = 362, band_irr = 6, weight = 48.0, w_ha = 5.7826 THz, 3.6333e+01 rad/ps, delta = 0.0013, gamma = 0.3706, [0.56 0.4  0.08]
# i = 2637, q_irr = 363, band_irr = 6, weight = 48.0, w_ha = 5.7592 THz, 3.6186e+01 rad/ps, delta = 0.0042, gamma = 0.4044, [0.6  0.4  0.08]
# i = 2638, q_irr = 364, band_irr = 6, weight = 48.0, w_ha = 5.7053 THz, 3.5848e+01 rad/ps, delta = 0.0709, gamma = 0.4405, [0.64 0.4  0.08]
# i = 2639, q_irr = 365, band_irr = 6, weight = 24.0, w_ha = 5.5977 THz, 3.5172e+01 rad/ps, delta = 0.0524, gamma = 0.5024, [0.68 0.4  0.08]
# i = 2640, q_irr = 366, band_irr = 6, weight = 24.0, w_ha = 5.8471 THz, 3.6739e+01 rad/ps, delta = 0.0376, gamma = 0.3893, [0.52 0.44 0.08]
# i = 2641, q_irr = 367, band_irr = 6, weight = 48.0, w_ha = 5.8436 THz, 3.6716e+01 rad/ps, delta = 0.0630, gamma = 0.3743, [0.56 0.44 0.08]
# i = 2642, q_irr = 368, band_irr = 6, weight = 48.0, w_ha = 5.8122 THz, 3.6519e+01 rad/ps, delta = 0.0902, gamma = 0.4007, [0.6  0.44 0.08]
# i = 2643, q_irr = 369, band_irr = 6, weight = 24.0, w_ha = 5.7583 THz, 3.6181e+01 rad/ps, delta = 0.1228, gamma = 0.4396, [0.64 0.44 0.08]
# i = 2644, q_irr = 370, band_irr = 6, weight = 24.0, w_ha = 5.9022 THz, 3.7084e+01 rad/ps, delta = 0.1073, gamma = 0.3526, [0.56 0.48 0.08]
# i = 2645, q_irr = 371, band_irr = 6, weight = 24.0, w_ha = 5.8679 THz, 3.6869e+01 rad/ps, delta = 0.1107, gamma = 0.3738, [0.6  0.48 0.08]
# i = 2646, q_irr = 372, band_irr = 6, weight = 24.0, w_ha = 5.4192 THz, 3.4050e+01 rad/ps, delta = -0.0952, gamma = 0.1873, [0.36 0.24 0.12]
# i = 2647, q_irr = 373, band_irr = 6, weight = 48.0, w_ha = 5.4971 THz, 3.4539e+01 rad/ps, delta = -0.1060, gamma = 0.1983, [0.4  0.24 0.12]
# i = 2648, q_irr = 374, band_irr = 6, weight = 48.0, w_ha = 5.6115 THz, 3.5258e+01 rad/ps, delta = -0.0936, gamma = 0.2041, [0.44 0.24 0.12]
# i = 2649, q_irr = 375, band_irr = 6, weight = 48.0, w_ha = 5.7286 THz, 3.5994e+01 rad/ps, delta = -0.0924, gamma = 0.2262, [0.48 0.24 0.12]
# i = 2650, q_irr = 376, band_irr = 6, weight = 48.0, w_ha = 5.8258 THz, 3.6604e+01 rad/ps, delta = -0.0922, gamma = 0.2206, [0.52 0.24 0.12]
# i = 2651, q_irr = 377, band_irr = 6, weight = 48.0, w_ha = 5.8931 THz, 3.7027e+01 rad/ps, delta = -0.1005, gamma = 0.2246, [0.56 0.24 0.12]
# i = 2652, q_irr = 378, band_irr = 6, weight = 48.0, w_ha = 5.9274 THz, 3.7243e+01 rad/ps, delta = -0.1118, gamma = 0.2373, [0.6  0.24 0.12]
# i = 2653, q_irr = 379, band_irr = 6, weight = 24.0, w_ha = 5.4710 THz, 3.4375e+01 rad/ps, delta = -0.1098, gamma = 0.1920, [0.4  0.28 0.12]
# i = 2654, q_irr = 380, band_irr = 6, weight = 48.0, w_ha = 5.5492 THz, 3.4866e+01 rad/ps, delta = -0.1151, gamma = 0.1947, [0.44 0.28 0.12]
# i = 2655, q_irr = 381, band_irr = 6, weight = 48.0, w_ha = 5.6504 THz, 3.5502e+01 rad/ps, delta = -0.1035, gamma = 0.2251, [0.48 0.28 0.12]
# i = 2656, q_irr = 382, band_irr = 6, weight = 48.0, w_ha = 5.7468 THz, 3.6108e+01 rad/ps, delta = -0.1004, gamma = 0.2281, [0.52 0.28 0.12]
# i = 2657, q_irr = 383, band_irr = 6, weight = 48.0, w_ha = 5.8202 THz, 3.6569e+01 rad/ps, delta = -0.0927, gamma = 0.2391, [0.56 0.28 0.12]
# i = 2658, q_irr = 384, band_irr = 6, weight = 48.0, w_ha = 5.8621 THz, 3.6833e+01 rad/ps, delta = -0.0907, gamma = 0.2430, [0.6  0.28 0.12]
# i = 2659, q_irr = 385, band_irr = 6, weight = 48.0, w_ha = 5.8654 THz, 3.6853e+01 rad/ps, delta = -0.0944, gamma = 0.2488, [0.64 0.28 0.12]
# i = 2660, q_irr = 386, band_irr = 6, weight = 48.0, w_ha = 5.8331 THz, 3.6650e+01 rad/ps, delta = -0.0907, gamma = 0.2429, [0.68 0.28 0.12]
# i = 2661, q_irr = 387, band_irr = 6, weight = 48.0, w_ha = 5.7660 THz, 3.6229e+01 rad/ps, delta = -0.0797, gamma = 0.2270, [0.72 0.28 0.12]
# i = 2662, q_irr = 388, band_irr = 6, weight = 48.0, w_ha = 5.6720 THz, 3.5638e+01 rad/ps, delta = -0.0898, gamma = 0.2212, [0.76 0.28 0.12]
# i = 2663, q_irr = 389, band_irr = 6, weight = 48.0, w_ha = 5.5730 THz, 3.5016e+01 rad/ps, delta = -0.1132, gamma = 0.1933, [0.8  0.28 0.12]
# i = 2664, q_irr = 390, band_irr = 6, weight = 24.0, w_ha = 5.5082 THz, 3.4609e+01 rad/ps, delta = -0.1192, gamma = 0.1827, [0.84 0.28 0.12]
# i = 2665, q_irr = 391, band_irr = 6, weight = 24.0, w_ha = 5.5449 THz, 3.4839e+01 rad/ps, delta = -0.1322, gamma = 0.1988, [0.44 0.32 0.12]
# i = 2666, q_irr = 392, band_irr = 6, weight = 48.0, w_ha = 5.6092 THz, 3.5244e+01 rad/ps, delta = -0.1428, gamma = 0.2387, [0.48 0.32 0.12]
# i = 2667, q_irr = 393, band_irr = 6, weight = 48.0, w_ha = 5.6841 THz, 3.5714e+01 rad/ps, delta = -0.1059, gamma = 0.2599, [0.52 0.32 0.12]
# i = 2668, q_irr = 394, band_irr = 6, weight = 48.0, w_ha = 5.7489 THz, 3.6122e+01 rad/ps, delta = -0.0940, gamma = 0.2551, [0.56 0.32 0.12]
# i = 2669, q_irr = 395, band_irr = 6, weight = 48.0, w_ha = 5.7889 THz, 3.6373e+01 rad/ps, delta = -0.0806, gamma = 0.2586, [0.6  0.32 0.12]
# i = 2670, q_irr = 396, band_irr = 6, weight = 48.0, w_ha = 5.7952 THz, 3.6412e+01 rad/ps, delta = -0.0747, gamma = 0.2810, [0.64 0.32 0.12]
# i = 2671, q_irr = 397, band_irr = 6, weight = 48.0, w_ha = 5.7541 THz, 3.6154e+01 rad/ps, delta = -0.0615, gamma = 0.2747, [0.68 0.32 0.12]
# i = 2672, q_irr = 398, band_irr = 6, weight = 48.0, w_ha = 5.6869 THz, 3.5732e+01 rad/ps, delta = -0.0717, gamma = 0.2573, [0.72 0.32 0.12]
# i = 2673, q_irr = 399, band_irr = 6, weight = 48.0, w_ha = 5.6069 THz, 3.5229e+01 rad/ps, delta = -0.1027, gamma = 0.2270, [0.76 0.32 0.12]
# i = 2674, q_irr = 400, band_irr = 6, weight = 24.0, w_ha = 5.5611 THz, 3.4941e+01 rad/ps, delta = -0.1268, gamma = 0.1962, [0.8  0.32 0.12]
# i = 2675, q_irr = 401, band_irr = 6, weight = 24.0, w_ha = 5.6285 THz, 3.5365e+01 rad/ps, delta = -0.1693, gamma = 0.2333, [0.48 0.36 0.12]
# i = 2676, q_irr = 402, band_irr = 6, weight = 48.0, w_ha = 5.6697 THz, 3.5624e+01 rad/ps, delta = -0.1304, gamma = 0.2641, [0.52 0.36 0.12]
# i = 2677, q_irr = 403, band_irr = 6, weight = 48.0, w_ha = 5.7080 THz, 3.5865e+01 rad/ps, delta = -0.0991, gamma = 0.2928, [0.56 0.36 0.12]
# i = 2678, q_irr = 404, band_irr = 6, weight = 48.0, w_ha = 5.7301 THz, 3.6003e+01 rad/ps, delta = -0.0588, gamma = 0.3123, [0.6  0.36 0.12]
# i = 2679, q_irr = 405, band_irr = 6, weight = 48.0, w_ha = 5.7236 THz, 3.5963e+01 rad/ps, delta = -0.0345, gamma = 0.3289, [0.64 0.36 0.12]
# i = 2680, q_irr = 406, band_irr = 6, weight = 48.0, w_ha = 5.6652 THz, 3.5596e+01 rad/ps, delta = -0.0390, gamma = 0.3376, [0.68 0.36 0.12]
# i = 2681, q_irr = 407, band_irr = 6, weight = 48.0, w_ha = 5.5906 THz, 3.5127e+01 rad/ps, delta = -0.0797, gamma = 0.2810, [0.72 0.36 0.12]
# i = 2682, q_irr = 408, band_irr = 6, weight = 24.0, w_ha = 5.5585 THz, 3.4925e+01 rad/ps, delta = -0.1197, gamma = 0.2107, [0.76 0.36 0.12]
# i = 2683, q_irr = 409, band_irr = 6, weight = 24.0, w_ha = 5.7118 THz, 3.5889e+01 rad/ps, delta = -0.1169, gamma = 0.3190, [0.52 0.4  0.12]
# i = 2684, q_irr = 410, band_irr = 6, weight = 48.0, w_ha = 5.7244 THz, 3.5968e+01 rad/ps, delta = -0.0761, gamma = 0.3278, [0.56 0.4  0.12]
# i = 2685, q_irr = 411, band_irr = 6, weight = 48.0, w_ha = 5.7207 THz, 3.5944e+01 rad/ps, delta = -0.0129, gamma = 0.3296, [0.6  0.4  0.12]
# i = 2686, q_irr = 412, band_irr = 6, weight = 48.0, w_ha = 5.6916 THz, 3.5761e+01 rad/ps, delta = 0.0133, gamma = 0.3717, [0.64 0.4  0.12]
# i = 2687, q_irr = 413, band_irr = 6, weight = 48.0, w_ha = 5.6087 THz, 3.5241e+01 rad/ps, delta = 0.0306, gamma = 0.4237, [0.68 0.4  0.12]
# i = 2688, q_irr = 414, band_irr = 6, weight = 24.0, w_ha = 5.4830 THz, 3.4451e+01 rad/ps, delta = 0.0209, gamma = 0.4808, [0.72 0.4  0.12]
# i = 2689, q_irr = 415, band_irr = 6, weight = 24.0, w_ha = 5.7821 THz, 3.6330e+01 rad/ps, delta = -0.0276, gamma = 0.3763, [0.56 0.44 0.12]
# i = 2690, q_irr = 416, band_irr = 6, weight = 48.0, w_ha = 5.7648 THz, 3.6221e+01 rad/ps, delta = 0.0310, gamma = 0.3793, [0.6  0.44 0.12]
# i = 2691, q_irr = 417, band_irr = 6, weight = 48.0, w_ha = 5.7245 THz, 3.5968e+01 rad/ps, delta = 0.0865, gamma = 0.4205, [0.64 0.44 0.12]
# i = 2692, q_irr = 418, band_irr = 6, weight = 24.0, w_ha = 5.6639 THz, 3.5588e+01 rad/ps, delta = 0.0738, gamma = 0.4338, [0.68 0.44 0.12]
# i = 2693, q_irr = 419, band_irr = 6, weight = 24.0, w_ha = 5.8234 THz, 3.6590e+01 rad/ps, delta = 0.0999, gamma = 0.3848, [0.6  0.48 0.12]
# i = 2694, q_irr = 420, band_irr = 6, weight = 24.0, w_ha = 5.7805 THz, 3.6320e+01 rad/ps, delta = 0.1273, gamma = 0.3958, [0.64 0.48 0.12]
# i = 2695, q_irr = 421, band_irr = 6, weight = 24.0, w_ha = 5.5604 THz, 3.4937e+01 rad/ps, delta = -0.1396, gamma = 0.1908, [0.48 0.32 0.16]
# i = 2696, q_irr = 422, band_irr = 6, weight = 48.0, w_ha = 5.6116 THz, 3.5259e+01 rad/ps, delta = -0.1278, gamma = 0.2254, [0.52 0.32 0.16]
# i = 2697, q_irr = 423, band_irr = 6, weight = 48.0, w_ha = 5.6865 THz, 3.5729e+01 rad/ps, delta = -0.0863, gamma = 0.2434, [0.56 0.32 0.16]
# i = 2698, q_irr = 424, band_irr = 6, weight = 48.0, w_ha = 5.7522 THz, 3.6142e+01 rad/ps, delta = -0.0782, gamma = 0.2571, [0.6  0.32 0.16]
# i = 2699, q_irr = 425, band_irr = 6, weight = 48.0, w_ha = 5.7895 THz, 3.6376e+01 rad/ps, delta = -0.0705, gamma = 0.2743, [0.64 0.32 0.16]
# i = 2700, q_irr = 426, band_irr = 6, weight = 24.0, w_ha = 5.6147 THz, 3.5278e+01 rad/ps, delta = -0.1588, gamma = 0.2402, [0.52 0.36 0.16]
# i = 2701, q_irr = 427, band_irr = 6, weight = 48.0, w_ha = 5.6436 THz, 3.5460e+01 rad/ps, delta = -0.1033, gamma = 0.2563, [0.56 0.36 0.16]
# i = 2702, q_irr = 428, band_irr = 6, weight = 48.0, w_ha = 5.6836 THz, 3.5711e+01 rad/ps, delta = -0.0735, gamma = 0.2837, [0.6  0.36 0.16]
# i = 2703, q_irr = 429, band_irr = 6, weight = 48.0, w_ha = 5.7103 THz, 3.5879e+01 rad/ps, delta = -0.0474, gamma = 0.3195, [0.64 0.36 0.16]
# i = 2704, q_irr = 430, band_irr = 6, weight = 48.0, w_ha = 5.7031 THz, 3.5833e+01 rad/ps, delta = -0.0341, gamma = 0.3047, [0.68 0.36 0.16]
# i = 2705, q_irr = 431, band_irr = 6, weight = 48.0, w_ha = 5.6660 THz, 3.5601e+01 rad/ps, delta = -0.0386, gamma = 0.3047, [0.72 0.36 0.16]
# i = 2706, q_irr = 432, band_irr = 6, weight = 48.0, w_ha = 5.6150 THz, 3.5280e+01 rad/ps, delta = -0.1008, gamma = 0.2515, [0.76 0.36 0.16]
# i = 2707, q_irr = 433, band_irr = 6, weight = 24.0, w_ha = 5.5909 THz, 3.5129e+01 rad/ps, delta = -0.1305, gamma = 0.2119, [0.8  0.36 0.16]
# i = 2708, q_irr = 434, band_irr = 6, weight = 24.0, w_ha = 5.6654 THz, 3.5597e+01 rad/ps, delta = -0.1060, gamma = 0.2844, [0.56 0.4  0.16]
# i = 2709, q_irr = 435, band_irr = 6, weight = 48.0, w_ha = 5.6659 THz, 3.5600e+01 rad/ps, delta = -0.0746, gamma = 0.3083, [0.6  0.4  0.16]
# i = 2710, q_irr = 436, band_irr = 6, weight = 48.0, w_ha = 5.6610 THz, 3.5569e+01 rad/ps, delta = -0.0100, gamma = 0.3497, [0.64 0.4  0.16]
# i = 2711, q_irr = 437, band_irr = 6, weight = 48.0, w_ha = 5.6346 THz, 3.5403e+01 rad/ps, delta = 0.0127, gamma = 0.3827, [0.68 0.4  0.16]
# i = 2712, q_irr = 438, band_irr = 6, weight = 48.0, w_ha = 5.5693 THz, 3.4993e+01 rad/ps, delta = -0.0315, gamma = 0.3607, [0.72 0.4  0.16]
# i = 2713, q_irr = 439, band_irr = 6, weight = 24.0, w_ha = 5.5521 THz, 3.4885e+01 rad/ps, delta = -0.1091, gamma = 0.2789, [0.76 0.4  0.16]
# i = 2714, q_irr = 440, band_irr = 6, weight = 24.0, w_ha = 5.7068 THz, 3.5857e+01 rad/ps, delta = -0.0366, gamma = 0.3748, [0.6  0.44 0.16]
# i = 2715, q_irr = 441, band_irr = 6, weight = 48.0, w_ha = 5.6780 THz, 3.5676e+01 rad/ps, delta = 0.0098, gamma = 0.3698, [0.64 0.44 0.16]
# i = 2716, q_irr = 442, band_irr = 6, weight = 48.0, w_ha = 5.6296 THz, 3.5372e+01 rad/ps, delta = 0.0465, gamma = 0.4035, [0.68 0.44 0.16]
# i = 2717, q_irr = 443, band_irr = 6, weight = 24.0, w_ha = 5.5446 THz, 3.4838e+01 rad/ps, delta = 0.0795, gamma = 0.4457, [0.72 0.44 0.16]
# i = 2718, q_irr = 444, band_irr = 6, weight = 24.0, w_ha = 5.7313 THz, 3.6011e+01 rad/ps, delta = 0.0912, gamma = 0.4030, [0.64 0.48 0.16]
# i = 2719, q_irr = 445, band_irr = 6, weight = 24.0, w_ha = 5.6821 THz, 3.5702e+01 rad/ps, delta = 0.1035, gamma = 0.4143, [0.68 0.48 0.16]
# i = 2720, q_irr = 446, band_irr = 6, weight = 24.0, w_ha = 5.6126 THz, 3.5265e+01 rad/ps, delta = -0.0941, gamma = 0.2721, [0.6 0.4 0.2]
# i = 2721, q_irr = 447, band_irr = 6, weight = 48.0, w_ha = 5.6077 THz, 3.5234e+01 rad/ps, delta = -0.0578, gamma = 0.3100, [0.64 0.4  0.2 ]
# i = 2722, q_irr = 448, band_irr = 6, weight = 48.0, w_ha = 5.6188 THz, 3.5304e+01 rad/ps, delta = -0.0054, gamma = 0.3538, [0.68 0.4  0.2 ]
# i = 2723, q_irr = 449, band_irr = 6, weight = 24.0, w_ha = 5.6252 THz, 3.5344e+01 rad/ps, delta = -0.0337, gamma = 0.3353, [0.64 0.44 0.2 ]
# i = 2724, q_irr = 450, band_irr = 6, weight = 48.0, w_ha = 5.5880 THz, 3.5110e+01 rad/ps, delta = 0.0203, gamma = 0.4063, [0.68 0.44 0.2 ]
# i = 2725, q_irr = 451, band_irr = 6, weight = 48.0, w_ha = 5.5402 THz, 3.4810e+01 rad/ps, delta = 0.0621, gamma = 0.4057, [0.72 0.44 0.2 ]
# i = 2726, q_irr = 452, band_irr = 6, weight = 24.0, w_ha = 5.5362 THz, 3.4785e+01 rad/ps, delta = -0.0552, gamma = 0.3467, [0.76 0.44 0.2 ]
# i = 2727, q_irr = 453, band_irr = 6, weight = 24.0, w_ha = 5.6308 THz, 3.5379e+01 rad/ps, delta = 0.0814, gamma = 0.4163, [0.68 0.48 0.2 ]
# i = 2728, q_irr = 454, band_irr = 6, weight = 24.0, w_ha = 5.5747 THz, 3.5027e+01 rad/ps, delta = 0.1095, gamma = 0.4526, [0.72 0.48 0.2 ]
# i = 2729, q_irr = 455, band_irr = 6, weight = 24.0, w_ha = 5.5216 THz, 3.4693e+01 rad/ps, delta = 0.0514, gamma = 0.4512, [0.72 0.48 0.24]

# %%
total_cv_weighted = 0.0
frequencies_qpa_d0 = []
cv_contributions_qpa_d0 = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
T = 150.0                # Temperature in Kelvin
integrated_modes_count = 0

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight
    integrated_modes_count += 1

    frequencies_qpa_d0.append(w_qs)
    cv_contributions_qpa_d0.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23
print(f"Modes used (integrated): {integrated_modes_count}")
print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Modes used (integrated): 2730
# Cv of unitcell(mol of unitcell): 43.7880 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Spectral Density at a specific Q-point ---
#target_q = np.array([0.2, 0, 0])

# Find the closest index in your q_coords
#q_diffs = np.linalg.norm(q_coords - target_q, axis=1)
#target_q_idx = np.argmin(q_diffs)

target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)  # the closest q-point index

print(f"Plotting for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: Band-major order means i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # Define a local frequency range around the peak for a smooth plot
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    #plt.plot(w_plot, b_w, label=f"Band {b+1} ($\omega_0$={w_qs:.2f})")
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_val:.2f})")
    
print(f"Plot width = {plot_width:.3f} THz for g_val = {g_val}")
plt.title(f"Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{{\\mathbf{{q}},s}}(\\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()


for b in range(num_bands):
    # Mapping: Band-major order
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]
    #d_val = d_interps[mode_idx](w_qs)
    d_val = 0
    g_val = abs(g_interps[mode_idx](w_qs))
    
    # We use the same w_plot logic from your plotting script
    plot_width = max(g_val * 5, 2.0) 
    w_plot = np.linspace(w_qs + d_val - plot_width, w_qs + d_val + plot_width, 1000)
    
    # Calculate Spectral Density b(w) using Eq (2)
    denom = (w_plot - w_qs - d_val)**2 + g_val**2
    b_w = (1/np.pi) * (g_val / denom)
    
    # Numerical Integration of the Lorentzian peak
    integral = np.trapz(b_w, w_plot)
    
    print(f"Band {b+1}: Integral = {integral:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting for Q-point: [0.2 0.  0. ] (Index: 5)
# Plot width = 2.000 THz for g_val = 0.25471281342462987
# Band 1: Integral = 0.9943 (Bare w0 = 0.94)
# Band 2: Integral = 0.9944 (Bare w0 = 0.94)
# Band 3: Integral = 0.9926 (Bare w0 = 1.93)
# Band 4: Integral = 0.9151 (Bare w0 = 3.41)
# Band 5: Integral = 0.9152 (Bare w0 = 3.41)
# Band 6: Integral = 0.9194 (Bare w0 = 5.63)

# %%
total_cv_weighted = 0.0
frequencies_qpa = []
cv_contributions_qpa = []

kB = 8.617333262e-5      # Boltzmann constant in eV/K
THz_to_eV = 0.004135667  # Conversion factor (h * 1e12)
T = 150.0                # Temperature in Kelvin

for i in range(num_total_modes):
    # Mapping the global index 'i' back to the irreducible q-point index
    # Since w_bare is (num_bands * Nq_irr), the q-index repeats every Nq_irr
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    #if w_qs < 1e-10: continue
    
    # 1. Get Delta and Gamma for this specific irreducible mode
    d_val = d_interps[i](w_qs)
    #d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Strict BQPA Lorentzian Integration
    g_floor = max(g_val, 1e-4) # prevent gamma=0
    dw = g_floor / 10.0 # mode-adative
    w_min = max(0.001, w_qs + d_val - 100 * g_floor)
    w_max = w_qs + d_val + 100 * g_floor
    local_grid = np.arange(w_min, w_max, dw)
    
    mode_integral = 0.0
    for w in local_grid:
        # Spectral Density b_qs(w)
        denom = (w - w_qs - d_val)**2 + g_val**2
        b_w = (1/np.pi) * (g_val / denom)
        
        # Heat Capacity Kernel
        x = (w * THz_to_eV) / (kB * T)
        if x < 50:
            cv_kernel = kB * (x**2) * np.exp(x) / (np.exp(x) - 1)**2
            mode_integral += b_w * cv_kernel * dw
    
    # Multiply the mode's contribution by its degeneracy weight
    total_cv_weighted += mode_integral * weight

    frequencies_qpa.append(w_qs)
    cv_contributions_qpa.append(mode_integral)
    
# --- 3. Final Normalization by total BZ points ---
cv_per_cell = total_cv_weighted / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Cv of unitcell(mol of unitcell): {cv_j_mol:.4f} J/K/mol")
# Out:
# Cv of unitcell(mol of unitcell): 44.0427 J/K/mol

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Extract Gamma values for all modes ---
gamma_values = []
frequencies_for_gamma = []

for i in range(num_total_modes):
    w_qs = w_bare[i]
    g_val = abs(g_interps[i](w_qs))
    
    gamma_values.append(g_val)
    frequencies_for_gamma.append(w_qs)

# --- 2. Plotting ---
plt.figure(figsize=(10, 6))
plt.scatter(frequencies_for_gamma, gamma_values, s=10, alpha=0.5, color='green', label='Mode Gamma ($\Gamma$)')

# Add a trend line (polynomial fit) to see the overall behavior
z = np.polyfit(frequencies_for_gamma, gamma_values, 2)
p = np.poly1d(z)
freq_range = np.linspace(min(frequencies_for_gamma), max(frequencies_for_gamma), 100)
#plt.plot(freq_range, p(freq_range), "r--", linewidth=2, label='Trend line ($\Gamma \propto \omega^n$)')

plt.title('Phonon Mode Gamma ($\Gamma$) vs. Frequency', fontsize=15)
plt.xlabel('Harmonic Frequency (THz)', fontsize=12)
plt.ylabel('Gamma (THz)', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()

print(f"Average Gamma: {np.mean(gamma_values):.4f} THz")
print(f"Max Gamma: {np.max(gamma_values):.4f} THz at {frequencies_for_gamma[np.argmax(gamma_values)]:.2f} THz")
# Out:
# Average Gamma: 0.1394 THz
# Max Gamma: 0.4650 THz at 4.51 THz

# %%
import matplotlib.pyplot as plt


cv_contributions_qpa_d0 = np.array(cv_contributions_qpa_d0)
cv_contributions_qpa = np.array(cv_contributions_qpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='blue', label='QPA, delta=0')

plt.scatter(frequencies_qpa, cv_contributions_qpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='green', label='QPA')

# Constant
#const1_conv = 45.1754 / 6
#const2_conv = 45.2270 / 6

#plt.axhline(const1_conv, color='blue', linestyle='--', linewidth=2, label='Cv/mode of qpa(delta=0)')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode of qpa')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'QPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
plt.ylim(4, 8.5)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87462/1487154117.py:28: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Reshape harmonic frequencies ---
# w_harmonic shape: (Nq_irr, num_bands)
w_harmonic = w_bare.reshape(num_bands, Nq_irr).T 

# --- 2. DOS Calculation Function ---
def calculate_harmonic_dos(frequencies, weights, energy_grid, sigma=0.05):
    """
    frequencies: (Nq_irr, num_bands)
    weights: (Nq_irr,) - Multiplicity of each q-point
    energy_grid: Frequency axis for the DOS plot
    sigma: Gaussian broadening width (THz)
    """
    dos = np.zeros_like(energy_grid)
    for i in range(len(weights)):
        for j in range(frequencies.shape[1]):
            # Add Gaussian contribution for each mode: weight * G(omega - w_ij)
            diff = energy_grid - frequencies[i, j]
            dos += weights[i] * np.exp(-0.5 * (diff / sigma)**2) / (sigma * np.sqrt(2 * np.pi))
    
    # Normalize by total number of q-points in full BZ
    return dos / np.sum(weights)

# --- 3. Setup Grid and Compute ---
# Create a frequency axis from 0 to slightly above max frequency
w_max = np.max(w_harmonic) * 1.05
energy_axis = np.linspace(0, w_max, 1000)

# Calculate DOS (You can adjust sigma for smoothness)
dos_harmonic = calculate_harmonic_dos(w_harmonic, degeneracies, energy_axis, sigma=0.04)

# --- 4. Plotting ---
plt.figure(figsize=(9, 6))
plt.plot(energy_axis, dos_harmonic, color='blue', linewidth=2, label='Harmonic DOS')
plt.fill_between(energy_axis, 0, dos_harmonic, color='blue', alpha=0.2)

plt.title('Harmonic Phonon Density of States (DOS)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States (States/THz)', fontsize=12)
plt.xlim(0, w_max)
plt.ylim(0, np.max(dos_harmonic) * 1.1)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print(f"Harmonic DOS plot complete.")
print(f"Frequency range: 0.0 to {np.max(w_harmonic):.3f} THz")
# Out:
# Harmonic DOS plot complete.
# Frequency range: 0.0 to 6.019 THz

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    d_val = d_interps[i](w_qs)
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Prepare DOS Grid ---
energy_axis = np.linspace(0, np.max(w_harmonic) * 1.1, 1000)
dos_qpa_varied = np.zeros_like(energy_axis)

print("Calculating QPA DOS using mode-specific Self-Energy...")

# --- 2. Accumulate Lorentzians with mode-specific parameters ---
for i in range(num_total_modes):
    # Mapping back to the irreducible weight
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    
    w_qs = w_bare[i]
    
    # 1. Get Delta and Gamma at the harmonic frequency (As per your Cv code)
    #d_val = d_interps[i](w_qs)
    d_val = 0
    g_val = abs(g_interps[i](w_qs))
    
    # 2. Define the Lorentzian for this specific mode
    # Peak is at (w_qs + d_val), width is g_val
    denom = (energy_axis - (w_qs + d_val))**2 + g_val**2
    # Prevent division by zero if g_val is 0
    if g_val > 1e-6:
        b_w = (1.0 / np.pi) * (g_val / denom)
    else:
        # Fallback to a very narrow peak if Gamma is near zero
        b_w = np.exp(-0.5 * ((energy_axis - (w_qs + d_val)) / 0.01)**2) / (0.01 * np.sqrt(2 * np.pi))
        
    # 3. Add to total DOS with degeneracy weight
    dos_qpa_varied += weight * b_w

# --- 3. Final Normalization ---
dos_qpa_varied /= Nq_total

# --- 4. Plotting Comparison ---
plt.figure(figsize=(10, 6))

# Harmonic for reference
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.4)

# QPA with varied parameters
plt.plot(energy_axis, dos_qpa_varied, color='green', linewidth=2, label='QPA DOS (Mode-specific $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_qpa_varied, color='green', alpha=0.15)

plt.title('Phonon DOS: Harmonic vs. QPA (Mode-specific)', fontsize=15)
plt.xlabel('Frequency (THz)', fontsize=12)
plt.ylabel('Density of States', fontsize=12)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()

print("QPA (Mode-specific) DOS plotting complete.")
# Out:
# Calculating QPA DOS using mode-specific Self-Energy...
# QPA (Mode-specific) DOS plotting complete.

# %%
import numpy as np

total_cv_full = 0.0
frequencies_bqpa = []
cv_contributions_bqpa = []

# Define global frequency bounds from the loaded spectrum file
global_w_min = spec_data[:, 0].min()
global_w_max = spec_data[:, 0].max()

print(f"Starting Full Frequency-Dependent BQPA integration...")

for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    if w_qs < 1e-10: continue

    # Local step size based on broadening at resonance
    g_ref = abs(g_interps[i](w_qs))
    dw = max(g_ref, 1e-4) / 10.0
    
    # Integration grid for this mode
    w_grid = np.arange(global_w_min, global_w_max, dw)
    
    # Evaluate frequency-dependent Delta and Gamma
    d_ws = d_interps[i](w_grid)
    g_ws = np.abs(g_interps[i](w_grid))
    
    # Spectral Density b_qs(w)
    denoms = (w_grid - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denoms)
    
    # Heat Capacity Kernel with Singularity Fix
    x = (w_grid * THz_to_eV) / (kB * T)
    cv_kernels = np.zeros_like(x)
    
    # Handle x=0 limit (kB) and general case
    m_zero = (x < 1e-7)
    m_finite = (x >= 1e-7) & (x < 50)
    
    cv_kernels[m_zero] = kB
    cv_kernels[m_finite] = kB * (x[m_finite]**2 * np.exp(x[m_finite])) / (np.exp(x[m_finite]) - 1)**2
    
    # Mode contribution (Area under b_w * Cv_kernel)
    mode_integral = np.sum(b_ws * cv_kernels) * dw
    total_cv_weighted = mode_integral * weight
    
    total_cv_full += total_cv_weighted
    frequencies_bqpa.append(w_qs)
    cv_contributions_bqpa.append(mode_integral)

# Final Normalization
cv_per_cell = total_cv_full / Nq_total
cv_j_mol = cv_per_cell * 1.60218e-19 * 6.02214e23

print(f"Full Frequency-Dependent Cv: {cv_j_mol:.4f} J/K/mol")
# Out:
# Starting Full Frequency-Dependent BQPA integration...
# Full Frequency-Dependent Cv: 40.9598 J/K/mol

# %%
import matplotlib.pyplot as plt

cv_contributions_bqpa = np.array(cv_contributions_bqpa)
plt.figure(figsize=(10, 6))

# 1. Scatter plot
#plt.scatter(frequencies_qpa_d0, cv_contributions_qpa_d0 * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
 #           color='blue', label='QPA, delta=0')

plt.scatter(frequencies_bqpa, cv_contributions_bqpa * 1.60218e-19 * 6.02214e23, alpha=0.4, s=10, 
            color='purple', label='BQPA')

# Constant
#const1_conv = 49.2084 / 6
#const2_conv = 48.761459 / 6

#plt.axhline(const1_conv, color='purple', linestyle='--', linewidth=2, label='Cv/mode of BQPA')
#plt.axhline(const2_conv, color='green', linestyle='--', linewidth=2, label='Cv/mode at gamma=1.0')

# 2. Harmonic Reference Curve
# We use frequencies to define the range
if len(frequencies_qpa_d0) > 0:
    w_ref = np.linspace(min(frequencies_qpa_d0), max(frequencies_qpa_d0), 500)
    x_ref = (w_ref * THz_to_eV) / (kB * T)
    # C_v kernel calculation
    cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

    #cv_harmonic = np.zeros_like(x_ref)
    #small_x = x_ref < 1e-3
    #large_x = ~small_x
    #cv_harmonic[small_x] = kB
    #cv_harmonic[large_x] = kB * (x_ref[large_x]**2) * np.exp(x_ref[large_x]) / (np.exp(x_ref[large_x]) - 1)**2

    
    plt.plot(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', linestyle='--', label='Harmonic Heat Capacity Kernel', linewidth=2)
    #plt.scatter(w_ref, cv_harmonic * 1.60218e-19 * 6.02214e23, color='red', label='Harmonic Heat Capacity Kernel', alpha=0.4, s=10)

plt.title(f'BQPA Heat Capacity Contribution vs. Frequency (T = {T} K)')
plt.xlabel('Phonon Frequency (THz)')
plt.ylabel('Mode Heat Capacity $C_{v,qs}$ (J/K/mol)')
#plt.ylim(7.5, 10)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()
plt.show()
# Out:
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87462/703786594.py:26: RuntimeWarning: invalid value encountered in divide
#   cv_harmonic = kB * (x_ref**2) * np.exp(x_ref) / (np.exp(x_ref) - 1)**2

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 4. Plot Full Spectral Density at a specific Q-point ---
target_q = np.array([0.2, 0, 0])  # target q-point
distances = np.linalg.norm(q_coords - target_q, axis=1)
target_q_idx = np.argmin(distances)

print(f"Plotting Full Spectral Density for Q-point: {q_coords[target_q_idx]} (Index: {target_q_idx})")

plt.figure(figsize=(9, 5))

# Loop through all 6 bands for this specific irreducible q-point
for b in range(num_bands):
    # Mapping: i = b * Nq_irr + target_q_idx
    mode_idx = b * Nq_irr + target_q_idx
    
    w_qs = w_bare[mode_idx]

    g_ref = abs(g_interps[mode_idx](w_qs))
    d_ref = d_interps[mode_idx](w_qs)
    
    # Define a local frequency range around the renormalized peak
    plot_width = max(g_ref * 5, 20.0) 
    w_plot = np.linspace(w_qs + d_ref - plot_width, w_qs + d_ref + plot_width, 1000)
    
    # Clip to ensure we stay within the BTE spectrum file bounds
    w_plot = np.clip(w_plot, global_w_min, global_w_max)
    
    # --- Full Frequency-Dependent Calculation ---
    # Evaluate d(w) and g(w) at every point in the plot range
    d_ws = d_interps[mode_idx](w_plot)
    g_ws = np.abs(g_interps[mode_idx](w_plot))
    
    # Spectral Density b(w) = (1/pi) * [ g(w) / ( (w - w_qs - d(w))^2 + g(w)^2 ) ]
    denom = (w_plot - w_qs - d_ws)**2 + g_ws**2
    b_w = (1/np.pi) * (g_ws / denom)
    
    # Plotting the result for the band
    plt.plot(w_plot, b_w/ (2 * np.pi), label=f"Band {b+1} ($\omega_0$={w_qs:.2f}, $\omega_{{re}}$={w_qs+d_ref:.2f})")

plt.title(f"Full Phonon Spectral Densities $b(\\omega)$ at q={q_coords[target_q_idx]}")
plt.xlabel("Frequency (THz)")
plt.ylabel("Spectral Density $b_{\mathbf{q},s}(\omega)$")
plt.legend(fontsize='x-small', ncol=2)
plt.grid(alpha=0.3)
plt.show()

for b in range(num_bands):
    mode_idx = b * Nq_irr + target_q_idx
    w_qs = w_bare[mode_idx]
    
    # We must integrate over the FULL range of your data to capture 
    # the weight of broad/flat modes.
    w_val = np.arange(global_w_min, global_w_max, 0.01) # Use a fine constant grid
    
    # Evaluate full frequency-dependent d and g
    d_ws = d_interps[mode_idx](w_val)
    g_ws = np.abs(g_interps[mode_idx](w_val))
    
    # Calculate b(w)
    denom = (w_val - w_qs - d_ws)**2 + g_ws**2
    b_ws = (1/np.pi) * (g_ws / denom)
    
    # Numerical integration (Area)
    area = np.trapz(b_ws, w_val)
    
    print(f"Band {b+1}: Integral = {area:.4f} (Bare w0 = {w_qs:.2f})")
# Out:
# Plotting Full Spectral Density for Q-point: [0.2 0.  0. ] (Index: 5)
# Band 1: Integral = 1.0055 (Bare w0 = 0.94)
# Band 2: Integral = 1.0049 (Bare w0 = 0.94)
# Band 3: Integral = 1.0032 (Bare w0 = 1.93)
# Band 4: Integral = 1.0096 (Bare w0 = 3.41)
# Band 5: Integral = 1.0096 (Bare w0 = 3.41)
# Band 6: Integral = 1.0033 (Bare w0 = 5.63)

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_normalized_modes_simple(file_path):
    with open(file_path, 'r') as f:
        content = f.read().strip().split('\n')
    
    modes_list = []
    current_mode = {}
    temp_grid_density = []

    for line in content:
        parts = line.split()
        if len(parts) == 1:
            if current_mode:
                half = len(temp_grid_density) // 2
                current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
                current_mode['y'] = np.array(temp_grid_density[half:])
                modes_list.append(current_mode)
            current_mode = {'center': float(parts[0]) / (2 * np.pi)}
            temp_grid_density = []
        else:
            temp_grid_density.extend([float(p) for p in parts])

    if current_mode:
        half = len(temp_grid_density) // 2
        current_mode['x'] = np.array(temp_grid_density[:half]) / (2 * np.pi)
        current_mode['y'] = np.array(temp_grid_density[half:])
        modes_list.append(current_mode)

    plt.figure(figsize=(10, 6))

    for idx, m in enumerate(modes_list):
        norm_factor = np.trapz(m['y'], m['x'])
        y_norm = m['y'] / norm_factor
        plt.plot(m['x'], y_norm/ (2 * np.pi), label=f'Mode {idx+1}')

    plt.xlabel('Frequency (THz)')
    plt.ylabel('Normalized Spectral Density')
    plt.title('Normalized Vibrational Modes')
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()


plot_normalized_modes_simple('bspec_omega_5.dat')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 46
#      42     plt.legend()
#      43     plt.show()
# ---> 46 plot_normalized_modes_simple('bspec_omega_5.dat')
#
# Cell In[34], line 5, in plot_normalized_modes_simple(file_path)
#       4 def plot_normalized_modes_simple(file_path):
# ----> 5     with open(file_path, 'r') as f:
#       6         content = f.read().strip().split('\n')
#       8     modes_list = []
#
# File /opt/anaconda3/envs/phonopy/lib/python3.8/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bspec_omega_5.dat'

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. Setup Energy Grid ---
# Use the global bounds from your spectrum data
energy_axis = np.linspace(global_w_min, global_w_max, 1000)
dos_bqpa_full = np.zeros_like(energy_axis)

print("Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...")

# --- 2. Accumulate Full Spectral Density for each mode ---
for i in range(num_total_modes):
    q_irr_idx = i % Nq_irr
    weight = degeneracies[q_irr_idx]
    w_qs = w_bare[i]
    
    # 1. Evaluate Delta(w) and Gamma(w) on the entire energy axis
    d_ws = d_interps[i](energy_axis)
    g_ws = np.abs(g_interps[i](energy_axis))
    
    # 2. Calculate the Full Spectral Density b_qs(w)
    # This reflects the true shape of the phonon state in an anharmonic potential
    denoms = (energy_axis - w_qs - d_ws)**2 + g_ws**2
    
    # Avoid division by zero for very stable modes
    g_ws_safe = np.where(g_ws < 1e-6, 1e-6, g_ws)
    b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
    
    # 3. Add to total DOS with degeneracy weight
    dos_bqpa_full += weight * b_ws

# --- 3. Final Normalization ---
dos_bqpa_full /= Nq_total

# --- 4. Plotting Comparison: Harmonic vs QPA vs BQPA ---
plt.figure(figsize=(12, 7))

# 1. Harmonic DOS (Reference)
plt.plot(energy_axis, dos_harmonic, 'k--', label='Harmonic DOS', alpha=0.3)

# 2. QPA DOS (From previous step - if you have the variable)
#if 'dos_qpa_varied' in locals():
#    plt.plot(energy_axis, dos_qpa_varied, color='green', label='QPA DOS (Single-point $\Sigma$)', alpha=0.5)

# 3. Full BQPA DOS
plt.plot(energy_axis, dos_bqpa_full, color='purple', linewidth=2.5, label='Full BQPA DOS (Freq-dependent $\Sigma$)')
plt.fill_between(energy_axis, 0, dos_bqpa_full, color='purple', alpha=0.15)

plt.title('Phonon DOS: Full BQPA Comparison', fontsize=16)
plt.xlabel('Frequency (THz)', fontsize=13)
plt.ylabel('Density of States', fontsize=13)
plt.xlim(0, global_w_max)
plt.grid(True, linestyle=':', alpha=0.6)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Calculating Full BQPA DOS (Frequency-dependent Spectral Density)...
# /var/folders/8s/1wbk7ft168n0hgr946kyvykr0000gn/T/ipykernel_87462/737035693.py:27: RuntimeWarning: divide by zero encountered in divide
#   b_ws = (1.0 / np.pi) * (g_ws_safe / denoms)
